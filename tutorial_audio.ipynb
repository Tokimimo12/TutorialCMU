# %%
from constants import SDK_PATH, DATA_PATH, WORD_EMB_PATH, CACHE_PATH
import sys
import pandas as pd
# Out:
# SDK_PATH: C:\Users\Viki\Documents\Thesis\CMU-MultimodalSDK

# %%
if SDK_PATH is None:
    print("SDK path is not specified! Please specify first in constants/paths.py")
    exit(0)
else:
    sys.path.append(SDK_PATH)
    print(f"SDK path is set to {SDK_PATH}")
# Out:
# SDK path is set to C:\Users\Viki\Documents\Thesis\CMU-MultimodalSDK

# %%
import sys
for path in sys.path:
    print(path)
# Out:
# C:\Users\Viki\Documents\Thesis\tryout3
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\python310.zip
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\DLLs
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib
# C:\Users\Viki\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0
# C:\Users\Viki\Documents\Thesis\tryout3\.venv
#
# C:\Users\Viki\Documents\Thesis\tryout3\.venv\lib\site-packages
# C:\Users\Viki\Documents\Thesis\tryout3\.venv\lib\site-packages\win32
# C:\Users\Viki\Documents\Thesis\tryout3\.venv\lib\site-packages\win32\lib
# C:\Users\Viki\Documents\Thesis\tryout3\.venv\lib\site-packages\Pythonwin
# C:\Users\Viki\Documents\Thesis\CMU-MultimodalSDK

# %%
import mmsdk
import os
import re
import numpy as np
from mmsdk import mmdatasdk as md
from subprocess import check_call, CalledProcessError



import pandas as pd
import csv


# we can see they are in the format of 'video_id[segment_no]', but the splits was specified with video_id only
# we need to use regex or something to match the video IDs...
import torch
import torch.nn as nn

from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm_notebook
from collections import defaultdict
import random

from torch.optim import Adam, SGD
from sklearn.metrics import accuracy_score
import tqdm
from tqdm import tqdm_notebook
import random
import numpy as np


from torch import optim
from torch.utils.tensorboard import SummaryWriter

# %%
if not os.path.exists(DATA_PATH):
    check_call(' '.join(['mkdir', '-p', DATA_PATH]), shell=True)

DATASET = md.cmu_mosi

try:
    md.mmdataset(DATASET.highlevel, DATA_PATH)
except RuntimeError:
    print("High-level features have been downloaded previously.")

try:
    md.mmdataset(DATASET.raw, DATA_PATH)
except RuntimeError:
    print("Raw data have been downloaded previously.")
    
try:
    md.mmdataset(DATASET.labels, DATA_PATH)
except RuntimeError:
    print("Labels have been downloaded previously.")
# Out:
# Normalized destination path: C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu/CMU-MOSI/language/CMU_MOSI_TimestampedWordVectors.csd
# [2024-12-04 11:08:11.240] | Error   | C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu/CMU-MOSI/language/CMU_MOSI_TimestampedWordVectors.csd file already exists ...
# High-level features have been downloaded previously.
# Normalized destination path: C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu/CMU-MOSI/language/CMU_MOSI_TimestampedWords.csd
# [2024-12-04 11:08:11.242] | Error   | C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu/CMU-MOSI/language/CMU_MOSI_TimestampedWords.csd file already exists ...
# Raw data have been downloaded previously.
# Normalized destination path: C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu/CMU-MOSI/labels/CMU_MOSI_Opinion_Labels.csd
# [2024-12-04 11:08:11.242] | Error   | C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu/CMU-MOSI/labels/CMU_MOSI_Opinion_Labels.csd file already exists ...
# Labels have been downloaded previously.

# %%
# list the directory contents... let's see what features there are
data_files = os.listdir(DATA_PATH)
print('\n'.join(data_files))
# Out:
# embedding_and_mapping.pt
# http__immortal.multicomp.cs.cmu.edu

# %%
import os

folder_path = "C:\\Users\\Viki\\Documents\\Thesis\\tryout3\\data"
for root, dirs, files in os.walk(folder_path):
    print(f"Directory: {root}")
    for file in files:
        print(f"  {file}")
# Out:
# Directory: C:\Users\Viki\Documents\Thesis\tryout3\data
#   embedding_and_mapping.pt
# Directory: C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu
# Directory: C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu\CMU-MOSI
# Directory: C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu\CMU-MOSI\acoustic
#   CMU_MOSI_COVAREP.csd
#   CMU_MOSI_OpenSmile_EB10.csd
#   CMU_MOSI_openSMILE_IS09.csd
# Directory: C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu\CMU-MOSI\labels
#   CMU_MOSI_Opinion_Labels.csd
# Directory: C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu\CMU-MOSI\language
#   CMU_MOSI_TimestampedPhones.csd
#   CMU_MOSI_TimestampedWords.csd
#   CMU_MOSI_TimestampedWordVectors.csd
# Directory: C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu\CMU-MOSI\visual
#   CMU_MOSI_Visual_Facet_41.csd
#   CMU_MOSI_Visual_Facet_42.csd
#   CMU_MOSI_Visual_OpenFace_1.csd
#   CMU_MOSI_Visual_OpenFace_2.csd

# %%
# Define your different modalities - refer to the filenames of the CSD files
visual_field_Facet41 = 'CMU_MOSI_Visual_Facet_41'
visual_field_Facet42 = 'CMU_MOSI_Visual_Facet_42'
visual_field_OpenFace1 = 'CMU_MOSI_Visual_OpenFace_1'


# visual_field_OpenFace2 = 'CMU_MOSI_Visual_OpenFace_2'
# [2024-11-24 21:59:03.886] | Error   | C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu\http__immortal.multicomp.cs.cmu.edu\CMU-MOSI\visual\CMU_MOSI_Visual_OpenFace_2.csd resource is not a valid hdf5 computational sequence format ...


acoustic_field_COVAREP = 'CMU_MOSI_COVAREP'
acoustic_field_OpenSmile_EB10 = 'CMU_MOSI_OpenSmile_EB10'
acoustic_field_OpenSmile_IS09 = 'CMU_MOSI_openSMILE_IS09'



text_field_Words = 'CMU_MOSI_TimestampedWords'
text_field_Phones = 'CMU_MOSI_TimestampedPhones'
text_field_WordVectors = 'CMU_MOSI_TimestampedWordVectors'

# %%
# text_field = 'CMU_MOSI_ModifiedTimestampedWords'


# List of features
features = [
    text_field_Words,
    # text_field_Phones,
    text_field_WordVectors,
    visual_field_Facet41, 
    # visual_field_Facet42,
    # visual_field_OpenFace1,
    # visual_field_OpenFace2,
    acoustic_field_COVAREP,
    # acoustic_field_OpenSmile_IS09,
    # acoustic_field_OpenSmile_EB10
]


# Recipe with correct subdirectory paths for each modality
recipe = {
    text_field_Words: os.path.join(DATA_PATH, "http__immortal.multicomp.cs.cmu.edu", "CMU-MOSI", "language", text_field_Words) + '.csd',
    
    # not helpful
    # text_field_Phones: os.path.join(DATA_PATH, "http__immortal.multicomp.cs.cmu.edu","CMU-MOSI", "language", text_field_Phones) + '.csd',

    text_field_WordVectors: os.path.join(DATA_PATH, "http__immortal.multicomp.cs.cmu.edu", "CMU-MOSI", "language", text_field_WordVectors) + '.csd',
    
    visual_field_Facet41: os.path.join(DATA_PATH, "http__immortal.multicomp.cs.cmu.edu", "CMU-MOSI", "visual", visual_field_Facet41) + '.csd',
    
    # visual_field_Facet42: os.path.join(DATA_PATH, "http__immortal.multicomp.cs.cmu.edu", "CMU-MOSI", "visual", visual_field_Facet42) + '.csd',
    
    # visual_field_OpenFace1: os.path.join(DATA_PATH, "http__immortal.multicomp.cs.cmu.edu", "CMU-MOSI", "visual", visual_field_OpenFace1) + '.csd',
    
    
    #not taken into account cause not runnable - 
    # visual_field_OpenFace2: os.path.join(DATA_PATH, "http__immortal.multicomp.cs.cmu.edu", "CMU-MOSI", "visual", visual_field_OpenFace2) + '.csd',
    
    acoustic_field_COVAREP: os.path.join(DATA_PATH, "http__immortal.multicomp.cs.cmu.edu", "CMU-MOSI", "acoustic", acoustic_field_COVAREP) + '.csd',
    
    # acoustic_field_OpenSmile_EB10: os.path.join(DATA_PATH, "http__immortal.multicomp.cs.cmu.edu", "CMU-MOSI", "acoustic", acoustic_field_OpenSmile_EB10) + '.csd',
    
    # has same and less features as EB10
    # acoustic_field_OpenSmile_IS09: os.path.join(DATA_PATH, "http__immortal.multicomp.cs.cmu.edu", "CMU-MOSI", "acoustic", acoustic_field_OpenSmile_IS09) + '.csd'
}



print (recipe)
dataset = md.mmdataset(recipe)
# Out:
# {'CMU_MOSI_TimestampedWords': 'C:\\Users\\Viki\\Documents\\Thesis\\tryout3\\data\\http__immortal.multicomp.cs.cmu.edu\\CMU-MOSI\\language\\CMU_MOSI_TimestampedWords.csd', 'CMU_MOSI_TimestampedWordVectors': 'C:\\Users\\Viki\\Documents\\Thesis\\tryout3\\data\\http__immortal.multicomp.cs.cmu.edu\\CMU-MOSI\\language\\CMU_MOSI_TimestampedWordVectors.csd', 'CMU_MOSI_Visual_Facet_41': 'C:\\Users\\Viki\\Documents\\Thesis\\tryout3\\data\\http__immortal.multicomp.cs.cmu.edu\\CMU-MOSI\\visual\\CMU_MOSI_Visual_Facet_41.csd', 'CMU_MOSI_COVAREP': 'C:\\Users\\Viki\\Documents\\Thesis\\tryout3\\data\\http__immortal.multicomp.cs.cmu.edu\\CMU-MOSI\\acoustic\\CMU_MOSI_COVAREP.csd'}
# [2024-12-04 11:08:11.312] | Success | Computational sequence read from file C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu\CMU-MOSI\language\CMU_MOSI_TimestampedWords.csd ...
# [2024-12-04 11:08:11.320] | Status  | Checking the integrity of the <words> computational sequence ...
# [2024-12-04 11:08:11.320] | Status  | Checking the format of the data in <words> computational sequence ...
# [2024-12-04 11:08:11.367] | Success | <words> computational sequence data in correct format.
# [2024-12-04 11:08:11.367] | Status  | Checking the format of the metadata in <words> computational sequence ...
# [2024-12-04 11:08:11.367] | Warning | <words> computational sequence does not have all the required metadata ... continuing
# [2024-12-04 11:08:11.368] | Success | Computational sequence read from file C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu\CMU-MOSI\language\CMU_MOSI_TimestampedWordVectors.csd ...
# [2024-12-04 11:08:11.389] | Status  | Checking the integrity of the <glove_vectors> computational sequence ...
# [2024-12-04 11:08:11.389] | Status  | Checking the format of the data in <glove_vectors> computational sequence ...
# [2024-12-04 11:08:11.467] | Success | <glove_vectors> computational sequence data in correct format.
# [2024-12-04 11:08:11.467] | Status  | Checking the format of the metadata in <glove_vectors> computational sequence ...
# [2024-12-04 11:08:11.467] | Warning | <glove_vectors> computational sequence does not have all the required metadata ... continuing
# [2024-12-04 11:08:11.468] | Success | Computational sequence read from file C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu\CMU-MOSI\visual\CMU_MOSI_Visual_Facet_41.csd ...
# [2024-12-04 11:08:11.486] | Status  | Checking the integrity of the <FACET_4.1> computational sequence ...
# [2024-12-04 11:08:11.486] | Status  | Checking the format of the data in <FACET_4.1> computational sequence ...
# [2024-12-04 11:08:11.555] | Success | <FACET_4.1> computational sequence data in correct format.
# [2024-12-04 11:08:11.555] | Status  | Checking the format of the metadata in <FACET_4.1> computational sequence ...
# [2024-12-04 11:08:11.555] | Warning | <FACET_4.1> computational sequence does not have all the required metadata ... continuing
# [2024-12-04 11:08:11.558] | Success | Computational sequence read from file C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu\CMU-MOSI\acoustic\CMU_MOSI_COVAREP.csd ...
# [2024-12-04 11:08:11.568] | Status  | Checking the integrity of the <COVAREP> computational sequence ...
# [2024-12-04 11:08:11.568] | Status  | Checking the format of the data in <COVAREP> computational sequence ...
# [2024-12-04 11:08:11.634] | Success | <COVAREP> computational sequence data in correct format.
# [2024-12-04 11:08:11.634] | Status  | Checking the format of the metadata in <COVAREP> computational sequence ...
# [2024-12-04 11:08:11.634] | Warning | <COVAREP> computational sequence does not have all the required metadata ... continuing
# [2024-12-04 11:08:11.634] | Success | Dataset initialized successfully ...

# %%
print("=== Metadata FACE 41 Visual===\n")
print("Visual FACE 41 Metadata:", dataset[visual_field_Facet41].metadata)
print("\n")

print("=== Metadata COVAREP Acoustic===\n")
print("Acoustic COVAREP Metadata:", dataset[acoustic_field_COVAREP].metadata)
print("\n")

print("=== Metadata Words===\n")
print("Words Metadata:", dataset[text_field_Words].metadata)
print("\n")

print("=== Metadata WordVectors===\n")
print("WordVectors Metadata:", dataset[text_field_WordVectors].metadata)
print("\n")
# Out:
# === Metadata FACE 41 Visual===
#
# Visual FACE 41 Metadata: {'alignment compatible': True, 'computational sequence description': 'FACET 4.1 Visual Features for CMU-MOSI Dataset', 'computational sequence version': 1.0, 'contact': 'abagherz@andrew.cmu.edu', 'creator': 'Amir Zadeh', 'dataset bib citation': '@article{zadeh2016multimodal,title={Multimodal sentiment intensity analysis in videos: Facial gestures and verbal messages},author={Zadeh, Amir and Zellers, Rowan and Pincus, Eli and Morency, Louis-Philippe},journal={IEEE Intelligent Systems},volume={31},number={6},pages={82--88},year={2016},publisher={IEEE}}', 'dataset name': 'CMU-MOSI', 'dataset version': 1.0, 'dimension names': ['Face X', 'Face Y', 'Face Width', 'Face Height', 'angerEvidence', 'contemptEvidence', 'disgustEvidence', 'joyEvidence', 'fearEvidence', 'negativeEvidence', 'neutralEvidence', 'positiveEvidence', 'sadnessEvidence', 'surpriseEvidence', 'confusionEvidence', 'frustrationEvidence', 'angerIntensity', 'contemptIntensity', 'disgustIntensity', 'joyIntensity', 'fearIntensity', 'negativeIntensity', 'neutralIntensity', 'positiveIntensity', 'sadnessIntensity', 'surpriseIntensity', 'confusionIntensity', 'frustrationIntensity', 'AU1Evidence', 'AU2Evidence', 'AU4Evidence', 'AU5Evidence', 'AU6Evidence', 'AU7Evidence', 'AU9Evidence', 'AU10Evidence', 'AU12Evidence', 'AU14Evidence', 'AU15Evidence', 'AU17Evidence', 'AU18Evidence', 'AU20Evidence', 'AU23Evidence', 'AU24Evidence', 'AU25Evidence', 'AU26Evidence', 'AU28Evidence'], 'featureset bib citation': '@online{emotient,author = {iMotions},title = {Facial Expression Analysis},year = {2017},url = {goo.gl/1rh1JN}}', 'md5': None, 'root name': 'FACET_4.1', 'uuid': '75b82d70-387f-4c1a-935e-99462b7e4388'}
#
#
# === Metadata COVAREP Acoustic===
#
# Acoustic COVAREP Metadata: {'alignment compatible': True, 'computational sequence description': 'COVAREP Acoustic Features for CMU-MOSI Dataset', 'computational sequence version': 1.0, 'contact': 'abagherz@andrew.cmu.edu', 'creator': 'Amir Zadeh', 'dataset bib citation': '@article{zadeh2016multimodal,title={Multimodal sentiment intensity analysis in videos: Facial gestures and verbal messages},author={Zadeh, Amir and Zellers, Rowan and Pincus, Eli and Morency, Louis-Philippe},journal={IEEE Intelligent Systems},volume={31},number={6},pages={82--88},year={2016},publisher={IEEE}}', 'dataset name': 'CMU-MOSI', 'dataset version': 1.0, 'dimension names': ['F0', 'VUV', 'NAQ', 'QOQ', 'H1H2', 'PSP', 'MDQ', 'peakSlope', 'Rd', 'Rd_conf', 'creak', 'MCEP_0', 'MCEP_1', 'MCEP_2', 'MCEP_3', 'MCEP_4', 'MCEP_5', 'MCEP_6', 'MCEP_7', 'MCEP_8', 'MCEP_9', 'MCEP_10', 'MCEP_11', 'MCEP_12', 'MCEP_13', 'MCEP_14', 'MCEP_15', 'MCEP_16', 'MCEP_17', 'MCEP_18', 'MCEP_19', 'MCEP_20', 'MCEP_21', 'MCEP_22', 'MCEP_23', 'MCEP_24', 'HMPDM_0', 'HMPDM_1', 'HMPDM_2', 'HMPDM_3', 'HMPDM_4', 'HMPDM_5', 'HMPDM_6', 'HMPDM_7', 'HMPDM_8', 'HMPDM_9', 'HMPDM_10', 'HMPDM_11', 'HMPDM_12', 'HMPDM_13', 'HMPDM_14', 'HMPDM_15', 'HMPDM_16', 'HMPDM_17', 'HMPDM_18', 'HMPDM_19', 'HMPDM_20', 'HMPDM_21', 'HMPDM_22', 'HMPDM_23', 'HMPDM_24', 'HMPDD_0', 'HMPDD_1', 'HMPDD_2', 'HMPDD_3', 'HMPDD_4', 'HMPDD_5', 'HMPDD_6', 'HMPDD_7', 'HMPDD_8', 'HMPDD_9', 'HMPDD_10', 'HMPDD_11', 'HMPDD_12'], 'featureset bib citation': '@inproceedings{degottex2014covarep,title={COVAREP-A collaborative voice analysis repository for speech technologies},author={Degottex, Gilles and Kane, John and Drugman, Thomas and Raitio, Tuomo and Scherer, Stefan},booktitle={Acoustics, Speech and Signal Processing (ICASSP), 2014 IEEE International Conference on},pages={960--964},year={2014},organization={IEEE}}', 'md5': None, 'root name': 'COVAREP', 'uuid': 'b3040d49-2a1b-45f8-b991-16fb1acc75c5'}
#
#
# === Metadata Words===
#
# Words Metadata: {'alignment compatible': False, 'computational sequence description': 'Word sequences for CMU-MOSI Dataset', 'computational sequence version': 1.0, 'contact': 'abagherz@andrew.cmu.edu', 'creator': 'Amir Zadeh', 'dataset bib citation': '@article{zadeh2016multimodal,title={Multimodal sentiment intensity analysis in videos: Facial gestures and verbal messages},author={Zadeh, Amir and Zellers, Rowan and Pincus, Eli and Morency, Louis-Philippe},journal={IEEE Intelligent Systems},volume={31},number={6},pages={82--88},year={2016},publisher={IEEE}}', 'dataset name': 'CMU-MOSI', 'dataset version': 1.0, 'dimension names': ['word'], 'featureset bib citation': '@article{P2FA,title={Speaker identification on the SCOTUS corpus},author={Yuan, Jiahong and Liberman, Mark},journal={Journal of the Acoustical Society of America},volume={123},number={5},pages={3878},year={2008},publisher={[New York: Acoustical Society of America]}}', 'md5': None, 'root name': 'words', 'uuid': 'cf8e3281-bcec-49ff-be0e-6f98b55ad4d0'}
#
#
# === Metadata WordVectors===
#
# WordVectors Metadata: {'alignment compatible': True, 'computational sequence description': 'Word vector sequences for CMU-MOSI Dataset', 'computational sequence version': 1.0, 'contact': 'abagherz@andrew.cmu.edu', 'creator': 'Amir Zadeh', 'dataset bib citation': '@article{zadeh2016multimodal,title={Multimodal sentiment intensity analysis in videos: Facial gestures and verbal messages},author={Zadeh, Amir and Zellers, Rowan and Pincus, Eli and Morency, Louis-Philippe},journal={IEEE Intelligent Systems},volume={31},number={6},pages={82--88},year={2016},publisher={IEEE}}', 'dataset name': 'CMU-MOSI', 'dataset version': 1.0, 'dimension names': ['glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_vector', 'glove_ ...

# %%
fields_metadata = [
    {"Field": "Visual FACE 41", "Metadata": dataset[visual_field_Facet41].metadata},
    # {"Field": "Visual FACE 42", "Metadata": dataset[visual_field_Facet42].metadata},
    # {"Field": "Visual OpenFace", "Metadata": dataset[visual_field_OpenFace1].metadata},
    {"Field": "Acoustic COVAREP", "Metadata": dataset[acoustic_field_COVAREP].metadata},
    # {"Field": "Acoustic OpenSmile EB10", "Metadata": dataset[acoustic_field_OpenSmile_EB10].metadata},
    # {"Field": "Acoustic OpenSmile IS09", "Metadata": dataset[acoustic_field_OpenSmile_IS09].metadata},
    {"Field": "Words", "Metadata": dataset[text_field_Words].metadata},
    # {"Field": "Phones", "Metadata": dataset[text_field_Phones].metadata},
    {"Field": "WordVectors", "Metadata": dataset[text_field_WordVectors].metadata},
]

# Normalize (flatten) the metadata dictionaries
normalized_data = []
for entry in fields_metadata:
    metadata_flat = pd.json_normalize(entry["Metadata"], sep="_")
    metadata_flat["Field"] = entry["Field"]
    normalized_data.append(metadata_flat)

# print(f"normalized metadata: {normalized_data}")

df_metadata = pd.concat(normalized_data, ignore_index=True)
df_metadata = df_metadata[["Field"] + [col for col in df_metadata.columns if col != "Field"]]

print(df_metadata)



# # Save the DataFrame to a CSV file
# csv_filename = "metadata_summary.csv"
# df_metadata.to_csv(csv_filename, index=False)
# 
# print(f"Metadata successfully saved to {csv_filename}")
# 
# 
# 
#remove \ for Acoustic OpenSmile EB10
#remove b" and " for Acoustic OpenSmile IS09
# Out:
#               Field  alignment compatible  \
# 0    Visual FACE 41                  True
# 1  Acoustic COVAREP                  True
# 2             Words                 False
# 3       WordVectors                  True
#
#                computational sequence description  \
# 0  FACET 4.1 Visual Features for CMU-MOSI Dataset
# 1  COVAREP Acoustic Features for CMU-MOSI Dataset
# 2             Word sequences for CMU-MOSI Dataset
# 3      Word vector sequences for CMU-MOSI Dataset
#
#    computational sequence version                  contact     creator  \
# 0                             1.0  abagherz@andrew.cmu.edu  Amir Zadeh
# 1                             1.0  abagherz@andrew.cmu.edu  Amir Zadeh
# 2                             1.0  abagherz@andrew.cmu.edu  Amir Zadeh
# 3                             1.0  abagherz@andrew.cmu.edu  Amir Zadeh
#
#                                 dataset bib citation dataset name  \
# 0  @article{zadeh2016multimodal,title={Multimodal...     CMU-MOSI
# 1  @article{zadeh2016multimodal,title={Multimodal...     CMU-MOSI
# 2  @article{zadeh2016multimodal,title={Multimodal...     CMU-MOSI
# 3  @article{zadeh2016multimodal,title={Multimodal...     CMU-MOSI
#
#    dataset version                                    dimension names  \
# 0              1.0  [Face X, Face Y, Face Width, Face Height, ange...
# 1              1.0  [F0, VUV, NAQ, QOQ, H1H2, PSP, MDQ, peakSlope,...
# 2              1.0                                             [word]
# 3              1.0  [glove_vector, glove_vector, glove_vector, glo...
#
#                              featureset bib citation   md5      root name  \
# 0  @online{emotient,author = {iMotions},title = {...  None      FACET_4.1
# 1  @inproceedings{degottex2014covarep,title={COVA...  None        COVAREP
# 2  @article{P2FA,title={Speaker identification on...  None          words
# 3  @inproceedings{pennington2014glove,title={Glov...  None  glove_vectors
#
#                                    uuid
# 0  75b82d70-387f-4c1a-935e-99462b7e4388
# 1  b3040d49-2a1b-45f8-b991-16fb1acc75c5
# 2  cf8e3281-bcec-49ff-be0e-6f98b55ad4d0
# 3  156d7173-63fc-476b-8fc7-636283a7edb3

# %%
df_components = df_metadata[["Field", "dimension names"]]

# Define the replacements in a dictionary
replacements = {
    'b"': '',
    '"': '',
    '\'' : '',
    '[': '',
    ']': ''

}



def replace_strings(x):
    if isinstance(x, str):
        for old, new in replacements.items():
            x = x.replace(old, new)
    return x


# Apply the replacements using map
df_components = df_components.applymap(replace_strings)

print(df_components)

# Save the DataFrame to a CSV file
csv_filename = "componentsWithoutIS.csv"
df_components.to_csv(csv_filename, index=False)
# Out:
#               Field                                    dimension names
# 0    Visual FACE 41  [Face X, Face Y, Face Width, Face Height, ange...
# 1  Acoustic COVAREP  [F0, VUV, NAQ, QOQ, H1H2, PSP, MDQ, peakSlope,...
# 2             Words                                             [word]
# 3       WordVectors  [glove_vector, glove_vector, glove_vector, glo...
# C:\Users\Viki\AppData\Local\Temp\ipykernel_19120\4218429857.py:23: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_components = df_components.applymap(replace_strings)

# %%
import pandas as pd
import csv

# Define the replacements in a dictionary
replacements = {
    'b"': '',
    '\"': '',
    '\'': '',
    '[': '',
    ']': ''
}

# Function to apply replacements
def replace_strings(x):
    if isinstance(x, str):
        for old, new in replacements.items():
            x = x.replace(old, new)
    return x

# Read the CSV file into a DataFrame
with open('componentsWithoutIS.csv', 'r', newline='', encoding='utf-8') as csvfile:
    reader = csv.reader(csvfile)
    rows = []
    for row in reader:
        new_row = []
        for element in row:
            # Split elements by comma and strip spaces
            split_elements = [e.strip() for e in element.split(',')]
            new_row.extend(split_elements)
        rows.append(new_row)

# Create DataFrame from the processed rows
df = pd.DataFrame(rows)

# Apply the replacements using applymap to the entire DataFrame
df = df.applymap(replace_strings)

# Save the modified DataFrame back to a CSV file
df.to_csv('componentsModifiedWithoutIS.csv', index=False)
# Out:
# C:\Users\Viki\AppData\Local\Temp\ipykernel_19120\2718881803.py:36: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(replace_strings)

# %%
# Load the dataset from a CSV file
# Replace 'your_file.csv' with the path to your actual file
df = pd.read_csv('componentsModifiedWithoutIS.csv', header=None)

# Flatten the DataFrame into a single list, keeping track of field positions
data = []
for col in df.columns:
    for row in df.index:
        value = df.iloc[row, col]
        if pd.notna(value):  # Exclude empty elements
            data.append((value.strip(), f"Row {row+1}, Column {col+1}"))

# Create a dictionary to count occurrences and track positions
duplicate_tracker = {}
for value, position in data:
    if value in duplicate_tracker:
        duplicate_tracker[value]['count'] += 1
        duplicate_tracker[value]['positions'].append(position)
    else:
        duplicate_tracker[value] = {'count': 1, 'positions': [position]}

# Write results to a text file
with open('outputDuplicatesWithoutIS.txt', 'w') as output_file:
    output_file.write("Duplicates Found:\n")
    for value, info in duplicate_tracker.items():
        if info['count'] > 1:
            output_file.write(
                f"{value}: {info['count']}; Positions: {', '.join(info['positions'])}\n"
            )

print("Duplicate analysis complete. Results saved to 'outputWithoutIS.txt'.")
# Out:
# Duplicate analysis complete. Results saved to 'outputWithoutIS.txt'.

# %%
# we define a simple averaging function that does not depend on intervals
def avg(intervals: np.array, features: np.array) -> np.array:
    try:
        return np.average(features, axis=0)
    except:
        return features

# first we align to words with averaging, collapse_function receives a list of functions
dataset.align(text_field_Words, collapse_functions=[avg])
# Out:
# [2024-12-04 11:08:12.065] | Status  | Unify was called ...
# [2024-12-04 11:08:12.065] | Success | Unify completed ...
# [2024-12-04 11:08:12.066] | Status  | Pre-alignment based on <CMU_MOSI_TimestampedWords> computational sequence started ...
# [2024-12-04 11:08:13.260] | Status  | Pre-alignment done for <CMU_MOSI_TimestampedWordVectors> ...
# [2024-12-04 11:08:14.492] | Status  | Pre-alignment done for <CMU_MOSI_Visual_Facet_41> ...
# [2024-12-04 11:08:20.391] | Status  | Pre-alignment done for <CMU_MOSI_COVAREP> ...
# [2024-12-04 11:08:20.494] | Status  | Alignment starting ...
# Overall Progress:   0%|          | 0/93 [00:00<?, ? Computational Sequence Entries/s]
#   0%|          | 0/464 [00:00<?, ? Segments/s]
# Aligning 03bSnISJMiM:   0%|          | 0/464 [00:00<?, ? Segments/s]
# Aligning 03bSnISJMiM:   3%|▎         | 15/464 [00:00<00:03, 139.14 Segments/s]
# Aligning 03bSnISJMiM:   7%|▋         | 33/464 [00:00<00:02, 161.52 Segments/s]
# Aligning 03bSnISJMiM:  13%|█▎        | 62/464 [00:00<00:01, 214.98 Segments/s]
# Aligning 03bSnISJMiM:  19%|█▉        | 89/464 [00:00<00:01, 235.11 Segments/s]
# Aligning 03bSnISJMiM:  26%|██▋       | 122/464 [00:00<00:01, 264.73 Segments/s]
# Aligning 03bSnISJMiM:  33%|███▎      | 154/464 [00:00<00:01, 280.86 Segments/s]
# Aligning 03bSnISJMiM:  39%|███▉      | 183/464 [00:00<00:00, 281.89 Segments/s]
# Aligning 03bSnISJMiM:  48%|████▊     | 223/464 [00:00<00:00, 317.63 Segments/s]
# Aligning 03bSnISJMiM:  55%|█████▍    | 255/464 [00:00<00:00, 286.17 Segments/s]
# Aligning 03bSnISJMiM:  61%|██████▏   | 285/464 [00:01<00:00, 281.33 Segments/s]
# Aligning 03bSnISJMiM:  68%|██████▊   | 314/464 [00:01<00:00, 262.99 Segments/s]
# Aligning 03bSnISJMiM:  73%|███████▎  | 341/464 [00:01<00:00, 242.31 Segments/s]
# Aligning 03bSnISJMiM:  79%|███████▉  | 366/464 [00:01<00:00, 243.27 Segments/s]
# Aligning 03bSnISJMiM:  84%|████████▍ | 391/464 [00:01<00:00, 243.24 Segments/s]
# Aligning 03bSnISJMiM:  90%|████████▉ | 416/464 [00:01<00:00, 242.81 Segments/s]
# Aligning 03bSnISJMiM:  95%|█████████▌| 441/464 [00:01<00:00, 243.13 Segments/s]
# Overall Progress:   1%|          | 1/93 [00:01<02:48,  1.83s/ Computational Sequence Entries]
#   0%|          | 0/485 [00:00<?, ? Segments/s]
# Aligning 0h-zjBukYpk:   0%|          | 0/485 [00:00<?, ? Segments/s]
# Aligning 0h-zjBukYpk:  10%|▉         | 48/485 [00:00<00:00, 470.55 Segments/s]
# Aligning 0h-zjBukYpk:  22%|██▏       | 105/485 [00:00<00:00, 521.98 Segments/s]
# Aligning 0h-zjBukYpk:  33%|███▎      | 158/485 [00:00<00:00, 403.25 Segments/s]
# Aligning 0h-zjBukYpk:  41%|████▏     | 201/485 [00:00<00:00, 357.41 Segments/s]
# Aligning 0h-zjBukYpk:  49%|████▉     | 239/485 [00:00<00:00, 312.17 Segments/s]
# Aligning 0h-zjBukYpk:  61%|██████▏   | 298/485 [00:00<00:00, 383.92 Segments/s]
# Aligning 0h-zjBukYpk:  75%|███████▌  | 364/485 [00:00<00:00, 458.15 Segments/s]
# Aligning 0h-zjBukYpk:  85%|████████▌ | 414/485 [00:01<00:00, 412.61 Segments/s]
# Aligning 0h-zjBukYpk:  95%|█████████▍| 459/485 [00:01<00:00, 354.25 Segments/s]
# Overall Progress:   2%|▏         | 2/93 [00:03<02:16,  1.50s/ Computational Sequence Entries]
#   0%|          | 0/237 [00:00<?, ? Segments/s]
# Aligning 1DmNV9C1hbY:   0%|          | 0/237 [00:00<?, ? Segments/s]
# Aligning 1DmNV9C1hbY:  35%|███▌      | 84/237 [00:00<00:00, 836.07 Segments/s]
# Aligning 1DmNV9C1hbY:  71%|███████   | 168/237 [00:00<00:00, 733.10 Segments/s]
# Overall Progress:   3%|▎         | 3/93 [00:03<01:28,  1.02 Computational Sequence Entries/s]
#   0%|          | 0/562 [00:00<?, ? Segments/s]
# Aligning 1iG0909rllw:   0%|          | 0/562 [00:00<?, ? Segments/s]
# Aligning 1iG0909rllw:   4%|▎         | 21/562 [00:00<00:02, 207.15 Segments/s]
# Aligning 1iG0909rllw:   8%|▊         | 45/562 [00:00<00:02, 224.65 Segments/s]
# Aligning 1iG0909rllw:  14%|█▎        | 76/562 [00:00<00:01, 262.51 Segments/s]
# Aligning 1iG0909rllw:  22%|██▏       | 122/562 [00:00<00:01, 339.80 Segments/s]
# Aligning 1iG0909rllw:  33%|███▎      | 188/562 [00:00<00:00, 454.67 Segments/s]
# Aligning 1iG0909rllw:  42%|████▏     | 234/562 [00:00<00:00, 410.97 Segments/s]
# Aligning 1iG0909rllw:  49%|████▉     | 276/562 [00:00<00:00, 374.68 Segments/s]
# Aligning 1iG0909rllw:  56%|█████▌    | 315/562 [00:00<00:00, 321.16 Segments/s]
# Aligning 1iG0909rllw:  62%|██████▏   | 349/562 [00:01<00:00, 320.37 Segments/s]
# Aligning 1iG0909rllw:  69%|██████▉   | 390/562 [00:01<00:00, 343.91 Segments/s]
# Aligning 1iG0909rllw:  81%|████████  | 456/562 [00:01<00:00, 429.51 Segments/s]
# Aligning 1iG0909rllw:  89%|████████▉ | 501/562 [00:01<00:00, 409.27 Segments/s]
# Aligning 1iG0909rllw:  97%|█████████▋| 544/562 [00:01<00:00, 391.96 Segments/s]
# Overall Progress:   4%|▍         | 4/93 [00:05<01:47,  1.21s/ Computational Sequence Entries]
#   0%|          | 0/651 [00:00<?, ? Segments/s]
# Aligning 2WGyTLYerpo:   0%|          | 0/651 [00:00<?, ? Segments/s]
# Aligning 2WGyTLYerpo:   4%|▍         | 28/651 [00:00<00:02, 279.47 Segments/s]
# Aligning 2WGyTLYerpo:  10%|▉         | 65/651 [00:00<00:01, 329.03 Segments/s]
# Aligning 2WGyTLYerpo:  20%|██        | 132/651 [00:00<00:01, 483.35 Segments/s]
# Aligning 2WGyTLYerpo:  28%|██▊       | 181/651 [00:00<00:01, 459.16 Segments/s]
# Aligning 2WGyTLYerpo:  35%|███▌      | 228/651 [00:00<00:01, 377.03 Segments/s]
# Aligning 2WGyTLYerpo:  41%|████      | 268/651 [00:00<00:01, 336.51 Segments/s]
# Aligning 2WGyTLYerpo:  47%|████▋     | 304/651 [00:00<00:01, 322.15 Segments/s]
# Aligning 2WGyTLYerpo:  54%|█████▍    | 353/651 [00:00<00:00, 365.65 Segments/s]
# Aligning 2WGyTLYerpo:  63%|██████▎   | 407/651 [00:01<00:00, 411.45 Segments/s]
# Aligning 2WGyTLYerpo:  69%|██████▉   | 450/651 [00:01<00:00, 381.42 Segments/s]
# Aligning 2WGyTLYerpo:  75%|███████▌  | 490/651 [00:01<00:00, 329.00 Segments/s]
# Aligning 2WGyTLYerpo:  81%|████████  | 525/651 [00:01<00:00, 314.08 Segments/s]
# Aligning 2WGyTLYerpo:  86%|████████▌ | 558/651 [00:01<00:00, 308.53 Segments/s]
# Aligning 2WGyTLYerpo:  92%|█████████▏| 599/651 [00:01<00:00, 332.51 Segments/s]
# Aligning 2WGyTLYerpo: 100%|█████████▉| 650/651 [00:01<00:00, 378.59 Segments/s]
# Overall Progress:   5%|▌         | 5/93 [00:06<02:05,  1.43s/ Computational Sequence Entries]
#   0%|          | 0/700 [00:00<?, ? Segments/s]
# Aligning 2iD-tVS8NPw:   0%|          | 0/700 [00:00<?, ? Segments/s]
# Aligning 2iD-tVS8NPw:   7%|▋         | 50/700 [00:00<00:01, 493.07 Segments/s]
# Aligning 2iD-tVS8NPw:  14%|█▍        | 100/700 [00:00<00:01, 489.82 Segments/s]
# Aligning 2iD-tVS8NPw:  22%|██▏       | 152/700 [00:00<00:01, 502.61 Segments/s]
# Aligning 2iD-tVS8NPw:  29%|██▉       | 203/700 [00:00<00:01, 461.70 Segments/s]
# Aligning 2iD-tVS8NPw:  36%|███▌      | 250/700 [00:00<00:01, 407.16 Segments/s]
# Aligning 2iD-tVS8NPw:  42%|████▏     | 292/700 [00:00<00:01, 362.35 Segments/s]
# Aligning 2iD-tVS8NPw:  47%|████▋     | 330/700 [00:00<00:01, 346.55 Segments/s]
# Aligning 2iD-tVS8NPw:  53%|█████▎    | 374/700 [00:00<00:00, 370.86 Segments/s]
# Aligning 2iD-tVS8NPw:  61%|██████    | 427/700 [00:01<00:00, 414.74 Segments/s]
# Aligning 2iD-tVS8NPw:  68%|██████▊   | 476/700 [00:01<00:00, 432.04 Segments/s]
# Aligning 2iD-tVS8NPw:  74%|███████▍  | 521/700 [00:01<00:00, 394.38 Segments/s]
# Aligning 2iD-tVS8NPw:  80%|████████  | 562/700 [00:01<00:00, 368.29 Segments/s]
# Aligning 2iD-tVS8NPw:  86%|████████▌ | 600/700 [00:01<00:00, 314.88 Segments/s]
# Aligning 2iD-tVS8NPw:  91%|█████████ | 634/700 [00:01<00:00, 293.91 Segments/s]
# Aligning 2iD-tVS8NPw:  96%|█████████▌| 672/700 [00:01<00:00, 314.34 Segments/s]
# Overall Progress:   6%|▋         | 6/93 [00:08<02:17,  1.58s/ Computational Sequence Entries]
#   0%|          | 0/262 [00:00<?, ? Segments/s]
# Aligning 5W7Z1C_fDaE:   0%|          | 0/262 [00:00<?, ? Segments/s]
# Aligning 5W7Z1C_fDaE:  33%|███▎      | 86/262 [00:00<00:00, 858.68 Segments/s]
# Aligning 5W7Z1C_fDaE:  66%|██████▌   | 172/262 [00:00<00:00, 616.29 Segments/s]
# Aligning 5W7Z1C_fDaE:  91%|█████████ | 238/262 [00:00<00:00, 540.43 Segments/s]
# Overall Progress:   8%|▊         | 7/93 [00:09<01:45,  1.23s/ Computational Sequence Entries]
#   0%|          | 0/411 [00:00<?, ? Segments/s]
# Aligning 6Egk_28TtTM:   0%|          | 0/411 [00:00<?, ? Segments/s]
# Aligning 6Egk_28TtTM:   6%|▋         | 26/411 [00:00<00:01, 257.83 Segments/s]
# Aligning 6Egk_28TtTM:  20%|██        | 83/411 [00:00<00:00, 438.94 Segments/s]
# Aligning 6Egk_28TtTM:  35%|███▌      | 144/411 [00:00<00:00, 516.56 Segments/s]
# Aligning 6Egk_28TtTM:  48%|████▊     | 196/411 [00:00<00:00, 448.78 Segments/s]
# Aligning 6Egk_28TtTM:  59%|█████▉    | 243/411 [00:00<00:00, 371.58 Segments/s]
# Aligning 6Egk_28TtTM:  69%|██████▉   | 283/411 [00:00<00:00, 368.02 Segments/s]
# Aligning 6Egk_28TtTM:  82%|████████▏ | 335/411 [00:00<00:00, 408.46 Segments/s]
# Aligning 6Egk_28TtTM:  98%|█████████▊| 404/411 [00:00<00:00, 486.74 Segments/s]
# Overall Progress:   9%|▊         | 8/93 [00:10<01:36,  1.14s/ Computational Sequence Entries]
#   0%|          | 0/374 [00:00<?, ? Segments/s]
# Aligning 6_0THN4chvY:   0%|          | 0/374 [00:00<?, ? Segments/s]
# Aligning 6_0THN4chvY:  11%|█         | 40/374 [00:00<00:00, 389.73 Segments/s]
# Aligning 6_0THN4chvY:  21%|██        | 79/374 [00:00<00:00, 351.52 Segments/s]
# Aligning 6_0THN4chvY:  31%|███       | 115/374 [00:00<00:00, 343.24 Segments/s]
# Aligning 6_0THN4chvY:  42%|████▏     | 157/374 [00:00<00:00, 365.76 Segments/s]
# Aligning 6_0THN4chvY:  52%|█████▏    | 194/374 [00:00<00:00, 358.96 Segments/s]
# Aligning 6_0THN4chvY:  61%|██████▏   | 230/374 [00:00<00:00, 335.71 Segments/s]
# Aligning 6_0THN4chvY:  71%|███████   | 265/374 [00:00<00:00, 339.97 Segments/s]
# Aligning 6_0THN4chvY:  90%|████████▉ | 335/374 [00:00<00:00, 447.98 Segments/s]
# Overall Progress:  10%|▉         | 9/93 [00:11<01:30,  1.07s/ Computational Sequence Entries]
#   0%|          | 0/591 [00:00<?, ? Segments/s]
# Aligning 73jzhE8R1TQ:   0%|          | 0/591 [00:00<?, ? Segments/s]
# Aligning 73jzhE8R1TQ:   5%|▍         | 29/591 [00:00<00:01, 289.73 Segments/s]
# Aligning 73jzhE8R1TQ:  10%|▉         | 59/591 [00:00<00:01, 293.46 Segments/s]
# Aligning 73jzhE8R1TQ:  15%|█▌        | 89/591 [00:00<00:01, 277.97 Segments/s]
# Aligning 73jzhE8R1TQ:  24%|██▍       | 142/591 [00:00<00:01, 371.74 Segments/s]
# Aligning 73jzhE8R1TQ:  33%|███▎      | 197/591 [00:00<00:00, 430.70 Segments/s]
# Aligning 73jzhE8R1TQ:  41%|████      | 241/591 [00:00<00:00, 383.98 Segments/s]
# Aligning 73jzhE8R1TQ:  48%|████▊     | 281/591 [00:00<00:00, 354.94 Segments/s]
# Aligning 73jzhE8R1TQ:  54%|█████▍    | 318/591 [00:00<00:00, 328.91 Segments/s]
# Aligning 73jzhE8R1TQ:  60%|██████    | 356/591 [00:01<00:00, 342.32 Segments/s]
# Aligning 73jzhE8R1TQ:  72%|███████▏  | 424/591 [00:01<00:00, 434.84 Segments/s]
# Aligning 73jzhE8R1TQ:  83%|████████▎ | 490/591 [00:01<00:00, 496.21 Segments/s]
# Aligning 73jzhE8R1TQ:  92%|█████████▏| 542/591 [00:01<00:00, 391.10 Segments/s]
# Aligning 73jzhE8R1TQ:  99%|█████████▉| 586/591 [00:01<00:00, 345.02 Segments/s]
# Overall Progress:  11%|█         | 10/93 [00:12<01:43,  1.25s/ Computational Sequence Entries]
#   0%|          | 0/636 [00:00<?, ? Segments/s]
# Aligning 7JsX8y1ysxY:   0%|          | 0/636 [00:00<?, ? Segments/s]
# Aligning 7JsX8y1ysxY:   4%|▍         | 25/636 [00:00<00:02, 247.34 Segments/s]
# Aligning 7JsX8y1ysxY:   9%|▉         | 58/636 [00:00<00:01, 294.57 Segments/s]
# Aligning 7JsX8y1ysxY:  17%|█▋        | 109/636 [00:00<00:01, 390.34 Segments/s]
# Aligning 7JsX8y1ysxY:  26%|██▋       | 167/636 [00:00<00:01, 461.16 Segments/s]
# Aligning 7JsX8y1ysxY:  34%|███▎      | 214/636 [00:00<00:01, 406.05 Segments/s]
# Aligning 7JsX8y1ysxY:  40%|████      | 256/636 [00:00<00:01, 352.96 Segments/s]
# Aligning 7JsX8y1ysxY:  46%|████▌     | 293/636 [00:00<00:01, 334.21 Segments/s]
# Aligning 7JsX8y1ysxY:  52%|█████▏    | 328/636 [00:00<00:00, 320.18 Segments/s]
# Aligning 7JsX8y1ysxY:  59%|█████▉    | 378/636 [00:01<00:00, 367.97 Segments/s]
# Aligning 7JsX8y1ysxY:  69%|██████▉   | 440/636 [00:01<00:00, 436.14 Segments/s]
# Aligning 7JsX8y1ysxY:  76%|███████▋  | 486/636 [00:01<00:00, 385.37 Segments/s]
# Aligning 7JsX8y1ysxY:  83%|████████▎ | 527/636 [00:01<00:00, 361.39 Segments/s]
# Aligning 7JsX8y1ysxY:  89%|████████▉ | 565/636 [00:01<00:00, 348.82 Segments/s]
# Aligning 7JsX8y1ysxY:  94%|█████████▍| 601/636 [00:01<00:00, 311.80 Segments/s]
# Aligning 7JsX8y1ysxY: 100%|█████████▉| 634/636 [00:01<00:00, 309.24 Segments/s]
# Overall Progress:  12%|█▏        | 11/93 [00:14<01:56,  1.42s/ Computational Sequence Entries]
#   0%|          | 0/654 [00:00<?, ? Segments/s]
# Aligning 8OtFthrtaJM:   0%|          | 0/654 [00:00<?, ? Segments/s]
# Aligning 8OtFthrtaJM:   8%|▊         | 53/654 [00:00<00:01, 529.75 Segments/s]
# Aligning 8OtFthrtaJM:  16%|█▌        | 106/654 [00:00<00:01, 512.52 Segments/s]
# Aligning 8OtFthrtaJM:  24%|██▍       | 158/654 [00:00<00:01, 402.62 Segments/s]
# Aligning 8OtFthrtaJM:  31%|███       | 201/654 [00:00<00:01, 319.37 Segments/s]
# Aligning 8OtFthrtaJM:  39%|███▊      | 252/654 [00:00<00:01, 369.29 Segments/s]
# Aligning 8OtFthrtaJM:  47%|████▋     | 306/654 [00:00<00:00, 416.63 Segments/s]
# Aligning 8OtFthrtaJM:  54%|█████▎    | 351/654 [00:00<00:00, 387.07 Segments/s]
# Aligning 8OtFthrtaJM:  60%|██████    | 393/654 [00:01<00:00, 340.35 Segments/s]
# Aligning 8OtFthrtaJM:  66%|██████▌   | 430/654 [00:01<00:00, 343.42 Segments/s]
# Aligning 8OtFthrtaJM:  75%|███████▍  | 488/654 [00:01<00:00, 404.30 Segments/s]
# Aligning 8OtFthrtaJM:  83%|████████▎ | 542/654 [00:01<00:00, 440.86 Segments/s]
# Aligning 8OtFthrtaJM:  90%|█████████ | 589/654 [00:01<00:00, 368.63 Segments/s]
# Aligning 8OtFthrtaJM:  96%|█████████▋| 630/654 [00:01<00:00, 344.32 Segments/s]
# Overall Progress:  13%|█▎        | 12/93 [00:16<02:04,  1.53s/ Computational Sequence Entries]
#   0%|          | 0/584 [00:00<?, ? Segments/s]
# Aligning 8d-gEyoeBzc:   0%|          | 0/584 [00:00<?, ? Segments/s]
# Aligning 8d-gEyoeBzc:   5%|▍         | 27/584 [00:00<00:02, 267.85 Segments/s]
# Aligning 8d-gEyoeBzc:  12%|█▏        | 70/584 [00:00<00:01, 359.97 Segments/s]
# Aligning 8d-gEyoeBzc:  20%|██        | 118/584 [00:00<00:01, 413.92 Segments/s]
# Aligning 8d-gEyoeBzc:  27%|██▋       | 160/584 [00:00<00:01, 386.90 Segments/s]
# Aligning 8d-gEyoeBzc:  34%|███▍      | 199/584 [00:00<00:01, 323.47 Segments/s]
# Aligning 8d-gEyoeBzc:  40%|███▉      | 233/584 [00:00<00:01, 281.72 Segments/s]
# Aligning 8d-gEyoeBzc:  45%|████▌     | 263/584 [00:00<00:01, 260.12 Segments/s]
# Aligning 8d-gEyoeBzc:  52%|█████▏    | 305/584 [00:00<00:00, 300.14 Segments/s]
# Aligning 8d-gEyoeBzc:  63%|██████▎   | 367/584 [00:01<00:00, 384.80 Segments/s]
# Aligning 8d-gEyoeBzc:  72%|███████▏  | 422/584 [00:01<00:00, 429.23 Segments/s]
# Aligning 8d-gEyoeBzc:  80%|████████  | 468/584 [00:01<00:00, 373.56 Segments/s]
# Aligning 8d-gEyoeBzc:  87%|████████▋ | 509/584 [00:01<00:00, 343.10 Segments/s]
# Aligning 8d-gEyoeBzc:  93%|█████████▎| 546/584 [00:01<00:00, 320.87 Segments/s]
# Overall Progress:  14%|█▍        | 13/93 [00:18<02:07,  1.59s/ Computational Sequence Entries]
#   0%|          | 0/523 [00:00<?, ? Segments/s]
# Aligning 8qrpnFRGt2A:   0%|          | 0/523 [00:00<?, ? Segments/s]
# Aligning 8qrpnFRGt2A:  10%|▉         | 51/523 [00:00<00:00, 509.35 Segments/s]
# Aligning 8qrpnFRGt2A:  20%|█▉        | 102/523 [00:00<00:01, 399.35 Segments/s]
# Aligning 8qrpnFRGt2A:  28%|██▊       | 144/523 [00:00<00:01, 376.61 Segments/s]
# Aligning 8qrpnFRGt2A:  35%|███▍      | 183/523 [00:00<00:01, 311.98 Segments/s]
# Aligning 8qrpnFRGt2A:  45%|████▍     | 233/523 [00:00<00:00, 365.01 Segments/s]
# Aligning 8qrpnFRGt2A:  57%|█████▋    | 296/523 [00:00<00:00, 439.80 Segments/s]
# Aligning 8qrpnFRGt2A:  69%|██████▊   | 359/523 [00:00<00:00, 494.17 Segments/s]
# Aligning 8qrpnFRGt2A:  79%|███████▊  | 411/523 [00:00<00:00, 424.27 Segments/s]
# Aligning 8qrpnFRGt2A:  87%|████████▋ | 457/523 [00:01<00:00, 363.88 Segments/s]
# Aligning 8qrpnFRGt2A:  95%|█████████▌| 497/523 [00:01<00:00, 327.35 Segments/s]
# Overall Progress:  15%|█▌        | 14/93 [00:19<02:02,  1.55s/ Computational Sequence Entries]
#   0%|          | 0/554 [00:00<?, ? Segments/s]
# Aligning 9J25DZhivz8:   0%|          | 0/554 [00:00<?, ? Segments/s]
# Aligning 9J25DZhivz8:   5%|▌         | 28/554 [00:00<00:01, 277.13 Segments/s]
# Aligning 9J25DZhivz8:  14%|█▍        | 78/554 [00:00<00:01, 404.36 Segments/s]
# Aligning 9J25DZhivz8:  25%|██▍       | 137/554 [00:00<00:00, 485.50 Segments/s]
# Aligning 9J25DZhivz8:  34%|███▎      | 186/554 [00:00<00:00, 412.42 Segments/s]
# Aligning 9J25DZhivz8:  41%|████▏     | 229/554 [00:00<00:00, 374.15 Segments/s]
# Aligning 9J25DZhivz8:  48%|████▊     | 268/554 [00:00<00:00, 326.05 Segments/s]
# Aligning 9J25DZhivz8:  58%|█████▊    | 321/554 [00:00<00:00, 379.71 Segments/s]
# Aligning 9J25DZhivz8:  69%|██████▉   | 385/554 [00:00<00:00, 448.26 Segments/s]
# Aligning 9J25DZhivz8:  78%|███████▊  | 433/554 [00:01<00:00, 409.24 Segments/s]
# Aligning 9J25DZhivz8:  86%|████████▌ | 477/554 [00:01<00:00, 382.68 Segments/s]
# Aligning 9J25DZhivz8:  93%|█████████▎| 517/554 [00:01<00:00, 361.69 Segments/s]
# Overall Progress:  16%|█▌        | 15/93 [00:20<01:57,  1.51s/ Computational Sequence Entries]
#   0%|          | 0/645 [00:00<?, ? Segments/s]
# Aligning 9T9Hf74oK10:   0%|          | 0/645 [00:00<?, ? Segments/s]
# Aligning 9T9Hf74oK10:  10%|█         | 65/645 [00:00<00:00, 639.01 Segments/s]
# Aligning 9T9Hf74oK10:  20%|██        | 129/645 [00:00<00:01, 445.55 Segments/s]
# Aligning 9T9Hf74oK10:  27%|██▋       | 177/645 [00:00<00:01, 347.62 Segments/s]
# Aligning 9T9Hf74oK10:  33%|███▎      | 215/645 [00:00<00:01, 348.20 Segments/s]
# Aligning 9T9Hf74oK10:  42%|████▏     | 270/645 [00:00<00:00, 405.29 Segments/s]
# Aligning 9T9Hf74oK10:  53%|█████▎    | 342/645 [00:00<00:00, 495.30 Segments/s]
# Aligning 9T9Hf74oK10:  61%|██████    | 395/645 [00:00<00:00, 504.19 Segments/s]
# Aligning 9T9Hf74oK10:  71%|███████   | 458/645 [00:00<00:00, 540.18 Segments/s]
# Aligning 9T9Hf74oK10:  80%|███████▉  | 514/645 [00:01<00:00, 438.70 Segments/s]
# Aligning 9T9Hf74oK10:  87%|████████▋ | 562/645 [00:01<00:00, 382.73 Segments/s]
# Aligning 9T9Hf74oK10:  94%|█████████▎| 604/645 [00:01<00:00, 348.44 Segments/s]
# Aligning 9T9Hf74oK10: 100%|█████████▉| 642/645 [00:01<00:00, 314.41 Segments/s]
# Overall Progress:  17%|█▋        | 16/93 [00:22<01:59,  1.56s/ Computational Sequence Entries]
#   0%|          | 0/300 [00:00<?, ? Segments/s]
# Aligning 9c67fiY0wGQ:   0%|          | 0/300 [00:00<?, ? Segments/s]
# Aligning 9c67fiY0wGQ:  14%|█▍        | 43/300 [00:00<00:00, 428.26 Segments/s]
# Aligning 9c67fiY0wGQ:  29%|██▊       | 86/300 [00:00<00:00, 410.58 Segments/s]
# Aligning 9c67fiY0wGQ:  46%|████▌     | 137/300 [00:00<00:00, 454.02 Segments/s]
# Aligning 9c67fiY0wGQ:  70%|███████   | 210/300 [00:00<00:00, 559.29 Segments/s]
# Aligning 9c67fiY0wGQ:  98%|█████████▊| 295/300 [00:00<00:00, 661.51 Segments/s]
# Overall Progress:  18%|█▊        | 17/93 [00:23<01:34,  1.25s/ Computational Sequence Entries]
#   0%|          | 0/735 [00:00<?, ? Segments/s]
# Aligning 9qR7uwkblbs:   0%|          | 0/735 [00:00<?, ? Segments/s]
# Aligning 9qR7uwkblbs:   4%|▎         | 27/735 [00:00<00:02, 268.76 Segments/s]
# Aligning 9qR7uwkblbs:   8%|▊         | 60/735 [00:00<00:02, 303.51 Segments/s]
# Aligning 9qR7uwkblbs:  12%|█▏        | 91/735 [00:00<00:02, 287.49 Segments/s]
# Aligning 9qR7uwkblbs:  16%|█▋        | 120/735 [00:00<00:02, 279.61 Segments/s]
# Aligning 9qR7uwkblbs:  20%|██        | 149/735 [00:00<00:02, 274.99 Segments/s]
# Aligning 9qR7uwkblbs:  24%|██▍       | 180/735 [00:00<00:01, 283.53 Segments/s]
# Aligning 9qR7uwkblbs:  32%|███▏      | 232/735 [00:00<00:01, 356.26 Segments/s]
# Aligning 9qR7uwkblbs:  40%|███▉      | 292/735 [00:00<00:01, 429.42 Segments/s]
# Aligning 9qR7uwkblbs:  46%|████▌     | 336/735 [00:00<00:00, 419.62 Segments/s]
# Aligning 9qR7uwkblbs:  52%|█████▏    | 379/735 [00:01<00:00, 402.33 Segments/s]
# Aligning 9qR7uwkblbs:  57%|█████▋    | 420/735 [00:01<00:00, 370.30 Segments/s]
# Aligning 9qR7uwkblbs:  62%|██████▏   | 458/735 [00:01<00:00, 338.00 Segments/s]
# Aligning 9qR7uwkblbs:  68%|██████▊   | 503/735 [00:01<00:00, 366.07 Segments/s]
# Aligning 9qR7uwkblbs:  75%|███████▍  | 550/735 [00:01<00:00, 393.34 Segments/s]
# Aligning 9qR7uwkblbs:  83%|████████▎ | 608/735 [00:01<00:00, 443.77 Segments/s]
# Aligning 9qR7uwkblbs:  89%|████████▉ | 654/735 [00:01<00:00, 442.69 Segments/s]
# Aligning 9qR7uwkblbs:  95%|█████████▌| 699/735 [00:01<00:00, 436.06 Segments/s]
# Overall Progress:  19%|█▉        | 18/93 [00:25<01:48,  1.45s/ Computational Sequence Entries]
#   0%|          | 0/659 [00:00<?, ? Segments/s]
# Aligning Af8D0E4ZXaw:   0%|          | 0/659 [00:00<?, ? Segments/s]
# Aligning Af8D0E4ZXaw:   8%|▊         | 56/659 [00:00<00:01, 556.73 Segments/s]
# Aligning Af8D0E4ZXaw:  17%|█▋        | 112/659 [00:00<00:01, 400.15 Segments/s]
# Aligning Af8D0E4ZXaw:  24%|██▎       | 155/659 [00:00<00:01, 335.32 Segments/s]
# Aligning Af8D0E4ZXaw:  29%|██▉       | 191/659 [00:00<00:01, 305.13 Segments/s]
# Aligning Af8D0E4ZXaw:  34%|███▍      | 223/659 [00:00<00:01, 281.31 Segments/s]
# Aligning Af8D0E4ZXaw:  38%|███▊      | 252/659 [00:00<00:01, 277.41 Segments/s]
# Aligning Af8D0E4ZXaw:  43%|████▎     | 281/659 [00:00<00:01, 279.12 Segments/s]
# Aligning Af8D0E4ZXaw:  49%|████▊     | 320/659 [00:01<00:01, 308.72 Segments/s]
# Aligning Af8D0E4ZXaw:  57%|█████▋    | 373/659 [00:01<00:00, 369.42 Segments/s]
# Aligning Af8D0E4ZXaw:  66%|██████▌   | 433/659 [00:01<00:00, 434.37 Segments/s]
# Aligning Af8D0E4ZXaw:  73%|███████▎  | 478/659 [00:01<00:00, 382.44 Segments/s]
# Aligning Af8D0E4ZXaw:  79%|███████▉  | 519/659 [00:01<00:00, 337.09 Segments/s]
# Aligning Af8D0E4ZXaw:  84%|████████▍ | 555/659 [00:01<00:00, 332.54 Segments/s]
# Aligning Af8D0E4ZXaw:  92%|█████████▏| 607/659 [00:01<00:00, 379.43 Segments/s]
# Overall Progress:  20%|██        | 19/93 [00:26<01:55,  1.56s/ Computational Sequence Entries]
#   0%|          | 0/406 [00:00<?, ? Segments/s]
# Aligning BI97DNYfe5I:   0%|          | 0/406 [00:00<?, ? Segments/s]
# Aligning BI97DNYfe5I:  18%|█▊        | 75/406 [00:00<00:00, 747.96 Segments/s]
# Aligning BI97DNYfe5I:  37%|███▋      | 150/406 [00:00<00:00, 433.52 Segments/s]
# Aligning BI97DNYfe5I:  51%|█████     | 206/406 [00:00<00:00, 472.66 Segments/s]
# Aligning BI97DNYfe5I:  64%|██████▍   | 259/406 [00:00<00:00, 454.95 Segments/s]
# Aligning BI97DNYfe5I:  76%|███████▌  | 308/406 [00:00<00:00, 432.28 Segments/s]
# Aligning BI97DNYfe5I:  87%|████████▋ | 354/406 [00:00<00:00, 419.75 Segments/s]
# Overall Progress:  22%|██▏       | 20/93 [00:27<01:39,  1.36s/ Computational Sequence Entries]
#   0%|          | 0/566 [00:00<?, ? Segments/s]
# Aligning BXuRRbG0Ugk:   0%|          | 0/566 [00:00<?, ? Segments/s]
# Aligning BXuRRbG0Ugk:  11%|█         | 62/566 [00:00<00:00, 617.07 Segments/s]
# Aligning BXuRRbG0Ugk:  22%|██▏       | 124/566 [00:00<00:01, 403.68 Segments/s]
# Aligning BXuRRbG0Ugk:  30%|██▉       | 169/566 [00:00<00:01, 345.83 Segments/s]
# Aligning BXuRRbG0Ugk:  36%|███▋      | 206/566 [00:00<00:01, 310.78 Segments/s]
# Aligning BXuRRbG0Ugk:  45%|████▍     | 252/566 [00:00<00:00, 349.77 Segments/s]
# Aligning BXuRRbG0Ugk:  54%|█████▎    | 303/566 [00:00<00:00, 391.28 Segments/s]
# Aligning BXuRRbG0Ugk:  61%|██████    | 345/566 [00:00<00:00, 346.88 Segments/s]
# Aligning BXuRRbG0Ugk:  67%|██████▋   | 382/566 [00:01<00:00, 338.93 Segments/s]
# Aligning BXuRRbG0Ugk:  74%|███████▍  | 419/566 [00:01<00:00, 344.88 Segments/s]
# Aligning BXuRRbG0Ugk:  83%|████████▎ | 470/566 [00:01<00:00, 389.02 Segments/s]
# Aligning BXuRRbG0Ugk:  90%|█████████ | 511/566 [00:01<00:00, 386.17 Segments/s]
# Aligning BXuRRbG0Ugk:  97%|█████████▋| 551/566 [00:01<00:00, 352.66 Segments/s]
# Overall Progress:  23%|██▎       | 21/93 [00:29<01:42,  1.43s/ Computational Sequence Entries]
#   0%|          | 0/282 [00:00<?, ? Segments/s]
# Aligning Bfr499ggo-0:   0%|          | 0/282 [00:00<?, ? Segments/s]
# Aligning Bfr499ggo-0:  12%|█▏        | 35/282 [00:00<00:00, 343.49 Segments/s]
# Aligning Bfr499ggo-0:  34%|███▍      | 97/282 [00:00<00:00, 502.69 Segments/s]
# Aligning Bfr499ggo-0:  56%|█████▌    | 158/282 [00:00<00:00, 549.28 Segments/s]
# Aligning Bfr499ggo-0:  76%|███████▌  | 213/282 [00:00<00:00, 521.69 Segments/s]
# Aligning Bfr499ggo-0:  94%|█████████▍| 266/282 [00:00<00:00, 441.59 Segments/s]
# Overall Progress:  24%|██▎       | 22/93 [00:29<01:24,  1.19s/ Computational Sequence Entries]
#   0%|          | 0/659 [00:00<?, ? Segments/s]
# Aligning BioHAh1qJAQ:   0%|          | 0/659 [00:00<?, ? Segments/s]
# Aligning BioHAh1qJAQ:   6%|▌         | 41/659 [00:00<00:01, 405.52 Segments/s]
# Aligning BioHAh1qJAQ:  15%|█▌        | 100/659 [00:00<00:01, 507.79 Segments/s]
# Aligning BioHAh1qJAQ:  23%|██▎       | 151/659 [00:00<00:01, 449.43 Segments/s]
# Aligning BioHAh1qJAQ:  30%|██▉       | 197/659 [00:00<00:01, 425.23 Segments/s]
# Aligning BioHAh1qJAQ:  36%|███▋      | 240/659 [00:00<00:01, 349.73 Segments/s]
# Aligning BioHAh1qJAQ:  42%|████▏     | 277/659 [00:00<00:01, 319.62 Segments/s]
# Aligning BioHAh1qJAQ:  49%|████▉     | 325/659 [00:00<00:00, 361.16 Segments/s]
# Aligning BioHAh1qJAQ:  60%|█████▉    | 394/659 [00:00<00:00, 450.48 Segments/s]
# Aligning BioHAh1qJAQ:  67%|██████▋   | 442/659 [00:01<00:00, 424.14 Segments/s]
# Aligning BioHAh1qJAQ:  74%|███████▍  | 487/659 [00:01<00:00, 358.37 Segments/s]
# Aligning BioHAh1qJAQ:  80%|███████▉  | 526/659 [00:01<00:00, 330.24 Segments/s]
# Aligning BioHAh1qJAQ:  85%|████████▌ | 562/659 [00:01<00:00, 304.38 Segments/s]
# Aligning BioHAh1qJAQ:  93%|█████████▎| 611/659 [00:01<00:00, 347.12 Segments/s]
# Overall Progress:  25%|██▍       | 23/93 [00:31<01:34,  1.36s/ Computational Sequence Entries]
#   0%|          | 0/695 [00:00<?, ? Segments/s]
# Aligning BvYR0L6f2Ig:   0%|          | 0/695 [00:00<?, ? Segments/s]
# Aligning BvYR0L6f2Ig:   4%|▍         | 28/695 [00:00<00:02, 278.50 Segments/s]
# Aligning BvYR0L6f2Ig:   9%|▉         | 62/695 [00:00<00:02, 312.23 Segments/s]
# Aligning BvYR0L6f2Ig:  14%|█▎        | 94/695 [00:00<00:01, 314.36 Segments/s]
# Aligning BvYR0L6f2Ig:  18%|█▊        | 127/695 [00:00<00:01, 319.58 Segments/s]
# Aligning BvYR0L6f2Ig:  26%|██▌       | 178/695 [00:00<00:01, 386.64 Segments/s]
# Aligning BvYR0L6f2Ig:  34%|███▍      | 238/695 [00:00<00:00, 458.70 Segments/s]
# Aligning BvYR0L6f2Ig:  41%|████      | 284/695 [00:00<00:01, 393.66 Segments/s]
# Aligning BvYR0L6f2Ig:  47%|████▋     | 325/695 [00:00<00:01, 343.85 Segments/s]
# Aligning BvYR0L6f2Ig:  52%|█████▏    | 362/695 [00:01<00:01, 326.97 Segments/s]
# Aligning BvYR0L6f2Ig:  57%|█████▋    | 396/695 [00:01<00:00, 323.85 Segments/s]
# Aligning BvYR0L6f2Ig:  65%|██████▌   | 454/695 [00:01<00:00, 390.43 Segments/s]
# Aligning BvYR0L6f2Ig:  72%|███████▏  | 502/695 [00:01<00:00, 412.15 Segments/s]
# Aligning BvYR0L6f2Ig:  78%|███████▊  | 545/695 [00:01<00:00, 378.52 Segments/s]
# Aligning BvYR0L6f2Ig:  84%|████████▍ | 585/695 [00:01<00:00, 350.03 Segments/s]
# Aligning BvYR0L6f2Ig:  89%|████████▉ | 622/695 [00:01<00:00, 325.55 Segments/s]
# Aligning BvYR0L6f2Ig:  98%|█████████▊| 681/695 [00:01<00:00, 391.32 Segments/s]
# Overall Progress:  26%|██▌       | 24/93 [00:33<01:44,  1.52s/ Computational Sequence Entries]
#   0%|          | 0/777 [00:00<?, ? Segments/s]
# Aligning Ci-AH39fi3Y:   0%|          | 0/777 [00:00<?, ? Segments/s]
# Aligning Ci-AH39fi3Y:   8%|▊         | 63/777 [00:00<00:01, 622.13 Segments/s]
# Aligning Ci-AH39fi3Y:  16%|█▌        | 126/777 [00:00<00:01, 556.98 Segments/s]
# Aligning Ci-AH39fi3Y:  24%|██▎       | 183/777 [00:00<00:01, 503.19 Segments/s]
# Aligning Ci-AH39fi3Y:  30%|███       | 234/777 [00:00<00:01, 429.79 Segments/s]
# Aligning Ci-AH39fi3Y:  36%|███▌      | 279/777 [00:00<00:01, 384.45 Segments/s]
# Aligning Ci-AH39fi3Y:  41%|████      | 319/777 [00:00<00:01, 345.97 Segments/s]
# Aligning Ci-AH39fi3Y:  46%|████▌     | 355/777 [00:00<00:01, 320.93 Segments/s]
# Aligning Ci-AH39fi3Y:  50%|████▉     | 388/777 [00:01<00:01, 322.18 Segments/s]
# Aligning Ci-AH39fi3Y:  54%|█████▍    | 421/777 [00:01<00:01, 312.19 Segments/s]
# Aligning Ci-AH39fi3Y:  58%|█████▊    | 454/777 [00:01<00:01, 316.31 Segments/s]
# Aligning Ci-AH39fi3Y:  63%|██████▎   | 486/777 [00:01<00:00, 309.70 Segments/s]
# Aligning Ci-AH39fi3Y:  70%|██████▉   | 541/777 [00:01<00:00, 374.74 Segments/s]
# Aligning Ci-AH39fi3Y:  79%|███████▉  | 612/777 [00:01<00:00, 468.16 Segments/s]
# Aligning Ci-AH39fi3Y:  86%|████████▌ | 665/777 [00:01<00:00, 484.16 Segments/s]
# Aligning Ci-AH39fi3Y:  92%|█████████▏| 715/777 [00:01<00:00, 468.42 Segments/s]
# Aligning Ci-AH39fi3Y:  98%|█████████▊| 763/777 [00:01<00:00, 404.54 Segments/s]
# Overall Progress:  27%|██▋       | 25/93 [00:35<01:52,  1.66s/ Computational Sequence Entries]
#   0%|          | 0/590 [00:00<?, ? Segments/s]
# Aligning Clx4VXItLTE:   0%|          | 0/590 [00:00<?, ? Segments/s]
# Aligning Clx4VXItLTE:   5%|▌         | 32/590 [00:00<00:01, 310.48 Segments/s]
# Aligning Clx4VXItLTE:  11%|█         | 64/590 [00:00<00:01, 284.49 Segments/s]
# Aligning Clx4VXItLTE:  20%|█▉        | 116/590 [00:00<00:01, 383.45 Segments/s]
# Aligning Clx4VXItLTE:  30%|██▉       | 176/590 [00:00<00:00, 464.39 Segments/s]
# Aligning Clx4VXItLTE:  38%|███▊      | 224/590 [00:00<00:00, 403.74 Segments/s]
# Aligning Clx4VXItLTE:  45%|████▌     | 266/590 [00:00<00:00, 393.56 Segments/s]
# Aligning Clx4VXItLTE:  52%|█████▏    | 307/590 [00:00<00:00, 331.25 Segments/s]
# Aligning Clx4VXItLTE:  59%|█████▊    | 346/590 [00:00<00:00, 345.96 Segments/s]
# Aligning Clx4VXItLTE:  70%|███████   | 415/590 [00:01<00:00, 438.20 Segments/s]
# Aligning Clx4VXItLTE:  78%|███████▊  | 462/590 [00:01<00:00, 442.11 Segments/s]
# Aligning Clx4VXItLTE:  86%|████████▋ | 509/590 [00:01<00:00, 395.06 Segments/s]
# Aligning Clx4VXItLTE:  93%|█████████▎| 551/590 [00:01<00:00, 349.16 Segments/s]
# Aligning Clx4VXItLTE: 100%|█████████▉| 589/590 [00:01<00:00, 342.65 Segments/s]
# Overall Progress:  28%|██▊       | 26/93 [00:37<01:49,  1.64s/ Computational Sequence Entries]
#   0%|          | 0/411 [00:00<?, ? Segments/s]
# Aligning Dg_0XKD0Mf4:   0%|          | 0/411 [00:00<?, ? Segments/s]
# Aligning Dg_0XKD0Mf4:  16%|█▌        | 66/411 [00:00<00:00, 658.44 Segments/s]
# Aligning Dg_0XKD0Mf4:  33%|███▎      | 136/411 [00:00<00:00, 679.76 Segments/s]
# Aligning Dg_0XKD0Mf4:  50%|████▉     | 204/411 [00:00<00:00, 463.51 Segments/s]
# Aligning Dg_0XKD0Mf4:  63%|██████▎   | 257/411 [00:00<00:00, 421.14 Segments/s]
# Aligning Dg_0XKD0Mf4:  74%|███████▎  | 303/411 [00:00<00:00, 392.13 Segments/s]
# Aligning Dg_0XKD0Mf4:  84%|████████▍ | 345/411 [00:00<00:00, 388.53 Segments/s]
# Aligning Dg_0XKD0Mf4:  96%|█████████▋| 396/411 [00:00<00:00, 421.00 Segments/s]
# Overall Progress:  29%|██▉       | 27/93 [00:38<01:34,  1.43s/ Computational Sequence Entries]
#   0%|          | 0/559 [00:00<?, ? Segments/s]
# Aligning G-xst2euQUc:   0%|          | 0/559 [00:00<?, ? Segments/s]
# Aligning G-xst2euQUc:  12%|█▏        | 67/559 [00:00<00:00, 665.46 Segments/s]
# Aligning G-xst2euQUc:  24%|██▍       | 134/559 [00:00<00:01, 420.35 Segments/s]
# Aligning G-xst2euQUc:  33%|███▎      | 182/559 [00:00<00:01, 360.20 Segments/s]
# Aligning G-xst2euQUc:  40%|███▉      | 221/559 [00:00<00:01, 319.49 Segments/s]
# Aligning G-xst2euQUc:  49%|████▉     | 273/559 [00:00<00:00, 370.64 Segments/s]
# Aligning G-xst2euQUc:  62%|██████▏   | 346/559 [00:00<00:00, 465.71 Segments/s]
# Aligning G-xst2euQUc:  72%|███████▏  | 400/559 [00:00<00:00, 485.58 Segments/s]
# Aligning G-xst2euQUc:  81%|████████  | 452/559 [00:01<00:00, 424.63 Segments/s]
# Aligning G-xst2euQUc:  89%|████████▉ | 498/559 [00:01<00:00, 351.10 Segments/s]
# Aligning G-xst2euQUc:  96%|█████████▌| 537/559 [00:01<00:00, 341.72 Segments/s]
# Overall Progress:  30%|███       | 28/93 [00:39<01:34,  1.45s/ Computational Sequence Entries]
#   0%|          | 0/763 [00:00<?, ? Segments/s]
# Aligning G6GlGvlkxAQ:   0%|          | 0/763 [00:00<?, ? Segments/s]
# Aligning G6GlGvlkxAQ:   6%|▌         | 47/763 [00:00<00:01, 461.66 Segments/s]
# Aligning G6GlGvlkxAQ:  14%|█▍        | 110/763 [00:00<00:01, 559.01 Segments/s]
# Aligning G6GlGvlkxAQ:  22%|██▏       | 166/763 [00:00<00:01, 435.35 Segments/s]
# Aligning G6GlGvlkxAQ:  28%|██▊       | 213/763 [00:00<00:01, 380.14 Segments/s]
# Aligning G6GlGvlkxAQ:  33%|███▎      | 254/763 [00:00<00:01, 373.82 Segments/s]
# Aligning G6GlGvlkxAQ:  40%|████      | 306/763 [00:00<00:01, 414.44 Segments/s]
# Aligning G6GlGvlkxAQ:  48%|████▊     | 363/763 [00:00<00:00, 456.44 Segments/s]
# Aligning G6GlGvlkxAQ:  54%|█████▍    | 411/763 [00:01<00:00, 387.80 Segments/s]
# Aligning G6GlGvlkxAQ:  59%|█████▉    | 453/763 [00:01<00:00, 369.07 Segments/s]
# Aligning G6GlGvlkxAQ:  64%|██████▍   | 492/763 [00:01<00:00, 337.90 Segments/s]
# Aligning G6GlGvlkxAQ:  70%|██████▉   | 534/763 [00:01<00:00, 357.54 Segments/s]
# Aligning G6GlGvlkxAQ:  78%|███████▊  | 597/763 [00:01<00:00, 428.02 Segments/s]
# Aligning G6GlGvlkxAQ:  85%|████████▍ | 645/763 [00:01<00:00, 442.09 Segments/s]
# Aligning G6GlGvlkxAQ:  91%|█████████ | 691/763 [00:01<00:00, 393.37 Segments/s]
# Aligning G6GlGvlkxAQ:  96%|█████████▌| 733/763 [00:01<00:00, 378.72 Segments/s]
# Overall Progress:  31%|███       | 29/93 [00:41<01:42,  1.60s/ Computational Sequence Entries]
#   0%|          | 0/417 [00:00<?, ? Segments/s]
# Aligning GWuJjcEuzt8:   0%|          | 0/417 [00:00<?, ? Segments/s]
# Aligning GWuJjcEuzt8:   6%|▋         | 27/417 [00:00<00:01, 264.17 Segments/s]
# Aligning GWuJjcEuzt8:  22%|██▏       | 92/417 [00:00<00:00, 487.00 Segments/s]
# Aligning GWuJjcEuzt8:  37%|███▋      | 155/417 [00:00<00:00, 550.16 Segments/s]
# Aligning GWuJjcEuzt8:  51%|█████     | 211/417 [00:00<00:00, 487.17 Segments/s]
# Aligning GWuJjcEuzt8:  63%|██████▎   | 261/417 [00:00<00:00, 395.12 Segments/s]
# Aligning GWuJjcEuzt8:  73%|███████▎  | 304/417 [00:00<00:00, 365.05 Segments/s]
# Aligning GWuJjcEuzt8:  83%|████████▎ | 346/417 [00:00<00:00, 377.90 Segments/s]
# Aligning GWuJjcEuzt8:  97%|█████████▋| 404/417 [00:00<00:00, 432.62 Segments/s]
# Overall Progress:  32%|███▏      | 30/93 [00:42<01:29,  1.41s/ Computational Sequence Entries]
#   0%|          | 0/622 [00:00<?, ? Segments/s]
# Aligning HEsqda8_d0Q:   0%|          | 0/622 [00:00<?, ? Segments/s]
# Aligning HEsqda8_d0Q:   8%|▊         | 49/622 [00:00<00:01, 484.30 Segments/s]
# Aligning HEsqda8_d0Q:  18%|█▊        | 112/622 [00:00<00:00, 569.29 Segments/s]
# Aligning HEsqda8_d0Q:  27%|██▋       | 169/622 [00:00<00:00, 530.50 Segments/s]
# Aligning HEsqda8_d0Q:  36%|███▌      | 225/622 [00:00<00:00, 538.37 Segments/s]
# Aligning HEsqda8_d0Q:  45%|████▌     | 280/622 [00:00<00:00, 527.01 Segments/s]
# Aligning HEsqda8_d0Q:  54%|█████▎    | 333/622 [00:00<00:00, 522.38 Segments/s]
# Aligning HEsqda8_d0Q:  63%|██████▎   | 393/622 [00:00<00:00, 543.30 Segments/s]
# Aligning HEsqda8_d0Q:  72%|███████▏  | 448/622 [00:00<00:00, 540.68 Segments/s]
# Aligning HEsqda8_d0Q:  81%|████████  | 503/622 [00:00<00:00, 525.64 Segments/s]
# Aligning HEsqda8_d0Q:  89%|████████▉ | 556/622 [00:01<00:00, 490.18 Segments/s]
# Aligning HEsqda8_d0Q:  99%|█████████▊| 613/622 [00:01<00:00, 511.82 Segments/s]
# Overall Progress:  33%|███▎      | 31/93 [00:43<01:23,  1.35s/ Computational Sequence Entries]
#   0%|          | 0/640 [00:00<?, ? Segments/s]
# Aligning I5y0__X72p0:   0%|          | 0/640 [00:00<?, ? Segments/s]
# Aligning I5y0__X72p0:  12%|█▏        | 75/640 [00:00<00:00, 744.17 Segments/s]
# Aligning I5y0__X72p0:  23%|██▎       | 150/640 [00:00<00:00, 685.18 Segments/s]
# Aligning I5y0__X72p0:  36%|███▋      | 232/640 [00:00<00:00, 741.26 Segments/s]
# Aligning I5y0__X72p0:  49%|████▉     | 314/640 [00:00<00:00, 766.36 Segments/s]
# Aligning I5y0__X72p0:  62%|██████▏   | 394/640 [00:00<00:00, 775.88 Segments/s]
# Aligning I5y0__X72p0:  74%|███████▍  | 476/640 [00:00<00:00, 789.74 Segments/s]
# Aligning I5y0__X72p0:  87%|████████▋ | 556/640 [00:00<00:00, 792.94 Segments/s]
# Aligning I5y0__X72p0:  99%|█████████▉| 636/640 [00:00<00:00, 792.63 Segments/s]
# Overall Progress:  34%|███▍      | 32/93 [00:44<01:12,  1.20s/ Computational Sequence Entries]
#   0%|          | 0/316 [00:00<?, ? Segments/s]
# Aligning Iu2PFX3z_1s:   0%|          | 0/316 [00:00<?, ? Segments/s]
# Aligning Iu2PFX3z_1s:  32%|███▏      | 100/316 [00:00<00:00, 988.45 Segments/s]
# Aligning Iu2PFX3z_1s:  63%|██████▎   | 199/316 [00:00<00:00, 957.95 Segments/s]
# Aligning Iu2PFX3z_1s:  93%|█████████▎| 295/316 [00:00<00:00, 950.08 Segments/s]
# Overall Progress:  35%|███▌      | 33/93 [00:44<00:56,  1.07 Computational Sequence Entries/s]
#   0%|          | 0/450 [00:00<?, ? Segments/s]
# Aligning IumbAb8q2dM:   0%|          | 0/450 [00:00<?, ? Segments/s]
# Aligning IumbAb8q2dM:  20%|██        | 91/450 [00:00<00:00, 905.95 Segments/s]
# Aligning IumbAb8q2dM:  40%|████      | 182/450 [00:00<00:00, 900.18 Segments/s]
# Aligning IumbAb8q2dM:  61%|██████    | 273/450 [00:00<00:00, 889.48 Segments/s]
# Aligning IumbAb8q2dM:  80%|████████  | 362/450 [00:00<00:00, 872.81 Segments/s]
# Overall Progress:  37%|███▋      | 34/93 [00:45<00:47,  1.23 Computational Sequence Entries/s]
#   0%|          | 0/219 [00:00<?, ? Segments/s]
# Aligning Jkswaaud0hk:   0%|          | 0/219 [00:00<?, ? Segments/s]
# Aligning Jkswaaud0hk:  50%|█████     | 110/219 [00:00<00:00, 1094.43 Segments/s]
# Overall Progress:  38%|███▊      | 35/93 [00:45<00:36,  1.59 Computational Sequence Entries/s]
#   0%|          | 0/735 [00:00<?, ? Segments/s]
# Aligning LSi-o-IrDMs:   0%|          | 0/735 [00:00<?, ? Segments/s]
# Aligning LSi-o-IrDMs:  11%|█         | 81/735 [00:00<00:00, 806.07 Segments/s]
# Aligning LSi-o-IrDMs:  22%|██▏       | 162/735 [00:00<00:00, 807.75 Segments/s]
# Aligning LSi-o-IrDMs:  33%|███▎      | 243/735 [00:00<00:00, 801.72 Segments/s]
# Aligning LSi-o-IrDMs:  44%|████▍     | 325/735 [00:00<00:00, 806.91 Segments/s]
# Aligning LSi-o-IrDMs:  56%|█████▌    | 408/735 [00:00<00:00, 812.35 Segments/s]
# Aligning LSi-o-IrDMs:  67%|██████▋   | 490/735 [00:00<00:00, 811.28 Segments/s]
# Aligning LSi-o-IrDMs:  78%|███████▊  | 572/735 [00:00<00:00, 807.76 Segments/s]
# Aligning LSi-o-IrDMs:  89%|████████▉ | 653/735 [00:00<00:00, 808.17 Segments/s]
# Aligning LSi-o-IrDMs: 100%|█████████▉| 734/735 [00:00<00:00, 807.63 Segments/s]
# Overall Progress:  39%|███▊      | 36/93 [00:46<00:40,  1.40 Computational Sequence Entries/s]
#   0%|          | 0/385 [00:00<?, ? Segments/s]
# Aligning MLal-t_vJPM:   0%|          | 0/385 [00:00<?, ? Segments/s]
# Aligning MLal-t_vJPM:  25%|██▌       | 98/385 [00:00<00:00, 972.50 Segments/s]
# Aligning MLal-t_vJPM:  51%|█████     | 196/385 [00:00<00:00, 964.12 Segments/s]
# Aligning MLal-t_vJPM:  76%|███████▌  | 293/385 [00:00<00:00, 936.98 Segments/s]
# Overall Progress:  40%|███▉      | 37/93 [00:46<00:34,  1.60 Computational Sequence Entries/s]
#   0%|          | 0/266 [00:00<?, ? Segments/s]
# Aligning Njd1F0vZSm4:   0%|          | 0/266 [00:00<?, ? Segments/s]
# Aligning Njd1F0vZSm4:  38%|███▊      | 102/266 [00:00<00:00, 1013.17 Segments/s]
# Aligning Njd1F0vZSm4:  77%|███████▋  | 204/266 [00:00<00:00, 1011.21 Segments/s]
# Overall Progress:  41%|████      | 38/93 [00:47<00:28,  1.93 Computational Sequence Entries/s]
#   0%|          | 0/621 [00:00<?, ? Segments/s]
# Aligning Nzq88NnDkEk:   0%|          | 0/621 [00:00<?, ? Segments/s]
# Aligning Nzq88NnDkEk:  13%|█▎        | 82/621 [00:00<00:00, 814.58 Segments/s]
# Aligning Nzq88NnDkEk:  26%|██▋       | 164/621 [00:00<00:00, 814.22 Segments/s]
# Aligning Nzq88NnDkEk:  40%|███▉      | 247/621 [00:00<00:00, 817.33 Segments/s]
# Aligning Nzq88NnDkEk:  53%|█████▎    | 332/621 [00:00<00:00, 827.94 Segments/s]
# Aligning Nzq88NnDkEk:  67%|██████▋   | 415/621 [00:00<00:00, 827.15 Segments/s]
# Aligning Nzq88NnDkEk:  80%|████████  | 499/621 [00:00<00:00, 828.75 Segments/s]
# Aligning Nzq88NnDkEk:  94%|█████████▎| 582/621 [00:00<00:00, 819.21 Segments/s]
# Overall Progress:  42%|████▏     | 39/93 [00:48<00:31,  1.69 Computational Sequence Entries/s]
#   0%|          | 0/311 [00:00<?, ? Segments/s]
# Aligning OQvJTdtJ2H4:   0%|          | 0/311 [00:00<?, ? Segments/s]
# Aligning OQvJTdtJ2H4:  32%|███▏      | 99/311 [00:00<00:00, 980.78 Segments/s]
# Aligning OQvJTdtJ2H4:  64%|██████▎   | 198/311 [00:00<00:00, 977.63 Segments/s]
# Aligning OQvJTdtJ2H4:  95%|█████████▌| 296/311 [00:00<00:00, 948.52 Segments/s]
# Overall Progress:  43%|████▎     | 40/93 [00:48<00:27,  1.95 Computational Sequence Entries/s]
#   0%|          | 0/597 [00:00<?, ? Segments/s]
# Aligning OtBXNcAL_lE:   0%|          | 0/597 [00:00<?, ? Segments/s]
# Aligning OtBXNcAL_lE:  14%|█▎        | 82/597 [00:00<00:00, 813.73 Segments/s]
# Aligning OtBXNcAL_lE:  27%|██▋       | 164/597 [00:00<00:00, 800.79 Segments/s]
# Aligning OtBXNcAL_lE:  41%|████      | 245/597 [00:00<00:00, 795.57 Segments/s]
# Aligning OtBXNcAL_lE:  55%|█████▍    | 327/597 [00:00<00:00, 802.24 Segments/s]
# Aligning OtBXNcAL_lE:  68%|██████▊   | 408/597 [00:00<00:00, 723.21 Segments/s]
# Aligning OtBXNcAL_lE:  82%|████████▏ | 490/597 [00:00<00:00, 751.85 Segments/s]
# Aligning OtBXNcAL_lE:  95%|█████████▍| 567/597 [00:00<00:00, 745.80 Segments/s]
# Overall Progress:  44%|████▍     | 41/93 [00:49<00:31,  1.68 Computational Sequence Entries/s]
#   0%|          | 0/740 [00:00<?, ? Segments/s]
# Aligning Oz06ZWiO20M:   0%|          | 0/740 [00:00<?, ? Segments/s]
# Aligning Oz06ZWiO20M:  11%|█         | 78/740 [00:00<00:00, 779.79 Segments/s]
# Aligning Oz06ZWiO20M:  21%|██        | 157/740 [00:00<00:00, 783.24 Segments/s]
# Aligning Oz06ZWiO20M:  32%|███▏      | 236/740 [00:00<00:00, 775.38 Segments/s]
# Aligning Oz06ZWiO20M:  42%|████▏     | 314/740 [00:00<00:00, 775.85 Segments/s]
# Aligning Oz06ZWiO20M:  53%|█████▎    | 392/740 [00:00<00:00, 757.72 Segments/s]
# Aligning Oz06ZWiO20M:  64%|██████▍   | 473/740 [00:00<00:00, 772.55 Segments/s]
# Aligning Oz06ZWiO20M:  74%|███████▍  | 551/740 [00:00<00:00, 756.82 Segments/s]
# Aligning Oz06ZWiO20M:  85%|████████▍ | 627/740 [00:00<00:00, 700.88 Segments/s]
# Aligning Oz06ZWiO20M:  94%|█████████▍| 698/740 [00:00<00:00, 635.45 Segments/s]
# Overall Progress:  45%|████▌     | 42/93 [00:50<00:37,  1.36 Computational Sequence Entries/s]
#   0%|          | 0/395 [00:00<?, ? Segments/s]
# Aligning POKffnXeBds:   0%|          | 0/395 [00:00<?, ? Segments/s]
# Aligning POKffnXeBds:  19%|█▉        | 76/395 [00:00<00:00, 744.96 Segments/s]
# Aligning POKffnXeBds:  39%|███▉      | 154/395 [00:00<00:00, 763.38 Segments/s]
# Aligning POKffnXeBds:  59%|█████▉    | 233/395 [00:00<00:00, 774.58 Segments/s]
# Aligning POKffnXeBds:  81%|████████▏ | 321/395 [00:00<00:00, 815.68 Segments/s]
# Overall Progress:  46%|████▌     | 43/93 [00:50<00:32,  1.52 Computational Sequence Entries/s]
#   0%|          | 0/385 [00:00<?, ? Segments/s]
# Aligning PZ-lDQFboO8:   0%|          | 0/385 [00:00<?, ? Segments/s]
# Aligning PZ-lDQFboO8:  25%|██▌       | 98/385 [00:00<00:00, 977.79 Segments/s]
# Aligning PZ-lDQFboO8:  51%|█████     | 196/385 [00:00<00:00, 976.16 Segments/s]
# Aligning PZ-lDQFboO8:  76%|███████▋  | 294/385 [00:00<00:00, 959.20 Segments/s]
# Overall Progress:  47%|████▋     | 44/93 [00:51<00:28,  1.72 Computational Sequence Entries/s]
#   0%|          | 0/663 [00:00<?, ? Segments/s]
# Aligning QN9ZIUWUXsY:   0%|          | 0/663 [00:00<?, ? Segments/s]
# Aligning QN9ZIUWUXsY:  12%|█▏        | 78/663 [00:00<00:00, 778.34 Segments/s]
# Aligning QN9ZIUWUXsY:  24%|██▎       | 156/663 [00:00<00:00, 725.83 Segments/s]
# Aligning QN9ZIUWUXsY:  35%|███▍      | 229/663 [00:00<00:00, 685.82 Segments/s]
# Aligning QN9ZIUWUXsY:  47%|████▋     | 310/663 [00:00<00:00, 731.73 Segments/s]
# Aligning QN9ZIUWUXsY:  59%|█████▉    | 391/663 [00:00<00:00, 758.86 Segments/s]
# Aligning QN9ZIUWUXsY:  71%|███████   | 472/663 [00:00<00:00, 772.38 Segments/s]
# Aligning QN9ZIUWUXsY:  83%|████████▎ | 552/663 [00:00<00:00, 780.12 Segments/s]
# Aligning QN9ZIUWUXsY:  95%|█████████▌| 631/663 [00:00<00:00, 782.02 Segments/s]
# Overall Progress:  48%|████▊     | 45/93 [00:51<00:32,  1.49 Computational Sequence Entries/s]
#   0%|          | 0/484 [00:00<?, ? Segments/s]
# Aligning Qr1Ca94K55A:   0%|          | 0/484 [00:00<?, ? Segments/s]
# Aligning Qr1Ca94K55A:  19%|█▊        | 90/484 [00:00<00:00, 897.72 Segments/s]
# Aligning Qr1Ca94K55A:  37%|███▋      | 180/484 [00:00<00:00, 875.08 Segments/s]
# Aligning Qr1Ca94K55A:  56%|█████▌    | 270/484 [00:00<00:00, 884.81 Segments/s]
# Aligning Qr1Ca94K55A:  74%|███████▍  | 360/484 [00:00<00:00, 890.23 Segments/s]
# Aligning Qr1Ca94K55A:  93%|█████████▎| 450/484 [00:00<00:00, 883.61 Segments/s]
# Overall Progress:  49%|████▉     | 46/93 [00:52<00:29,  1.57 Computational Sequence Entries/s]
#   0%|          | 0/706 [00:00<?, ? Segments/s]
# Aligning Sqr0AcuoNnk:   0%|          | 0/706 [00:00<?, ? Segments/s]
# Aligning Sqr0AcuoNnk:  11%|█▏        | 80/706 [00:00<00:00, 793.65 Segments/s]
# Aligning Sqr0AcuoNnk:  23%|██▎       | 160/706 [00:00<00:00, 785.76 Segments/s]
# Aligning Sqr0AcuoNnk:  34%|███▍      | 239/706 [00:00<00:00, 773.02 Segments/s]
# Aligning Sqr0AcuoNnk:  45%|████▌     | 320/706 [00:00<00:00, 784.06 Segments/s]
# Aligning Sqr0AcuoNnk:  57%|█████▋    | 399/706 [00:00<00:00, 779.25 Segments/s]
# Aligning Sqr0AcuoNnk:  68%|██████▊   | 480/706 [00:00<00:00, 787.39 Segments/s]
# Aligning Sqr0AcuoNnk:  79%|███████▉  | 560/706 [00:00<00:00, 790.68 Segments/s]
# Aligning Sqr0AcuoNnk:  91%|█████████ | 641/706 [00:00<00:00, 794.70 Segments/s]
# Overall Progress:  51%|█████     | 47/93 [00:53<00:32,  1.40 Computational Sequence Entries/s]
#   0%|          | 0/317 [00:00<?, ? Segments/s]
# Aligning TvyZBvOMOTc:   0%|          | 0/317 [00:00<?, ? Segments/s]
# Aligning TvyZBvOMOTc:  32%|███▏      | 101/317 [00:00<00:00, 1002.25 Segments/s]
# Aligning TvyZBvOMOTc:  64%|██████▎   | 202/317 [00:00<00:00, 1006.74 Segments/s]
# Aligning TvyZBvOMOTc:  96%|█████████▌| 304/317 [00:00<00:00, 1011.79 Segments/s]
# Overall Progress:  52%|█████▏    | 48/93 [00:53<00:26,  1.67 Computational Sequence Entries/s]
#   0%|          | 0/611 [00:00<?, ? Segments/s]
# Aligning VCslbP0mgZI:   0%|          | 0/611 [00:00<?, ? Segments/s]
# Aligning VCslbP0mgZI:  12%|█▏        | 75/611 [00:00<00:00, 747.29 Segments/s]
# Aligning VCslbP0mgZI:  25%|██▌       | 155/611 [00:00<00:00, 770.03 Segments/s]
# Aligning VCslbP0mgZI:  38%|███▊      | 235/611 [00:00<00:00, 779.95 Segments/s]
# Aligning VCslbP0mgZI:  52%|█████▏    | 317/611 [00:00<00:00, 790.28 Segments/s]
# Aligning VCslbP0mgZI:  65%|██████▍   | 397/611 [00:00<00:00, 783.57 Segments/s]
# Aligning VCslbP0mgZI:  78%|███████▊  | 476/611 [00:00<00:00, 781.25 Segments/s]
# Aligning VCslbP0mgZI:  91%|█████████ | 555/611 [00:00<00:00, 783.56 Segments/s]
# Overall Progress:  53%|█████▎    | 49/93 [00:54<00:28,  1.53 Computational Sequence Entries/s]
#   0%|          | 0/751 [00:00<?, ? Segments/s]
# Aligning VbQk4H8hgr0:   0%|          | 0/751 [00:00<?, ? Segments/s]
# Aligning VbQk4H8hgr0:  11%|█         | 80/751 [00:00<00:00, 789.64 Segments/s]
# Aligning VbQk4H8hgr0:  21%|██▏       | 160/751 [00:00<00:00, 791.06 Segments/s]
# Aligning VbQk4H8hgr0:  32%|███▏      | 240/751 [00:00<00:00, 783.43 Segments/s]
# Aligning VbQk4H8hgr0:  42%|████▏     | 319/751 [00:00<00:00, 754.32 Segments/s]
# Aligning VbQk4H8hgr0:  53%|█████▎    | 395/751 [00:00<00:00, 741.45 Segments/s]
# Aligning VbQk4H8hgr0:  63%|██████▎   | 470/751 [00:00<00:00, 737.12 Segments/s]
# Aligning VbQk4H8hgr0:  72%|███████▏  | 544/751 [00:00<00:00, 732.91 Segments/s]
# Aligning VbQk4H8hgr0:  82%|████████▏ | 618/751 [00:00<00:00, 732.30 Segments/s]
# Aligning VbQk4H8hgr0:  92%|█████████▏| 692/751 [00:00<00:00, 730.69 Segments/s]
# Overall Progress:  54%|█████▍    | 50/93 [00:55<00:32,  1.31 Computational Sequence Entries/s]
#   0%|          | 0/622 [00:00<?, ? Segments/s]
# Aligning Vj1wYRQjB-o:   0%|          | 0/622 [00:00<?, ? Segments/s]
# Aligning Vj1wYRQjB-o:  11%|█▏        | 70/622 [00:00<00:00, 698.54 Segments/s]
# Aligning Vj1wYRQjB-o:  24%|██▎       | 147/622 [00:00<00:00, 737.51 Segments/s]
# Aligning Vj1wYRQjB-o:  36%|███▌      | 221/622 [00:00<00:00, 736.09 Segments/s]
# Aligning Vj1wYRQjB-o:  47%|████▋     | 295/622 [00:00<00:00, 724.22 Segments/s]
# Aligning Vj1wYRQjB-o:  59%|█████▉    | 369/622 [00:00<00:00, 728.85 Segments/s]
# Aligning Vj1wYRQjB-o:  71%|███████   | 443/622 [00:00<00:00, 728.08 Segments/s]
# Aligning Vj1wYRQjB-o:  83%|████████▎ | 519/622 [00:00<00:00, 735.08 Segments/s]
# Aligning Vj1wYRQjB-o:  95%|█████████▌| 593/622 [00:00<00:00, 721.33 Segments/s]
# Overall Progress:  55%|█████▍    | 51/93 [00:56<00:33,  1.26 Computational Sequence Entries/s]
#   0%|          | 0/612 [00:00<?, ? Segments/s]
# Aligning W8NXH0Djyww:   0%|          | 0/612 [00:00<?, ? Segments/s]
# Aligning W8NXH0Djyww:  12%|█▏        | 71/612 [00:00<00:00, 704.11 Segments/s]
# ...
# Aligning k5Y_838nuGo:  62%|██████▏   | 386/623 [00:00<00:00, 761.29 Segments/s]
# Aligning k5Y_838nuGo:  74%|███████▍  | 464/623 [00:00<00:00, 766.92 Segments/s]
# Aligning k5Y_838nuGo:  87%|████████▋ | 541/623 [00:00<00:00, 762.79 Segments/s]
# Aligning k5Y_838nuGo:  99%|█████████▉| 618/623 [00:00<00:00, 739.92 Segments/s]
# Overall Progress:  82%|████████▏ | 76/93 [01:13<00:12,  1.39 Computational Sequence Entries/s]
#   0%|          | 0/655 [00:00<?, ? Segments/s]
# Aligning lXPQBPVc5Cw:   0%|          | 0/655 [00:00<?, ? Segments/s]
# Aligning lXPQBPVc5Cw:  12%|█▏        | 78/655 [00:00<00:00, 773.85 Segments/s]
# Aligning lXPQBPVc5Cw:  24%|██▍       | 156/655 [00:00<00:00, 746.87 Segments/s]
# Aligning lXPQBPVc5Cw:  36%|███▌      | 236/655 [00:00<00:00, 764.69 Segments/s]
# Aligning lXPQBPVc5Cw:  48%|████▊     | 313/655 [00:00<00:00, 741.81 Segments/s]
# Aligning lXPQBPVc5Cw:  60%|█████▉    | 391/655 [00:00<00:00, 752.56 Segments/s]
# Aligning lXPQBPVc5Cw:  72%|███████▏  | 469/655 [00:00<00:00, 759.49 Segments/s]
# Aligning lXPQBPVc5Cw:  83%|████████▎ | 546/655 [00:00<00:00, 753.34 Segments/s]
# Aligning lXPQBPVc5Cw:  95%|█████████▌| 623/655 [00:00<00:00, 757.91 Segments/s]
# Overall Progress:  83%|████████▎ | 77/93 [01:14<00:12,  1.30 Computational Sequence Entries/s]
#   0%|          | 0/593 [00:00<?, ? Segments/s]
# Aligning nbWiPyCm4g0:   0%|          | 0/593 [00:00<?, ? Segments/s]
# Aligning nbWiPyCm4g0:  12%|█▏        | 71/593 [00:00<00:00, 700.61 Segments/s]
# Aligning nbWiPyCm4g0:  25%|██▌       | 149/593 [00:00<00:00, 745.08 Segments/s]
# Aligning nbWiPyCm4g0:  38%|███▊      | 227/593 [00:00<00:00, 759.13 Segments/s]
# Aligning nbWiPyCm4g0:  51%|█████     | 303/593 [00:00<00:00, 744.52 Segments/s]
# Aligning nbWiPyCm4g0:  65%|██████▍   | 383/593 [00:00<00:00, 762.06 Segments/s]
# Aligning nbWiPyCm4g0:  78%|███████▊  | 460/593 [00:00<00:00, 761.57 Segments/s]
# Aligning nbWiPyCm4g0:  91%|█████████ | 537/593 [00:00<00:00, 759.61 Segments/s]
# Overall Progress:  84%|████████▍ | 78/93 [01:15<00:11,  1.29 Computational Sequence Entries/s]
#   0%|          | 0/574 [00:00<?, ? Segments/s]
# Aligning nzpVDcQ0ywM:   0%|          | 0/574 [00:00<?, ? Segments/s]
# Aligning nzpVDcQ0ywM:  14%|█▎        | 78/574 [00:00<00:00, 773.78 Segments/s]
# Aligning nzpVDcQ0ywM:  27%|██▋       | 156/574 [00:00<00:00, 771.20 Segments/s]
# Aligning nzpVDcQ0ywM:  41%|████      | 234/574 [00:00<00:00, 770.89 Segments/s]
# Aligning nzpVDcQ0ywM:  54%|█████▍    | 312/574 [00:00<00:00, 773.79 Segments/s]
# Aligning nzpVDcQ0ywM:  68%|██████▊   | 390/574 [00:00<00:00, 767.49 Segments/s]
# Aligning nzpVDcQ0ywM:  81%|████████▏ | 467/574 [00:00<00:00, 767.43 Segments/s]
# Aligning nzpVDcQ0ywM:  95%|█████████▌| 546/574 [00:00<00:00, 771.46 Segments/s]
# Overall Progress:  85%|████████▍ | 79/93 [01:16<00:10,  1.30 Computational Sequence Entries/s]
#   0%|          | 0/413 [00:00<?, ? Segments/s]
# Aligning ob23OKe5a9Q:   0%|          | 0/413 [00:00<?, ? Segments/s]
# Aligning ob23OKe5a9Q:  21%|██        | 85/413 [00:00<00:00, 842.72 Segments/s]
# Aligning ob23OKe5a9Q:  41%|████▏     | 171/413 [00:00<00:00, 852.24 Segments/s]
# Aligning ob23OKe5a9Q:  62%|██████▏   | 257/413 [00:00<00:00, 828.88 Segments/s]
# Aligning ob23OKe5a9Q:  83%|████████▎ | 341/413 [00:00<00:00, 830.00 Segments/s]
# Overall Progress:  86%|████████▌ | 80/93 [01:16<00:09,  1.44 Computational Sequence Entries/s]
#   0%|          | 0/489 [00:00<?, ? Segments/s]
# Aligning pLTX3ipuDJI:   0%|          | 0/489 [00:00<?, ? Segments/s]
# Aligning pLTX3ipuDJI:  17%|█▋        | 83/489 [00:00<00:00, 829.89 Segments/s]
# Aligning pLTX3ipuDJI:  35%|███▍      | 170/489 [00:00<00:00, 853.29 Segments/s]
# Aligning pLTX3ipuDJI:  52%|█████▏    | 256/489 [00:00<00:00, 744.97 Segments/s]
# Aligning pLTX3ipuDJI:  71%|███████   | 345/489 [00:00<00:00, 796.14 Segments/s]
# Aligning pLTX3ipuDJI:  89%|████████▉ | 434/489 [00:00<00:00, 825.47 Segments/s]
# Overall Progress:  87%|████████▋ | 81/93 [01:17<00:07,  1.50 Computational Sequence Entries/s]
#   0%|          | 0/720 [00:00<?, ? Segments/s]
# Aligning phBUpBr1hSo:   0%|          | 0/720 [00:00<?, ? Segments/s]
# Aligning phBUpBr1hSo:  11%|█         | 77/720 [00:00<00:00, 764.37 Segments/s]
# Aligning phBUpBr1hSo:  21%|██▏       | 154/720 [00:00<00:00, 749.83 Segments/s]
# Aligning phBUpBr1hSo:  32%|███▏      | 233/720 [00:00<00:00, 762.79 Segments/s]
# Aligning phBUpBr1hSo:  43%|████▎     | 310/720 [00:00<00:00, 765.09 Segments/s]
# Aligning phBUpBr1hSo:  54%|█████▍    | 387/720 [00:00<00:00, 762.54 Segments/s]
# Aligning phBUpBr1hSo:  64%|██████▍   | 464/720 [00:00<00:00, 753.65 Segments/s]
# Aligning phBUpBr1hSo:  75%|███████▌  | 540/720 [00:00<00:00, 708.89 Segments/s]
# Aligning phBUpBr1hSo:  85%|████████▌ | 613/720 [00:00<00:00, 713.80 Segments/s]
# Aligning phBUpBr1hSo:  96%|█████████▌| 689/720 [00:00<00:00, 725.34 Segments/s]
# Overall Progress:  88%|████████▊ | 82/93 [01:18<00:08,  1.32 Computational Sequence Entries/s]
#   0%|          | 0/701 [00:00<?, ? Segments/s]
# Aligning rnaNMUZpvvg:   0%|          | 0/701 [00:00<?, ? Segments/s]
# Aligning rnaNMUZpvvg:  11%|█         | 74/701 [00:00<00:00, 736.95 Segments/s]
# Aligning rnaNMUZpvvg:  21%|██        | 148/701 [00:00<00:00, 675.17 Segments/s]
# Aligning rnaNMUZpvvg:  32%|███▏      | 224/701 [00:00<00:00, 709.48 Segments/s]
# Aligning rnaNMUZpvvg:  43%|████▎     | 304/701 [00:00<00:00, 741.90 Segments/s]
# Aligning rnaNMUZpvvg:  54%|█████▍    | 379/701 [00:00<00:00, 742.38 Segments/s]
# Aligning rnaNMUZpvvg:  65%|██████▍   | 454/701 [00:00<00:00, 742.70 Segments/s]
# Aligning rnaNMUZpvvg:  75%|███████▌  | 529/701 [00:00<00:00, 743.62 Segments/s]
# Aligning rnaNMUZpvvg:  86%|████████▌ | 604/701 [00:00<00:00, 742.28 Segments/s]
# Aligning rnaNMUZpvvg:  97%|█████████▋| 679/701 [00:00<00:00, 736.75 Segments/s]
# Overall Progress:  89%|████████▉ | 83/93 [01:19<00:08,  1.22 Computational Sequence Entries/s]
#   0%|          | 0/589 [00:00<?, ? Segments/s]
# Aligning tIrG4oNLFzE:   0%|          | 0/589 [00:00<?, ? Segments/s]
# Aligning tIrG4oNLFzE:  13%|█▎        | 74/589 [00:00<00:00, 733.07 Segments/s]
# Aligning tIrG4oNLFzE:  25%|██▌       | 150/589 [00:00<00:00, 744.77 Segments/s]
# Aligning tIrG4oNLFzE:  39%|███▊      | 227/589 [00:00<00:00, 752.21 Segments/s]
# Aligning tIrG4oNLFzE:  52%|█████▏    | 305/589 [00:00<00:00, 759.86 Segments/s]
# Aligning tIrG4oNLFzE:  65%|██████▍   | 381/589 [00:00<00:00, 754.24 Segments/s]
# Aligning tIrG4oNLFzE:  78%|███████▊  | 458/589 [00:00<00:00, 757.28 Segments/s]
# Aligning tIrG4oNLFzE:  91%|█████████ | 536/589 [00:00<00:00, 763.09 Segments/s]
# Overall Progress:  90%|█████████ | 84/93 [01:19<00:07,  1.23 Computational Sequence Entries/s]
#   0%|          | 0/429 [00:00<?, ? Segments/s]
# Aligning tStelxIAHjw:   0%|          | 0/429 [00:00<?, ? Segments/s]
# Aligning tStelxIAHjw:  15%|█▌        | 66/429 [00:00<00:00, 658.10 Segments/s]
# Aligning tStelxIAHjw:  35%|███▌      | 151/429 [00:00<00:00, 766.43 Segments/s]
# Aligning tStelxIAHjw:  54%|█████▍    | 231/429 [00:00<00:00, 781.65 Segments/s]
# Aligning tStelxIAHjw:  74%|███████▍  | 317/429 [00:00<00:00, 812.29 Segments/s]
# Aligning tStelxIAHjw:  94%|█████████▍| 403/429 [00:00<00:00, 829.32 Segments/s]
# Overall Progress:  91%|█████████▏| 85/93 [01:20<00:05,  1.37 Computational Sequence Entries/s]
#   0%|          | 0/376 [00:00<?, ? Segments/s]
# Aligning tmZoasNr4rU:   0%|          | 0/376 [00:00<?, ? Segments/s]
# Aligning tmZoasNr4rU:  21%|██        | 78/376 [00:00<00:00, 772.55 Segments/s]
# Aligning tmZoasNr4rU:  41%|████▏     | 156/376 [00:00<00:00, 770.03 Segments/s]
# Aligning tmZoasNr4rU:  63%|██████▎   | 236/376 [00:00<00:00, 781.70 Segments/s]
# Aligning tmZoasNr4rU:  84%|████████▍ | 315/376 [00:00<00:00, 782.28 Segments/s]
# Overall Progress:  92%|█████████▏| 86/93 [01:21<00:04,  1.52 Computational Sequence Entries/s]
#   0%|          | 0/470 [00:00<?, ? Segments/s]
# Aligning v0zCBqDeKcE:   0%|          | 0/470 [00:00<?, ? Segments/s]
# Aligning v0zCBqDeKcE:  14%|█▍        | 67/470 [00:00<00:00, 660.19 Segments/s]
# Aligning v0zCBqDeKcE:  30%|███       | 141/470 [00:00<00:00, 703.70 Segments/s]
# Aligning v0zCBqDeKcE:  47%|████▋     | 221/470 [00:00<00:00, 738.85 Segments/s]
# Aligning v0zCBqDeKcE:  63%|██████▎   | 297/470 [00:00<00:00, 745.05 Segments/s]
# Aligning v0zCBqDeKcE:  79%|███████▉  | 372/470 [00:00<00:00, 742.93 Segments/s]
# Aligning v0zCBqDeKcE:  96%|█████████▌| 452/470 [00:00<00:00, 760.69 Segments/s]
# Overall Progress:  94%|█████████▎| 87/93 [01:21<00:03,  1.53 Computational Sequence Entries/s]
#   0%|          | 0/610 [00:00<?, ? Segments/s]
# Aligning vvZ4IcEtiZc:   0%|          | 0/610 [00:00<?, ? Segments/s]
# Aligning vvZ4IcEtiZc:  12%|█▏        | 75/610 [00:00<00:00, 735.80 Segments/s]
# Aligning vvZ4IcEtiZc:  25%|██▍       | 152/610 [00:00<00:00, 753.52 Segments/s]
# Aligning vvZ4IcEtiZc:  37%|███▋      | 228/610 [00:00<00:00, 748.08 Segments/s]
# Aligning vvZ4IcEtiZc:  50%|█████     | 307/610 [00:00<00:00, 762.01 Segments/s]
# Aligning vvZ4IcEtiZc:  63%|██████▎   | 384/610 [00:00<00:00, 764.24 Segments/s]
# Aligning vvZ4IcEtiZc:  76%|███████▌  | 461/610 [00:00<00:00, 764.24 Segments/s]
# Aligning vvZ4IcEtiZc:  88%|████████▊ | 539/610 [00:00<00:00, 767.99 Segments/s]
# Overall Progress:  95%|█████████▍| 88/93 [01:22<00:03,  1.43 Computational Sequence Entries/s]
#   0%|          | 0/589 [00:00<?, ? Segments/s]
# Aligning vyB00TXsimI:   0%|          | 0/589 [00:00<?, ? Segments/s]
# Aligning vyB00TXsimI:  11%|█         | 65/589 [00:00<00:00, 640.53 Segments/s]
# Aligning vyB00TXsimI:  22%|██▏       | 130/589 [00:00<00:00, 593.68 Segments/s]
# Aligning vyB00TXsimI:  33%|███▎      | 192/589 [00:00<00:00, 602.67 Segments/s]
# Aligning vyB00TXsimI:  44%|████▍     | 260/589 [00:00<00:00, 629.31 Segments/s]
# Aligning vyB00TXsimI:  58%|█████▊    | 339/589 [00:00<00:00, 683.01 Segments/s]
# Aligning vyB00TXsimI:  70%|██████▉   | 412/589 [00:00<00:00, 698.66 Segments/s]
# Aligning vyB00TXsimI:  83%|████████▎ | 487/589 [00:00<00:00, 711.30 Segments/s]
# Aligning vyB00TXsimI:  95%|█████████▌| 562/589 [00:00<00:00, 722.90 Segments/s]
# Overall Progress:  96%|█████████▌| 89/93 [01:23<00:03,  1.33 Computational Sequence Entries/s]
#   0%|          | 0/690 [00:00<?, ? Segments/s]
# Aligning wMbj6ajWbic:   0%|          | 0/690 [00:00<?, ? Segments/s]
# Aligning wMbj6ajWbic:  11%|█▏        | 78/690 [00:00<00:00, 768.82 Segments/s]
# Aligning wMbj6ajWbic:  22%|██▏       | 155/690 [00:00<00:00, 755.58 Segments/s]
# Aligning wMbj6ajWbic:  33%|███▎      | 231/690 [00:00<00:00, 749.94 Segments/s]
# Aligning wMbj6ajWbic:  44%|████▍     | 307/690 [00:00<00:00, 753.57 Segments/s]
# Aligning wMbj6ajWbic:  56%|█████▌    | 383/690 [00:00<00:00, 739.47 Segments/s]
# Aligning wMbj6ajWbic:  66%|██████▌   | 457/690 [00:00<00:00, 735.27 Segments/s]
# Aligning wMbj6ajWbic:  77%|███████▋  | 531/690 [00:00<00:00, 729.39 Segments/s]
# Aligning wMbj6ajWbic:  88%|████████▊ | 610/690 [00:00<00:00, 744.53 Segments/s]
# Aligning wMbj6ajWbic: 100%|█████████▉| 687/690 [00:00<00:00, 748.73 Segments/s]
# Overall Progress:  97%|█████████▋| 90/93 [01:24<00:02,  1.24 Computational Sequence Entries/s]
#   0%|          | 0/581 [00:00<?, ? Segments/s]
# Aligning yDtzw_Y-7RU:   0%|          | 0/581 [00:00<?, ? Segments/s]
# Aligning yDtzw_Y-7RU:  14%|█▍        | 80/581 [00:00<00:00, 796.44 Segments/s]
# Aligning yDtzw_Y-7RU:  28%|██▊       | 160/581 [00:00<00:00, 762.45 Segments/s]
# Aligning yDtzw_Y-7RU:  41%|████      | 238/581 [00:00<00:00, 767.52 Segments/s]
# Aligning yDtzw_Y-7RU:  54%|█████▍    | 315/581 [00:00<00:00, 767.50 Segments/s]
# Aligning yDtzw_Y-7RU:  67%|██████▋   | 392/581 [00:00<00:00, 761.05 Segments/s]
# Aligning yDtzw_Y-7RU:  81%|████████  | 469/581 [00:00<00:00, 755.37 Segments/s]
# Aligning yDtzw_Y-7RU:  94%|█████████▍| 545/581 [00:00<00:00, 744.85 Segments/s]
# Overall Progress:  98%|█████████▊| 91/93 [01:25<00:01,  1.25 Computational Sequence Entries/s]
#   0%|          | 0/616 [00:00<?, ? Segments/s]
# Aligning yvsjCA6Y5Fc:   0%|          | 0/616 [00:00<?, ? Segments/s]
# Aligning yvsjCA6Y5Fc:  12%|█▏        | 75/616 [00:00<00:00, 745.10 Segments/s]
# Aligning yvsjCA6Y5Fc:  25%|██▍       | 151/616 [00:00<00:00, 749.56 Segments/s]
# Aligning yvsjCA6Y5Fc:  37%|███▋      | 230/616 [00:00<00:00, 763.77 Segments/s]
# Aligning yvsjCA6Y5Fc:  50%|████▉     | 307/616 [00:00<00:00, 750.68 Segments/s]
# Aligning yvsjCA6Y5Fc:  62%|██████▏   | 384/616 [00:00<00:00, 757.05 Segments/s]
# Aligning yvsjCA6Y5Fc:  75%|███████▌  | 463/616 [00:00<00:00, 765.86 Segments/s]
# Aligning yvsjCA6Y5Fc:  88%|████████▊ | 540/616 [00:00<00:00, 762.06 Segments/s]
# Overall Progress:  99%|█████████▉| 92/93 [01:25<00:00,  1.24 Computational Sequence Entries/s]
#   0%|          | 0/676 [00:00<?, ? Segments/s]
# Aligning zhpQhgha_KU:   0%|          | 0/676 [00:00<?, ? Segments/s]
# Aligning zhpQhgha_KU:  11%|█▏        | 77/676 [00:00<00:00, 769.80 Segments/s]
# Aligning zhpQhgha_KU:  23%|██▎       | 154/676 [00:00<00:00, 753.22 Segments/s]
# Aligning zhpQhgha_KU:  34%|███▍      | 230/676 [00:00<00:00, 753.31 Segments/s]
# Aligning zhpQhgha_KU:  46%|████▌     | 310/676 [00:00<00:00, 767.94 Segments/s]
# Aligning zhpQhgha_KU:  57%|█████▋    | 387/676 [00:00<00:00, 726.43 Segments/s]
# Aligning zhpQhgha_KU:  68%|██████▊   | 460/676 [00:00<00:00, 723.98 Segments/s]
# Aligning zhpQhgha_KU:  79%|███████▉  | 537/676 [00:00<00:00, 737.55 Segments/s]
# Aligning zhpQhgha_KU:  91%|█████████ | 613/676 [00:00<00:00, 743.45 Segments/s]
# [2024-12-04 11:09:47.272] | Success | Alignment to <CMU_MOSI_TimestampedWords> complete.
# [2024-12-04 11:09:47.272] | Status  | Replacing dataset content with aligned computational sequences
# [2024-12-04 11:09:47.278] | Success | Initialized empty <CMU_MOSI_TimestampedWords> computational sequence.
# [2024-12-04 11:09:47.278] | Status  | Checking the format of the data in <CMU_MOSI_TimestampedWords> computational sequence ...
# [2024-12-04 11:09:47.352] | Success | <CMU_MOSI_TimestampedWords> computational sequence data in correct format.
# [2024-12-04 11:09:47.352] | Status  | Checking the format of the metadata in <CMU_MOSI_TimestampedWords> computational sequence ...
# [2024-12-04 11:09:47.352] | Warning | <CMU_MOSI_TimestampedWords> computational sequence does not have all the required metadata ... continuing
# [2024-12-04 11:09:47.352] | Success | Initialized empty <CMU_MOSI_TimestampedWordVectors> computational sequence.
# [2024-12-04 11:09:47.352] | Status  | Checking the format of the data in <CMU_MOSI_TimestampedWordVectors> computational sequence ...
# [2024-12-04 11:09:47.421] | Success | <CMU_MOSI_TimestampedWordVectors> computational sequence data in correct format.
# [2024-12-04 11:09:47.421] | Status  | Checking the format of the metadata in <CMU_MOSI_TimestampedWordVectors> computational sequence ...
# [2024-12-04 11:09:47.421] | Warning | <CMU_MOSI_TimestampedWordVectors> computational sequence does not have all the required metadata ... continuing
# [2024-12-04 11:09:47.421] | Success | Initialized empty <CMU_MOSI_Visual_Facet_41> computational sequence.
# [2024-12-04 11:09:47.421] | Status  | Checking the format of the data in <CMU_MOSI_Visual_Facet_41> computational sequence ...
# [2024-12-04 11:09:47.500] | Success | <CMU_MOSI_Visual_Facet_41> computational sequence data in correct format.
# [2024-12-04 11:09:47.500] | Status  | Checking the format of the metadata in <CMU_MOSI_Visual_Facet_41> computational sequence ...
# [2024-12-04 11:09:47.500] | Warning | <CMU_MOSI_Visual_Facet_41> computational sequence does not have all the required metadata ... continuing
# [2024-12-04 11:09:47.500] | Success | Initialized empty <CMU_MOSI_COVAREP> computational sequence.
# [2024-12-04 11:09:47.500] | Status  | Checking the format of the data in <CMU_MOSI_COVAREP> computational sequence ...
# [2024-12-04 11:09:47.581] | Success | <CMU_MOSI_COVAREP> computational sequence data in correct format.
# [2024-12-04 11:09:47.581] | Status  | Checking the format of the metadata in <CMU_MOSI_COVAREP> computational sequence ...
# [2024-12-04 11:09:47.581] | Warning | <CMU_MOSI_COVAREP> computational sequence does not have all the required metadata ... continuing

# %%
label_field = 'CMU_MOSI_Opinion_Labels'

# we add and align to lables to obtain labeled segments
# this time we don't apply collapse functions so that the temporal sequences are preserved
label_recipe = {label_field: os.path.join(DATA_PATH, "http__immortal.multicomp.cs.cmu.edu", "CMU-MOSI", "labels", label_field) + '.csd'}
dataset.add_computational_sequences(label_recipe, destination=None)
dataset.align(label_field)
# Out:
# [2024-12-04 11:09:47.636] | Success | Computational sequence read from file C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu\CMU-MOSI\labels\CMU_MOSI_Opinion_Labels.csd ...
# [2024-12-04 11:09:47.642] | Status  | Checking the integrity of the <Opinion Segment Labels> computational sequence ...
# [2024-12-04 11:09:47.642] | Status  | Checking the format of the data in <Opinion Segment Labels> computational sequence ...
# [2024-12-04 11:09:47.682] | Success | <Opinion Segment Labels> computational sequence data in correct format.
# [2024-12-04 11:09:47.682] | Status  | Checking the format of the metadata in <Opinion Segment Labels> computational sequence ...
# [2024-12-04 11:09:47.682] | Warning | <Opinion Segment Labels> computational sequence does not have all the required metadata ... continuing
# [2024-12-04 11:09:47.682] | Status  | Unify was called ...
# [2024-12-04 11:09:47.804] | Success | Unify completed ...
# [2024-12-04 11:09:47.807] | Status  | Pre-alignment based on <CMU_MOSI_Opinion_Labels> computational sequence started ...
# [2024-12-04 11:09:47.935] | Status  | Pre-alignment done for <CMU_MOSI_TimestampedWords> ...
# [2024-12-04 11:09:48.192] | Status  | Pre-alignment done for <CMU_MOSI_TimestampedWordVectors> ...
# [2024-12-04 11:09:48.345] | Status  | Pre-alignment done for <CMU_MOSI_COVAREP> ...
# [2024-12-04 11:09:48.484] | Status  | Pre-alignment done for <CMU_MOSI_Visual_Facet_41> ...
# [2024-12-04 11:09:48.490] | Status  | Alignment starting ...
# Overall Progress:   0%|          | 0/93 [00:00<?, ? Computational Sequence Entries/s]
#   0%|          | 0/13 [00:00<?, ? Segments/s]
# Aligning 03bSnISJMiM:   0%|          | 0/13 [00:00<?, ? Segments/s]
#
#   0%|          | 0/25 [00:00<?, ? Segments/s]
# Aligning 0h-zjBukYpk:   0%|          | 0/25 [00:00<?, ? Segments/s]
#
#   0%|          | 0/14 [00:00<?, ? Segments/s]
# Aligning 1DmNV9C1hbY:   0%|          | 0/14 [00:00<?, ? Segments/s]
#
#   0%|          | 0/30 [00:00<?, ? Segments/s]
# Aligning 1iG0909rllw:   0%|          | 0/30 [00:00<?, ? Segments/s]
#
#   0%|          | 0/63 [00:00<?, ? Segments/s]
# Aligning 2WGyTLYerpo:   0%|          | 0/63 [00:00<?, ? Segments/s]
# Overall Progress:   5%|▌         | 5/93 [00:00<00:02, 32.69 Computational Sequence Entries/s]
#   0%|          | 0/30 [00:00<?, ? Segments/s]
# Aligning 2iD-tVS8NPw:   0%|          | 0/30 [00:00<?, ? Segments/s]
#
#   0%|          | 0/24 [00:00<?, ? Segments/s]
# Aligning 5W7Z1C_fDaE:   0%|          | 0/24 [00:00<?, ? Segments/s]
#
#   0%|          | 0/12 [00:00<?, ? Segments/s]
# Aligning 6Egk_28TtTM:   0%|          | 0/12 [00:00<?, ? Segments/s]
#
#   0%|          | 0/14 [00:00<?, ? Segments/s]
# Aligning 6_0THN4chvY:   0%|          | 0/14 [00:00<?, ? Segments/s]
#
#   0%|          | 0/19 [00:00<?, ? Segments/s]
# Aligning 73jzhE8R1TQ:   0%|          | 0/19 [00:00<?, ? Segments/s]
# Overall Progress:  11%|█         | 10/93 [00:00<00:02, 38.39 Computational Sequence Entries/s]
#   0%|          | 0/39 [00:00<?, ? Segments/s]
# Aligning 7JsX8y1ysxY:   0%|          | 0/39 [00:00<?, ? Segments/s]
#
#   0%|          | 0/23 [00:00<?, ? Segments/s]
# Aligning 8OtFthrtaJM:   0%|          | 0/23 [00:00<?, ? Segments/s]
#
#   0%|          | 0/30 [00:00<?, ? Segments/s]
# Aligning 8d-gEyoeBzc:   0%|          | 0/30 [00:00<?, ? Segments/s]
#
#   0%|          | 0/26 [00:00<?, ? Segments/s]
# Aligning 8qrpnFRGt2A:   0%|          | 0/26 [00:00<?, ? Segments/s]
# Overall Progress:  15%|█▌        | 14/93 [00:00<00:02, 37.08 Computational Sequence Entries/s]
#   0%|          | 0/25 [00:00<?, ? Segments/s]
# Aligning 9J25DZhivz8:   0%|          | 0/25 [00:00<?, ? Segments/s]
#
#   0%|          | 0/25 [00:00<?, ? Segments/s]
# Aligning 9T9Hf74oK10:   0%|          | 0/25 [00:00<?, ? Segments/s]
#
#   0%|          | 0/12 [00:00<?, ? Segments/s]
# Aligning 9c67fiY0wGQ:   0%|          | 0/12 [00:00<?, ? Segments/s]
#
#   0%|          | 0/33 [00:00<?, ? Segments/s]
# Aligning 9qR7uwkblbs:   0%|          | 0/33 [00:00<?, ? Segments/s]
# Overall Progress:  19%|█▉        | 18/93 [00:00<00:02, 37.09 Computational Sequence Entries/s]
#   0%|          | 0/31 [00:00<?, ? Segments/s]
# Aligning Af8D0E4ZXaw:   0%|          | 0/31 [00:00<?, ? Segments/s]
#
#   0%|          | 0/31 [00:00<?, ? Segments/s]
# Aligning BI97DNYfe5I:   0%|          | 0/31 [00:00<?, ? Segments/s]
#
#   0%|          | 0/31 [00:00<?, ? Segments/s]
# Aligning BXuRRbG0Ugk:   0%|          | 0/31 [00:00<?, ? Segments/s]
#
#   0%|          | 0/22 [00:00<?, ? Segments/s]
# Aligning Bfr499ggo-0:   0%|          | 0/22 [00:00<?, ? Segments/s]
# Overall Progress:  24%|██▎       | 22/93 [00:00<00:01, 36.75 Computational Sequence Entries/s]
#   0%|          | 0/30 [00:00<?, ? Segments/s]
# Aligning BioHAh1qJAQ:   0%|          | 0/30 [00:00<?, ? Segments/s]
#
#   0%|          | 0/26 [00:00<?, ? Segments/s]
# Aligning BvYR0L6f2Ig:   0%|          | 0/26 [00:00<?, ? Segments/s]
#
#   0%|          | 0/44 [00:00<?, ? Segments/s]
# Aligning Ci-AH39fi3Y:   0%|          | 0/44 [00:00<?, ? Segments/s]
#
#   0%|          | 0/31 [00:00<?, ? Segments/s]
# Aligning Clx4VXItLTE:   0%|          | 0/31 [00:00<?, ? Segments/s]
# Overall Progress:  28%|██▊       | 26/93 [00:00<00:01, 33.69 Computational Sequence Entries/s]
#   0%|          | 0/18 [00:00<?, ? Segments/s]
# Aligning Dg_0XKD0Mf4:   0%|          | 0/18 [00:00<?, ? Segments/s]
#
#   0%|          | 0/21 [00:00<?, ? Segments/s]
# Aligning G-xst2euQUc:   0%|          | 0/21 [00:00<?, ? Segments/s]
#
#   0%|          | 0/29 [00:00<?, ? Segments/s]
# Aligning G6GlGvlkxAQ:   0%|          | 0/29 [00:00<?, ? Segments/s]
#
#   0%|          | 0/18 [00:00<?, ? Segments/s]
# Aligning GWuJjcEuzt8:   0%|          | 0/18 [00:00<?, ? Segments/s]
# Overall Progress:  32%|███▏      | 30/93 [00:00<00:01, 35.19 Computational Sequence Entries/s]
#   0%|          | 0/34 [00:00<?, ? Segments/s]
# Aligning HEsqda8_d0Q:   0%|          | 0/34 [00:00<?, ? Segments/s]
#
#   0%|          | 0/39 [00:00<?, ? Segments/s]
# Aligning I5y0__X72p0:   0%|          | 0/39 [00:00<?, ? Segments/s]
#
#   0%|          | 0/16 [00:00<?, ? Segments/s]
# Aligning Iu2PFX3z_1s:   0%|          | 0/16 [00:00<?, ? Segments/s]
#
#   0%|          | 0/22 [00:00<?, ? Segments/s]
# Aligning IumbAb8q2dM:   0%|          | 0/22 [00:00<?, ? Segments/s]
# Overall Progress:  37%|███▋      | 34/93 [00:00<00:01, 34.84 Computational Sequence Entries/s]
#   0%|          | 0/20 [00:00<?, ? Segments/s]
# Aligning Jkswaaud0hk:   0%|          | 0/20 [00:00<?, ? Segments/s]
#
#   0%|          | 0/29 [00:00<?, ? Segments/s]
# Aligning LSi-o-IrDMs:   0%|          | 0/29 [00:00<?, ? Segments/s]
#
#   0%|          | 0/18 [00:00<?, ? Segments/s]
# Aligning MLal-t_vJPM:   0%|          | 0/18 [00:00<?, ? Segments/s]
#
#   0%|          | 0/13 [00:00<?, ? Segments/s]
# Aligning Njd1F0vZSm4:   0%|          | 0/13 [00:00<?, ? Segments/s]
#
#   0%|          | 0/32 [00:00<?, ? Segments/s]
# Aligning Nzq88NnDkEk:   0%|          | 0/32 [00:00<?, ? Segments/s]
# Overall Progress:  42%|████▏     | 39/93 [00:01<00:01, 37.35 Computational Sequence Entries/s]
#   0%|          | 0/16 [00:00<?, ? Segments/s]
# Aligning OQvJTdtJ2H4:   0%|          | 0/16 [00:00<?, ? Segments/s]
#
#   0%|          | 0/24 [00:00<?, ? Segments/s]
# Aligning OtBXNcAL_lE:   0%|          | 0/24 [00:00<?, ? Segments/s]
#
#   0%|          | 0/25 [00:00<?, ? Segments/s]
# Aligning Oz06ZWiO20M:   0%|          | 0/25 [00:00<?, ? Segments/s]
#
#   0%|          | 0/13 [00:00<?, ? Segments/s]
# Aligning POKffnXeBds:   0%|          | 0/13 [00:00<?, ? Segments/s]
#
#   0%|          | 0/12 [00:00<?, ? Segments/s]
# Aligning PZ-lDQFboO8:   0%|          | 0/12 [00:00<?, ? Segments/s]
# Overall Progress:  47%|████▋     | 44/93 [00:01<00:01, 39.10 Computational Sequence Entries/s]
#   0%|          | 0/18 [00:00<?, ? Segments/s]
# Aligning QN9ZIUWUXsY:   0%|          | 0/18 [00:00<?, ? Segments/s]
#
#   0%|          | 0/14 [00:00<?, ? Segments/s]
# Aligning Qr1Ca94K55A:   0%|          | 0/14 [00:00<?, ? Segments/s]
#
#   0%|          | 0/22 [00:00<?, ? Segments/s]
# Aligning Sqr0AcuoNnk:   0%|          | 0/22 [00:00<?, ? Segments/s]
#
#   0%|          | 0/15 [00:00<?, ? Segments/s]
# Aligning TvyZBvOMOTc:   0%|          | 0/15 [00:00<?, ? Segments/s]
#
#   0%|          | 0/17 [00:00<?, ? Segments/s]
# Aligning VCslbP0mgZI:   0%|          | 0/17 [00:00<?, ? Segments/s]
# Overall Progress:  53%|█████▎    | 49/93 [00:01<00:01, 41.90 Computational Sequence Entries/s]
#   0%|          | 0/55 [00:00<?, ? Segments/s]
# Aligning VbQk4H8hgr0:   0%|          | 0/55 [00:00<?, ? Segments/s]
#
#   0%|          | 0/9 [00:00<?, ? Segments/s]
# Aligning Vj1wYRQjB-o:   0%|          | 0/9 [00:00<?, ? Segments/s]
#
#   0%|          | 0/32 [00:00<?, ? Segments/s]
# Aligning W8NXH0Djyww:   0%|          | 0/32 [00:00<?, ? Segments/s]
#
#   0%|          | 0/22 [00:00<?, ? Segments/s]
# Aligning WKA5OygbEKI:   0%|          | 0/22 [00:00<?, ? Segments/s]
#
#   0%|          | 0/11 [00:00<?, ? Segments/s]
# Aligning X3j2zQgwYgE:   0%|          | 0/11 [00:00<?, ? Segments/s]
# Overall Progress:  58%|█████▊    | 54/93 [00:01<00:00, 39.87 Computational Sequence Entries/s]
#   0%|          | 0/9 [00:00<?, ? Segments/s]
# Aligning ZAIRrfG22O0:   0%|          | 0/9 [00:00<?, ? Segments/s]
#
#   0%|          | 0/34 [00:00<?, ? Segments/s]
# Aligning ZUXBRvtny7o:   0%|          | 0/34 [00:00<?, ? Segments/s]
#
#   0%|          | 0/28 [00:00<?, ? Segments/s]
# Aligning _dI--eQ6qVU:   0%|          | 0/28 [00:00<?, ? Segments/s]
#
#   0%|          | 0/30 [00:00<?, ? Segments/s]
# Aligning aiEXnCPZubE:   0%|          | 0/30 [00:00<?, ? Segments/s]
#
#   0%|          | 0/21 [00:00<?, ? Segments/s]
# Aligning atnd_PF-Lbs:   0%|          | 0/21 [00:00<?, ? Segments/s]
# Overall Progress:  63%|██████▎   | 59/93 [00:01<00:00, 40.10 Computational Sequence Entries/s]
#   0%|          | 0/34 [00:00<?, ? Segments/s]
# Aligning bOL9jKpeJRs:   0%|          | 0/34 [00:00<?, ? Segments/s]
#
#   0%|          | 0/25 [00:00<?, ? Segments/s]
# Aligning bvLlb-M3UXU:   0%|          | 0/25 [00:00<?, ? Segments/s]
#
#   0%|          | 0/15 [00:00<?, ? Segments/s]
# Aligning c5xsKMxpXnc:   0%|          | 0/15 [00:00<?, ? Segments/s]
#
#   0%|          | 0/33 [00:00<?, ? Segments/s]
# Aligning c7UH_rxdZv4:   0%|          | 0/33 [00:00<?, ? Segments/s]
#
#   0%|          | 0/16 [00:00<?, ? Segments/s]
# Aligning cM3Yna7AavY:   0%|          | 0/16 [00:00<?, ? Segments/s]
# Overall Progress:  69%|██████▉   | 64/93 [00:01<00:00, 38.15 Computational Sequence Entries/s]
#   0%|          | 0/24 [00:00<?, ? Segments/s]
# Aligning cW1FSBF59ik:   0%|          | 0/24 [00:00<?, ? Segments/s]
#
#   0%|          | 0/29 [00:00<?, ? Segments/s]
# Aligning cXypl4FnoZo:   0%|          | 0/29 [00:00<?, ? Segments/s]
#
#   0%|          | 0/19 [00:00<?, ? Segments/s]
# Aligning d3_k5Xpfmik:   0%|          | 0/19 [00:00<?, ? Segments/s]
#
#   0%|          | 0/43 [00:00<?, ? Segments/s]
# Aligning d6hH302o4v8:   0%|          | 0/43 [00:00<?, ? Segments/s]
# Overall Progress:  73%|███████▎  | 68/93 [00:01<00:00, 36.40 Computational Sequence Entries/s]
#   0%|          | 0/15 [00:00<?, ? Segments/s]
# Aligning dq3Nf_lMPnE:   0%|          | 0/15 [00:00<?, ? Segments/s]
#
#   0%|          | 0/19 [00:00<?, ? Segments/s]
# Aligning etzxEpPuc6I:   0%|          | 0/19 [00:00<?, ? Segments/s]
#
#   0%|          | 0/30 [00:00<?, ? Segments/s]
# Aligning f9O3YtZ2VfI:   0%|          | 0/30 [00:00<?, ? Segments/s]
#
#   0%|          | 0/15 [00:00<?, ? Segments/s]
# Aligning f_pcplsH_V0:   0%|          | 0/15 [00:00<?, ? Segments/s]
#
#   0%|          | 0/14 [00:00<?, ? Segments/s]
# Aligning fvVhgmXxadc:   0%|          | 0/14 [00:00<?, ? Segments/s]
# Overall Progress:  78%|███████▊  | 73/93 [00:01<00:00, 39.17 Computational Sequence Entries/s]
#   0%|          | 0/18 [00:00<?, ? Segments/s]
# Aligning iiK8YX8oH1E:   0%|          | 0/18 [00:00<?, ? Segments/s]
#
#   0%|          | 0/27 [00:00<?, ? Segments/s]
# Aligning jUzDDGyPkXU:   0%|          | 0/27 [00:00<?, ? Segments/s]
#
#   0%|          | 0/31 [00:00<?, ? Segments/s]
# Aligning k5Y_838nuGo:   0%|          | 0/31 [00:00<?, ? Segments/s]
#
#   0%|          | 0/30 [00:00<?, ? Segments/s]
# Aligning lXPQBPVc5Cw:   0%|          | 0/30 [00:00<?, ? Segments/s]
# Overall Progress:  83%|████████▎ | 77/93 [00:02<00:00, 37.20 Computational Sequence Entries/s]
#   0%|          | 0/10 [00:00<?, ? Segments/s]
# Aligning nbWiPyCm4g0:   0%|          | 0/10 [00:00<?, ? Segments/s]
#
#   0%|          | 0/24 [00:00<?, ? Segments/s]
# Aligning nzpVDcQ0ywM:   0%|          | 0/24 [00:00<?, ? Segments/s]
#
#   0%|          | 0/14 [00:00<?, ? Segments/s]
# Aligning ob23OKe5a9Q:   0%|          | 0/14 [00:00<?, ? Segments/s]
#
#   0%|          | 0/16 [00:00<?, ? Segments/s]
# Aligning pLTX3ipuDJI:   0%|          | 0/16 [00:00<?, ? Segments/s]
#
#   0%|          | 0/21 [00:00<?, ? Segments/s]
# Aligning phBUpBr1hSo:   0%|          | 0/21 [00:00<?, ? Segments/s]
# Overall Progress:  88%|████████▊ | 82/93 [00:02<00:00, 39.31 Computational Sequence Entries/s]
#   0%|          | 0/22 [00:00<?, ? Segments/s]
# Aligning rnaNMUZpvvg:   0%|          | 0/22 [00:00<?, ? Segments/s]
#
#   0%|          | 0/18 [00:00<?, ? Segments/s]
# Aligning tIrG4oNLFzE:   0%|          | 0/18 [00:00<?, ? Segments/s]
#
#   0%|          | 0/16 [00:00<?, ? Segments/s]
# Aligning tStelxIAHjw:   0%|          | 0/16 [00:00<?, ? Segments/s]
#
#   0%|          | 0/20 [00:00<?, ? Segments/s]
# Aligning tmZoasNr4rU:   0%|          | 0/20 [00:00<?, ? Segments/s]
#
#   0%|          | 0/16 [00:00<?, ? Segments/s]
# Aligning v0zCBqDeKcE:   0%|          | 0/16 [00:00<?, ? Segments/s]
# Overall Progress:  94%|█████████▎| 87/93 [00:02<00:00, 40.26 Computational Sequence Entries/s]
#   0%|          | 0/12 [00:00<?, ? Segments/s]
# Aligning vvZ4IcEtiZc:   0%|          | 0/12 [00:00<?, ? Segments/s]
#
#   0%|          | 0/22 [00:00<?, ? Segments/s]
# Aligning vyB00TXsimI:   0%|          | 0/22 [00:00<?, ? Segments/s]
#
#   0%|          | 0/30 [00:00<?, ? Segments/s]
# Aligning wMbj6ajWbic:   0%|          | 0/30 [00:00<?, ? Segments/s]
#
#   0%|          | 0/24 [00:00<?, ? Segments/s]
# Aligning yDtzw_Y-7RU:   0%|          | 0/24 [00:00<?, ? Segments/s]
#
#   0%|          | 0/23 [00:00<?, ? Segments/s]
# Aligning yvsjCA6Y5Fc:   0%|          | 0/23 [00:00<?, ? Segments/s]
# Overall Progress:  99%|█████████▉| 92/93 [00:02<00:00, 40.35 Computational Sequence Entries/s]
#   0%|          | 0/35 [00:00<?, ? Segments/s]
# Aligning zhpQhgha_KU:   0%|          | 0/35 [00:00<?, ? Segments/s]
# [2024-12-04 11:09:50.930] | Success | Alignment to <CMU_MOSI_Opinion_Labels> complete.
# [2024-12-04 11:09:50.931] | Status  | Replacing dataset content with aligned computational sequences
# [2024-12-04 11:09:51.081] | Success | Initialized empty <CMU_MOSI_TimestampedWords> computational sequence.
# [2024-12-04 11:09:51.081] | Status  | Checking the format of the data in <CMU_MOSI_TimestampedWords> computational sequence ...
# [2024-12-04 11:09:51.087] | Success | <CMU_MOSI_TimestampedWords> computational sequence data in correct format.
# [2024-12-04 11:09:51.087] | Status  | Checking the format of the metadata in <CMU_MOSI_TimestampedWords> computational sequence ...
# [2024-12-04 11:09:51.087] | Warning | <CMU_MOSI_TimestampedWords> computational sequence does not have all the required metadata ... continuing
# [2024-12-04 11:09:51.087] | Success | Initialized empty <CMU_MOSI_TimestampedWordVectors> computational sequence.
# [2024-12-04 11:09:51.087] | Status  | Checking the format of the data in <CMU_MOSI_TimestampedWordVectors> computational sequence ...
# [2024-12-04 11:09:51.093] | Success | <CMU_MOSI_TimestampedWordVectors> computational sequence data in correct format.
# [2024-12-04 11:09:51.093] | Status  | Checking the format of the metadata in <CMU_MOSI_TimestampedWordVectors> computational sequence ...
# [2024-12-04 11:09:51.093] | Warning | <CMU_MOSI_TimestampedWordVectors> computational sequence does not have all the required metadata ... continuing
# [2024-12-04 11:09:51.093] | Success | Initialized empty <CMU_MOSI_Visual_Facet_41> computational sequence.
# [2024-12-04 11:09:51.093] | Status  | Checking the format of the data in <CMU_MOSI_Visual_Facet_41> computational sequence ...
# [2024-12-04 11:09:51.098] | Success | <CMU_MOSI_Visual_Facet_41> computational sequence data in correct format.
# [2024-12-04 11:09:51.098] | Status  | Checking the format of the metadata in <CMU_MOSI_Visual_Facet_41> computational sequence ...
# [2024-12-04 11:09:51.098] | Warning | <CMU_MOSI_Visual_Facet_41> computational sequence does not have all the required metadata ... continuing
# [2024-12-04 11:09:51.098] | Success | Initialized empty <CMU_MOSI_COVAREP> computational sequence.
# [2024-12-04 11:09:51.098] | Status  | Checking the format of the data in <CMU_MOSI_COVAREP> computational sequence ...
# [2024-12-04 11:09:51.105] | Success | <CMU_MOSI_COVAREP> computational sequence data in correct format.
# [2024-12-04 11:09:51.105] | Status  | Checking the format of the metadata in <CMU_MOSI_COVAREP> computational sequence ...
# [2024-12-04 11:09:51.105] | Warning | <CMU_MOSI_COVAREP> computational sequence does not have all the required metadata ... continuing
# [2024-12-04 11:09:51.105] | Success | Initialized empty <CMU_MOSI_Opinion_Labels> computational sequence.
# [2024-12-04 11:09:51.105] | Status  | Checking the format of the data in <CMU_MOSI_Opinion_Labels> computational sequence ...
# [2024-12-04 11:09:51.112] | Success | <CMU_MOSI_Opinion_Labels> computational sequence data in correct format.
# [2024-12-04 11:09:51.112] | Status  | Checking the format of the metadata in <CMU_MOSI_Opinion_Labels> computational sequence ...
# [2024-12-04 11:09:51.112] | Warning | <CMU_MOSI_Opinion_Labels> computational sequence does not have all the required metadata ... continuing

# %%
num_segments = len(dataset[visual_field_Facet41].keys())  # Assuming all fields have the same segment keys
print(f"Number of segments: {num_segments}")
# Out:
# Number of segments: 2198

# %%
# Extract unique video IDs
video_ids = set(seg.split("[")[0] for seg in dataset[visual_field_Facet41].keys())

# Count the number of unique video IDs
num_unique_ids = len(video_ids)

# Count segments for each video ID
video_segment_counts = {video_id: sum(seg.startswith(video_id) for seg in dataset[visual_field_Facet41].keys()) for video_id in video_ids}

# Print the total number of unique video IDs
print(f"Total number of unique video IDs: {num_unique_ids}\n")

# Print the segment counts for each video ID
for video_id, count in video_segment_counts.items():
    print(f"Video {video_id}: {count} segments")
# Out:
# Total number of unique video IDs: 93
#
# Video G-xst2euQUc: 21 segments
# Video vyB00TXsimI: 22 segments
# Video Vj1wYRQjB-o: 9 segments
# Video atnd_PF-Lbs: 21 segments
# Video iiK8YX8oH1E: 18 segments
# Video cXypl4FnoZo: 29 segments
# Video LSi-o-IrDMs: 29 segments
# Video c5xsKMxpXnc: 15 segments
# Video 9c67fiY0wGQ: 12 segments
# Video Jkswaaud0hk: 20 segments
# Video 5W7Z1C_fDaE: 24 segments
# Video bvLlb-M3UXU: 25 segments
# Video v0zCBqDeKcE: 16 segments
# Video Qr1Ca94K55A: 14 segments
# Video Nzq88NnDkEk: 32 segments
# Video BioHAh1qJAQ: 30 segments
# Video QN9ZIUWUXsY: 18 segments
# Video IumbAb8q2dM: 22 segments
# Video 6_0THN4chvY: 14 segments
# Video BvYR0L6f2Ig: 26 segments
# Video OtBXNcAL_lE: 24 segments
# Video BI97DNYfe5I: 31 segments
# Video tIrG4oNLFzE: 18 segments
# Video 7JsX8y1ysxY: 39 segments
# Video 8OtFthrtaJM: 23 segments
# Video f9O3YtZ2VfI: 30 segments
# Video 8qrpnFRGt2A: 26 segments
# Video ZAIRrfG22O0: 9 segments
# Video 03bSnISJMiM: 13 segments
# Video GWuJjcEuzt8: 18 segments
# Video PZ-lDQFboO8: 12 segments
# Video Af8D0E4ZXaw: 31 segments
# Video nzpVDcQ0ywM: 24 segments
# Video f_pcplsH_V0: 15 segments
# Video k5Y_838nuGo: 31 segments
# Video lXPQBPVc5Cw: 30 segments
# Video nbWiPyCm4g0: 10 segments
# Video VCslbP0mgZI: 17 segments
# Video yDtzw_Y-7RU: 24 segments
# Video VbQk4H8hgr0: 55 segments
# Video 9qR7uwkblbs: 33 segments
# Video HEsqda8_d0Q: 34 segments
# Video tStelxIAHjw: 16 segments
# Video MLal-t_vJPM: 18 segments
# Video 1DmNV9C1hbY: 14 segments
# Video Sqr0AcuoNnk: 22 segments
# Video WKA5OygbEKI: 22 segments
# Video phBUpBr1hSo: 21 segments
# Video 6Egk_28TtTM: 12 segments
# Video 0h-zjBukYpk: 25 segments
# Video _dI--eQ6qVU: 28 segments
# Video dq3Nf_lMPnE: 15 segments
# Video c7UH_rxdZv4: 33 segments
# Video fvVhgmXxadc: 14 segments
# Video Ci-AH39fi3Y: 44 segments
# Video ob23OKe5a9Q: 14 segments
# Video etzxEpPuc6I: 19 segments
# Video yvsjCA6Y5Fc: 23 segments
# Video wMbj6ajWbic: 30 segments
# Video G6GlGvlkxAQ: 29 segments
# Video bOL9jKpeJRs: 34 segments
# Video 2iD-tVS8NPw: 30 segments
# Video BXuRRbG0Ugk: 31 segments
# Video vvZ4IcEtiZc: 12 segments
# Video I5y0__X72p0: 39 segments
# Video Clx4VXItLTE: 31 segments
# Video ZUXBRvtny7o: 34 segments
# Video d3_k5Xpfmik: 19 segments
# Video Oz06ZWiO20M: 25 segments
# Video 2WGyTLYerpo: 62 segments
# Video 8d-gEyoeBzc: 30 segments
# Video jUzDDGyPkXU: 27 segments
# Video cM3Yna7AavY: 16 segments
# Video X3j2zQgwYgE: 11 segments
# Video Njd1F0vZSm4: 13 segments
# Video aiEXnCPZubE: 30 segments
# Video cW1FSBF59ik: 24 segments
# Video 9J25DZhivz8: 25 segments
# Video rnaNMUZpvvg: 22 segments
# Video tmZoasNr4rU: 20 segments
# Video zhpQhgha_KU: 35 segments
# Video d6hH302o4v8: 43 segments
# Video Dg_0XKD0Mf4: 18 segments
# Video 1iG0909rllw: 30 segments
# Video 9T9Hf74oK10: 25 segments
# Video POKffnXeBds: 13 segments
# Video OQvJTdtJ2H4: 16 segments
# Video Bfr499ggo-0: 22 segments
# Video TvyZBvOMOTc: 15 segments
# Video pLTX3ipuDJI: 16 segments
# Video Iu2PFX3z_1s: 16 segments
# Video W8NXH0Djyww: 32 segments
# Video 73jzhE8R1TQ: 19 segments

# %%
# obtain the train/dev/test splits - these splits are based on video IDs
train_split = DATASET.standard_folds.standard_train_fold
dev_split = DATASET.standard_folds.standard_valid_fold
test_split = DATASET.standard_folds.standard_test_fold

# inspect the splits: they only contain video IDs
print(f"lengths: train {len(train_split)}, dev {len(dev_split)}, test {len(test_split)}\n")
print(train_split)
print(dev_split)
print(test_split)
# Out:
# lengths: train 52, dev 10, test 31
#
# ['2iD-tVS8NPw', '8d-gEyoeBzc', 'Qr1Ca94K55A', 'Ci-AH39fi3Y', '8qrpnFRGt2A', 'Bfr499ggo-0', 'QN9ZIUWUXsY', '9T9Hf74oK10', '7JsX8y1ysxY', '1iG0909rllw', 'Oz06ZWiO20M', 'BioHAh1qJAQ', '9c67fiY0wGQ', 'Iu2PFX3z_1s', 'Nzq88NnDkEk', 'Clx4VXItLTE', '9J25DZhivz8', 'Af8D0E4ZXaw', 'TvyZBvOMOTc', 'W8NXH0Djyww', '8OtFthrtaJM', '0h-zjBukYpk', 'Vj1wYRQjB-o', 'GWuJjcEuzt8', 'BI97DNYfe5I', 'PZ-lDQFboO8', '1DmNV9C1hbY', 'OQvJTdtJ2H4', 'I5y0__X72p0', '9qR7uwkblbs', 'G6GlGvlkxAQ', '6_0THN4chvY', 'Njd1F0vZSm4', 'BvYR0L6f2Ig', '03bSnISJMiM', 'Dg_0XKD0Mf4', '5W7Z1C_fDaE', 'VbQk4H8hgr0', 'G-xst2euQUc', 'MLal-t_vJPM', 'BXuRRbG0Ugk', 'LSi-o-IrDMs', 'Jkswaaud0hk', '2WGyTLYerpo', '6Egk_28TtTM', 'Sqr0AcuoNnk', 'POKffnXeBds', '73jzhE8R1TQ', 'OtBXNcAL_lE', 'HEsqda8_d0Q', 'VCslbP0mgZI', 'IumbAb8q2dM']
# ['WKA5OygbEKI', 'c5xsKMxpXnc', 'atnd_PF-Lbs', 'bvLlb-M3UXU', 'bOL9jKpeJRs', '_dI--eQ6qVU', 'ZAIRrfG22O0', 'X3j2zQgwYgE', 'aiEXnCPZubE', 'ZUXBRvtny7o']
# ['tmZoasNr4rU', 'zhpQhgha_KU', 'lXPQBPVc5Cw', 'iiK8YX8oH1E', 'tStelxIAHjw', 'nzpVDcQ0ywM', 'etzxEpPuc6I', 'cW1FSBF59ik', 'd6hH302o4v8', 'k5Y_838nuGo', 'pLTX3ipuDJI', 'jUzDDGyPkXU', 'f_pcplsH_V0', 'yvsjCA6Y5Fc', 'nbWiPyCm4g0', 'rnaNMUZpvvg', 'wMbj6ajWbic', 'cM3Yna7AavY', 'yDtzw_Y-7RU', 'vyB00TXsimI', 'dq3Nf_lMPnE', 'phBUpBr1hSo', 'd3_k5Xpfmik', 'v0zCBqDeKcE', 'tIrG4oNLFzE', 'fvVhgmXxadc', 'ob23OKe5a9Q', 'cXypl4FnoZo', 'vvZ4IcEtiZc', 'f9O3YtZ2VfI', 'c7UH_rxdZv4']

# %%
# A sentinel epsilon for safe division, avoiding division by zero
EPS = 1e-8

word2id = defaultdict(lambda: len(word2id))
UNK = word2id['<unk>']
PAD = word2id['<pad>']
EOS = word2id['<eos>']
BOS = word2id['<bos>']
# SEP = word2id['<sep>']
DUMMY = word2id['<dummy>']

pattern = re.compile('(.*)\[.*\]')

# %%
vocab_size = len(word2id)
print(f"Vocabulary size: {vocab_size}")


# Assuming the input features are already defined elsewhere
# _words, _visual_Facet41, _visual_Facet42, _visual_OpenFace1, _acoustic_COVAREP, _acoustic_OpenSmile_EB10, _wordvectors
# Also assuming train_split, dev_split, test_split are already defined

# Placeholders for final train/dev/test dataset
train = []
dev = []
test = []

# Iterate over the segments in the dataset
num_drop = 0  # Counter to track the number of dropped data points

for segment in dataset[label_field].keys():
    # Get the video ID and features
    vid = re.search(pattern, segment).group(1)
    label = dataset[label_field][segment]['features']
    _words = dataset[text_field_Words][segment]['features']

    # Collect all visual and acoustic features
    _visual_Facet41 = dataset[visual_field_Facet41][segment]['features']
    # _visual_Facet42 = dataset[visual_field_Facet42][segment]['features']
    # _visual_OpenFace1 = dataset[visual_field_OpenFace1][segment]['features']

    _acoustic_COVAREP = dataset[acoustic_field_COVAREP][segment]['features']
    # _acoustic_OpenSmile_EB10 = dataset[acoustic_field_OpenSmile_EB10][segment]['features']

    _wordvectors = dataset[text_field_WordVectors][segment]['features']

    # # Check if all modalities have the same number of elements (length of sequence)
    # if not (_words.shape[0] == _visual_Facet41.shape[0] == _visual_Facet42.shape[0] == _visual_OpenFace1.shape[0] == 
    #         _acoustic_COVAREP.shape[0] == _acoustic_OpenSmile_EB10.shape[0] == _wordvectors.shape[0]):
    #     print(f"Error: Inconsistent sequence lengths for segment {vid}")
    #     num_drop += 1
    #     continue  # Skip this segment and continue with the next one


     # Check if all modalities have the same number of elements (length of sequence)
    if not (_words.shape[0] == _visual_Facet41.shape[0] == _acoustic_COVAREP.shape[0]
                    == _wordvectors.shape[0]):
        print(f"Error: Inconsistent sequence lengths for segment {vid}")
        num_drop += 1
        continue  # Skip this segment and continue with the next one

    # Lists to hold the processed data for each modality
    words = []
    visual = []
    acoustic = []
    wordvectors = []

    # Remove speech pauses (um, uhh, etc.)
    for i, word in enumerate(_words):
        
        if word[0] != b'sp':  # Remove speech pauses
            words.append(word2id[word[0].decode('utf-8')])  # Decode bytes to string and add to words


            # Append visual features (check the shape of each feature)
            visual.append(_visual_Facet41[i, :])  # Facet41
            # visual.append(_visual_Facet42[i, :])  # Facet42
            # visual.append(_visual_OpenFace1[i, :])  # OpenFace1

            # Append acoustic features (check the shape of each feature)
            acoustic.append(_acoustic_COVAREP[i, :])  # COVAREP
            # acoustic.append(_acoustic_OpenSmile_EB10[i, :])  # OpenSmile_EB10

            # combined_acoustic = np.vstack((_acoustic_COVAREP[i, :], _acoustic_OpenSmile_EB10[i, :]))
            # acoustic.append(combined_acoustic)

            # Append word vectors
            wordvectors.append(_wordvectors[i, :])  # Word vectors


    # LOOK AT THE SHAPES

    # Check the shapes of the collected features before converting to numpy arrays
    # print(f"Word vectors shape: {np.asarray(wordvectors).shape}")
    print(f"Words shape: {np.asarray(words).shape}")
    print(f"WordVectors shape: {np.asarray(wordvectors).shape}")
    print(f"Acoustic shape: {np.asarray(acoustic).shape}")

    print(f"Visual shape: {np.asarray(visual).shape}")

    # Convert lists to numpy arrays
    words = np.asarray(words)
    visual = np.asarray(visual)
    acoustic = np.asarray(acoustic)
    wordvectors = np.asarray(wordvectors)

    # Z-normalization for visual modality (across all visual features)
    std_dev_visual = np.std(visual, axis=0, keepdims=True)
    visual = np.nan_to_num((visual - visual.mean(0, keepdims=True)) / (EPS + std_dev_visual))
    visual[:, std_dev_visual.flatten() == 0] = EPS  # Safeguard for zero standard deviation

    # Z-normalization for acoustic modality (across all acoustic features)
    acoustic_mean = np.nanmean(acoustic, axis=0, keepdims=True)
    std_dev_acoustic = np.nanstd(acoustic, axis=0, keepdims=True)
    std_dev_acoustic = np.nan_to_num(std_dev_acoustic)
    std_dev_acoustic[std_dev_acoustic == 0] = EPS  # Safeguard for zero standard deviation

    acoustic = np.nan_to_num((acoustic - acoustic_mean) / (EPS + std_dev_acoustic))

    # Z-normalization for word vectors
    wordvectors_mean = np.nanmean(wordvectors, axis=0, keepdims=True)
    std_dev_wordvectors = np.nanstd(wordvectors, axis=0, keepdims=True)
    std_dev_wordvectors = np.nan_to_num(std_dev_wordvectors)
    std_dev_wordvectors[std_dev_wordvectors == 0] = EPS  # Safeguard for zero standard deviation
    wordvectors = np.nan_to_num((wordvectors - wordvectors_mean) / (EPS + std_dev_wordvectors))

    # plot_hist2(wordvectors, acoustic)

    # Ensure no NaN or Inf values in the data
    if np.any(np.isnan(acoustic)) or np.any(np.isinf(acoustic)):
        print(f"Error in acoustic data for segment {vid}")
    if np.any(np.isnan(visual)) or np.any(np.isinf(visual)):
        print(f"Error in visual data for segment {vid}")
    if np.any(np.isnan(words)) or np.any(np.isinf(words)):
        print(f"Error in wordvectors data for segment {vid}")

    # Add the data to the appropriate split
    if vid in train_split:
        train.append(((words, visual, acoustic, wordvectors), label, segment))
    elif vid in dev_split:
        dev.append(((words, visual, acoustic, wordvectors), label, segment))
    elif vid in test_split:
        test.append(((words, visual, acoustic,wordvectors), label, segment))
    else:
        print(f"Found video that doesn't belong to any splits: {vid}")

# Output number of dropped datapoints
print(f"Total number of {num_drop} datapoints have been dropped.")
# Check how many words are in the vocabulary
vocab_size = len(word2id)
print(f"Vocabulary size: {vocab_size}")
# Out:
# Vocabulary size: 5
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (19,)
# WordVectors shape: (19, 300)
# Acoustic shape: (19, 74)
# Visual shape: (19, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (29,)
# WordVectors shape: (29, 300)
# Acoustic shape: (29, 74)
# Visual shape: (29, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (18,)
# WordVectors shape: (18, 300)
# Acoustic shape: (18, 74)
# Visual shape: (18, 47)
# Words shape: (16,)
# WordVectors shape: (16, 300)
# Acoustic shape: (16, 74)
# Visual shape: (16, 47)
# Words shape: (15,)
# WordVectors shape: (15, 300)
# Acoustic shape: (15, 74)
# Visual shape: (15, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (2,)
# WordVectors shape: (2, 300)
# Acoustic shape: (2, 74)
# Visual shape: (2, 47)
# Words shape: (3,)
# WordVectors shape: (3, 300)
# Acoustic shape: (3, 74)
# Visual shape: (3, 47)
# Words shape: (25,)
# WordVectors shape: (25, 300)
# Acoustic shape: (25, 74)
# Visual shape: (25, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (16,)
# WordVectors shape: (16, 300)
# Acoustic shape: (16, 74)
# Visual shape: (16, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (42,)
# WordVectors shape: (42, 300)
# Acoustic shape: (42, 74)
# Visual shape: (42, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (18,)
# WordVectors shape: (18, 300)
# Acoustic shape: (18, 74)
# Visual shape: (18, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (17,)
# WordVectors shape: (17, 300)
# Acoustic shape: (17, 74)
# Visual shape: (17, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (3,)
# WordVectors shape: (3, 300)
# Acoustic shape: (3, 74)
# Visual shape: (3, 47)
# Words shape: (24,)
# WordVectors shape: (24, 300)
# Acoustic shape: (24, 74)
# Visual shape: (24, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (17,)
# WordVectors shape: (17, 300)
# Acoustic shape: (17, 74)
# Visual shape: (17, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (15,)
# WordVectors shape: (15, 300)
# Acoustic shape: (15, 74)
# Visual shape: (15, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (19,)
# WordVectors shape: (19, 300)
# Acoustic shape: (19, 74)
# Visual shape: (19, 47)
# Words shape: (32,)
# WordVectors shape: (32, 300)
# Acoustic shape: (32, 74)
# Visual shape: (32, 47)
# Words shape: (28,)
# WordVectors shape: (28, 300)
# Acoustic shape: (28, 74)
# Visual shape: (28, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (25,)
# WordVectors shape: (25, 300)
# Acoustic shape: (25, 74)
# Visual shape: (25, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (21,)
# WordVectors shape: (21, 300)
# Acoustic shape: (21, 74)
# Visual shape: (21, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (20,)
# WordVectors shape: (20, 300)
# Acoustic shape: (20, 74)
# Visual shape: (20, 47)
# Words shape: (3,)
# WordVectors shape: (3, 300)
# Acoustic shape: (3, 74)
# Visual shape: (3, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (21,)
# WordVectors shape: (21, 300)
# Acoustic shape: (21, 74)
# Visual shape: (21, 47)
# Words shape: (3,)
# WordVectors shape: (3, 300)
# Acoustic shape: (3, 74)
# Visual shape: (3, 47)
# Words shape: (3,)
# WordVectors shape: (3, 300)
# Acoustic shape: (3, 74)
# Visual shape: (3, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (38,)
# WordVectors shape: (38, 300)
# Acoustic shape: (38, 74)
# Visual shape: (38, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (17,)
# WordVectors shape: (17, 300)
# Acoustic shape: (17, 74)
# Visual shape: (17, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (3,)
# WordVectors shape: (3, 300)
# Acoustic shape: (3, 74)
# Visual shape: (3, 47)
# Words shape: (2,)
# WordVectors shape: (2, 300)
# Acoustic shape: (2, 74)
# Visual shape: (2, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (19,)
# WordVectors shape: (19, 300)
# Acoustic shape: (19, 74)
# Visual shape: (19, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (24,)
# WordVectors shape: (24, 300)
# Acoustic shape: (24, 74)
# Visual shape: (24, 47)
# Words shape: (16,)
# WordVectors shape: (16, 300)
# Acoustic shape: (16, 74)
# Visual shape: (16, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (16,)
# WordVectors shape: (16, 300)
# Acoustic shape: (16, 74)
# Visual shape: (16, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (32,)
# WordVectors shape: (32, 300)
# Acoustic shape: (32, 74)
# Visual shape: (32, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (25,)
# WordVectors shape: (25, 300)
# Acoustic shape: (25, 74)
# Visual shape: (25, 47)
# Words shape: (28,)
# WordVectors shape: (28, 300)
# Acoustic shape: (28, 74)
# Visual shape: (28, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (18,)
# WordVectors shape: (18, 300)
# Acoustic shape: (18, 74)
# Visual shape: (18, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (41,)
# WordVectors shape: (41, 300)
# Acoustic shape: (41, 74)
# Visual shape: (41, 47)
# Words shape: (32,)
# WordVectors shape: (32, 300)
# Acoustic shape: (32, 74)
# Visual shape: (32, 47)
# Words shape: (20,)
# WordVectors shape: (20, 300)
# Acoustic shape: (20, 74)
# Visual shape: (20, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (24,)
# WordVectors shape: (24, 300)
# Acoustic shape: (24, 74)
# Visual shape: (24, 47)
# Words shape: (18,)
# WordVectors shape: (18, 300)
# Acoustic shape: (18, 74)
# Visual shape: (18, 47)
# Words shape: (40,)
# WordVectors shape: (40, 300)
# Acoustic shape: (40, 74)
# Visual shape: (40, 47)
# Words shape: (32,)
# WordVectors shape: (32, 300)
# Acoustic shape: (32, 74)
# Visual shape: (32, 47)
# Words shape: (15,)
# WordVectors shape: (15, 300)
# Acoustic shape: (15, 74)
# Visual shape: (15, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (15,)
# WordVectors shape: (15, 300)
# Acoustic shape: (15, 74)
# Visual shape: (15, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (2,)
# WordVectors shape: (2, 300)
# Acoustic shape: (2, 74)
# Visual shape: (2, 47)
# Words shape: (2,)
# WordVectors shape: (2, 300)
# Acoustic shape: (2, 74)
# Visual shape: (2, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (20,)
# WordVectors shape: (20, 300)
# Acoustic shape: (20, 74)
# Visual shape: (20, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (15,)
# WordVectors shape: (15, 300)
# Acoustic shape: (15, 74)
# Visual shape: (15, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (19,)
# WordVectors shape: (19, 300)
# Acoustic shape: (19, 74)
# Visual shape: (19, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (18,)
# WordVectors shape: (18, 300)
# Acoustic shape: (18, 74)
# Visual shape: (18, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (3,)
# WordVectors shape: (3, 300)
# Acoustic shape: (3, 74)
# Visual shape: (3, 47)
# Words shape: (15,)
# WordVectors shape: (15, 300)
# Acoustic shape: (15, 74)
# Visual shape: (15, 47)
# Words shape: (22,)
# WordVectors shape: (22, 300)
# Acoustic shape: (22, 74)
# Visual shape: (22, 47)
# Words shape: (15,)
# WordVectors shape: (15, 300)
# Acoustic shape: (15, 74)
# Visual shape: (15, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (16,)
# WordVectors shape: (16, 300)
# Acoustic shape: (16, 74)
# Visual shape: (16, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (18,)
# WordVectors shape: (18, 300)
# Acoustic shape: (18, 74)
# Visual shape: (18, 47)
# Words shape: (19,)
# WordVectors shape: (19, 300)
# Acoustic shape: (19, 74)
# Visual shape: (19, 47)
# Words shape: (15,)
# WordVectors shape: (15, 300)
# Acoustic shape: (15, 74)
# Visual shape: (15, 47)
# Words shape: (25,)
# WordVectors shape: (25, 300)
# Acoustic shape: (25, 74)
# Visual shape: (25, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (25,)
# WordVectors shape: (25, 300)
# Acoustic shape: (25, 74)
# Visual shape: (25, 47)
# Words shape: (31,)
# WordVectors shape: (31, 300)
# Acoustic shape: (31, 74)
# Visual shape: (31, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (17,)
# WordVectors shape: (17, 300)
# Acoustic shape: (17, 74)
# Visual shape: (17, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (16,)
# WordVectors shape: (16, 300)
# Acoustic shape: (16, 74)
# Visual shape: (16, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (3,)
# WordVectors shape: (3, 300)
# Acoustic shape: (3, 74)
# Visual shape: (3, 47)
# Words shape: (21,)
# WordVectors shape: (21, 300)
# Acoustic shape: (21, 74)
# Visual shape: (21, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (17,)
# WordVectors shape: (17, 300)
# Acoustic shape: (17, 74)
# Visual shape: (17, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (20,)
# WordVectors shape: (20, 300)
# Acoustic shape: (20, 74)
# Visual shape: (20, 47)
# Words shape: (28,)
# WordVectors shape: (28, 300)
# Acoustic shape: (28, 74)
# Visual shape: (28, 47)
# Words shape: (23,)
# WordVectors shape: (23, 300)
# Acoustic shape: (23, 74)
# Visual shape: (23, 47)
# Words shape: (19,)
# WordVectors shape: (19, 300)
# Acoustic shape: (19, 74)
# Visual shape: (19, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (27,)
# WordVectors shape: (27, 300)
# Acoustic shape: (27, 74)
# Visual shape: (27, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (3,)
# WordVectors shape: (3, 300)
# Acoustic shape: (3, 74)
# Visual shape: (3, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (38,)
# WordVectors shape: (38, 300)
# Acoustic shape: (38, 74)
# Visual shape: (38, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (45,)
# WordVectors shape: (45, 300)
# Acoustic shape: (45, 74)
# Visual shape: (45, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (2,)
# WordVectors shape: (2, 300)
# Acoustic shape: (2, 74)
# Visual shape: (2, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (18,)
# WordVectors shape: (18, 300)
# Acoustic shape: (18, 74)
# Visual shape: (18, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (3,)
# WordVectors shape: (3, 300)
# Acoustic shape: (3, 74)
# Visual shape: (3, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (2,)
# WordVectors shape: (2, 300)
# Acoustic shape: (2, 74)
# Visual shape: (2, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (23,)
# WordVectors shape: (23, 300)
# Acoustic shape: (23, 74)
# Visual shape: (23, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (21,)
# WordVectors shape: (21, 300)
# Acoustic shape: (21, 74)
# Visual shape: (21, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (18,)
# WordVectors shape: (18, 300)
# Acoustic shape: (18, 74)
# Visual shape: (18, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (19,)
# WordVectors shape: (19, 300)
# Acoustic shape: (19, 74)
# Visual shape: (19, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (20,)
# WordVectors shape: (20, 300)
# Acoustic shape: (20, 74)
# Visual shape: (20, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (21,)
# WordVectors shape: (21, 300)
# Acoustic shape: (21, 74)
# Visual shape: (21, 47)
# Words shape: (27,)
# WordVectors shape: (27, 300)
# Acoustic shape: (27, 74)
# Visual shape: (27, 47)
# Words shape: (44,)
# WordVectors shape: (44, 300)
# Acoustic shape: (44, 74)
# Visual shape: (44, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (16,)
# WordVectors shape: (16, 300)
# Acoustic shape: (16, 74)
# Visual shape: (16, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (15,)
# WordVectors shape: (15, 300)
# Acoustic shape: (15, 74)
# Visual shape: (15, 47)
# Words shape: (22,)
# WordVectors shape: (22, 300)
# Acoustic shape: (22, 74)
# Visual shape: (22, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (28,)
# WordVectors shape: (28, 300)
# Acoustic shape: (28, 74)
# Visual shape: (28, 47)
# Words shape: (33,)
# WordVectors shape: (33, 300)
# Acoustic shape: (33, 74)
# Visual shape: (33, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (19,)
# WordVectors shape: (19, 300)
# Acoustic shape: (19, 74)
# Visual shape: (19, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (18,)
# WordVectors shape: (18, 300)
# Acoustic shape: (18, 74)
# Visual shape: (18, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (18,)
# WordVectors shape: (18, 300)
# Acoustic shape: (18, 74)
# Visual shape: (18, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (15,)
# WordVectors shape: (15, 300)
# Acoustic shape: (15, 74)
# Visual shape: (15, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (16,)
# WordVectors shape: (16, 300)
# Acoustic shape: (16, 74)
# Visual shape: (16, 47)
# Words shape: (38,)
# WordVectors shape: (38, 300)
# Acoustic shape: (38, 74)
# Visual shape: (38, 47)
# Words shape: (23,)
# WordVectors shape: (23, 300)
# Acoustic shape: (23, 74)
# Visual shape: (23, 47)
# Words shape: (21,)
# WordVectors shape: (21, 300)
# Acoustic shape: (21, 74)
# Visual shape: (21, 47)
# Words shape: (29,)
# WordVectors shape: (29, 300)
# Acoustic shape: (29, 74)
# Visual shape: (29, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (36,)
# WordVectors shape: (36, 300)
# Acoustic shape: (36, 74)
# Visual shape: (36, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (16,)
# WordVectors shape: (16, 300)
# Acoustic shape: (16, 74)
# Visual shape: (16, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (39,)
# WordVectors shape: (39, 300)
# Acoustic shape: (39, 74)
# Visual shape: (39, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (16,)
# WordVectors shape: (16, 300)
# Acoustic shape: (16, 74)
# Visual shape: (16, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (18,)
# WordVectors shape: (18, 300)
# Acoustic shape: (18, 74)
# Visual shape: (18, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (25,)
# WordVectors shape: (25, 300)
# Acoustic shape: (25, 74)
# Visual shape: (25, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (40,)
# WordVectors shape: (40, 300)
# Acoustic shape: (40, 74)
# Visual shape: (40, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (30,)
# WordVectors shape: (30, 300)
# Acoustic shape: (30, 74)
# Visual shape: (30, 47)
# Words shape: (20,)
# WordVectors shape: (20, 300)
# Acoustic shape: (20, 74)
# Visual shape: (20, 47)
# Words shape: (15,)
# WordVectors shape: (15, 300)
# Acoustic shape: (15, 74)
# Visual shape: (15, 47)
# Words shape: (19,)
# WordVectors shape: (19, 300)
# Acoustic shape: (19, 74)
# Visual shape: (19, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (25,)
# WordVectors shape: (25, 300)
# Acoustic shape: (25, 74)
# Visual shape: (25, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (17,)
# WordVectors shape: (17, 300)
# Acoustic shape: (17, 74)
# Visual shape: (17, 47)
# Words shape: (23,)
# WordVectors shape: (23, 300)
# Acoustic shape: (23, 74)
# Visual shape: (23, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (17,)
# WordVectors shape: (17, 300)
# Acoustic shape: (17, 74)
# Visual shape: (17, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (15,)
# WordVectors shape: (15, 300)
# Acoustic shape: (15, 74)
# Visual shape: (15, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (3,)
# WordVectors shape: (3, 300)
# Acoustic shape: (3, 74)
# Visual shape: (3, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (31,)
# WordVectors shape: (31, 300)
# Acoustic shape: (31, 74)
# Visual shape: (31, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (24,)
# WordVectors shape: (24, 300)
# Acoustic shape: (24, 74)
# Visual shape: (24, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (24,)
# WordVectors shape: (24, 300)
# Acoustic shape: (24, 74)
# Visual shape: (24, 47)
# Words shape: (29,)
# WordVectors shape: (29, 300)
# Acoustic shape: (29, 74)
# Visual shape: (29, 47)
# Words shape: (20,)
# WordVectors shape: (20, 300)
# Acoustic shape: (20, 74)
# Visual shape: (20, 47)
# Words shape: (3,)
# WordVectors shape: (3, 300)
# Acoustic shape: (3, 74)
# Visual shape: (3, 47)
# Words shape: (25,)
# WordVectors shape: (25, 300)
# Acoustic shape: (25, 74)
# Visual shape: (25, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (16,)
# WordVectors shape: (16, 300)
# Acoustic shape: (16, 74)
# Visual shape: (16, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (19,)
# WordVectors shape: (19, 300)
# Acoustic shape: (19, 74)
# Visual shape: (19, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (16,)
# WordVectors shape: (16, 300)
# Acoustic shape: (16, 74)
# Visual shape: (16, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (25,)
# WordVectors shape: (25, 300)
# Acoustic shape: (25, 74)
# Visual shape: (25, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (27,)
# WordVectors shape: (27, 300)
# Acoustic shape: (27, 74)
# Visual shape: (27, 47)
# Words shape: (20,)
# WordVectors shape: (20, 300)
# Acoustic shape: (20, 74)
# Visual shape: (20, 47)
# Words shape: (20,)
# WordVectors shape: (20, 300)
# Acoustic shape: (20, 74)
# Visual shape: (20, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (35,)
# WordVectors shape: (35, 300)
# Acoustic shape: (35, 74)
# Visual shape: (35, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (29,)
# WordVectors shape: (29, 300)
# Acoustic shape: (29, 74)
# Visual shape: (29, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (24,)
# WordVectors shape: (24, 300)
# Acoustic shape: (24, 74)
# Visual shape: (24, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (1,)
# WordVectors shape: (1, 300)
# Acoustic shape: (1, 74)
# Visual shape: (1, 47)
# Words shape: (22,)
# WordVectors shape: (22, 300)
# Acoustic shape: (22, 74)
# Visual shape: (22, 47)
# Words shape: (22,)
# WordVectors shape: (22, 300)
# Acoustic shape: (22, 74)
# Visual shape: (22, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (24,)
# WordVectors shape: (24, 300)
# Acoustic shape: (24, 74)
# Visual shape: (24, 47)
# Words shape: (15,)
# WordVectors shape: (15, 300)
# Acoustic shape: (15, 74)
# Visual shape: (15, 47)
# Words shape: (3,)
# WordVectors shape: (3, 300)
# Acoustic shape: (3, 74)
# Visual shape: (3, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (24,)
# WordVectors shape: (24, 300)
# Acoustic shape: (24, 74)
# Visual shape: (24, 47)
# Words shape: (18,)
# WordVectors shape: (18, 300)
# Acoustic shape: (18, 74)
# Visual shape: (18, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (15,)
# WordVectors shape: (15, 300)
# Acoustic shape: (15, 74)
# Visual shape: (15, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (40,)
# WordVectors shape: (40, 300)
# Acoustic shape: (40, 74)
# Visual shape: (40, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (18,)
# WordVectors shape: (18, 300)
# Acoustic shape: (18, 74)
# Visual shape: (18, 47)
# Words shape: (21,)
# WordVectors shape: (21, 300)
# Acoustic shape: (21, 74)
# Visual shape: (21, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (26,)
# WordVectors shape: (26, 300)
# Acoustic shape: (26, 74)
# Visual shape: (26, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (19,)
# WordVectors shape: (19, 300)
# Acoustic shape: (19, 74)
# Visual shape: (19, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (23,)
# WordVectors shape: (23, 300)
# Acoustic shape: (23, 74)
# Visual shape: (23, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (21,)
# WordVectors shape: (21, 300)
# Acoustic shape: (21, 74)
# Visual shape: (21, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (16,)
# WordVectors shape: (16, 300)
# Acoustic shape: (16, 74)
# Visual shape: (16, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (16,)
# WordVectors shape: (16, 300)
# Acoustic shape: (16, 74)
# Visual shape: (16, 47)
# Words shape: (1,)
# WordVectors shape: (1, 300)
# Acoustic shape: (1, 74)
# Visual shape: (1, 47)
# Words shape: (2,)
# WordVectors shape: (2, 300)
# Acoustic shape: (2, 74)
# Visual shape: (2, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# ...
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (15,)
# WordVectors shape: (15, 300)
# Acoustic shape: (15, 74)
# Visual shape: (15, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (27,)
# WordVectors shape: (27, 300)
# Acoustic shape: (27, 74)
# Visual shape: (27, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (16,)
# WordVectors shape: (16, 300)
# Acoustic shape: (16, 74)
# Visual shape: (16, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (22,)
# WordVectors shape: (22, 300)
# Acoustic shape: (22, 74)
# Visual shape: (22, 47)
# Words shape: (23,)
# WordVectors shape: (23, 300)
# Acoustic shape: (23, 74)
# Visual shape: (23, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (20,)
# WordVectors shape: (20, 300)
# Acoustic shape: (20, 74)
# Visual shape: (20, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (27,)
# WordVectors shape: (27, 300)
# Acoustic shape: (27, 74)
# Visual shape: (27, 47)
# Words shape: (15,)
# WordVectors shape: (15, 300)
# Acoustic shape: (15, 74)
# Visual shape: (15, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (27,)
# WordVectors shape: (27, 300)
# Acoustic shape: (27, 74)
# Visual shape: (27, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (25,)
# WordVectors shape: (25, 300)
# Acoustic shape: (25, 74)
# Visual shape: (25, 47)
# Words shape: (18,)
# WordVectors shape: (18, 300)
# Acoustic shape: (18, 74)
# Visual shape: (18, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (21,)
# WordVectors shape: (21, 300)
# Acoustic shape: (21, 74)
# Visual shape: (21, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (18,)
# WordVectors shape: (18, 300)
# Acoustic shape: (18, 74)
# Visual shape: (18, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (15,)
# WordVectors shape: (15, 300)
# Acoustic shape: (15, 74)
# Visual shape: (15, 47)
# Words shape: (29,)
# WordVectors shape: (29, 300)
# Acoustic shape: (29, 74)
# Visual shape: (29, 47)
# Words shape: (16,)
# WordVectors shape: (16, 300)
# Acoustic shape: (16, 74)
# Visual shape: (16, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (19,)
# WordVectors shape: (19, 300)
# Acoustic shape: (19, 74)
# Visual shape: (19, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (19,)
# WordVectors shape: (19, 300)
# Acoustic shape: (19, 74)
# Visual shape: (19, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (20,)
# WordVectors shape: (20, 300)
# Acoustic shape: (20, 74)
# Visual shape: (20, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (21,)
# WordVectors shape: (21, 300)
# Acoustic shape: (21, 74)
# Visual shape: (21, 47)
# Words shape: (20,)
# WordVectors shape: (20, 300)
# Acoustic shape: (20, 74)
# Visual shape: (20, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (15,)
# WordVectors shape: (15, 300)
# Acoustic shape: (15, 74)
# Visual shape: (15, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (15,)
# WordVectors shape: (15, 300)
# Acoustic shape: (15, 74)
# Visual shape: (15, 47)
# Words shape: (15,)
# WordVectors shape: (15, 300)
# Acoustic shape: (15, 74)
# Visual shape: (15, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (17,)
# WordVectors shape: (17, 300)
# Acoustic shape: (17, 74)
# Visual shape: (17, 47)
# Words shape: (16,)
# WordVectors shape: (16, 300)
# Acoustic shape: (16, 74)
# Visual shape: (16, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (15,)
# WordVectors shape: (15, 300)
# Acoustic shape: (15, 74)
# Visual shape: (15, 47)
# Words shape: (17,)
# WordVectors shape: (17, 300)
# Acoustic shape: (17, 74)
# Visual shape: (17, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (15,)
# WordVectors shape: (15, 300)
# Acoustic shape: (15, 74)
# Visual shape: (15, 47)
# Words shape: (16,)
# WordVectors shape: (16, 300)
# Acoustic shape: (16, 74)
# Visual shape: (16, 47)
# Words shape: (45,)
# WordVectors shape: (45, 300)
# Acoustic shape: (45, 74)
# Visual shape: (45, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (27,)
# WordVectors shape: (27, 300)
# Acoustic shape: (27, 74)
# Visual shape: (27, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (17,)
# WordVectors shape: (17, 300)
# Acoustic shape: (17, 74)
# Visual shape: (17, 47)
# Words shape: (19,)
# WordVectors shape: (19, 300)
# Acoustic shape: (19, 74)
# Visual shape: (19, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (20,)
# WordVectors shape: (20, 300)
# Acoustic shape: (20, 74)
# Visual shape: (20, 47)
# Words shape: (18,)
# WordVectors shape: (18, 300)
# Acoustic shape: (18, 74)
# Visual shape: (18, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (21,)
# WordVectors shape: (21, 300)
# Acoustic shape: (21, 74)
# Visual shape: (21, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (17,)
# WordVectors shape: (17, 300)
# Acoustic shape: (17, 74)
# Visual shape: (17, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (20,)
# WordVectors shape: (20, 300)
# Acoustic shape: (20, 74)
# Visual shape: (20, 47)
# Words shape: (16,)
# WordVectors shape: (16, 300)
# Acoustic shape: (16, 74)
# Visual shape: (16, 47)
# Words shape: (19,)
# WordVectors shape: (19, 300)
# Acoustic shape: (19, 74)
# Visual shape: (19, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (37,)
# WordVectors shape: (37, 300)
# Acoustic shape: (37, 74)
# Visual shape: (37, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (45,)
# WordVectors shape: (45, 300)
# Acoustic shape: (45, 74)
# Visual shape: (45, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (22,)
# WordVectors shape: (22, 300)
# Acoustic shape: (22, 74)
# Visual shape: (22, 47)
# Words shape: (28,)
# WordVectors shape: (28, 300)
# Acoustic shape: (28, 74)
# Visual shape: (28, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (21,)
# WordVectors shape: (21, 300)
# Acoustic shape: (21, 74)
# Visual shape: (21, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (58,)
# WordVectors shape: (58, 300)
# Acoustic shape: (58, 74)
# Visual shape: (58, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (15,)
# WordVectors shape: (15, 300)
# Acoustic shape: (15, 74)
# Visual shape: (15, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (17,)
# WordVectors shape: (17, 300)
# Acoustic shape: (17, 74)
# Visual shape: (17, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (5,)
# WordVectors shape: (5, 300)
# Acoustic shape: (5, 74)
# Visual shape: (5, 47)
# Words shape: (13,)
# WordVectors shape: (13, 300)
# Acoustic shape: (13, 74)
# Visual shape: (13, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (32,)
# WordVectors shape: (32, 300)
# Acoustic shape: (32, 74)
# Visual shape: (32, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (16,)
# WordVectors shape: (16, 300)
# Acoustic shape: (16, 74)
# Visual shape: (16, 47)
# Words shape: (4,)
# WordVectors shape: (4, 300)
# Acoustic shape: (4, 74)
# Visual shape: (4, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (31,)
# WordVectors shape: (31, 300)
# Acoustic shape: (31, 74)
# Visual shape: (31, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (14,)
# WordVectors shape: (14, 300)
# Acoustic shape: (14, 74)
# Visual shape: (14, 47)
# Words shape: (7,)
# WordVectors shape: (7, 300)
# Acoustic shape: (7, 74)
# Visual shape: (7, 47)
# Words shape: (12,)
# WordVectors shape: (12, 300)
# Acoustic shape: (12, 74)
# Visual shape: (12, 47)
# Words shape: (8,)
# WordVectors shape: (8, 300)
# Acoustic shape: (8, 74)
# Visual shape: (8, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (11,)
# WordVectors shape: (11, 300)
# Acoustic shape: (11, 74)
# Visual shape: (11, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (9,)
# WordVectors shape: (9, 300)
# Acoustic shape: (9, 74)
# Visual shape: (9, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (20,)
# WordVectors shape: (20, 300)
# Acoustic shape: (20, 74)
# Visual shape: (20, 47)
# Words shape: (18,)
# WordVectors shape: (18, 300)
# Acoustic shape: (18, 74)
# Visual shape: (18, 47)
# Words shape: (10,)
# WordVectors shape: (10, 300)
# Acoustic shape: (10, 74)
# Visual shape: (10, 47)
# Words shape: (6,)
# WordVectors shape: (6, 300)
# Acoustic shape: (6, 74)
# Visual shape: (6, 47)
# Words shape: (21,)
# WordVectors shape: (21, 300)
# Acoustic shape: (21, 74)
# Visual shape: (21, 47)
# Total number of 0 datapoints have been dropped.
# Vocabulary size: 2732
# C:\Users\Viki\Documents\Thesis\tryout3\.venv\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1882: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe', where=where)
# C:\Users\Viki\AppData\Local\Temp\ipykernel_19120\785341847.py:104: RuntimeWarning: invalid value encountered in subtract
#   acoustic = np.nan_to_num((acoustic - acoustic_mean) / (EPS + std_dev_acoustic))

# %%
# Ensure the train dataset has elements before sampling
if len(train) > 0:
    # Randomly sample one processed segment
    sample = random.choice(train)

    # Extract components
    (words, visual, acoustic, wordvectors), label, segment = sample

    # Display the details
    print(f"Segment: {segment}")
    print(f"Label: {label}")
    print(f"Words (sample, first 10 if too long): {words[:10] if len(words) > 10 else words}")
    print(f"Words shape: {words.shape}")
    print(f"Visual shape: {visual.shape}")
    print(f"Acoustic shape: {acoustic.shape}")
    print(f"WordVectors shape: {wordvectors.shape}")
else:
    print("The train dataset is empty. Check the preprocessing loop for issues.")
# Out:
# Segment: 8OtFthrtaJM[0]
# Label: [[0.4]]
# Words (sample, first 10 if too long): [129  46 179  42 125 720 721 245]
# Words shape: (8,)
# Visual shape: (8, 47)
# Acoustic shape: (8, 74)
# WordVectors shape: (8, 300)

# %%
# turn off the word2id - define a named function here to allow for pickling
def return_unk():
    return UNK
word2id.default_factory = return_unk

# %%
def multi_collate_acoustic(batch):
    '''
    Collate function for acoustic data only. Batch will be sorted based on the sequence length of the acoustic features.
    '''
    # Sort batch in descending order based on the length of the acoustic feature sequence
    batch = sorted(batch, key=lambda x: x[0][2].shape[0], reverse=True)
    
    # Extract labels and acoustic features from the batch
    labels = torch.cat([torch.from_numpy(sample[1]) for sample in batch], dim=0).float()
    acoustic = pad_sequence([torch.FloatTensor(sample[0][2]) for sample in batch], batch_first=True)
    
    # Sequence lengths (useful for RNNs)
    lengths = torch.LongTensor([sample[0][2].shape[0] for sample in batch])
    return acoustic, labels, lengths


batch_sz = 56
train_loader = DataLoader(train, shuffle=True, batch_size=batch_sz, collate_fn=multi_collate_acoustic)
dev_loader = DataLoader(dev, shuffle=False, batch_size=batch_sz*3, collate_fn=multi_collate_acoustic)
test_loader = DataLoader(test, shuffle=False, batch_size=batch_sz*3, collate_fn=multi_collate_acoustic)

# let's create a temporary dataloader just to see how the batch looks like
temp_loader = iter(DataLoader(test, shuffle=True, batch_size=8, collate_fn=multi_collate_acoustic))
batch = next(temp_loader)

# print(batch[0].shape) # word vectors, padded to maxlen
print(batch[0].shape) # acoustic features
print(batch[1]) # labels
print(batch[2]) # lengths
# Out:
# torch.Size([8, 27, 74])
# tensor([[ 0.2000],
#         [-0.6000],
#         [ 3.0000],
#         [-0.4000],
#         [ 2.2000],
#         [ 2.0000],
#         [ 0.6000],
#         [-2.4000]])
# tensor([27, 18, 12,  9,  7,  6,  4,  4])

# %%
# from torch import optim
# from torch.utils.tensorboard import SummaryWriter
# 
# class SingleEncoderModelAudio(nn.Module):
#     def __init__(self, input_size, hidden_dim, num_layers, dropout_rate, output_size):
#         super(SingleEncoderModelAudio, self).__init__()
#         
#         self.input_size = input_size
#         self.hidden_dim = hidden_dim
#         self.num_layers = num_layers
#         self.dropout_rate = dropout_rate    
#         # self.num_categories = num_categories
#         self.output_size = output_size
#         # GRU layer
#         self.gru = nn.GRU(input_size=self.input_size, 
#                           hidden_size=self.hidden_dim,  # Correct parameter is hidden_size
#                           num_layers=self.num_layers, 
#                           batch_first=True,  # Input is [batch_size, seq_length, input_size]
#                           dropout=self.dropout_rate if self.num_layers > 1 else 0)
# 
#         # Fully connected output layer
#         # self.fc1 = nn.Linear((self.hidden_dim), num_categories)
#         self.fc2 = nn.Linear((self.hidden_dim), output_size)
# 
# 
#     
#     def forward(self, x, lengths):
#         batch_size = lengths.size(0)
# 
#         # GRU forward pass
#         _, hidden = self.gru(x)  # `hidden` shape: (num_layers, batch_size, hidden_dim)
#         hidden = hidden[-1]  # Use the last hidden state
#         
#         # Fully connected layers
#         # fc1_out = self.fc1(hidden)  # Output of shape [batch_size, num_categories]
#         output = self.fc2(hidden)  # Output of shape [batch_size, output_size]
#         
#         return output
# 
# 
#     def compute_loss(self, batch_pred, y_labels):
#         # Use Mean Squared Error loss for regression
#         loss_fn = nn.MSELoss()
#         loss = loss_fn(batch_pred, y_labels)
#         return loss
# 
# 
#     def create_optimizer(self, lr):
#         # Optimizer (Adam) with the specified learning rate
#         optimizer = optim.Adam(self.parameters(), lr=lr)
#         return optimizer
#

# %%
import torch
import torch.nn as nn
from torch import optim
from torch.utils.tensorboard import SummaryWriter

class SingleEncoderModelAudio(nn.Module):
    def __init__(self, input_size, hidden_dim, num_layers, dropout_rate, output_size):
        super(SingleEncoderModelAudio, self).__init__()
        
        self.input_size = input_size
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.dropout_rate = dropout_rate    
        self.output_size = output_size
        
        # GRU layer
        self.gru = nn.GRU(input_size=self.input_size, 
                          hidden_size=self.hidden_dim,  # Correct parameter is hidden_size
                          num_layers=self.num_layers, 
                          batch_first=True,  # Input is [batch_size, seq_length, input_size]
                          dropout=self.dropout_rate if self.num_layers > 1 else 0)

        # Fully connected output layer
        self.fc2 = nn.Linear(self.hidden_dim, output_size)
        
        # Tanh activation function to scale outputs between -3 and 3
        self.tanh = nn.Tanh()

    def forward(self, x, lengths):
        batch_size = lengths.size(0)

        # GRU forward pass
        _, hidden = self.gru(x)  # `hidden` shape: (num_layers, batch_size, hidden_dim)
        hidden = hidden[-1]  # Use the last hidden state
        
        # Fully connected layers
        output = self.fc2(hidden)  # Output of shape [batch_size, output_size]
        
        # Apply tanh and scale the output to [-3, 3]
        output = 3 * self.tanh(output)
        
        return output

    def compute_loss(self, batch_pred, y_labels):
        # Use Mean Squared Error loss for regression
        loss_fn = nn.MSELoss()
        loss = loss_fn(batch_pred, y_labels)
        return loss

    def create_optimizer(self, lr):
        # Optimizer (Adam) with the specified learning rate
        optimizer = optim.Adam(self.parameters(), lr=lr)
        return optimizer

# %%
torch.manual_seed(123)
torch.cuda.manual_seed_all(123)

CUDA = torch.cuda.is_available()
MAX_EPOCH = 1000

input_size = 74  # Example: Number of features per time step (adjust as per your data)
# hidden_sizes = int(input_size)  # Number of GRU units
hidden_sizes = 128
num_layers = 2  # Number of layers in GRU
num_categories = 7  # Number of categories for classification (adjust as needed)
output_size = 1  # Output size (e.g., 1 for binary classification)


fc1_size = hidden_sizes
dropout = 0.5
curr_patience = patience = 8
num_trials = 3
grad_clip_value = 1.0
weight_decay = 0.1

print("Model ???")
model = SingleEncoderModelAudio(input_size=input_size, 
                                hidden_dim=hidden_sizes,
                                num_layers=num_layers,
                                dropout_rate=dropout,
                                # num_categories=num_categories,
                                output_size=output_size)
print("Model created")

# model.embed.requires_grad = False
optimizer = model.create_optimizer(lr=0.001)
print("Optimizer created")


if CUDA:
    model.cuda()
    
criterion = nn.MSELoss(reduction='sum')
criterion_test = nn.MSELoss(reduction='sum')

best_valid_loss = float('inf')

lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.1)
lr_scheduler.step() # for some reason it seems the StepLR needs to be stepped once first

train_losses = []
valid_losses = []
for e in range(MAX_EPOCH):
    model.train()
    train_iter = tqdm_notebook(train_loader)
    train_loss = 0.0
    
    for batch in train_iter:
        model.zero_grad()
        a, y, l = batch
        batch_size = a.size(0)
        if CUDA:
            a = a.cuda()
            y = y.cuda()
            l = l.cuda()
        
        y_tilde = model(a, l)
        # print(f"batch_pred: {y_tilde.shape}")
        # print(f"labels: {y.shape}")
        
        loss = criterion(y_tilde, y)
        loss.backward()
        torch.nn.utils.clip_grad_value_([param for param in model.parameters() if param.requires_grad], grad_clip_value)
        optimizer.step()
        train_iter.set_description(f"Epoch {e}/{MAX_EPOCH}, current batch loss: {round(loss.item()/batch_size, 4)}")
        train_loss += loss.item()
    train_loss = train_loss / len(train)
    train_losses.append(train_loss)
    print(f"Training loss: {round(train_loss, 4)}")
    
    # print("LOOP COMPLETED")

    model.eval()
    with torch.no_grad():
        valid_loss = 0.0
        for batch in dev_loader:
            model.zero_grad()
            a, y, l = batch
            if CUDA:
                a = a.cuda()
                y = y.cuda()
                l = l.cuda()
            y_tilde = model(a, l)
            loss = criterion(y_tilde, y)
            valid_loss += loss.item()
    
    valid_loss = valid_loss/len(dev)
    valid_losses.append(valid_loss)
    print(f"Validation loss: {round(valid_loss, 4)}")
    print(f"Current patience: {curr_patience}, current trial: {num_trials}.")
    if valid_loss <= best_valid_loss:
        best_valid_loss = valid_loss
        print("Found new best model on dev set!")
        torch.save(model.state_dict(), 'modelaudio.std')
        torch.save(optimizer.state_dict(), 'optimaudio.std')
        curr_patience = patience
    else:
        curr_patience -= 1
        if curr_patience <= -1:
            print("Running out of patience, loading previous best model.")
            num_trials -= 1
            curr_patience = patience
            model.load_state_dict(torch.load('modelaudio.std'))
            optimizer.load_state_dict(torch.load('optimaudio.std'))
            lr_scheduler.step()
            print(f"Current learning rate: {optimizer.state_dict()['param_groups'][0]['lr']}")
    
    if num_trials <= 0:
        print("Running out of patience, early stopping.")
        break
# Out:
# Model ???
# Model created
# Optimizer created
# C:\Users\Viki\Documents\Thesis\tryout3\.venv\lib\site-packages\torch\optim\lr_scheduler.py:224: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# C:\Users\Viki\AppData\Local\Temp\ipykernel_19120\2342320971.py:50: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   train_iter = tqdm_notebook(train_loader)
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.3361
# Validation loss: 2.7291
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2805
# Validation loss: 2.7245
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2789
# Validation loss: 2.7276
# Current patience: 8, current trial: 3.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.279
# Validation loss: 2.7305
# Current patience: 7, current trial: 3.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2832
# Validation loss: 2.7348
# Current patience: 6, current trial: 3.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2878
# Validation loss: 2.7281
# Current patience: 5, current trial: 3.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.281
# Validation loss: 2.7356
# Current patience: 4, current trial: 3.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2714
# Validation loss: 2.7352
# Current patience: 3, current trial: 3.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.278
# Validation loss: 2.7367
# Current patience: 2, current trial: 3.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2704
# Validation loss: 2.7364
# Current patience: 1, current trial: 3.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2698
# Validation loss: 2.7342
# Current patience: 0, current trial: 3.
# Running out of patience, loading previous best model.
# Current learning rate: 1e-05
# C:\Users\Viki\AppData\Local\Temp\ipykernel_19120\2342320971.py:108: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('modelaudio.std'))
# C:\Users\Viki\AppData\Local\Temp\ipykernel_19120\2342320971.py:109: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   optimizer.load_state_dict(torch.load('optimaudio.std'))
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2931
# Validation loss: 2.7248
# Current patience: 8, current trial: 2.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2869
# Validation loss: 2.7253
# Current patience: 7, current trial: 2.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2812
# Validation loss: 2.726
# Current patience: 6, current trial: 2.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2865
# Validation loss: 2.7267
# Current patience: 5, current trial: 2.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2805
# Validation loss: 2.7267
# Current patience: 4, current trial: 2.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2811
# Validation loss: 2.728
# Current patience: 3, current trial: 2.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2804
# Validation loss: 2.7282
# Current patience: 2, current trial: 2.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2921
# Validation loss: 2.7289
# Current patience: 1, current trial: 2.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2835
# Validation loss: 2.7286
# Current patience: 0, current trial: 2.
# Running out of patience, loading previous best model.
# Current learning rate: 1e-05
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2831
# Validation loss: 2.7248
# Current patience: 8, current trial: 1.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2736
# Validation loss: 2.7252
# Current patience: 7, current trial: 1.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2879
# Validation loss: 2.726
# Current patience: 6, current trial: 1.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2835
# Validation loss: 2.7261
# Current patience: 5, current trial: 1.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2812
# Validation loss: 2.7268
# Current patience: 4, current trial: 1.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2777
# Validation loss: 2.7273
# Current patience: 3, current trial: 1.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2805
# Validation loss: 2.7276
# Current patience: 2, current trial: 1.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2851
# Validation loss: 2.7282
# Current patience: 1, current trial: 1.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 2.2746
# Validation loss: 2.728
# Current patience: 0, current trial: 1.
# Running out of patience, loading previous best model.
# Current learning rate: 1e-05
# Running out of patience, early stopping.

# %%
# model.load_state_dict(torch.load('modelaudio.std'))
# y_true = []
# y_pred = []
# model.eval()
# with torch.no_grad():
#     test_loss = 0.0
#     for batch in test_loader:
#         model.zero_grad()
#         a, y, l = batch
#         if CUDA:
#             a = a.cuda()
#             y = y.cuda()
#             l = l.cuda()
#         y_tilde = model(a, l)
#         loss = criterion_test(y_tilde, y)
#         y_true.append(y_tilde.detach().cpu().numpy())
#         y_pred.append(y.detach().cpu().numpy())
#         test_loss += loss.item()
# print(f"Test set performance: {test_loss/len(test)}")
# y_true = np.concatenate(y_true, axis=0)
# y_pred = np.concatenate(y_pred, axis=0)
#                   
# y_true_bin = y_true >= 0
# y_pred_bin = y_pred >= 0
# bin_acc = accuracy_score(y_true_bin, y_pred_bin)
# print(f"Test set accuracy is {bin_acc}")

# %%
# model.load_state_dict(torch.load('modelaudio.std'))
# print("Model loaded successfully!")
# 
# y_true = []
# y_pred = []
# model.eval()
# with torch.no_grad():
#     test_loss = 0.0
#     for batch in test_loader:
#         model.zero_grad()
#         a, y, l = batch
#         
#         # Ensure proper device placement (CUDA or CPU)
#         if torch.cuda.is_available():
#             a = a.cuda()
#             y = y.cuda()
#             l = l.cuda()
# 
#         # Print input shapes
#         print(f"Input shapes - a: {a.shape}, y: {y.shape}, l: {l.shape}")
# 
#         y_tilde = model(a, l)
# 
#         # Print model output shape
#         print(f"Output shape of the model: {y_tilde.shape}")
# 
#         loss = criterion_test(y_tilde, y)
# 
#         # Print loss for each batch
#         print(f"Batch loss: {loss.item()}")
# 
#         y_true.append(y_tilde.detach().cpu().numpy())
#         y_pred.append(y.detach().cpu().numpy())
#         test_loss += loss.item()
# 
#     print(f"Test set performance: {test_loss / len(test_loader)}")
# 
# # Concatenate true and predicted values
# y_true = np.concatenate(y_true, axis=0)
# y_pred = np.concatenate(y_pred, axis=0)
# 
# # Print the first few values before thresholding
# print(f"First few values of y_true: {y_true[:10]}")
# print(f"First few values of y_pred: {y_pred[:10]}")
# 
# y_true_bin = y_true >= 0
# y_pred_bin = y_pred >= 0
# 
# # Print binarized values
# print(f"Binarized y_true: {y_true_bin[:10]}")
# print(f"Binarized y_pred: {y_pred_bin[:10]}")
# 
# bin_acc = accuracy_score(y_true_bin, y_pred_bin)
# print(f"Test set accuracy is {bin_acc}")

# %%
def convert_to_sentiment_category(score):
    if score == 3:
        return 'strongly positive'
    elif score >= 2 and score < 3:
        return 'positive'
    elif score >= 1 and score < 2:
        return 'weakly positive'
    elif score < 1 and score > -1:
        return 'neutral'
    elif score <= -1 and score > -2:
        return 'weakly negative'
    elif score <= -2 and score > -3:
        return 'negative'
    elif score == -3:
        return 'strongly negative'
    else:
        return 'unknown'

# %%
import numpy as np
from sklearn.metrics import accuracy_score


# Ensure that the model is loaded
model.load_state_dict(torch.load('modelaudio.std'))
print("Model loaded successfully!")

y_true = []
y_pred = []
model.eval()
with torch.no_grad():
    test_loss = 0.0
    for batch in test_loader:
        model.zero_grad()
        a, y, l = batch
        
        # Ensure proper device placement (CUDA or CPU)
        if torch.cuda.is_available():
            a = a.cuda()
            y = y.cuda()
            l = l.cuda()

        # Print input shapes
        print(f"Input shapes - a: {a.shape}, y: {y.shape}, l: {l.shape}")

        y_tilde = model(a, l)

        # Print model output shape
        print(f"Output shape of the model: {y_tilde.shape}")

        loss = criterion_test(y_tilde, y)

        # Print loss for each batch
        print(f"Batch loss: {loss.item()}")

        y_true.append(y.detach().cpu().numpy())  # True values
        y_pred.append(y_tilde.detach().cpu().numpy())  # Predicted values
        test_loss += loss.item()

    print(f"Test set performance (total loss): {test_loss / len(test_loader)}")

# Concatenate true and predicted values
y_true = np.concatenate(y_true, axis=0)
y_pred = np.concatenate(y_pred, axis=0)

# Convert both y_true and y_pred to sentiment categories
y_true_categories = [convert_to_sentiment_category(score) for score in y_true]
y_pred_categories = [convert_to_sentiment_category(score) for score in y_pred]

print(f"First few values of y_true: {y_true[:10]}")
print(f"First few true sentiment labels: {y_true_categories[:10]}")

print(f"First few values of y_pred: {y_pred[:10]}")
print(f"First few predicted sentiment labels: {y_pred_categories[:10]}")

# Compute accuracy by comparing predicted categories with true categories
accuracy = accuracy_score(y_true_categories, y_pred_categories)
print(f"Accuracy: {accuracy}")
# Out:
# Model loaded successfully!
# Input shapes - a: torch.Size([168, 44, 74]), y: torch.Size([168, 1]), l: torch.Size([168])
# Output shape of the model: torch.Size([168, 1])
# Batch loss: 609.8631591796875
# Input shapes - a: torch.Size([168, 82, 74]), y: torch.Size([168, 1]), l: torch.Size([168])
# Output shape of the model: torch.Size([168, 1])
# Batch loss: 386.1199645996094
# Input shapes - a: torch.Size([168, 112, 74]), y: torch.Size([168, 1]), l: torch.Size([168])
# Output shape of the model: torch.Size([168, 1])
# Batch loss: 582.5965576171875
# Input shapes - a: torch.Size([168, 58, 74]), y: torch.Size([168, 1]), l: torch.Size([168])
# Output shape of the model: torch.Size([168, 1])
# Batch loss: 368.5628662109375
# Input shapes - a: torch.Size([14, 21, 74]), y: torch.Size([14, 1]), l: torch.Size([14])
# Output shape of the model: torch.Size([14, 1])
# Batch loss: 12.608111381530762
# Test set performance (total loss): 391.9501317977905
# First few values of y_true: [[ 0.2]
#  [ 2. ]
#  [ 0.2]
#  [ 0.8]
#  [-1. ]
#  [ 0.2]
#  [ 2.2]
#  [ 1.4]
#  [ 2.6]
#  [-0.6]]
# First few true sentiment labels: ['neutral', 'positive', 'neutral', 'neutral', 'weakly negative', 'neutral', 'positive', 'weakly positive', 'positive', 'neutral']
# First few values of y_pred: [[0.02713954]
#  [0.2781067 ]
#  [0.28597698]
#  [0.2489056 ]
#  [0.26820102]
#  [0.26309028]
#  [0.26480076]
#  [0.26540947]
#  [0.2648409 ]
#  [0.2649407 ]]
# First few predicted sentiment labels: ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# Accuracy: 0.28717201166180756
# C:\Users\Viki\AppData\Local\Temp\ipykernel_19120\262063581.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('modelaudio.std'))

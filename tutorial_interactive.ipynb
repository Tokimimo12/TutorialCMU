# %% [markdown]
# # Tutorial on CMU-Multimodal SDK
#
# This is a tutorial on using ***CMU-Multimodal SDK*** to load and process multimodal time-series datasets and training a simple late-fusion LSTM model on the processed data.
#
# For this tutorial, we specify some constants in `./constans/paths.py`. Please first take a look and modify the paths to point to the correct folders.
#
# ## Downloading the data
#
# We start off by (down)loading the datasets. In the SDK each dataset has three sets of content: `highlevel`, `raw` and `labels`. `highlevel` contains the extracted features for each modality (e.g OpenFace facial landmarks, openSMILE acoustic features) while `raw` contains the raw transctripts, phonemes. `labels` are self-explanatory. Note that some datasets have more than just one set of annotations so `labels` could also give you multiple files.
#
# Currently there's a caveat that the SDK will not automatically detect if you have downloaded the data already. In event of that it will throw a `RuntimeError`. We work around that by `try/except`. This is not ideal but it will work for now.

# %%
from constants import SDK_PATH, DATA_PATH, WORD_EMB_PATH, CACHE_PATH
import sys
# Out:
# SDK_PATH: C:\Users\Viki\Documents\Thesis\CMU-MultimodalSDK

# %%
if SDK_PATH is None:
    print("SDK path is not specified! Please specify first in constants/paths.py")
    exit(0)
else:
    sys.path.append(SDK_PATH)
    print(f"SDK path is set to {SDK_PATH}")
# Out:
# SDK path is set to C:\Users\Viki\Documents\Thesis\CMU-MultimodalSDK

# %%
import sys
for path in sys.path:
    print(path)
# Out:
# C:\Users\Viki\Documents\Thesis\tryout3
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\python310.zip
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\DLLs
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib
# C:\Users\Viki\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0
# C:\Users\Viki\Documents\Thesis\tryout3\.venv
#
# C:\Users\Viki\Documents\Thesis\tryout3\.venv\lib\site-packages
# C:\Users\Viki\Documents\Thesis\tryout3\.venv\lib\site-packages\win32
# C:\Users\Viki\Documents\Thesis\tryout3\.venv\lib\site-packages\win32\lib
# C:\Users\Viki\Documents\Thesis\tryout3\.venv\lib\site-packages\Pythonwin
# C:\Users\Viki\Documents\Thesis\CMU-MultimodalSDK

# %%
import mmsdk
import os
import re
import numpy as np
from mmsdk import mmdatasdk as md
from subprocess import check_call, CalledProcessError

# %%
# create folders for storing the data
if not os.path.exists(DATA_PATH):
    check_call(' '.join(['mkdir', '-p', DATA_PATH]), shell=True)

# download highlevel features, low-level (raw) data and labels for the dataset MOSI
# if the files are already present, instead of downloading it you just load it yourself.
# here we use CMU_MOSI dataset as example.

DATASET = md.cmu_mosi

try:
    md.mmdataset(DATASET.highlevel, DATA_PATH)
except RuntimeError:
    print("High-level features have been downloaded previously.")

try:
    md.mmdataset(DATASET.raw, DATA_PATH)
except RuntimeError:
    print("Raw data have been downloaded previously.")
    
try:
    md.mmdataset(DATASET.labels, DATA_PATH)
except RuntimeError:
    print("Labels have been downloaded previously.")
# Out:
# Normalized destination path: C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu/CMU-MOSI/language/CMU_MOSI_TimestampedWordVectors.csd
# [2024-12-03 11:01:33.004] | Error   | C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu/CMU-MOSI/language/CMU_MOSI_TimestampedWordVectors.csd file already exists ...
# High-level features have been downloaded previously.
# Normalized destination path: C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu/CMU-MOSI/language/CMU_MOSI_TimestampedWords.csd
# [2024-12-03 11:01:33.004] | Error   | C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu/CMU-MOSI/language/CMU_MOSI_TimestampedWords.csd file already exists ...
# Raw data have been downloaded previously.
# Normalized destination path: C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu/CMU-MOSI/labels/CMU_MOSI_Opinion_Labels.csd
# [2024-12-03 11:01:33.005] | Error   | C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu/CMU-MOSI/labels/CMU_MOSI_Opinion_Labels.csd file already exists ...
# Labels have been downloaded previously.

# %% [markdown]
# ## Inspecting the downloaded files
#
# We can print the files in the target data folder to see what files are there.
#
# We can observe a bunch of files ending with `.csd` extension. This stands for ***computational sequences***, which is the underlying data structure for all features in the SDK. We will come back to that later when we load the data. For now we just print out what computational sequences we have downloaded.

# %%
# list the directory contents... let's see what features there are
data_files = os.listdir(DATA_PATH)
print('\n'.join(data_files))
# Out:
# embedding_and_mapping.pt
# http__immortal.multicomp.cs.cmu.edu

# %% [markdown]
# ## Loading a multimodal dataset
#
# Loading the dataset is as simple as telling the SDK what are the features you need and where are their computational sequences. You can construct a dictionary with format `{feature_name: csd_path}` and feed it to `mmdataset` object in the SDK.

# %%
import os

folder_path = "C:\\Users\\Viki\\Documents\\Thesis\\tryout3\\data"
for root, dirs, files in os.walk(folder_path):
    print(f"Directory: {root}")
    for file in files:
        print(f"  {file}")
# Out:
# Directory: C:\Users\Viki\Documents\Thesis\tryout3\data
#   embedding_and_mapping.pt
# Directory: C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu
# Directory: C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu\CMU-MOSI
# Directory: C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu\CMU-MOSI\acoustic
#   CMU_MOSI_COVAREP.csd
#   CMU_MOSI_OpenSmile_EB10.csd
#   CMU_MOSI_openSMILE_IS09.csd
# Directory: C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu\CMU-MOSI\labels
#   CMU_MOSI_Opinion_Labels.csd
# Directory: C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu\CMU-MOSI\language
#   CMU_MOSI_TimestampedPhones.csd
#   CMU_MOSI_TimestampedWords.csd
#   CMU_MOSI_TimestampedWordVectors.csd
# Directory: C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu\CMU-MOSI\visual
#   CMU_MOSI_Visual_Facet_41.csd
#   CMU_MOSI_Visual_Facet_42.csd
#   CMU_MOSI_Visual_OpenFace_1.csd
#   CMU_MOSI_Visual_OpenFace_2.csd

# %%
# Define your different modalities - refer to the filenames of the CSD files
visual_field_Facet41 = 'CMU_MOSI_Visual_Facet_41'
visual_field_Facet42 = 'CMU_MOSI_Visual_Facet_42'
visual_field_OpenFace1 = 'CMU_MOSI_Visual_OpenFace_1'


# visual_field_OpenFace2 = 'CMU_MOSI_Visual_OpenFace_2'
# [2024-11-24 21:59:03.886] | Error   | C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu\http__immortal.multicomp.cs.cmu.edu\CMU-MOSI\visual\CMU_MOSI_Visual_OpenFace_2.csd resource is not a valid hdf5 computational sequence format ...


acoustic_field_COVAREP = 'CMU_MOSI_COVAREP'
acoustic_field_OpenSmile_EB10 = 'CMU_MOSI_OpenSmile_EB10'
acoustic_field_OpenSmile_IS09 = 'CMU_MOSI_openSMILE_IS09'



text_field_Words = 'CMU_MOSI_TimestampedWords'
text_field_Phones = 'CMU_MOSI_TimestampedPhones'
text_field_WordVectors = 'CMU_MOSI_TimestampedWordVectors'



# text_field = 'CMU_MOSI_ModifiedTimestampedWords'
feature=[
    text_field_Words,
    visual_field_Facet41, 
    acoustic_field_COVAREP,
]

# List of features
features1 = [
    text_field_Words,
    text_field_Phones,
    text_field_WordVectors,
    visual_field_Facet41, 
    visual_field_Facet42,
    visual_field_OpenFace1,
    # visual_field_OpenFace2,
    acoustic_field_COVAREP,
    # acoustic_field_OpenSmile_EB10,
    acoustic_field_OpenSmile_IS09
]

recipe = {
    text_field_Words: os.path.join(DATA_PATH, "http__immortal.multicomp.cs.cmu.edu", "CMU-MOSI", "language", text_field_Words) + '.csd',
    
    visual_field_Facet41: os.path.join(DATA_PATH, "http__immortal.multicomp.cs.cmu.edu", "CMU-MOSI", "visual", visual_field_Facet41) + '.csd',
    
    acoustic_field_COVAREP: os.path.join(DATA_PATH, "http__immortal.multicomp.cs.cmu.edu", "CMU-MOSI", "acoustic", acoustic_field_COVAREP) + '.csd',
}
# Recipe with correct subdirectory paths for each modality
recipe1 = {
    text_field_Words: os.path.join(DATA_PATH, text_field_Words) + '.csd',
    
    text_field_Phones: os.path.join(DATA_PATH, "CMU-MOSI", "language", text_field_Phones) + '.csd',
    
    text_field_WordVectors: os.path.join(DATA_PATH, "CMU-MOSI", "language", text_field_WordVectors) + '.csd',
    
    visual_field_Facet41: os.path.join(DATA_PATH, "CMU-MOSI", "visual", visual_field_Facet41) + '.csd',
    
    visual_field_Facet42: os.path.join(DATA_PATH, "CMU-MOSI", "visual", visual_field_Facet42) + '.csd',
    
    visual_field_OpenFace1: os.path.join(DATA_PATH, "CMU-MOSI", "visual", visual_field_OpenFace1) + '.csd',
    
    # visual_field_OpenFace2: os.path.join(DATA_PATH, "http__immortal.multicomp.cs.cmu.edu", "CMU-MOSI", "visual", visual_field_OpenFace2) + '.csd',
    
    acoustic_field_COVAREP: os.path.join(DATA_PATH, "CMU-MOSI", "acoustic", acoustic_field_COVAREP) + '.csd',
    
    acoustic_field_OpenSmile_EB10: os.path.join(DATA_PATH, "CMU-MOSI", "acoustic", acoustic_field_OpenSmile_EB10) + '.csd',
    
    acoustic_field_OpenSmile_IS09: os.path.join(DATA_PATH, "CMU-MOSI", "acoustic", acoustic_field_OpenSmile_IS09) + '.csd'
}



print (recipe)
dataset = md.mmdataset(recipe)
# Out:
# {'CMU_MOSI_TimestampedWords': 'C:\\Users\\Viki\\Documents\\Thesis\\tryout3\\data\\http__immortal.multicomp.cs.cmu.edu\\CMU-MOSI\\language\\CMU_MOSI_TimestampedWords.csd', 'CMU_MOSI_Visual_Facet_41': 'C:\\Users\\Viki\\Documents\\Thesis\\tryout3\\data\\http__immortal.multicomp.cs.cmu.edu\\CMU-MOSI\\visual\\CMU_MOSI_Visual_Facet_41.csd', 'CMU_MOSI_COVAREP': 'C:\\Users\\Viki\\Documents\\Thesis\\tryout3\\data\\http__immortal.multicomp.cs.cmu.edu\\CMU-MOSI\\acoustic\\CMU_MOSI_COVAREP.csd'}
# [2024-12-03 11:01:33.096] | Success | Computational sequence read from file C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu\CMU-MOSI\language\CMU_MOSI_TimestampedWords.csd ...
# [2024-12-03 11:01:33.138] | Status  | Checking the integrity of the <words> computational sequence ...
# [2024-12-03 11:01:33.138] | Status  | Checking the format of the data in <words> computational sequence ...
# [2024-12-03 11:01:33.296] | Success | <words> computational sequence data in correct format.
# [2024-12-03 11:01:33.296] | Status  | Checking the format of the metadata in <words> computational sequence ...
# [2024-12-03 11:01:33.296] | Warning | <words> computational sequence does not have all the required metadata ... continuing
# [2024-12-03 11:01:33.298] | Success | Computational sequence read from file C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu\CMU-MOSI\visual\CMU_MOSI_Visual_Facet_41.csd ...
# [2024-12-03 11:01:33.336] | Status  | Checking the integrity of the <FACET_4.1> computational sequence ...
# [2024-12-03 11:01:33.336] | Status  | Checking the format of the data in <FACET_4.1> computational sequence ...
# [2024-12-03 11:01:33.472] | Success | <FACET_4.1> computational sequence data in correct format.
# [2024-12-03 11:01:33.473] | Status  | Checking the format of the metadata in <FACET_4.1> computational sequence ...
# [2024-12-03 11:01:33.473] | Warning | <FACET_4.1> computational sequence does not have all the required metadata ... continuing
# [2024-12-03 11:01:33.476] | Success | Computational sequence read from file C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu\CMU-MOSI\acoustic\CMU_MOSI_COVAREP.csd ...
# [2024-12-03 11:01:33.505] | Status  | Checking the integrity of the <COVAREP> computational sequence ...
# [2024-12-03 11:01:33.505] | Status  | Checking the format of the data in <COVAREP> computational sequence ...
# [2024-12-03 11:01:33.629] | Success | <COVAREP> computational sequence data in correct format.
# [2024-12-03 11:01:33.630] | Status  | Checking the format of the metadata in <COVAREP> computational sequence ...
# [2024-12-03 11:01:33.630] | Warning | <COVAREP> computational sequence does not have all the required metadata ... continuing
# [2024-12-03 11:01:33.630] | Success | Dataset initialized successfully ...

# %% [markdown]
# ## A peek into the dataset
#
# The multimodal dataset, after loaded, has the following hierarchy:
#
#
# ```
#             computational_sequence_1 ---...
#            /                                   ...
#           /                                    /
#          /                          first_video     features -- T X N array
#         /                          /               /
# dataset ---computational_sequence_2 -- second_video
#         \                          \               \
#          \                          third_video     intervals -- T X 2 array
#           \                                    \...
#            \
#             computational_sequence_3 ---...
# ```
#
# It looks like a nested dictionary and can be indexed as if it is a nested dictionary. A dataset contains multiple computational sequences whose key is the `text_field`, `visual_field`, `acoustic_field` as defined above. Each computational sequence, however, has multiple video IDs in it, and different computational sequences are supposed to have the same set of video IDs. Within each video, there are two arrays: `features` and `intervals`, denoting the feature values at each time step and the start and end timestamp for each step. We can take a look at its content.

# %%
print(list(dataset.keys()))
print("=" * 80)

print(list(dataset[visual_field_Facet41].keys()))
print("=" * 80)

some_id = list(dataset[visual_field_Facet41].keys())[15]
print(list(dataset[visual_field_Facet41][some_id].keys()))
print("=" * 80)

print(list(dataset[visual_field_Facet41][some_id]['intervals'].shape))
print("=" * 80)

print(list(dataset[visual_field_Facet41][some_id]['features'].shape))
print(list(dataset[text_field_Words][some_id]['features'].shape))
print(list(dataset[acoustic_field_COVAREP][some_id]['features'].shape))
print("Different modalities have different number of time steps!")
# Out:
# ['CMU_MOSI_TimestampedWords', 'CMU_MOSI_Visual_Facet_41', 'CMU_MOSI_COVAREP']
# ================================================================================
# ['03bSnISJMiM', '0h-zjBukYpk', '1DmNV9C1hbY', '1iG0909rllw', '2WGyTLYerpo', '2iD-tVS8NPw', '5W7Z1C_fDaE', '6Egk_28TtTM', '6_0THN4chvY', '73jzhE8R1TQ', '7JsX8y1ysxY', '8OtFthrtaJM', '8d-gEyoeBzc', '8qrpnFRGt2A', '9J25DZhivz8', '9T9Hf74oK10', '9c67fiY0wGQ', '9qR7uwkblbs', 'Af8D0E4ZXaw', 'BI97DNYfe5I', 'BXuRRbG0Ugk', 'Bfr499ggo-0', 'BioHAh1qJAQ', 'BvYR0L6f2Ig', 'Ci-AH39fi3Y', 'Clx4VXItLTE', 'Dg_0XKD0Mf4', 'G-xst2euQUc', 'G6GlGvlkxAQ', 'GWuJjcEuzt8', 'HEsqda8_d0Q', 'I5y0__X72p0', 'Iu2PFX3z_1s', 'IumbAb8q2dM', 'Jkswaaud0hk', 'LSi-o-IrDMs', 'MLal-t_vJPM', 'Njd1F0vZSm4', 'Nzq88NnDkEk', 'OQvJTdtJ2H4', 'OtBXNcAL_lE', 'Oz06ZWiO20M', 'POKffnXeBds', 'PZ-lDQFboO8', 'QN9ZIUWUXsY', 'Qr1Ca94K55A', 'Sqr0AcuoNnk', 'TvyZBvOMOTc', 'VCslbP0mgZI', 'VbQk4H8hgr0', 'Vj1wYRQjB-o', 'W8NXH0Djyww', 'WKA5OygbEKI', 'X3j2zQgwYgE', 'ZAIRrfG22O0', 'ZUXBRvtny7o', '_dI--eQ6qVU', 'aiEXnCPZubE', 'atnd_PF-Lbs', 'bOL9jKpeJRs', 'bvLlb-M3UXU', 'c5xsKMxpXnc', 'c7UH_rxdZv4', 'cM3Yna7AavY', 'cW1FSBF59ik', 'cXypl4FnoZo', 'd3_k5Xpfmik', 'd6hH302o4v8', 'dq3Nf_lMPnE', 'etzxEpPuc6I', 'f9O3YtZ2VfI', 'f_pcplsH_V0', 'fvVhgmXxadc', 'iiK8YX8oH1E', 'jUzDDGyPkXU', 'k5Y_838nuGo', 'lXPQBPVc5Cw', 'nbWiPyCm4g0', 'nzpVDcQ0ywM', 'ob23OKe5a9Q', 'pLTX3ipuDJI', 'phBUpBr1hSo', 'rnaNMUZpvvg', 'tIrG4oNLFzE', 'tStelxIAHjw', 'tmZoasNr4rU', 'v0zCBqDeKcE', 'vvZ4IcEtiZc', 'vyB00TXsimI', 'wMbj6ajWbic', 'yDtzw_Y-7RU', 'yvsjCA6Y5Fc', 'zhpQhgha_KU']
# ================================================================================
# ['features', 'intervals']
# ================================================================================
# [5404, 2]
# ================================================================================
# [5404, 47]
# [645, 1]
# [18009, 74]
# Different modalities have different number of time steps!

# %%
print("=== Metadata FACE 41 Visual===\n")
print("Visual FACE 41 Metadata:", dataset[visual_field_Facet41].metadata)
print("\n")

print("=== Metadata COVAREP Acoustic===\n")
print("Acoustic COVAREP Metadata:", dataset[acoustic_field_COVAREP].metadata)
print("\n")

print("=== Metadata Words===\n")
print("Words Metadata:", dataset[text_field_Words].metadata)
print("\n")
# Out:
# === Metadata FACE 41 Visual===
#
# Visual FACE 41 Metadata: {'alignment compatible': True, 'computational sequence description': 'FACET 4.1 Visual Features for CMU-MOSI Dataset', 'computational sequence version': 1.0, 'contact': 'abagherz@andrew.cmu.edu', 'creator': 'Amir Zadeh', 'dataset bib citation': '@article{zadeh2016multimodal,title={Multimodal sentiment intensity analysis in videos: Facial gestures and verbal messages},author={Zadeh, Amir and Zellers, Rowan and Pincus, Eli and Morency, Louis-Philippe},journal={IEEE Intelligent Systems},volume={31},number={6},pages={82--88},year={2016},publisher={IEEE}}', 'dataset name': 'CMU-MOSI', 'dataset version': 1.0, 'dimension names': ['Face X', 'Face Y', 'Face Width', 'Face Height', 'angerEvidence', 'contemptEvidence', 'disgustEvidence', 'joyEvidence', 'fearEvidence', 'negativeEvidence', 'neutralEvidence', 'positiveEvidence', 'sadnessEvidence', 'surpriseEvidence', 'confusionEvidence', 'frustrationEvidence', 'angerIntensity', 'contemptIntensity', 'disgustIntensity', 'joyIntensity', 'fearIntensity', 'negativeIntensity', 'neutralIntensity', 'positiveIntensity', 'sadnessIntensity', 'surpriseIntensity', 'confusionIntensity', 'frustrationIntensity', 'AU1Evidence', 'AU2Evidence', 'AU4Evidence', 'AU5Evidence', 'AU6Evidence', 'AU7Evidence', 'AU9Evidence', 'AU10Evidence', 'AU12Evidence', 'AU14Evidence', 'AU15Evidence', 'AU17Evidence', 'AU18Evidence', 'AU20Evidence', 'AU23Evidence', 'AU24Evidence', 'AU25Evidence', 'AU26Evidence', 'AU28Evidence'], 'featureset bib citation': '@online{emotient,author = {iMotions},title = {Facial Expression Analysis},year = {2017},url = {goo.gl/1rh1JN}}', 'md5': None, 'root name': 'FACET_4.1', 'uuid': '75b82d70-387f-4c1a-935e-99462b7e4388'}
#
#
# === Metadata COVAREP Acoustic===
#
# Acoustic COVAREP Metadata: {'alignment compatible': True, 'computational sequence description': 'COVAREP Acoustic Features for CMU-MOSI Dataset', 'computational sequence version': 1.0, 'contact': 'abagherz@andrew.cmu.edu', 'creator': 'Amir Zadeh', 'dataset bib citation': '@article{zadeh2016multimodal,title={Multimodal sentiment intensity analysis in videos: Facial gestures and verbal messages},author={Zadeh, Amir and Zellers, Rowan and Pincus, Eli and Morency, Louis-Philippe},journal={IEEE Intelligent Systems},volume={31},number={6},pages={82--88},year={2016},publisher={IEEE}}', 'dataset name': 'CMU-MOSI', 'dataset version': 1.0, 'dimension names': ['F0', 'VUV', 'NAQ', 'QOQ', 'H1H2', 'PSP', 'MDQ', 'peakSlope', 'Rd', 'Rd_conf', 'creak', 'MCEP_0', 'MCEP_1', 'MCEP_2', 'MCEP_3', 'MCEP_4', 'MCEP_5', 'MCEP_6', 'MCEP_7', 'MCEP_8', 'MCEP_9', 'MCEP_10', 'MCEP_11', 'MCEP_12', 'MCEP_13', 'MCEP_14', 'MCEP_15', 'MCEP_16', 'MCEP_17', 'MCEP_18', 'MCEP_19', 'MCEP_20', 'MCEP_21', 'MCEP_22', 'MCEP_23', 'MCEP_24', 'HMPDM_0', 'HMPDM_1', 'HMPDM_2', 'HMPDM_3', 'HMPDM_4', 'HMPDM_5', 'HMPDM_6', 'HMPDM_7', 'HMPDM_8', 'HMPDM_9', 'HMPDM_10', 'HMPDM_11', 'HMPDM_12', 'HMPDM_13', 'HMPDM_14', 'HMPDM_15', 'HMPDM_16', 'HMPDM_17', 'HMPDM_18', 'HMPDM_19', 'HMPDM_20', 'HMPDM_21', 'HMPDM_22', 'HMPDM_23', 'HMPDM_24', 'HMPDD_0', 'HMPDD_1', 'HMPDD_2', 'HMPDD_3', 'HMPDD_4', 'HMPDD_5', 'HMPDD_6', 'HMPDD_7', 'HMPDD_8', 'HMPDD_9', 'HMPDD_10', 'HMPDD_11', 'HMPDD_12'], 'featureset bib citation': '@inproceedings{degottex2014covarep,title={COVAREP-A collaborative voice analysis repository for speech technologies},author={Degottex, Gilles and Kane, John and Drugman, Thomas and Raitio, Tuomo and Scherer, Stefan},booktitle={Acoustics, Speech and Signal Processing (ICASSP), 2014 IEEE International Conference on},pages={960--964},year={2014},organization={IEEE}}', 'md5': None, 'root name': 'COVAREP', 'uuid': 'b3040d49-2a1b-45f8-b991-16fb1acc75c5'}
#
#
# === Metadata Words===
#
# Words Metadata: {'alignment compatible': False, 'computational sequence description': 'Word sequences for CMU-MOSI Dataset', 'computational sequence version': 1.0, 'contact': 'abagherz@andrew.cmu.edu', 'creator': 'Amir Zadeh', 'dataset bib citation': '@article{zadeh2016multimodal,title={Multimodal sentiment intensity analysis in videos: Facial gestures and verbal messages},author={Zadeh, Amir and Zellers, Rowan and Pincus, Eli and Morency, Louis-Philippe},journal={IEEE Intelligent Systems},volume={31},number={6},pages={82--88},year={2016},publisher={IEEE}}', 'dataset name': 'CMU-MOSI', 'dataset version': 1.0, 'dimension names': ['word'], 'featureset bib citation': '@article{P2FA,title={Speaker identification on the SCOTUS corpus},author={Yuan, Jiahong and Liberman, Mark},journal={Journal of the Acoustical Society of America},volume={123},number={5},pages={3878},year={2008},publisher={[New York: Acoustical Society of America]}}', 'md5': None, 'root name': 'words', 'uuid': 'cf8e3281-bcec-49ff-be0e-6f98b55ad4d0'}

# %%
# # List all keys in the visual and acoustic fields
# # print("Keys in visual FACE41 field:", dataset[visual_field_Facet41].keys())
# # print("Keys in visual FACE42 field:", dataset[visual_field_Facet41].keys())
# # print("Keys in visual OpenFace field:", dataset[visual_field_OpenFace1].keys())
# # 
# # print("Keys in acousticC field:", dataset[acoustic_field_COVAREP].keys())
# # print("Keys in acousticOEB field:", dataset[acoustic_field_OpenSmile_EB10].keys())
# # print("Keys in acousticOIS field:", dataset[acoustic_field_OpenSmile_IS09].keys())
# 
# print("=== Metadata FACE 41 Visual===\n")
# print("Visual FACE 41 Metadata:", dataset[visual_field_Facet41].metadata)
# print("\n")
# 
# print("=== Metadata FACE 42 Visual===\n")
# print("Visual FACE 42 Metadata:", dataset[visual_field_Facet42].metadata)
# print("\n")
# 
# print("=== Metadata OpenFace Visual===\n")
# print("Visual OpenFace Metadata:", dataset[visual_field_OpenFace1].metadata)
# print("\n")
# 
# print("=== Metadata COVAREP Acoustic===\n")
# print("Acoustic COVAREP Metadata:", dataset[acoustic_field_COVAREP].metadata)
# print("\n")
# 
# # print("=== Metadata OpenSmile EB10 Acoustic===\n")
# # print("Acoustic OpenSmile EB10 Metadata:", dataset[acoustic_field_OpenSmile_EB10].metadata)
# # print("\n")
# 
# print("=== Metadata OpenSmile IS09 Acoustic===\n")
# print("Acoustic OpenSmile IS09 Metadata:", dataset[acoustic_field_OpenSmile_IS09].metadata)
# print("\n")
# 
# print("=== Metadata Words===\n")
# print("Words Metadata:", dataset[text_field_Words].metadata)
# print("\n")
# 
# print("=== Metadata Phones===\n")
# print("Phones Metadata:", dataset[text_field_Phones].metadata)
# print("\n")
# 
# print("=== Metadata WordVectors===\n")
# print("WordVectors Metadata:", dataset[text_field_WordVectors].metadata)
# print("\n")

# %%
# import pandas as pd
# 
# # Assuming 'dataset' and field variables (e.g., visual_field_Facet41) are already defined
# 
# # List of fields and their metadata
# fields_metadata = [
#     {"Field": "Visual FACE 41", "Metadata": dataset[visual_field_Facet41].metadata},
#     {"Field": "Visual FACE 42", "Metadata": dataset[visual_field_Facet42].metadata},
#     {"Field": "Visual OpenFace", "Metadata": dataset[visual_field_OpenFace1].metadata},
#     {"Field": "Acoustic COVAREP", "Metadata": dataset[acoustic_field_COVAREP].metadata},
#     {"Field": "Acoustic OpenSmile EB10", "Metadata": dataset[acoustic_field_OpenSmile_EB10].metadata},
#     {"Field": "Acoustic OpenSmile IS09", "Metadata": dataset[acoustic_field_OpenSmile_IS09].metadata},
#     {"Field": "Words", "Metadata": dataset[text_field_Words].metadata},
#     {"Field": "Phones", "Metadata": dataset[text_field_Phones].metadata},
#     {"Field": "WordVectors", "Metadata": dataset[text_field_WordVectors].metadata},
# ]
# 
# # Normalize (flatten) the metadata dictionaries
# normalized_data = []
# for entry in fields_metadata:
#     metadata_flat = pd.json_normalize(entry["Metadata"], sep="_")
#     metadata_flat["Field"] = entry["Field"]
#     normalized_data.append(metadata_flat)
# 
# # Concatenate all normalized data into a single DataFrame
# df_metadata = pd.concat(normalized_data, ignore_index=True)
# 
# # Reorder columns so "Field" is first
# df_metadata = df_metadata[["Field"] + [col for col in df_metadata.columns if col != "Field"]]
# 
# 
# # Save the DataFrame to a CSV file
# csv_filename = "metadata_summary.csv"
# df_metadata.to_csv(csv_filename, index=False)
# 
# print(f"Metadata successfully saved to {csv_filename}")
# 
# 
# 
# #remove \ for Acoustic OpenSmile EB10
# #remove b" and " for Acoustic OpenSmile IS09

# %%
# print(df_metadata.columns.tolist())
# 
# dimension_column = "dimension names"
# 
# 
# if dimension_column in df_metadata.columns:
#     # Extract the column as a pandas DataFrame and print it
#     dimension_data = df_metadata[[dimension_column]]
#     print(dimension_data)
# else:
#     print(f"The column '{dimension_column}' does not exist in the DataFrame.")
# 
# 
# csv_filename = "columns.csv"
# dimension_data.to_csv(csv_filename, index=False)
# 
# # delete "b""[ or "[ or [ from the start of the line
# # delete ] or ]" or ]""" from the end of the line

# %%
# import pandas as pd
# 
# # Specify the path to your CSV file
# csv_file_path = 'columns.csv'
# 
# # Read the CSV file with the specified separator
# df = pd.read_csv(csv_file_path, sep="\',\'", engine='python')
# 
# csv_filename = "columnsSeparatedElements.csv"
# df.to_csv(csv_filename, index=False)
# 
# 
# # Display the DataFrame to verify the contents
# print(df)

# %%
 # Iterate through all segments
# for segment in dataset[visual_field].keys():
#     # Access features for each modality
#     visual_features = dataset[visual_field][segment]['features']
#     acoustic_features = dataset[acoustic_field][segment]['features']
#     text_features = dataset[text_field][segment]['features']
#     
#     # Print segment information
#     print(f"Segment ID: {segment}")
#     print(f"Visual features shape: {visual_features.shape}")
#     print(f"Acoustic features shape: {acoustic_features.shape}")
#     print(f"Text features shape: {text_features.shape}")
#     
#     # Compute basic statistics for each segment
#     visual_mean = np.mean(visual_features, axis=0)
#     visual_std = np.std(visual_features, axis=0)
#     acoustic_mean = np.mean(acoustic_features, axis=0)
#     acoustic_std = np.std(acoustic_features, axis=0)
#     
#     print(f"Visual feature mean: {visual_mean}")
#     print(f"Visual feature std dev: {visual_std}")
#     print(f"Acoustic feature mean: {acoustic_mean}")
#     print(f"Acoustic feaure std dev: {acoustic_std}")
#     print("=" * 40)

# %% [markdown]
# ## Alignment of multimodal time series
#
# To work with multimodal time series that contains multiple views of data with different frequencies, we have to first align them to a ***pivot*** modality. The convention is to align to ***words***. Alignment groups feature vectors from other modalities into bins denoted by the timestamps of the pivot modality, and apply a certain processing function to each bin. We call this function ***collapse function***, because usually it is a pooling function that collapses multiple feature vectors from another modality into one single vector. This will give you sequences of same lengths in each modality (as the length of the pivot modality) for all videos.
#
# Here we define our collapse funtion as simple averaging. We feed the function to the SDK when we invoke `align` method. Note that the SDK always expect collapse functions with two arguments: `intervals` and `features`. Even if you don't use intervals (as is in the case below) you still need to define your function in the following way.
#
# ***Note: Currently the SDK applies the collapse function to all modalities including the pivot, and obviously text modality cannot be "averaged", causing some errors. My solution is to define the avg function such that it averages the features when it can, and return the content as is when it cannot average.***

# %%
# we define a simple averaging function that does not depend on intervals
def avg(intervals: np.array, features: np.array) -> np.array:
    try:
        return np.average(features, axis=0)
    except:
        return features

# first we align to words with averaging, collapse_function receives a list of functions
dataset.align(text_field_Words, collapse_functions=[avg])
# Out:
# [2024-12-03 11:01:33.803] | Status  | Unify was called ...
# [2024-12-03 11:01:33.804] | Success | Unify completed ...
# [2024-12-03 11:01:33.804] | Status  | Pre-alignment based on <CMU_MOSI_TimestampedWords> computational sequence started ...
# [2024-12-03 11:01:36.017] | Status  | Pre-alignment done for <CMU_MOSI_Visual_Facet_41> ...
# [2024-12-03 11:01:47.223] | Status  | Pre-alignment done for <CMU_MOSI_COVAREP> ...
# [2024-12-03 11:01:47.316] | Status  | Alignment starting ...
# Overall Progress:   0%|          | 0/93 [00:00<?, ? Computational Sequence Entries/s]
#   0%|          | 0/464 [00:00<?, ? Segments/s]
# Aligning 03bSnISJMiM:   0%|          | 0/464 [00:00<?, ? Segments/s]
# Aligning 03bSnISJMiM:   2%|▏         | 9/464 [00:00<00:05, 88.80 Segments/s]
# Aligning 03bSnISJMiM:   6%|▋         | 29/464 [00:00<00:02, 153.16 Segments/s]
# Aligning 03bSnISJMiM:  10%|█         | 47/464 [00:00<00:02, 163.13 Segments/s]
# Aligning 03bSnISJMiM:  14%|█▍        | 67/464 [00:00<00:02, 177.45 Segments/s]
# Aligning 03bSnISJMiM:  19%|█▊        | 86/464 [00:00<00:02, 181.71 Segments/s]
# Aligning 03bSnISJMiM:  23%|██▎       | 105/464 [00:00<00:01, 179.99 Segments/s]
# Aligning 03bSnISJMiM:  27%|██▋       | 124/464 [00:00<00:02, 169.09 Segments/s]
# Aligning 03bSnISJMiM:  31%|███▏      | 145/464 [00:00<00:01, 179.11 Segments/s]
# Aligning 03bSnISJMiM:  36%|███▌      | 168/464 [00:00<00:01, 193.62 Segments/s]
# Aligning 03bSnISJMiM:  43%|████▎     | 201/464 [00:01<00:01, 232.49 Segments/s]
# Aligning 03bSnISJMiM:  50%|█████     | 233/464 [00:01<00:00, 255.87 Segments/s]
# Aligning 03bSnISJMiM:  58%|█████▊    | 267/464 [00:01<00:00, 280.62 Segments/s]
# Aligning 03bSnISJMiM:  64%|██████▍   | 299/464 [00:01<00:00, 291.75 Segments/s]
# Aligning 03bSnISJMiM:  72%|███████▏  | 332/464 [00:01<00:00, 301.28 Segments/s]
# Aligning 03bSnISJMiM:  78%|███████▊  | 363/464 [00:01<00:00, 290.98 Segments/s]
# Aligning 03bSnISJMiM:  85%|████████▌ | 396/464 [00:01<00:00, 299.77 Segments/s]
# Aligning 03bSnISJMiM:  92%|█████████▏| 427/464 [00:01<00:00, 292.71 Segments/s]
# Aligning 03bSnISJMiM:  98%|█████████▊| 457/464 [00:01<00:00, 294.45 Segments/s]
# Overall Progress:   1%|          | 1/93 [00:01<02:56,  1.92s/ Computational Sequence Entries]
#   0%|          | 0/485 [00:00<?, ? Segments/s]
# Aligning 0h-zjBukYpk:   0%|          | 0/485 [00:00<?, ? Segments/s]
# Aligning 0h-zjBukYpk:   4%|▎         | 17/485 [00:00<00:02, 169.97 Segments/s]
# Aligning 0h-zjBukYpk:  10%|█         | 49/485 [00:00<00:01, 254.83 Segments/s]
# Aligning 0h-zjBukYpk:  17%|█▋        | 81/485 [00:00<00:01, 282.02 Segments/s]
# Aligning 0h-zjBukYpk:  23%|██▎       | 111/485 [00:00<00:01, 287.78 Segments/s]
# Aligning 0h-zjBukYpk:  29%|██▉       | 141/485 [00:00<00:01, 290.68 Segments/s]
# Aligning 0h-zjBukYpk:  37%|███▋      | 180/485 [00:00<00:00, 323.33 Segments/s]
# Aligning 0h-zjBukYpk:  44%|████▍     | 215/485 [00:00<00:00, 329.55 Segments/s]
# Aligning 0h-zjBukYpk:  52%|█████▏    | 250/485 [00:00<00:00, 334.85 Segments/s]
# Aligning 0h-zjBukYpk:  59%|█████▊    | 284/485 [00:00<00:00, 313.99 Segments/s]
# Aligning 0h-zjBukYpk:  65%|██████▌   | 316/485 [00:01<00:00, 301.38 Segments/s]
# Aligning 0h-zjBukYpk:  73%|███████▎  | 352/485 [00:01<00:00, 317.26 Segments/s]
# Aligning 0h-zjBukYpk:  79%|███████▉  | 384/485 [00:01<00:00, 302.86 Segments/s]
# Aligning 0h-zjBukYpk:  86%|████████▌ | 415/485 [00:01<00:00, 301.91 Segments/s]
# Aligning 0h-zjBukYpk:  92%|█████████▏| 446/485 [00:01<00:00, 300.57 Segments/s]
# Aligning 0h-zjBukYpk:  99%|█████████▊| 478/485 [00:01<00:00, 305.06 Segments/s]
# Overall Progress:   2%|▏         | 2/93 [00:03<02:38,  1.74s/ Computational Sequence Entries]
#   0%|          | 0/237 [00:00<?, ? Segments/s]
# Aligning 1DmNV9C1hbY:   0%|          | 0/237 [00:00<?, ? Segments/s]
# Aligning 1DmNV9C1hbY:  14%|█▎        | 32/237 [00:00<00:00, 305.11 Segments/s]
# Aligning 1DmNV9C1hbY:  28%|██▊       | 66/237 [00:00<00:00, 320.75 Segments/s]
# Aligning 1DmNV9C1hbY:  44%|████▍     | 105/237 [00:00<00:00, 349.96 Segments/s]
# Aligning 1DmNV9C1hbY:  61%|██████    | 145/237 [00:00<00:00, 366.96 Segments/s]
# Aligning 1DmNV9C1hbY:  80%|███████▉  | 189/237 [00:00<00:00, 391.88 Segments/s]
# Aligning 1DmNV9C1hbY: 100%|█████████▉| 236/237 [00:00<00:00, 417.53 Segments/s]
# Overall Progress:   3%|▎         | 3/93 [00:04<01:50,  1.23s/ Computational Sequence Entries]
#   0%|          | 0/562 [00:00<?, ? Segments/s]
# Aligning 1iG0909rllw:   0%|          | 0/562 [00:00<?, ? Segments/s]
# Aligning 1iG0909rllw:   4%|▎         | 21/562 [00:00<00:02, 207.29 Segments/s]
# Aligning 1iG0909rllw:  10%|▉         | 55/562 [00:00<00:01, 278.18 Segments/s]
# Aligning 1iG0909rllw:  16%|█▌        | 89/562 [00:00<00:01, 302.64 Segments/s]
# Aligning 1iG0909rllw:  22%|██▏       | 124/562 [00:00<00:01, 316.49 Segments/s]
# Aligning 1iG0909rllw:  29%|██▊       | 161/562 [00:00<00:01, 334.42 Segments/s]
# Aligning 1iG0909rllw:  35%|███▍      | 195/562 [00:00<00:01, 336.16 Segments/s]
# Aligning 1iG0909rllw:  41%|████      | 229/562 [00:00<00:01, 332.79 Segments/s]
# Aligning 1iG0909rllw:  47%|████▋     | 263/562 [00:00<00:00, 328.35 Segments/s]
# Aligning 1iG0909rllw:  53%|█████▎    | 297/562 [00:00<00:00, 330.69 Segments/s]
# Aligning 1iG0909rllw:  59%|█████▉    | 333/562 [00:01<00:00, 337.61 Segments/s]
# Aligning 1iG0909rllw:  65%|██████▌   | 367/562 [00:01<00:00, 334.15 Segments/s]
# Aligning 1iG0909rllw:  72%|███████▏  | 403/562 [00:01<00:00, 338.67 Segments/s]
# Aligning 1iG0909rllw:  78%|███████▊  | 437/562 [00:01<00:00, 337.80 Segments/s]
# Aligning 1iG0909rllw:  84%|████████▍ | 471/562 [00:01<00:00, 332.03 Segments/s]
# Aligning 1iG0909rllw:  90%|████████▉ | 505/562 [00:01<00:00, 332.22 Segments/s]
# Aligning 1iG0909rllw:  96%|█████████▌| 540/562 [00:01<00:00, 336.42 Segments/s]
# Overall Progress:   4%|▍         | 4/93 [00:05<02:06,  1.42s/ Computational Sequence Entries]
#   0%|          | 0/651 [00:00<?, ? Segments/s]
# Aligning 2WGyTLYerpo:   0%|          | 0/651 [00:00<?, ? Segments/s]
# Aligning 2WGyTLYerpo:   4%|▎         | 24/651 [00:00<00:02, 236.09 Segments/s]
# Aligning 2WGyTLYerpo:   8%|▊         | 55/651 [00:00<00:02, 275.73 Segments/s]
# Aligning 2WGyTLYerpo:  13%|█▎        | 84/651 [00:00<00:02, 281.57 Segments/s]
# Aligning 2WGyTLYerpo:  18%|█▊        | 120/651 [00:00<00:01, 308.05 Segments/s]
# Aligning 2WGyTLYerpo:  24%|██▎       | 153/651 [00:00<00:01, 314.59 Segments/s]
# Aligning 2WGyTLYerpo:  28%|██▊       | 185/651 [00:00<00:01, 311.57 Segments/s]
# Aligning 2WGyTLYerpo:  33%|███▎      | 217/651 [00:00<00:01, 308.92 Segments/s]
# Aligning 2WGyTLYerpo:  38%|███▊      | 248/651 [00:00<00:01, 305.17 Segments/s]
# Aligning 2WGyTLYerpo:  43%|████▎     | 279/651 [00:00<00:01, 286.98 Segments/s]
# Aligning 2WGyTLYerpo:  48%|████▊     | 311/651 [00:01<00:01, 294.49 Segments/s]
# Aligning 2WGyTLYerpo:  53%|█████▎    | 346/651 [00:01<00:00, 308.65 Segments/s]
# Aligning 2WGyTLYerpo:  58%|█████▊    | 379/651 [00:01<00:00, 313.34 Segments/s]
# Aligning 2WGyTLYerpo:  63%|██████▎   | 411/651 [00:01<00:00, 313.63 Segments/s]
# Aligning 2WGyTLYerpo:  68%|██████▊   | 443/651 [00:01<00:00, 242.69 Segments/s]
# Aligning 2WGyTLYerpo:  73%|███████▎  | 477/651 [00:01<00:00, 266.06 Segments/s]
# Aligning 2WGyTLYerpo:  79%|███████▉  | 513/651 [00:01<00:00, 289.36 Segments/s]
# Aligning 2WGyTLYerpo:  84%|████████▍ | 546/651 [00:01<00:00, 298.81 Segments/s]
# Aligning 2WGyTLYerpo:  89%|████████▉ | 579/651 [00:01<00:00, 307.02 Segments/s]
# Aligning 2WGyTLYerpo:  94%|█████████▍| 611/651 [00:02<00:00, 302.89 Segments/s]
# Aligning 2WGyTLYerpo:  99%|█████████▉| 643/651 [00:02<00:00, 296.98 Segments/s]
# Overall Progress:   5%|▌         | 5/93 [00:08<02:30,  1.71s/ Computational Sequence Entries]
#   0%|          | 0/700 [00:00<?, ? Segments/s]
# Aligning 2iD-tVS8NPw:   0%|          | 0/700 [00:00<?, ? Segments/s]
# Aligning 2iD-tVS8NPw:   2%|▏         | 17/700 [00:00<00:04, 168.30 Segments/s]
# Aligning 2iD-tVS8NPw:   6%|▋         | 45/700 [00:00<00:02, 229.87 Segments/s]
# Aligning 2iD-tVS8NPw:  10%|█         | 70/700 [00:00<00:02, 235.80 Segments/s]
# Aligning 2iD-tVS8NPw:  14%|█▍        | 99/700 [00:00<00:02, 255.89 Segments/s]
# Aligning 2iD-tVS8NPw:  18%|█▊        | 128/700 [00:00<00:02, 264.41 Segments/s]
# Aligning 2iD-tVS8NPw:  22%|██▏       | 155/700 [00:00<00:02, 265.38 Segments/s]
# Aligning 2iD-tVS8NPw:  26%|██▋       | 185/700 [00:00<00:01, 276.30 Segments/s]
# Aligning 2iD-tVS8NPw:  30%|███       | 213/700 [00:00<00:01, 264.17 Segments/s]
# Aligning 2iD-tVS8NPw:  36%|███▌      | 249/700 [00:00<00:01, 292.12 Segments/s]
# Aligning 2iD-tVS8NPw:  40%|███▉      | 279/700 [00:01<00:01, 277.14 Segments/s]
# Aligning 2iD-tVS8NPw:  44%|████▍     | 309/700 [00:01<00:01, 282.56 Segments/s]
# Aligning 2iD-tVS8NPw:  48%|████▊     | 339/700 [00:01<00:01, 285.77 Segments/s]
# Aligning 2iD-tVS8NPw:  53%|█████▎    | 368/700 [00:01<00:01, 284.42 Segments/s]
# Aligning 2iD-tVS8NPw:  57%|█████▋    | 401/700 [00:01<00:01, 296.78 Segments/s]
# Aligning 2iD-tVS8NPw:  62%|██████▏   | 435/700 [00:01<00:00, 308.96 Segments/s]
# Aligning 2iD-tVS8NPw:  67%|██████▋   | 468/700 [00:01<00:00, 312.76 Segments/s]
# Aligning 2iD-tVS8NPw:  71%|███████▏  | 500/700 [00:01<00:00, 313.73 Segments/s]
# Aligning 2iD-tVS8NPw:  76%|███████▌  | 532/700 [00:01<00:00, 302.32 Segments/s]
# Aligning 2iD-tVS8NPw:  81%|████████  | 565/700 [00:01<00:00, 308.42 Segments/s]
# Aligning 2iD-tVS8NPw:  86%|████████▌ | 601/700 [00:02<00:00, 321.82 Segments/s]
# Aligning 2iD-tVS8NPw:  91%|█████████ | 634/700 [00:02<00:00, 319.03 Segments/s]
# Aligning 2iD-tVS8NPw:  95%|█████████▌| 666/700 [00:02<00:00, 319.24 Segments/s]
# Aligning 2iD-tVS8NPw: 100%|██████████| 700/700 [00:02<00:00, 321.01 Segments/s]
# Overall Progress:   6%|▋         | 6/93 [00:10<02:49,  1.95s/ Computational Sequence Entries]
#   0%|          | 0/262 [00:00<?, ? Segments/s]
# Aligning 5W7Z1C_fDaE:   0%|          | 0/262 [00:00<?, ? Segments/s]
# Aligning 5W7Z1C_fDaE:  18%|█▊        | 48/262 [00:00<00:00, 472.38 Segments/s]
# Aligning 5W7Z1C_fDaE:  37%|███▋      | 96/262 [00:00<00:00, 461.19 Segments/s]
# Aligning 5W7Z1C_fDaE:  55%|█████▍    | 143/262 [00:00<00:00, 446.22 Segments/s]
# Aligning 5W7Z1C_fDaE:  72%|███████▏  | 188/262 [00:00<00:00, 434.86 Segments/s]
# Aligning 5W7Z1C_fDaE:  89%|████████▊ | 232/262 [00:00<00:00, 427.71 Segments/s]
# Overall Progress:   8%|▊         | 7/93 [00:11<02:10,  1.51s/ Computational Sequence Entries]
#   0%|          | 0/411 [00:00<?, ? Segments/s]
# Aligning 6Egk_28TtTM:   0%|          | 0/411 [00:00<?, ? Segments/s]
# Aligning 6Egk_28TtTM:   9%|▉         | 36/411 [00:00<00:01, 352.34 Segments/s]
# Aligning 6Egk_28TtTM:  18%|█▊        | 72/411 [00:00<00:00, 349.35 Segments/s]
# Aligning 6Egk_28TtTM:  26%|██▌       | 107/411 [00:00<00:00, 339.37 Segments/s]
# Aligning 6Egk_28TtTM:  34%|███▍      | 141/411 [00:00<00:00, 310.22 Segments/s]
# Aligning 6Egk_28TtTM:  42%|████▏     | 173/411 [00:00<00:00, 302.85 Segments/s]
# Aligning 6Egk_28TtTM:  50%|████▉     | 205/411 [00:00<00:00, 306.89 Segments/s]
# Aligning 6Egk_28TtTM:  57%|█████▋    | 236/411 [00:00<00:00, 289.20 Segments/s]
# Aligning 6Egk_28TtTM:  66%|██████▌   | 270/411 [00:00<00:00, 303.83 Segments/s]
# Aligning 6Egk_28TtTM:  75%|███████▍  | 307/411 [00:00<00:00, 322.70 Segments/s]
# Aligning 6Egk_28TtTM:  83%|████████▎ | 341/411 [00:01<00:00, 327.70 Segments/s]
# Aligning 6Egk_28TtTM:  91%|█████████ | 374/411 [00:01<00:00, 309.48 Segments/s]
# Aligning 6Egk_28TtTM:  99%|█████████▉| 406/411 [00:01<00:00, 296.87 Segments/s]
# Overall Progress:   9%|▊         | 8/93 [00:12<02:03,  1.46s/ Computational Sequence Entries]
#   0%|          | 0/374 [00:00<?, ? Segments/s]
# Aligning 6_0THN4chvY:   0%|          | 0/374 [00:00<?, ? Segments/s]
# Aligning 6_0THN4chvY:  10%|▉         | 37/374 [00:00<00:00, 362.68 Segments/s]
# Aligning 6_0THN4chvY:  20%|██        | 75/374 [00:00<00:00, 372.62 Segments/s]
# Aligning 6_0THN4chvY:  30%|███       | 113/374 [00:00<00:00, 370.72 Segments/s]
# Aligning 6_0THN4chvY:  41%|████      | 153/374 [00:00<00:00, 380.53 Segments/s]
# Aligning 6_0THN4chvY:  52%|█████▏    | 195/374 [00:00<00:00, 391.51 Segments/s]
# Aligning 6_0THN4chvY:  64%|██████▎   | 238/374 [00:00<00:00, 401.01 Segments/s]
# Aligning 6_0THN4chvY:  75%|███████▍  | 279/374 [00:00<00:00, 389.87 Segments/s]
# Aligning 6_0THN4chvY:  85%|████████▌ | 319/374 [00:00<00:00, 378.89 Segments/s]
# Aligning 6_0THN4chvY:  95%|█████████▌| 357/374 [00:00<00:00, 370.53 Segments/s]
# Overall Progress:  10%|▉         | 9/93 [00:13<01:50,  1.31s/ Computational Sequence Entries]
#   0%|          | 0/591 [00:00<?, ? Segments/s]
# Aligning 73jzhE8R1TQ:   0%|          | 0/591 [00:00<?, ? Segments/s]
# Aligning 73jzhE8R1TQ:   6%|▌         | 35/591 [00:00<00:01, 344.26 Segments/s]
# Aligning 73jzhE8R1TQ:  12%|█▏        | 70/591 [00:00<00:01, 296.59 Segments/s]
# Aligning 73jzhE8R1TQ:  17%|█▋        | 102/591 [00:00<00:01, 304.62 Segments/s]
# Aligning 73jzhE8R1TQ:  23%|██▎       | 134/591 [00:00<00:01, 309.18 Segments/s]
# Aligning 73jzhE8R1TQ:  28%|██▊       | 168/591 [00:00<00:01, 317.96 Segments/s]
# Aligning 73jzhE8R1TQ:  34%|███▍      | 200/591 [00:00<00:01, 310.14 Segments/s]
# Aligning 73jzhE8R1TQ:  39%|███▉      | 232/591 [00:00<00:01, 296.36 Segments/s]
# Aligning 73jzhE8R1TQ:  44%|████▍     | 262/591 [00:00<00:01, 280.99 Segments/s]
# Aligning 73jzhE8R1TQ:  49%|████▉     | 291/591 [00:00<00:01, 273.95 Segments/s]
# Aligning 73jzhE8R1TQ:  56%|█████▌    | 329/591 [00:01<00:00, 303.09 Segments/s]
# Aligning 73jzhE8R1TQ:  62%|██████▏   | 367/591 [00:01<00:00, 323.82 Segments/s]
# Aligning 73jzhE8R1TQ:  68%|██████▊   | 401/591 [00:01<00:00, 327.63 Segments/s]
# Aligning 73jzhE8R1TQ:  74%|███████▎  | 435/591 [00:01<00:00, 308.77 Segments/s]
# Aligning 73jzhE8R1TQ:  79%|███████▉  | 467/591 [00:01<00:00, 291.43 Segments/s]
# Aligning 73jzhE8R1TQ:  85%|████████▍ | 501/591 [00:01<00:00, 302.91 Segments/s]
# Aligning 73jzhE8R1TQ:  90%|█████████ | 534/591 [00:01<00:00, 309.54 Segments/s]
# Aligning 73jzhE8R1TQ:  96%|█████████▌| 566/591 [00:01<00:00, 292.72 Segments/s]
# Overall Progress:  11%|█         | 10/93 [00:15<02:05,  1.52s/ Computational Sequence Entries]
#   0%|          | 0/636 [00:00<?, ? Segments/s]
# Aligning 7JsX8y1ysxY:   0%|          | 0/636 [00:00<?, ? Segments/s]
# Aligning 7JsX8y1ysxY:   5%|▌         | 33/636 [00:00<00:01, 323.50 Segments/s]
# Aligning 7JsX8y1ysxY:  11%|█         | 71/636 [00:00<00:01, 351.61 Segments/s]
# Aligning 7JsX8y1ysxY:  17%|█▋        | 108/636 [00:00<00:01, 356.89 Segments/s]
# Aligning 7JsX8y1ysxY:  23%|██▎       | 144/636 [00:00<00:01, 308.40 Segments/s]
# Aligning 7JsX8y1ysxY:  28%|██▊       | 176/636 [00:00<00:01, 305.66 Segments/s]
# Aligning 7JsX8y1ysxY:  33%|███▎      | 209/636 [00:00<00:01, 313.10 Segments/s]
# Aligning 7JsX8y1ysxY:  38%|███▊      | 242/636 [00:00<00:01, 318.23 Segments/s]
# Aligning 7JsX8y1ysxY:  43%|████▎     | 275/636 [00:00<00:01, 313.12 Segments/s]
# Aligning 7JsX8y1ysxY:  48%|████▊     | 307/636 [00:00<00:01, 302.56 Segments/s]
# Aligning 7JsX8y1ysxY:  53%|█████▎    | 338/636 [00:01<00:01, 296.40 Segments/s]
# Aligning 7JsX8y1ysxY:  59%|█████▊    | 373/636 [00:01<00:00, 311.21 Segments/s]
# Aligning 7JsX8y1ysxY:  64%|██████▍   | 407/636 [00:01<00:00, 319.52 Segments/s]
# Aligning 7JsX8y1ysxY:  69%|██████▉   | 440/636 [00:01<00:00, 313.41 Segments/s]
# Aligning 7JsX8y1ysxY:  74%|███████▍  | 472/636 [00:01<00:00, 304.50 Segments/s]
# Aligning 7JsX8y1ysxY:  79%|███████▉  | 505/636 [00:01<00:00, 310.24 Segments/s]
# Aligning 7JsX8y1ysxY:  85%|████████▌ | 543/636 [00:01<00:00, 328.26 Segments/s]
# Aligning 7JsX8y1ysxY:  91%|█████████ | 576/636 [00:01<00:00, 326.05 Segments/s]
# Aligning 7JsX8y1ysxY:  96%|█████████▌| 609/636 [00:01<00:00, 302.25 Segments/s]
# Overall Progress:  12%|█▏        | 11/93 [00:17<02:17,  1.68s/ Computational Sequence Entries]
#   0%|          | 0/654 [00:00<?, ? Segments/s]
# Aligning 8OtFthrtaJM:   0%|          | 0/654 [00:00<?, ? Segments/s]
# Aligning 8OtFthrtaJM:   5%|▌         | 34/654 [00:00<00:01, 331.54 Segments/s]
# Aligning 8OtFthrtaJM:  10%|█         | 68/654 [00:00<00:01, 318.52 Segments/s]
# Aligning 8OtFthrtaJM:  15%|█▌        | 100/654 [00:00<00:01, 285.17 Segments/s]
# Aligning 8OtFthrtaJM:  20%|█▉        | 129/654 [00:00<00:01, 281.23 Segments/s]
# Aligning 8OtFthrtaJM:  24%|██▍       | 158/654 [00:00<00:01, 280.86 Segments/s]
# Aligning 8OtFthrtaJM:  29%|██▉       | 189/654 [00:00<00:01, 288.43 Segments/s]
# Aligning 8OtFthrtaJM:  34%|███▍      | 225/654 [00:00<00:01, 307.77 Segments/s]
# Aligning 8OtFthrtaJM:  39%|███▉      | 256/654 [00:00<00:01, 307.66 Segments/s]
# Aligning 8OtFthrtaJM:  45%|████▍     | 292/654 [00:00<00:01, 322.15 Segments/s]
# Aligning 8OtFthrtaJM:  50%|█████     | 330/654 [00:01<00:00, 338.85 Segments/s]
# Aligning 8OtFthrtaJM:  56%|█████▌    | 364/654 [00:01<00:00, 301.48 Segments/s]
# Aligning 8OtFthrtaJM:  60%|██████    | 395/654 [00:01<00:00, 301.32 Segments/s]
# Aligning 8OtFthrtaJM:  66%|██████▌   | 429/654 [00:01<00:00, 311.14 Segments/s]
# Aligning 8OtFthrtaJM:  70%|███████   | 461/654 [00:01<00:00, 313.54 Segments/s]
# Aligning 8OtFthrtaJM:  75%|███████▌  | 493/654 [00:01<00:00, 312.40 Segments/s]
# Aligning 8OtFthrtaJM:  80%|████████  | 525/654 [00:01<00:00, 296.09 Segments/s]
# Aligning 8OtFthrtaJM:  85%|████████▌ | 557/654 [00:01<00:00, 301.21 Segments/s]
# Aligning 8OtFthrtaJM:  90%|████████▉ | 588/654 [00:01<00:00, 301.28 Segments/s]
# Aligning 8OtFthrtaJM:  95%|█████████▍| 620/654 [00:02<00:00, 304.63 Segments/s]
# Aligning 8OtFthrtaJM: 100%|██████████| 654/654 [00:02<00:00, 312.78 Segments/s]
# Overall Progress:  13%|█▎        | 12/93 [00:19<02:27,  1.82s/ Computational Sequence Entries]
#   0%|          | 0/584 [00:00<?, ? Segments/s]
# Aligning 8d-gEyoeBzc:   0%|          | 0/584 [00:00<?, ? Segments/s]
# Aligning 8d-gEyoeBzc:   5%|▌         | 32/584 [00:00<00:01, 317.80 Segments/s]
# Aligning 8d-gEyoeBzc:  11%|█▏        | 66/584 [00:00<00:01, 327.17 Segments/s]
# Aligning 8d-gEyoeBzc:  17%|█▋        | 99/584 [00:00<00:01, 322.98 Segments/s]
# Aligning 8d-gEyoeBzc:  23%|██▎       | 132/584 [00:00<00:01, 319.26 Segments/s]
# Aligning 8d-gEyoeBzc:  28%|██▊       | 164/584 [00:00<00:01, 311.13 Segments/s]
# Aligning 8d-gEyoeBzc:  34%|███▎      | 196/584 [00:00<00:01, 308.47 Segments/s]
# Aligning 8d-gEyoeBzc:  40%|███▉      | 232/584 [00:00<00:01, 323.31 Segments/s]
# Aligning 8d-gEyoeBzc:  45%|████▌     | 265/584 [00:00<00:00, 323.20 Segments/s]
# Aligning 8d-gEyoeBzc:  51%|█████     | 298/584 [00:00<00:00, 323.17 Segments/s]
# Aligning 8d-gEyoeBzc:  57%|█████▋    | 331/584 [00:01<00:00, 318.44 Segments/s]
# Aligning 8d-gEyoeBzc:  62%|██████▏   | 363/584 [00:01<00:00, 314.98 Segments/s]
# Aligning 8d-gEyoeBzc:  68%|██████▊   | 395/584 [00:01<00:00, 310.57 Segments/s]
# Aligning 8d-gEyoeBzc:  73%|███████▎  | 428/584 [00:01<00:00, 316.04 Segments/s]
# Aligning 8d-gEyoeBzc:  79%|███████▉  | 464/584 [00:01<00:00, 328.14 Segments/s]
# Aligning 8d-gEyoeBzc:  85%|████████▌ | 499/584 [00:01<00:00, 330.56 Segments/s]
# Aligning 8d-gEyoeBzc:  91%|█████████▏| 534/584 [00:01<00:00, 335.72 Segments/s]
# Aligning 8d-gEyoeBzc:  97%|█████████▋| 568/584 [00:01<00:00, 331.75 Segments/s]
# Overall Progress:  14%|█▍        | 13/93 [00:21<02:26,  1.83s/ Computational Sequence Entries]
#   0%|          | 0/523 [00:00<?, ? Segments/s]
# Aligning 8qrpnFRGt2A:   0%|          | 0/523 [00:00<?, ? Segments/s]
# Aligning 8qrpnFRGt2A:   6%|▌         | 29/523 [00:00<00:01, 285.81 Segments/s]
# Aligning 8qrpnFRGt2A:  11%|█▏        | 60/523 [00:00<00:01, 296.70 Segments/s]
# Aligning 8qrpnFRGt2A:  18%|█▊        | 94/523 [00:00<00:01, 314.38 Segments/s]
# Aligning 8qrpnFRGt2A:  24%|██▍       | 126/523 [00:00<00:01, 313.55 Segments/s]
# Aligning 8qrpnFRGt2A:  30%|███       | 159/523 [00:00<00:01, 318.80 Segments/s]
# Aligning 8qrpnFRGt2A:  37%|███▋      | 191/523 [00:00<00:01, 311.05 Segments/s]
# Aligning 8qrpnFRGt2A:  43%|████▎     | 223/523 [00:00<00:00, 302.31 Segments/s]
# Aligning 8qrpnFRGt2A:  49%|████▊     | 254/523 [00:00<00:00, 283.15 Segments/s]
# Aligning 8qrpnFRGt2A:  54%|█████▍    | 283/523 [00:00<00:00, 271.82 Segments/s]
# Aligning 8qrpnFRGt2A:  61%|██████    | 317/523 [00:01<00:00, 288.80 Segments/s]
# Aligning 8qrpnFRGt2A:  67%|██████▋   | 350/523 [00:01<00:00, 300.28 Segments/s]
# Aligning 8qrpnFRGt2A:  74%|███████▎  | 385/523 [00:01<00:00, 314.24 Segments/s]
# Aligning 8qrpnFRGt2A:  80%|███████▉  | 417/523 [00:01<00:00, 307.55 Segments/s]
# Aligning 8qrpnFRGt2A:  86%|████████▌ | 448/523 [00:01<00:00, 294.24 Segments/s]
# Aligning 8qrpnFRGt2A:  92%|█████████▏| 479/523 [00:01<00:00, 297.01 Segments/s]
# Aligning 8qrpnFRGt2A:  98%|█████████▊| 511/523 [00:01<00:00, 302.92 Segments/s]
# Overall Progress:  15%|█▌        | 14/93 [00:23<02:22,  1.81s/ Computational Sequence Entries]
#   0%|          | 0/554 [00:00<?, ? Segments/s]
# Aligning 9J25DZhivz8:   0%|          | 0/554 [00:00<?, ? Segments/s]
# Aligning 9J25DZhivz8:   6%|▌         | 32/554 [00:00<00:01, 312.42 Segments/s]
# Aligning 9J25DZhivz8:  12%|█▏        | 64/554 [00:00<00:01, 290.46 Segments/s]
# Aligning 9J25DZhivz8:  17%|█▋        | 94/554 [00:00<00:01, 288.97 Segments/s]
# Aligning 9J25DZhivz8:  23%|██▎       | 126/554 [00:00<00:01, 297.59 Segments/s]
# Aligning 9J25DZhivz8:  29%|██▉       | 160/554 [00:00<00:01, 310.37 Segments/s]
# Aligning 9J25DZhivz8:  35%|███▌      | 195/554 [00:00<00:01, 320.72 Segments/s]
# Aligning 9J25DZhivz8:  42%|████▏     | 231/554 [00:00<00:00, 330.80 Segments/s]
# Aligning 9J25DZhivz8:  48%|████▊     | 265/554 [00:00<00:00, 321.39 Segments/s]
# Aligning 9J25DZhivz8:  54%|█████▍    | 298/554 [00:00<00:00, 318.51 Segments/s]
# Aligning 9J25DZhivz8:  60%|█████▉    | 330/554 [00:01<00:00, 313.97 Segments/s]
# Aligning 9J25DZhivz8:  66%|██████▌   | 366/554 [00:01<00:00, 326.47 Segments/s]
# Aligning 9J25DZhivz8:  72%|███████▏  | 399/554 [00:01<00:00, 320.62 Segments/s]
# Aligning 9J25DZhivz8:  78%|███████▊  | 432/554 [00:01<00:00, 309.45 Segments/s]
# Aligning 9J25DZhivz8:  84%|████████▍ | 464/554 [00:01<00:00, 301.69 Segments/s]
# Aligning 9J25DZhivz8:  89%|████████▉ | 495/554 [00:01<00:00, 284.77 Segments/s]
# Aligning 9J25DZhivz8:  95%|█████████▍| 526/554 [00:01<00:00, 289.46 Segments/s]
# Overall Progress:  16%|█▌        | 15/93 [00:25<02:21,  1.82s/ Computational Sequence Entries]
#   0%|          | 0/645 [00:00<?, ? Segments/s]
# Aligning 9T9Hf74oK10:   0%|          | 0/645 [00:00<?, ? Segments/s]
# Aligning 9T9Hf74oK10:   3%|▎         | 19/645 [00:00<00:03, 185.85 Segments/s]
# Aligning 9T9Hf74oK10:   9%|▊         | 56/645 [00:00<00:02, 293.18 Segments/s]
# Aligning 9T9Hf74oK10:  14%|█▍        | 90/645 [00:00<00:01, 311.96 Segments/s]
# Aligning 9T9Hf74oK10:  19%|█▉        | 122/645 [00:00<00:01, 313.85 Segments/s]
# Aligning 9T9Hf74oK10:  24%|██▍       | 155/645 [00:00<00:01, 316.23 Segments/s]
# Aligning 9T9Hf74oK10:  29%|██▉       | 187/645 [00:00<00:01, 311.26 Segments/s]
# Aligning 9T9Hf74oK10:  34%|███▍      | 219/645 [00:00<00:01, 312.71 Segments/s]
# Aligning 9T9Hf74oK10:  39%|███▉      | 251/645 [00:00<00:01, 312.19 Segments/s]
# Aligning 9T9Hf74oK10:  44%|████▍     | 283/645 [00:00<00:01, 306.84 Segments/s]
# Aligning 9T9Hf74oK10:  49%|████▊     | 314/645 [00:01<00:01, 285.39 Segments/s]
# Aligning 9T9Hf74oK10:  53%|█████▎    | 344/645 [00:01<00:01, 288.27 Segments/s]
# Aligning 9T9Hf74oK10:  59%|█████▉    | 380/645 [00:01<00:00, 308.36 Segments/s]
# Aligning 9T9Hf74oK10:  64%|██████▍   | 412/645 [00:01<00:00, 304.67 Segments/s]
# Aligning 9T9Hf74oK10:  70%|██████▉   | 450/645 [00:01<00:00, 323.60 Segments/s]
# Aligning 9T9Hf74oK10:  75%|███████▌  | 485/645 [00:01<00:00, 330.31 Segments/s]
# Aligning 9T9Hf74oK10:  80%|████████  | 519/645 [00:01<00:00, 325.71 Segments/s]
# Aligning 9T9Hf74oK10:  86%|████████▌ | 552/645 [00:01<00:00, 310.34 Segments/s]
# Aligning 9T9Hf74oK10:  91%|█████████ | 588/645 [00:01<00:00, 322.80 Segments/s]
# Aligning 9T9Hf74oK10:  97%|█████████▋| 627/645 [00:01<00:00, 339.56 Segments/s]
# Overall Progress:  17%|█▋        | 16/93 [00:27<02:25,  1.89s/ Computational Sequence Entries]
#   0%|          | 0/300 [00:00<?, ? Segments/s]
# Aligning 9c67fiY0wGQ:   0%|          | 0/300 [00:00<?, ? Segments/s]
# Aligning 9c67fiY0wGQ:  14%|█▍        | 43/300 [00:00<00:00, 424.89 Segments/s]
# Aligning 9c67fiY0wGQ:  30%|███       | 90/300 [00:00<00:00, 446.49 Segments/s]
# Aligning 9c67fiY0wGQ:  45%|████▌     | 135/300 [00:00<00:00, 431.83 Segments/s]
# Aligning 9c67fiY0wGQ:  60%|█████▉    | 179/300 [00:00<00:00, 377.64 Segments/s]
# Aligning 9c67fiY0wGQ:  73%|███████▎  | 218/300 [00:00<00:00, 372.89 Segments/s]
# Aligning 9c67fiY0wGQ:  88%|████████▊ | 263/300 [00:00<00:00, 396.39 Segments/s]
# Overall Progress:  18%|█▊        | 17/93 [00:27<01:57,  1.55s/ Computational Sequence Entries]
#   0%|          | 0/735 [00:00<?, ? Segments/s]
# Aligning 9qR7uwkblbs:   0%|          | 0/735 [00:00<?, ? Segments/s]
# Aligning 9qR7uwkblbs:   5%|▌         | 37/735 [00:00<00:01, 360.26 Segments/s]
# Aligning 9qR7uwkblbs:  10%|█         | 74/735 [00:00<00:01, 353.96 Segments/s]
# Aligning 9qR7uwkblbs:  15%|█▍        | 110/735 [00:00<00:01, 326.45 Segments/s]
# Aligning 9qR7uwkblbs:  19%|█▉        | 143/735 [00:00<00:01, 314.58 Segments/s]
# Aligning 9qR7uwkblbs:  24%|██▍       | 177/735 [00:00<00:01, 320.67 Segments/s]
# Aligning 9qR7uwkblbs:  29%|██▉       | 215/735 [00:00<00:01, 337.65 Segments/s]
# Aligning 9qR7uwkblbs:  34%|███▍      | 250/735 [00:00<00:01, 338.28 Segments/s]
# Aligning 9qR7uwkblbs:  39%|███▊      | 284/735 [00:00<00:01, 255.65 Segments/s]
# Aligning 9qR7uwkblbs:  43%|████▎     | 313/735 [00:01<00:02, 190.07 Segments/s]
# Aligning 9qR7uwkblbs:  46%|████▌     | 337/735 [00:01<00:02, 140.17 Segments/s]
# Aligning 9qR7uwkblbs:  48%|████▊     | 356/735 [00:01<00:02, 137.18 Segments/s]
# Aligning 9qR7uwkblbs:  51%|█████     | 373/735 [00:01<00:02, 139.74 Segments/s]
# Aligning 9qR7uwkblbs:  53%|█████▎    | 390/735 [00:01<00:02, 125.86 Segments/s]
# Aligning 9qR7uwkblbs:  55%|█████▌    | 405/735 [00:02<00:02, 118.43 Segments/s]
# Aligning 9qR7uwkblbs:  57%|█████▋    | 419/735 [00:02<00:02, 122.58 Segments/s]
# Aligning 9qR7uwkblbs:  59%|█████▉    | 433/735 [00:02<00:03, 98.67 Segments/s]
# Aligning 9qR7uwkblbs:  63%|██████▎   | 460/735 [00:02<00:02, 132.08 Segments/s]
# Aligning 9qR7uwkblbs:  66%|██████▌   | 485/735 [00:02<00:01, 157.60 Segments/s]
# Aligning 9qR7uwkblbs:  70%|███████   | 517/735 [00:02<00:01, 195.98 Segments/s]
# Aligning 9qR7uwkblbs:  74%|███████▍  | 547/735 [00:02<00:00, 220.54 Segments/s]
# Aligning 9qR7uwkblbs:  79%|███████▊  | 577/735 [00:02<00:00, 240.31 Segments/s]
# Aligning 9qR7uwkblbs:  82%|████████▏ | 603/735 [00:03<00:00, 241.48 Segments/s]
# Aligning 9qR7uwkblbs:  86%|████████▌ | 629/735 [00:03<00:00, 236.74 Segments/s]
# Aligning 9qR7uwkblbs:  89%|████████▉ | 656/735 [00:03<00:00, 244.23 Segments/s]
# Aligning 9qR7uwkblbs:  94%|█████████▍| 692/735 [00:03<00:00, 275.77 Segments/s]
# Aligning 9qR7uwkblbs:  99%|█████████▊| 725/735 [00:03<00:00, 290.88 Segments/s]
# Overall Progress:  19%|█▉        | 18/93 [00:31<02:40,  2.14s/ Computational Sequence Entries]
#   0%|          | 0/659 [00:00<?, ? Segments/s]
# Aligning Af8D0E4ZXaw:   0%|          | 0/659 [00:00<?, ? Segments/s]
# Aligning Af8D0E4ZXaw:   3%|▎         | 17/659 [00:00<00:03, 166.31 Segments/s]
# Aligning Af8D0E4ZXaw:   6%|▋         | 42/659 [00:00<00:02, 211.26 Segments/s]
# Aligning Af8D0E4ZXaw:  11%|█▏        | 75/659 [00:00<00:02, 261.12 Segments/s]
# Aligning Af8D0E4ZXaw:  16%|█▌        | 106/659 [00:00<00:01, 279.00 Segments/s]
# Aligning Af8D0E4ZXaw:  21%|██        | 139/659 [00:00<00:01, 296.39 Segments/s]
# Aligning Af8D0E4ZXaw:  26%|██▌       | 169/659 [00:00<00:01, 297.17 Segments/s]
# Aligning Af8D0E4ZXaw:  30%|███       | 199/659 [00:00<00:01, 292.61 Segments/s]
# Aligning Af8D0E4ZXaw:  35%|███▍      | 229/659 [00:00<00:01, 256.33 Segments/s]
# Aligning Af8D0E4ZXaw:  41%|████      | 267/659 [00:00<00:01, 289.71 Segments/s]
# Aligning Af8D0E4ZXaw:  46%|████▋     | 306/659 [00:01<00:01, 318.03 Segments/s]
# Aligning Af8D0E4ZXaw:  52%|█████▏    | 345/659 [00:01<00:00, 335.21 Segments/s]
# Aligning Af8D0E4ZXaw:  58%|█████▊    | 380/659 [00:01<00:00, 306.87 Segments/s]
# Aligning Af8D0E4ZXaw:  63%|██████▎   | 412/659 [00:01<00:00, 297.31 Segments/s]
# Aligning Af8D0E4ZXaw:  68%|██████▊   | 447/659 [00:01<00:00, 309.88 Segments/s]
# Aligning Af8D0E4ZXaw:  73%|███████▎  | 481/659 [00:01<00:00, 318.10 Segments/s]
# Aligning Af8D0E4ZXaw:  78%|███████▊  | 515/659 [00:01<00:00, 323.99 Segments/s]
# Aligning Af8D0E4ZXaw:  83%|████████▎ | 548/659 [00:01<00:00, 299.80 Segments/s]
# Aligning Af8D0E4ZXaw:  89%|████████▊ | 584/659 [00:01<00:00, 314.48 Segments/s]
# Aligning Af8D0E4ZXaw:  94%|█████████▍| 621/659 [00:02<00:00, 329.91 Segments/s]
# Aligning Af8D0E4ZXaw:  99%|█████████▉| 655/659 [00:02<00:00, 322.90 Segments/s]
# Overall Progress:  20%|██        | 19/93 [00:33<02:39,  2.16s/ Computational Sequence Entries]
#   0%|          | 0/406 [00:00<?, ? Segments/s]
# Aligning BI97DNYfe5I:   0%|          | 0/406 [00:00<?, ? Segments/s]
# Aligning BI97DNYfe5I:   9%|▉         | 36/406 [00:00<00:01, 353.76 Segments/s]
# Aligning BI97DNYfe5I:  18%|█▊        | 72/406 [00:00<00:00, 344.08 Segments/s]
# Aligning BI97DNYfe5I:  26%|██▋       | 107/406 [00:00<00:00, 341.41 Segments/s]
# Aligning BI97DNYfe5I:  37%|███▋      | 151/406 [00:00<00:00, 376.38 Segments/s]
# Aligning BI97DNYfe5I:  48%|████▊     | 193/406 [00:00<00:00, 388.31 Segments/s]
# Aligning BI97DNYfe5I:  58%|█████▊    | 235/406 [00:00<00:00, 397.05 Segments/s]
# Aligning BI97DNYfe5I:  68%|██████▊   | 275/406 [00:00<00:00, 386.10 Segments/s]
# Aligning BI97DNYfe5I:  77%|███████▋  | 314/406 [00:00<00:00, 376.35 Segments/s]
# Aligning BI97DNYfe5I:  87%|████████▋ | 353/406 [00:00<00:00, 378.59 Segments/s]
# Aligning BI97DNYfe5I:  97%|█████████▋| 393/406 [00:01<00:00, 384.62 Segments/s]
# Overall Progress:  22%|██▏       | 20/93 [00:34<02:14,  1.84s/ Computational Sequence Entries]
#   0%|          | 0/566 [00:00<?, ? Segments/s]
# Aligning BXuRRbG0Ugk:   0%|          | 0/566 [00:00<?, ? Segments/s]
# Aligning BXuRRbG0Ugk:   6%|▋         | 36/566 [00:00<00:01, 356.08 Segments/s]
# Aligning BXuRRbG0Ugk:  13%|█▎        | 72/566 [00:00<00:01, 348.46 Segments/s]
# Aligning BXuRRbG0Ugk:  19%|█▉        | 107/566 [00:00<00:01, 322.30 Segments/s]
# Aligning BXuRRbG0Ugk:  25%|██▍       | 141/566 [00:00<00:01, 326.63 Segments/s]
# Aligning BXuRRbG0Ugk:  31%|███▏      | 177/566 [00:00<00:01, 333.88 Segments/s]
# Aligning BXuRRbG0Ugk:  37%|███▋      | 211/566 [00:00<00:01, 332.99 Segments/s]
# Aligning BXuRRbG0Ugk:  43%|████▎     | 245/566 [00:00<00:00, 326.87 Segments/s]
# Aligning BXuRRbG0Ugk:  49%|████▉     | 278/566 [00:00<00:00, 325.33 Segments/s]
# Aligning BXuRRbG0Ugk:  55%|█████▌    | 313/566 [00:00<00:00, 332.63 Segments/s]
# Aligning BXuRRbG0Ugk:  61%|██████▏   | 347/566 [00:01<00:00, 311.06 Segments/s]
# Aligning BXuRRbG0Ugk:  67%|██████▋   | 379/566 [00:01<00:00, 302.75 Segments/s]
# Aligning BXuRRbG0Ugk:  73%|███████▎  | 415/566 [00:01<00:00, 318.84 Segments/s]
# Aligning BXuRRbG0Ugk:  79%|███████▉  | 448/566 [00:01<00:00, 321.10 Segments/s]
# Aligning BXuRRbG0Ugk:  86%|████████▌ | 484/566 [00:01<00:00, 331.34 Segments/s]
# Aligning BXuRRbG0Ugk:  92%|█████████▏| 519/566 [00:01<00:00, 336.49 Segments/s]
# Aligning BXuRRbG0Ugk:  98%|█████████▊| 557/566 [00:01<00:00, 348.32 Segments/s]
# Overall Progress:  23%|██▎       | 21/93 [00:36<02:09,  1.81s/ Computational Sequence Entries]
#   0%|          | 0/282 [00:00<?, ? Segments/s]
# Aligning Bfr499ggo-0:   0%|          | 0/282 [00:00<?, ? Segments/s]
# Aligning Bfr499ggo-0:  14%|█▍        | 40/282 [00:00<00:00, 395.79 Segments/s]
# Aligning Bfr499ggo-0:  28%|██▊       | 80/282 [00:00<00:00, 392.19 Segments/s]
# Aligning Bfr499ggo-0:  43%|████▎     | 120/282 [00:00<00:00, 367.27 Segments/s]
# Aligning Bfr499ggo-0:  56%|█████▌    | 157/282 [00:00<00:00, 362.89 Segments/s]
# Aligning Bfr499ggo-0:  70%|██████▉   | 196/282 [00:00<00:00, 371.73 Segments/s]
# Aligning Bfr499ggo-0:  83%|████████▎ | 234/282 [00:00<00:00, 368.45 Segments/s]
# Aligning Bfr499ggo-0:  99%|█████████▉| 279/282 [00:00<00:00, 393.02 Segments/s]
# Overall Progress:  24%|██▎       | 22/93 [00:37<01:45,  1.49s/ Computational Sequence Entries]
#   0%|          | 0/659 [00:00<?, ? Segments/s]
# Aligning BioHAh1qJAQ:   0%|          | 0/659 [00:00<?, ? Segments/s]
# Aligning BioHAh1qJAQ:   5%|▌         | 34/659 [00:00<00:01, 334.42 Segments/s]
# Aligning BioHAh1qJAQ:  10%|█         | 68/659 [00:00<00:01, 316.66 Segments/s]
# Aligning BioHAh1qJAQ:  15%|█▌        | 100/659 [00:00<00:01, 314.50 Segments/s]
# Aligning BioHAh1qJAQ:  20%|██        | 132/659 [00:00<00:01, 313.19 Segments/s]
# Aligning BioHAh1qJAQ:  25%|██▍       | 164/659 [00:00<00:01, 304.74 Segments/s]
# Aligning BioHAh1qJAQ:  31%|███       | 201/659 [00:00<00:01, 321.57 Segments/s]
# Aligning BioHAh1qJAQ:  36%|███▌      | 238/659 [00:00<00:01, 336.24 Segments/s]
# Aligning BioHAh1qJAQ:  42%|████▏     | 274/659 [00:00<00:01, 341.75 Segments/s]
# Aligning BioHAh1qJAQ:  47%|████▋     | 309/659 [00:00<00:01, 317.40 Segments/s]
# Aligning BioHAh1qJAQ:  52%|█████▏    | 342/659 [00:01<00:01, 313.06 Segments/s]
# Aligning BioHAh1qJAQ:  57%|█████▋    | 374/659 [00:01<00:00, 310.95 Segments/s]
# Aligning BioHAh1qJAQ:  62%|██████▏   | 406/659 [00:01<00:00, 312.86 Segments/s]
# Aligning BioHAh1qJAQ:  66%|██████▋   | 438/659 [00:01<00:00, 304.71 Segments/s]
# Aligning BioHAh1qJAQ:  71%|███████   | 469/659 [00:01<00:00, 299.53 Segments/s]
# Aligning BioHAh1qJAQ:  76%|███████▋  | 504/659 [00:01<00:00, 311.45 Segments/s]
# Aligning BioHAh1qJAQ:  82%|████████▏ | 539/659 [00:01<00:00, 321.98 Segments/s]
# Aligning BioHAh1qJAQ:  87%|████████▋ | 575/659 [00:01<00:00, 330.61 Segments/s]
# Aligning BioHAh1qJAQ:  93%|█████████▎| 610/659 [00:01<00:00, 332.55 Segments/s]
# Aligning BioHAh1qJAQ:  98%|█████████▊| 644/659 [00:02<00:00, 330.49 Segments/s]
# Overall Progress:  25%|██▍       | 23/93 [00:39<01:56,  1.66s/ Computational Sequence Entries]
#   0%|          | 0/695 [00:00<?, ? Segments/s]
# Aligning BvYR0L6f2Ig:   0%|          | 0/695 [00:00<?, ? Segments/s]
# Aligning BvYR0L6f2Ig:   3%|▎         | 20/695 [00:00<00:03, 198.23 Segments/s]
# Aligning BvYR0L6f2Ig:   7%|▋         | 51/695 [00:00<00:02, 261.89 Segments/s]
# Aligning BvYR0L6f2Ig:  12%|█▏        | 83/695 [00:00<00:02, 284.50 Segments/s]
# Aligning BvYR0L6f2Ig:  16%|█▌        | 112/695 [00:00<00:02, 275.28 Segments/s]
# Aligning BvYR0L6f2Ig:  21%|██        | 143/695 [00:00<00:01, 286.34 Segments/s]
# Aligning BvYR0L6f2Ig:  25%|██▌       | 175/695 [00:00<00:01, 295.52 Segments/s]
# Aligning BvYR0L6f2Ig:  30%|███       | 211/695 [00:00<00:01, 313.70 Segments/s]
# Aligning BvYR0L6f2Ig:  35%|███▌      | 244/695 [00:00<00:01, 317.65 Segments/s]
# Aligning BvYR0L6f2Ig:  40%|███▉      | 276/695 [00:00<00:01, 318.02 Segments/s]
# Aligning BvYR0L6f2Ig:  44%|████▍     | 308/695 [00:01<00:01, 310.22 Segments/s]
# Aligning BvYR0L6f2Ig:  49%|████▉     | 341/695 [00:01<00:01, 314.51 Segments/s]
# Aligning BvYR0L6f2Ig:  55%|█████▍    | 379/695 [00:01<00:00, 332.45 Segments/s]
# Aligning BvYR0L6f2Ig:  59%|█████▉    | 413/695 [00:01<00:00, 333.35 Segments/s]
# Aligning BvYR0L6f2Ig:  64%|██████▍   | 447/695 [00:01<00:00, 311.01 Segments/s]
# Aligning BvYR0L6f2Ig:  69%|██████▉   | 479/695 [00:01<00:00, 300.81 Segments/s]
# Aligning BvYR0L6f2Ig:  74%|███████▍  | 516/695 [00:01<00:00, 319.93 Segments/s]
# Aligning BvYR0L6f2Ig:  80%|███████▉  | 553/695 [00:01<00:00, 331.86 Segments/s]
# Aligning BvYR0L6f2Ig:  85%|████████▍ | 589/695 [00:01<00:00, 338.80 Segments/s]
# Aligning BvYR0L6f2Ig:  90%|████████▉ | 624/695 [00:01<00:00, 330.02 Segments/s]
# Aligning BvYR0L6f2Ig:  95%|█████████▍| 660/695 [00:02<00:00, 337.97 Segments/s]
# Overall Progress:  26%|██▌       | 24/93 [00:41<02:06,  1.83s/ Computational Sequence Entries]
#   0%|          | 0/777 [00:00<?, ? Segments/s]
# Aligning Ci-AH39fi3Y:   0%|          | 0/777 [00:00<?, ? Segments/s]
# Aligning Ci-AH39fi3Y:   3%|▎         | 22/777 [00:00<00:03, 219.32 Segments/s]
# Aligning Ci-AH39fi3Y:   8%|▊         | 59/777 [00:00<00:02, 305.92 Segments/s]
# Aligning Ci-AH39fi3Y:  12%|█▏        | 94/777 [00:00<00:02, 324.77 Segments/s]
# Aligning Ci-AH39fi3Y:  17%|█▋        | 129/777 [00:00<00:01, 332.80 Segments/s]
# Aligning Ci-AH39fi3Y:  21%|██        | 163/777 [00:00<00:01, 322.80 Segments/s]
# Aligning Ci-AH39fi3Y:  26%|██▌       | 200/777 [00:00<00:01, 335.89 Segments/s]
# Aligning Ci-AH39fi3Y:  31%|███       | 241/777 [00:00<00:01, 356.47 Segments/s]
# Aligning Ci-AH39fi3Y:  36%|███▌      | 277/777 [00:00<00:01, 348.35 Segments/s]
# Aligning Ci-AH39fi3Y:  40%|████      | 314/777 [00:00<00:01, 352.75 Segments/s]
# Aligning Ci-AH39fi3Y:  45%|████▌     | 353/777 [00:01<00:01, 363.19 Segments/s]
# Aligning Ci-AH39fi3Y:  50%|█████     | 390/777 [00:01<00:01, 336.34 Segments/s]
# Aligning Ci-AH39fi3Y:  55%|█████▌    | 428/777 [00:01<00:01, 346.81 Segments/s]
# Aligning Ci-AH39fi3Y:  60%|█████▉    | 464/777 [00:01<00:01, 300.35 Segments/s]
# Aligning Ci-AH39fi3Y:  64%|██████▍   | 496/777 [00:01<00:00, 304.58 Segments/s]
# Aligning Ci-AH39fi3Y:  68%|██████▊   | 528/777 [00:01<00:00, 308.03 Segments/s]
# Aligning Ci-AH39fi3Y:  72%|███████▏  | 560/777 [00:01<00:00, 269.13 Segments/s]
# Aligning Ci-AH39fi3Y:  76%|███████▌  | 589/777 [00:01<00:00, 273.83 Segments/s]
# Aligning Ci-AH39fi3Y:  80%|███████▉  | 618/777 [00:02<00:00, 184.80 Segments/s]
# Aligning Ci-AH39fi3Y:  82%|████████▏ | 641/777 [00:02<00:00, 156.04 Segments/s]
# Aligning Ci-AH39fi3Y:  87%|████████▋ | 674/777 [00:02<00:00, 188.15 Segments/s]
# Aligning Ci-AH39fi3Y:  91%|█████████ | 705/777 [00:02<00:00, 213.19 Segments/s]
# Aligning Ci-AH39fi3Y:  95%|█████████▍| 738/777 [00:02<00:00, 237.73 Segments/s]
# Aligning Ci-AH39fi3Y:  99%|█████████▉| 768/777 [00:02<00:00, 252.84 Segments/s]
# Overall Progress:  27%|██▋       | 25/93 [00:44<02:24,  2.13s/ Computational Sequence Entries]
#   0%|          | 0/590 [00:00<?, ? Segments/s]
# Aligning Clx4VXItLTE:   0%|          | 0/590 [00:00<?, ? Segments/s]
# Aligning Clx4VXItLTE:   5%|▍         | 28/590 [00:00<00:02, 268.75 Segments/s]
# Aligning Clx4VXItLTE:   9%|▉         | 55/590 [00:00<00:02, 250.10 Segments/s]
# Aligning Clx4VXItLTE:  14%|█▎        | 81/590 [00:00<00:02, 251.57 Segments/s]
# Aligning Clx4VXItLTE:  20%|██        | 118/590 [00:00<00:01, 295.63 Segments/s]
# Aligning Clx4VXItLTE:  26%|██▋       | 155/590 [00:00<00:01, 319.92 Segments/s]
# Aligning Clx4VXItLTE:  32%|███▏      | 189/590 [00:00<00:01, 325.54 Segments/s]
# Aligning Clx4VXItLTE:  38%|███▊      | 222/590 [00:00<00:01, 300.55 Segments/s]
# Aligning Clx4VXItLTE:  43%|████▎     | 253/590 [00:00<00:01, 286.86 Segments/s]
# Aligning Clx4VXItLTE:  48%|████▊     | 284/590 [00:00<00:01, 291.59 Segments/s]
# Aligning Clx4VXItLTE:  53%|█████▎    | 314/590 [00:01<00:00, 284.65 Segments/s]
# Aligning Clx4VXItLTE:  58%|█████▊    | 344/590 [00:01<00:00, 288.25 Segments/s]
# Aligning Clx4VXItLTE:  64%|██████▎   | 376/590 [00:01<00:00, 295.55 Segments/s]
# Aligning Clx4VXItLTE:  69%|██████▉   | 410/590 [00:01<00:00, 306.70 Segments/s]
# Aligning Clx4VXItLTE:  75%|███████▌  | 443/590 [00:01<00:00, 312.69 Segments/s]
# Aligning Clx4VXItLTE:  81%|████████  | 475/590 [00:01<00:00, 308.96 Segments/s]
# Aligning Clx4VXItLTE:  86%|████████▋ | 509/590 [00:01<00:00, 317.56 Segments/s]
# Aligning Clx4VXItLTE:  92%|█████████▏| 545/590 [00:01<00:00, 329.12 Segments/s]
# Aligning Clx4VXItLTE:  98%|█████████▊| 578/590 [00:01<00:00, 324.10 Segments/s]
# Overall Progress:  28%|██▊       | 26/93 [00:46<02:19,  2.08s/ Computational Sequence Entries]
#   0%|          | 0/411 [00:00<?, ? Segments/s]
# Aligning Dg_0XKD0Mf4:   0%|          | 0/411 [00:00<?, ? Segments/s]
# Aligning Dg_0XKD0Mf4:   7%|▋         | 30/411 [00:00<00:01, 295.68 Segments/s]
# Aligning Dg_0XKD0Mf4:  16%|█▌        | 66/411 [00:00<00:01, 330.77 Segments/s]
# Aligning Dg_0XKD0Mf4:  25%|██▌       | 103/411 [00:00<00:00, 343.54 Segments/s]
# Aligning Dg_0XKD0Mf4:  34%|███▍      | 141/411 [00:00<00:00, 355.86 Segments/s]
# Aligning Dg_0XKD0Mf4:  44%|████▎     | 179/411 [00:00<00:00, 361.00 Segments/s]
# Aligning Dg_0XKD0Mf4:  53%|█████▎    | 218/411 [00:00<00:00, 368.90 Segments/s]
# Aligning Dg_0XKD0Mf4:  62%|██████▏   | 255/411 [00:00<00:00, 364.77 Segments/s]
# Aligning Dg_0XKD0Mf4:  72%|███████▏  | 296/411 [00:00<00:00, 376.82 Segments/s]
# Aligning Dg_0XKD0Mf4:  82%|████████▏ | 337/411 [00:00<00:00, 386.82 Segments/s]
# Aligning Dg_0XKD0Mf4:  92%|█████████▏| 378/411 [00:01<00:00, 393.41 Segments/s]
# Overall Progress:  29%|██▉       | 27/93 [00:47<01:58,  1.79s/ Computational Sequence Entries]
#   0%|          | 0/559 [00:00<?, ? Segments/s]
# Aligning G-xst2euQUc:   0%|          | 0/559 [00:00<?, ? Segments/s]
# Aligning G-xst2euQUc:   4%|▍         | 22/559 [00:00<00:02, 215.44 Segments/s]
# Aligning G-xst2euQUc:  11%|█         | 61/559 [00:00<00:01, 313.46 Segments/s]
# Aligning G-xst2euQUc:  17%|█▋        | 94/559 [00:00<00:01, 316.98 Segments/s]
# Aligning G-xst2euQUc:  24%|██▍       | 134/559 [00:00<00:01, 345.73 Segments/s]
# Aligning G-xst2euQUc:  32%|███▏      | 177/559 [00:00<00:01, 374.55 Segments/s]
# Aligning G-xst2euQUc:  39%|███▊      | 216/559 [00:00<00:00, 378.31 Segments/s]
# Aligning G-xst2euQUc:  45%|████▌     | 254/559 [00:00<00:00, 358.42 Segments/s]
# Aligning G-xst2euQUc:  52%|█████▏    | 291/559 [00:00<00:00, 361.42 Segments/s]
# Aligning G-xst2euQUc:  59%|█████▊    | 328/559 [00:00<00:00, 360.29 Segments/s]
# Aligning G-xst2euQUc:  66%|██████▌   | 368/559 [00:01<00:00, 370.71 Segments/s]
# Aligning G-xst2euQUc:  73%|███████▎  | 409/559 [00:01<00:00, 379.71 Segments/s]
# Aligning G-xst2euQUc:  80%|████████  | 448/559 [00:01<00:00, 323.48 Segments/s]
# Aligning G-xst2euQUc:  87%|████████▋ | 484/559 [00:01<00:00, 331.50 Segments/s]
# Aligning G-xst2euQUc:  93%|█████████▎| 521/559 [00:01<00:00, 339.53 Segments/s]
# Aligning G-xst2euQUc: 100%|██████████| 559/559 [00:01<00:00, 349.76 Segments/s]
# Overall Progress:  30%|███       | 28/93 [00:49<01:53,  1.74s/ Computational Sequence Entries]
#   0%|          | 0/763 [00:00<?, ? Segments/s]
# Aligning G6GlGvlkxAQ:   0%|          | 0/763 [00:00<?, ? Segments/s]
# Aligning G6GlGvlkxAQ:   4%|▍         | 30/763 [00:00<00:02, 297.20 Segments/s]
# Aligning G6GlGvlkxAQ:   8%|▊         | 60/763 [00:00<00:02, 282.65 Segments/s]
# Aligning G6GlGvlkxAQ:  12%|█▏        | 95/763 [00:00<00:02, 311.72 Segments/s]
# Aligning G6GlGvlkxAQ:  17%|█▋        | 133/763 [00:00<00:01, 337.10 Segments/s]
# Aligning G6GlGvlkxAQ:  22%|██▏       | 167/763 [00:00<00:01, 330.32 Segments/s]
# Aligning G6GlGvlkxAQ:  27%|██▋       | 205/763 [00:00<00:01, 342.83 Segments/s]
# Aligning G6GlGvlkxAQ:  31%|███▏      | 240/763 [00:00<00:01, 341.53 Segments/s]
# Aligning G6GlGvlkxAQ:  36%|███▌      | 275/763 [00:00<00:01, 339.95 Segments/s]
# Aligning G6GlGvlkxAQ:  41%|████      | 310/763 [00:00<00:01, 341.66 Segments/s]
# Aligning G6GlGvlkxAQ:  45%|████▌     | 345/763 [00:01<00:01, 334.98 Segments/s]
# Aligning G6GlGvlkxAQ:  50%|█████     | 382/763 [00:01<00:01, 343.19 Segments/s]
# Aligning G6GlGvlkxAQ:  55%|█████▍    | 419/763 [00:01<00:00, 349.17 Segments/s]
# Aligning G6GlGvlkxAQ:  60%|█████▉    | 454/763 [00:01<00:00, 349.06 Segments/s]
# Aligning G6GlGvlkxAQ:  64%|██████▍   | 492/763 [00:01<00:00, 352.68 Segments/s]
# Aligning G6GlGvlkxAQ:  69%|██████▉   | 528/763 [00:01<00:00, 294.49 Segments/s]
# Aligning G6GlGvlkxAQ:  73%|███████▎  | 560/763 [00:01<00:00, 295.56 Segments/s]
# Aligning G6GlGvlkxAQ:  77%|███████▋  | 591/763 [00:01<00:00, 298.79 Segments/s]
# Aligning G6GlGvlkxAQ:  82%|████████▏ | 622/763 [00:01<00:00, 289.90 Segments/s]
# Aligning G6GlGvlkxAQ:  85%|████████▌ | 652/763 [00:02<00:00, 273.08 Segments/s]
# Aligning G6GlGvlkxAQ:  89%|████████▉ | 682/763 [00:02<00:00, 278.48 Segments/s]
# Aligning G6GlGvlkxAQ:  93%|█████████▎| 711/763 [00:02<00:00, 269.05 Segments/s]
# Aligning G6GlGvlkxAQ:  97%|█████████▋| 739/763 [00:02<00:00, 267.40 Segments/s]
# Overall Progress:  31%|███       | 29/93 [00:51<02:05,  1.97s/ Computational Sequence Entries]
#   0%|          | 0/417 [00:00<?, ? Segments/s]
# Aligning GWuJjcEuzt8:   0%|          | 0/417 [00:00<?, ? Segments/s]
# Aligning GWuJjcEuzt8:   5%|▍         | 19/417 [00:00<00:02, 189.06 Segments/s]
# Aligning GWuJjcEuzt8:  11%|█         | 46/417 [00:00<00:01, 236.31 Segments/s]
# Aligning GWuJjcEuzt8:  18%|█▊        | 74/417 [00:00<00:01, 253.60 Segments/s]
# Aligning GWuJjcEuzt8:  24%|██▍       | 102/417 [00:00<00:01, 263.81 Segments/s]
# Aligning GWuJjcEuzt8:  32%|███▏      | 135/417 [00:00<00:00, 285.47 Segments/s]
# Aligning GWuJjcEuzt8:  39%|███▉      | 164/417 [00:00<00:00, 281.56 Segments/s]
# Aligning GWuJjcEuzt8:  47%|████▋     | 194/417 [00:00<00:00, 286.94 Segments/s]
# Aligning GWuJjcEuzt8:  55%|█████▌    | 230/417 [00:00<00:00, 307.48 Segments/s]
# Aligning GWuJjcEuzt8:  63%|██████▎   | 264/417 [00:00<00:00, 315.37 Segments/s]
# Aligning GWuJjcEuzt8:  73%|███████▎  | 303/417 [00:01<00:00, 336.11 Segments/s]
# Aligning GWuJjcEuzt8:  81%|████████  | 337/417 [00:01<00:00, 336.46 Segments/s]
# Aligning GWuJjcEuzt8:  89%|████████▉ | 371/417 [00:01<00:00, 326.81 Segments/s]
# Aligning GWuJjcEuzt8:  97%|█████████▋| 404/417 [00:01<00:00, 326.61 Segments/s]
# Overall Progress:  32%|███▏      | 30/93 [00:52<01:52,  1.79s/ Computational Sequence Entries]
#   0%|          | 0/622 [00:00<?, ? Segments/s]
# Aligning HEsqda8_d0Q:   0%|          | 0/622 [00:00<?, ? Segments/s]
# Aligning HEsqda8_d0Q:   4%|▎         | 23/622 [00:00<00:02, 220.86 Segments/s]
# Aligning HEsqda8_d0Q:   7%|▋         | 46/622 [00:00<00:03, 162.97 Segments/s]
# Aligning HEsqda8_d0Q:  13%|█▎        | 78/622 [00:00<00:02, 219.79 Segments/s]
# Aligning HEsqda8_d0Q:  18%|█▊        | 111/622 [00:00<00:01, 256.21 Segments/s]
# Aligning HEsqda8_d0Q:  23%|██▎       | 144/622 [00:00<00:01, 280.41 Segments/s]
# Aligning HEsqda8_d0Q:  29%|██▉       | 180/622 [00:00<00:01, 303.91 Segments/s]
# Aligning HEsqda8_d0Q:  35%|███▍      | 217/622 [00:00<00:01, 322.34 Segments/s]
# Aligning HEsqda8_d0Q:  41%|████      | 254/622 [00:00<00:01, 335.37 Segments/s]
# Aligning HEsqda8_d0Q:  46%|████▋     | 289/622 [00:00<00:01, 327.78 Segments/s]
# Aligning HEsqda8_d0Q:  52%|█████▏    | 323/622 [00:01<00:00, 320.71 Segments/s]
# Aligning HEsqda8_d0Q:  57%|█████▋    | 356/622 [00:01<00:00, 317.84 Segments/s]
# Aligning HEsqda8_d0Q:  62%|██████▏   | 388/622 [00:01<00:00, 318.28 Segments/s]
# Aligning HEsqda8_d0Q:  68%|██████▊   | 422/622 [00:01<00:00, 324.10 Segments/s]
# Aligning HEsqda8_d0Q:  73%|███████▎  | 457/622 [00:01<00:00, 328.41 Segments/s]
# Aligning HEsqda8_d0Q:  80%|███████▉  | 495/622 [00:01<00:00, 342.02 Segments/s]
# Aligning HEsqda8_d0Q:  85%|████████▌ | 530/622 [00:01<00:00, 315.67 Segments/s]
# Aligning HEsqda8_d0Q:  91%|█████████ | 563/622 [00:01<00:00, 311.58 Segments/s]
# Aligning HEsqda8_d0Q:  96%|█████████▌| 598/622 [00:01<00:00, 321.69 Segments/s]
# Overall Progress:  33%|███▎      | 31/93 [00:54<01:55,  1.87s/ Computational Sequence Entries]
#   0%|          | 0/640 [00:00<?, ? Segments/s]
# Aligning I5y0__X72p0:   0%|          | 0/640 [00:00<?, ? Segments/s]
# Aligning I5y0__X72p0:   5%|▌         | 33/640 [00:00<00:01, 327.15 Segments/s]
# Aligning I5y0__X72p0:  10%|█         | 66/640 [00:00<00:01, 319.53 Segments/s]
# Aligning I5y0__X72p0:  15%|█▌        | 98/640 [00:00<00:01, 314.86 Segments/s]
# Aligning I5y0__X72p0:  20%|██        | 131/640 [00:00<00:01, 319.30 Segments/s]
# Aligning I5y0__X72p0:  26%|██▌       | 164/640 [00:00<00:01, 320.30 Segments/s]
# Aligning I5y0__X72p0:  31%|███       | 199/640 [00:00<00:01, 328.30 Segments/s]
# Aligning I5y0__X72p0:  37%|███▋      | 235/640 [00:00<00:01, 335.30 Segments/s]
# Aligning I5y0__X72p0:  42%|████▏     | 269/640 [00:00<00:01, 320.62 Segments/s]
# Aligning I5y0__X72p0:  47%|████▋     | 302/640 [00:00<00:01, 298.29 Segments/s]
# Aligning I5y0__X72p0:  52%|█████▏    | 335/640 [00:01<00:00, 305.80 Segments/s]
# Aligning I5y0__X72p0:  57%|█████▋    | 366/640 [00:01<00:00, 294.66 Segments/s]
# Aligning I5y0__X72p0:  62%|██████▏   | 396/640 [00:01<00:00, 287.56 Segments/s]
# Aligning I5y0__X72p0:  66%|██████▋   | 425/640 [00:01<00:00, 278.79 Segments/s]
# Aligning I5y0__X72p0:  71%|███████   | 454/640 [00:01<00:00, 280.83 Segments/s]
# Aligning I5y0__X72p0:  76%|███████▌  | 486/640 [00:01<00:00, 286.37 Segments/s]
# Aligning I5y0__X72p0:  80%|████████  | 515/640 [00:01<00:00, 285.58 Segments/s]
# Aligning I5y0__X72p0:  85%|████████▌ | 545/640 [00:01<00:00, 287.03 Segments/s]
# Aligning I5y0__X72p0:  90%|█████████ | 576/640 [00:01<00:00, 292.39 Segments/s]
# Aligning I5y0__X72p0:  96%|█████████▌| 613/640 [00:02<00:00, 313.49 Segments/s]
# Overall Progress:  34%|███▍      | 32/93 [00:57<01:58,  1.94s/ Computational Sequence Entries]
#   0%|          | 0/316 [00:00<?, ? Segments/s]
# ...
# Aligning tIrG4oNLFzE:  50%|████▉     | 292/589 [00:00<00:00, 331.77 Segments/s]
# Aligning tIrG4oNLFzE:  56%|█████▌    | 328/589 [00:00<00:00, 337.37 Segments/s]
# Aligning tIrG4oNLFzE:  62%|██████▏   | 363/589 [00:01<00:00, 340.42 Segments/s]
# Aligning tIrG4oNLFzE:  68%|██████▊   | 399/589 [00:01<00:00, 343.98 Segments/s]
# Aligning tIrG4oNLFzE:  74%|███████▎  | 434/589 [00:01<00:00, 336.87 Segments/s]
# Aligning tIrG4oNLFzE:  79%|███████▉  | 468/589 [00:01<00:00, 328.14 Segments/s]
# Aligning tIrG4oNLFzE:  85%|████████▌ | 501/589 [00:01<00:00, 324.44 Segments/s]
# Aligning tIrG4oNLFzE:  91%|█████████ | 534/589 [00:01<00:00, 305.45 Segments/s]
# Aligning tIrG4oNLFzE:  96%|█████████▌| 565/589 [00:01<00:00, 297.15 Segments/s]
# Overall Progress:  90%|█████████ | 84/93 [02:18<00:16,  1.83s/ Computational Sequence Entries]
#   0%|          | 0/429 [00:00<?, ? Segments/s]
# Aligning tStelxIAHjw:   0%|          | 0/429 [00:00<?, ? Segments/s]
# Aligning tStelxIAHjw:   8%|▊         | 34/429 [00:00<00:01, 337.04 Segments/s]
# Aligning tStelxIAHjw:  16%|█▌        | 68/429 [00:00<00:01, 329.80 Segments/s]
# Aligning tStelxIAHjw:  24%|██▎       | 101/429 [00:00<00:01, 318.46 Segments/s]
# Aligning tStelxIAHjw:  33%|███▎      | 140/429 [00:00<00:00, 345.42 Segments/s]
# Aligning tStelxIAHjw:  41%|████▏     | 177/429 [00:00<00:00, 350.64 Segments/s]
# Aligning tStelxIAHjw:  50%|█████     | 215/429 [00:00<00:00, 358.76 Segments/s]
# Aligning tStelxIAHjw:  59%|█████▉    | 253/429 [00:00<00:00, 365.59 Segments/s]
# Aligning tStelxIAHjw:  68%|██████▊   | 290/429 [00:00<00:00, 360.76 Segments/s]
# Aligning tStelxIAHjw:  76%|███████▌  | 327/429 [00:00<00:00, 361.19 Segments/s]
# Aligning tStelxIAHjw:  85%|████████▍ | 364/429 [00:01<00:00, 346.80 Segments/s]
# Aligning tStelxIAHjw:  94%|█████████▎| 402/429 [00:01<00:00, 356.17 Segments/s]
# Overall Progress:  91%|█████████▏| 85/93 [02:20<00:13,  1.65s/ Computational Sequence Entries]
#   0%|          | 0/376 [00:00<?, ? Segments/s]
# Aligning tmZoasNr4rU:   0%|          | 0/376 [00:00<?, ? Segments/s]
# Aligning tmZoasNr4rU:   8%|▊         | 31/376 [00:00<00:01, 305.75 Segments/s]
# Aligning tmZoasNr4rU:  17%|█▋        | 65/376 [00:00<00:00, 321.76 Segments/s]
# Aligning tmZoasNr4rU:  26%|██▌       | 98/376 [00:00<00:00, 309.59 Segments/s]
# Aligning tmZoasNr4rU:  35%|███▍      | 130/376 [00:00<00:00, 310.89 Segments/s]
# Aligning tmZoasNr4rU:  43%|████▎     | 162/376 [00:00<00:00, 300.19 Segments/s]
# Aligning tmZoasNr4rU:  52%|█████▏    | 196/376 [00:00<00:00, 310.84 Segments/s]
# Aligning tmZoasNr4rU:  62%|██████▏   | 232/376 [00:00<00:00, 325.88 Segments/s]
# Aligning tmZoasNr4rU:  70%|███████   | 265/376 [00:00<00:00, 321.90 Segments/s]
# Aligning tmZoasNr4rU:  79%|███████▉  | 298/376 [00:00<00:00, 318.35 Segments/s]
# Aligning tmZoasNr4rU:  88%|████████▊ | 330/376 [00:01<00:00, 309.40 Segments/s]
# Aligning tmZoasNr4rU:  97%|█████████▋| 363/376 [00:01<00:00, 314.18 Segments/s]
# Overall Progress:  92%|█████████▏| 86/93 [02:21<00:10,  1.52s/ Computational Sequence Entries]
#   0%|          | 0/470 [00:00<?, ? Segments/s]
# Aligning v0zCBqDeKcE:   0%|          | 0/470 [00:00<?, ? Segments/s]
# Aligning v0zCBqDeKcE:   7%|▋         | 32/470 [00:00<00:01, 310.41 Segments/s]
# Aligning v0zCBqDeKcE:  15%|█▍        | 69/470 [00:00<00:01, 338.95 Segments/s]
# Aligning v0zCBqDeKcE:  22%|██▏       | 104/470 [00:00<00:01, 342.24 Segments/s]
# Aligning v0zCBqDeKcE:  30%|██▉       | 139/470 [00:00<00:00, 337.23 Segments/s]
# Aligning v0zCBqDeKcE:  38%|███▊      | 177/470 [00:00<00:00, 351.59 Segments/s]
# Aligning v0zCBqDeKcE:  45%|████▌     | 213/470 [00:00<00:00, 353.18 Segments/s]
# Aligning v0zCBqDeKcE:  53%|█████▎    | 250/470 [00:00<00:00, 357.11 Segments/s]
# Aligning v0zCBqDeKcE:  61%|██████    | 286/470 [00:00<00:00, 345.18 Segments/s]
# Aligning v0zCBqDeKcE:  68%|██████▊   | 321/470 [00:00<00:00, 331.74 Segments/s]
# Aligning v0zCBqDeKcE:  76%|███████▌  | 355/470 [00:01<00:00, 329.49 Segments/s]
# Aligning v0zCBqDeKcE:  83%|████████▎ | 389/470 [00:01<00:00, 319.28 Segments/s]
# Aligning v0zCBqDeKcE:  90%|█████████ | 424/470 [00:01<00:00, 326.20 Segments/s]
# Aligning v0zCBqDeKcE:  97%|█████████▋| 457/470 [00:01<00:00, 322.20 Segments/s]
# Overall Progress:  94%|█████████▎| 87/93 [02:22<00:08,  1.49s/ Computational Sequence Entries]
#   0%|          | 0/610 [00:00<?, ? Segments/s]
# Aligning vvZ4IcEtiZc:   0%|          | 0/610 [00:00<?, ? Segments/s]
# Aligning vvZ4IcEtiZc:   6%|▌         | 35/610 [00:00<00:01, 343.23 Segments/s]
# Aligning vvZ4IcEtiZc:  12%|█▏        | 71/610 [00:00<00:01, 347.42 Segments/s]
# Aligning vvZ4IcEtiZc:  17%|█▋        | 106/610 [00:00<00:01, 348.52 Segments/s]
# Aligning vvZ4IcEtiZc:  23%|██▎       | 141/610 [00:00<00:01, 334.87 Segments/s]
# Aligning vvZ4IcEtiZc:  29%|██▉       | 176/610 [00:00<00:01, 337.48 Segments/s]
# Aligning vvZ4IcEtiZc:  35%|███▌      | 215/610 [00:00<00:01, 353.59 Segments/s]
# Aligning vvZ4IcEtiZc:  41%|████▏     | 252/610 [00:00<00:01, 356.16 Segments/s]
# Aligning vvZ4IcEtiZc:  47%|████▋     | 288/610 [00:00<00:00, 339.49 Segments/s]
# Aligning vvZ4IcEtiZc:  53%|█████▎    | 323/610 [00:00<00:00, 331.59 Segments/s]
# Aligning vvZ4IcEtiZc:  59%|█████▊    | 357/610 [00:01<00:00, 294.07 Segments/s]
# Aligning vvZ4IcEtiZc:  64%|██████▎   | 388/610 [00:01<00:00, 286.42 Segments/s]
# Aligning vvZ4IcEtiZc:  70%|██████▉   | 425/610 [00:01<00:00, 307.77 Segments/s]
# Aligning vvZ4IcEtiZc:  76%|███████▌  | 465/610 [00:01<00:00, 330.17 Segments/s]
# Aligning vvZ4IcEtiZc:  82%|████████▏ | 499/610 [00:01<00:00, 331.18 Segments/s]
# Aligning vvZ4IcEtiZc:  87%|████████▋ | 533/610 [00:01<00:00, 328.69 Segments/s]
# Aligning vvZ4IcEtiZc:  93%|█████████▎| 568/610 [00:01<00:00, 333.56 Segments/s]
# Aligning vvZ4IcEtiZc:  99%|█████████▉| 604/610 [00:01<00:00, 340.52 Segments/s]
# Overall Progress:  95%|█████████▍| 88/93 [02:24<00:08,  1.60s/ Computational Sequence Entries]
#   0%|          | 0/589 [00:00<?, ? Segments/s]
# Aligning vyB00TXsimI:   0%|          | 0/589 [00:00<?, ? Segments/s]
# Aligning vyB00TXsimI:   6%|▌         | 33/589 [00:00<00:01, 328.41 Segments/s]
# Aligning vyB00TXsimI:  11%|█         | 66/589 [00:00<00:01, 286.92 Segments/s]
# Aligning vyB00TXsimI:  17%|█▋        | 101/589 [00:00<00:01, 312.36 Segments/s]
# Aligning vyB00TXsimI:  23%|██▎       | 137/589 [00:00<00:01, 329.00 Segments/s]
# Aligning vyB00TXsimI:  29%|██▉       | 173/589 [00:00<00:01, 338.65 Segments/s]
# Aligning vyB00TXsimI:  35%|███▌      | 208/589 [00:00<00:01, 335.58 Segments/s]
# Aligning vyB00TXsimI:  41%|████      | 242/589 [00:00<00:01, 335.55 Segments/s]
# Aligning vyB00TXsimI:  47%|████▋     | 279/589 [00:00<00:00, 344.69 Segments/s]
# Aligning vyB00TXsimI:  54%|█████▍    | 317/589 [00:00<00:00, 355.34 Segments/s]
# Aligning vyB00TXsimI:  60%|█████▉    | 353/589 [00:01<00:00, 344.36 Segments/s]
# Aligning vyB00TXsimI:  66%|██████▌   | 388/589 [00:01<00:00, 325.04 Segments/s]
# Aligning vyB00TXsimI:  71%|███████▏  | 421/589 [00:01<00:00, 310.61 Segments/s]
# Aligning vyB00TXsimI:  77%|███████▋  | 455/589 [00:01<00:00, 316.83 Segments/s]
# Aligning vyB00TXsimI:  83%|████████▎ | 490/589 [00:01<00:00, 324.58 Segments/s]
# Aligning vyB00TXsimI:  89%|████████▉ | 523/589 [00:01<00:00, 322.91 Segments/s]
# Aligning vyB00TXsimI:  94%|█████████▍| 556/589 [00:01<00:00, 310.48 Segments/s]
# Aligning vyB00TXsimI: 100%|█████████▉| 588/589 [00:01<00:00, 299.46 Segments/s]
# Overall Progress:  96%|█████████▌| 89/93 [02:26<00:06,  1.68s/ Computational Sequence Entries]
#   0%|          | 0/690 [00:00<?, ? Segments/s]
# Aligning wMbj6ajWbic:   0%|          | 0/690 [00:00<?, ? Segments/s]
# Aligning wMbj6ajWbic:   5%|▌         | 37/690 [00:00<00:01, 360.31 Segments/s]
# Aligning wMbj6ajWbic:  11%|█         | 74/690 [00:00<00:01, 352.06 Segments/s]
# Aligning wMbj6ajWbic:  16%|█▌        | 110/690 [00:00<00:01, 337.89 Segments/s]
# Aligning wMbj6ajWbic:  21%|██        | 144/690 [00:00<00:01, 318.19 Segments/s]
# Aligning wMbj6ajWbic:  26%|██▌       | 176/690 [00:00<00:01, 318.74 Segments/s]
# Aligning wMbj6ajWbic:  30%|███       | 208/690 [00:00<00:01, 315.43 Segments/s]
# Aligning wMbj6ajWbic:  35%|███▌      | 242/690 [00:00<00:01, 319.95 Segments/s]
# Aligning wMbj6ajWbic:  40%|███▉      | 275/690 [00:00<00:01, 303.18 Segments/s]
# Aligning wMbj6ajWbic:  44%|████▍     | 306/690 [00:00<00:01, 290.55 Segments/s]
# Aligning wMbj6ajWbic:  49%|████▉     | 339/690 [00:01<00:01, 301.30 Segments/s]
# Aligning wMbj6ajWbic:  54%|█████▍    | 374/690 [00:01<00:01, 314.02 Segments/s]
# Aligning wMbj6ajWbic:  59%|█████▉    | 407/690 [00:01<00:00, 316.34 Segments/s]
# Aligning wMbj6ajWbic:  64%|██████▍   | 442/690 [00:01<00:00, 325.15 Segments/s]
# Aligning wMbj6ajWbic:  69%|██████▉   | 475/690 [00:01<00:00, 323.15 Segments/s]
# Aligning wMbj6ajWbic:  74%|███████▍  | 511/690 [00:01<00:00, 332.38 Segments/s]
# Aligning wMbj6ajWbic:  79%|███████▉  | 545/690 [00:01<00:00, 332.76 Segments/s]
# Aligning wMbj6ajWbic:  84%|████████▍ | 580/690 [00:01<00:00, 336.61 Segments/s]
# Aligning wMbj6ajWbic:  89%|████████▉ | 617/690 [00:01<00:00, 345.95 Segments/s]
# Aligning wMbj6ajWbic:  94%|█████████▍| 652/690 [00:02<00:00, 341.59 Segments/s]
# Aligning wMbj6ajWbic: 100%|█████████▉| 687/690 [00:02<00:00, 337.96 Segments/s]
# Overall Progress:  97%|█████████▋| 90/93 [02:28<00:05,  1.81s/ Computational Sequence Entries]
#   0%|          | 0/581 [00:00<?, ? Segments/s]
# Aligning yDtzw_Y-7RU:   0%|          | 0/581 [00:00<?, ? Segments/s]
# Aligning yDtzw_Y-7RU:   6%|▌         | 34/581 [00:00<00:01, 336.54 Segments/s]
# Aligning yDtzw_Y-7RU:  12%|█▏        | 68/581 [00:00<00:01, 316.90 Segments/s]
# Aligning yDtzw_Y-7RU:  17%|█▋        | 100/581 [00:00<00:01, 312.50 Segments/s]
# Aligning yDtzw_Y-7RU:  23%|██▎       | 132/581 [00:00<00:01, 309.81 Segments/s]
# Aligning yDtzw_Y-7RU:  29%|██▉       | 170/581 [00:00<00:01, 331.99 Segments/s]
# Aligning yDtzw_Y-7RU:  35%|███▌      | 204/581 [00:00<00:01, 325.79 Segments/s]
# Aligning yDtzw_Y-7RU:  41%|████▏     | 240/581 [00:00<00:01, 335.96 Segments/s]
# Aligning yDtzw_Y-7RU:  47%|████▋     | 274/581 [00:00<00:00, 331.92 Segments/s]
# Aligning yDtzw_Y-7RU:  53%|█████▎    | 308/581 [00:00<00:00, 315.42 Segments/s]
# Aligning yDtzw_Y-7RU:  59%|█████▊    | 341/581 [00:01<00:00, 318.61 Segments/s]
# Aligning yDtzw_Y-7RU:  64%|██████▍   | 374/581 [00:01<00:00, 312.69 Segments/s]
# Aligning yDtzw_Y-7RU:  70%|███████   | 407/581 [00:01<00:00, 316.77 Segments/s]
# Aligning yDtzw_Y-7RU:  76%|███████▌  | 439/581 [00:01<00:00, 315.52 Segments/s]
# Aligning yDtzw_Y-7RU:  81%|████████  | 471/581 [00:01<00:00, 311.72 Segments/s]
# Aligning yDtzw_Y-7RU:  87%|████████▋ | 503/581 [00:01<00:00, 299.15 Segments/s]
# Aligning yDtzw_Y-7RU:  92%|█████████▏| 536/581 [00:01<00:00, 304.49 Segments/s]
# Aligning yDtzw_Y-7RU:  98%|█████████▊| 568/581 [00:01<00:00, 307.81 Segments/s]
# Overall Progress:  98%|█████████▊| 91/93 [02:30<00:03,  1.83s/ Computational Sequence Entries]
#   0%|          | 0/616 [00:00<?, ? Segments/s]
# Aligning yvsjCA6Y5Fc:   0%|          | 0/616 [00:00<?, ? Segments/s]
# Aligning yvsjCA6Y5Fc:   6%|▌         | 34/616 [00:00<00:01, 329.52 Segments/s]
# Aligning yvsjCA6Y5Fc:  11%|█▏        | 70/616 [00:00<00:01, 340.68 Segments/s]
# Aligning yvsjCA6Y5Fc:  17%|█▋        | 106/616 [00:00<00:01, 348.77 Segments/s]
# Aligning yvsjCA6Y5Fc:  23%|██▎       | 142/616 [00:00<00:01, 347.23 Segments/s]
# Aligning yvsjCA6Y5Fc:  29%|██▊       | 177/616 [00:00<00:01, 346.28 Segments/s]
# Aligning yvsjCA6Y5Fc:  34%|███▍      | 212/616 [00:00<00:01, 331.68 Segments/s]
# Aligning yvsjCA6Y5Fc:  40%|████      | 248/616 [00:00<00:01, 340.17 Segments/s]
# Aligning yvsjCA6Y5Fc:  46%|████▌     | 284/616 [00:00<00:00, 345.08 Segments/s]
# Aligning yvsjCA6Y5Fc:  52%|█████▏    | 321/616 [00:00<00:00, 350.45 Segments/s]
# Aligning yvsjCA6Y5Fc:  58%|█████▊    | 357/616 [00:01<00:00, 348.38 Segments/s]
# Aligning yvsjCA6Y5Fc:  64%|██████▎   | 392/616 [00:01<00:00, 331.00 Segments/s]
# Aligning yvsjCA6Y5Fc:  69%|██████▉   | 428/616 [00:01<00:00, 339.24 Segments/s]
# Aligning yvsjCA6Y5Fc:  75%|███████▌  | 463/616 [00:01<00:00, 332.97 Segments/s]
# Aligning yvsjCA6Y5Fc:  81%|████████  | 497/616 [00:01<00:00, 321.58 Segments/s]
# Aligning yvsjCA6Y5Fc:  86%|████████▌ | 530/616 [00:01<00:00, 315.48 Segments/s]
# Aligning yvsjCA6Y5Fc:  91%|█████████ | 562/616 [00:01<00:00, 298.34 Segments/s]
# Aligning yvsjCA6Y5Fc:  97%|█████████▋| 595/616 [00:01<00:00, 305.60 Segments/s]
# Overall Progress:  99%|█████████▉| 92/93 [02:32<00:01,  1.84s/ Computational Sequence Entries]
#   0%|          | 0/676 [00:00<?, ? Segments/s]
# Aligning zhpQhgha_KU:   0%|          | 0/676 [00:00<?, ? Segments/s]
# Aligning zhpQhgha_KU:   5%|▌         | 34/676 [00:00<00:01, 327.93 Segments/s]
# Aligning zhpQhgha_KU:  10%|█         | 69/676 [00:00<00:01, 340.54 Segments/s]
# Aligning zhpQhgha_KU:  15%|█▌        | 104/676 [00:00<00:01, 320.53 Segments/s]
# Aligning zhpQhgha_KU:  21%|██        | 143/676 [00:00<00:01, 344.01 Segments/s]
# Aligning zhpQhgha_KU:  26%|██▋       | 179/676 [00:00<00:01, 347.93 Segments/s]
# Aligning zhpQhgha_KU:  32%|███▏      | 216/676 [00:00<00:01, 354.24 Segments/s]
# Aligning zhpQhgha_KU:  37%|███▋      | 252/676 [00:00<00:01, 355.35 Segments/s]
# Aligning zhpQhgha_KU:  43%|████▎     | 290/676 [00:00<00:01, 361.10 Segments/s]
# Aligning zhpQhgha_KU:  48%|████▊     | 327/676 [00:00<00:00, 355.51 Segments/s]
# Aligning zhpQhgha_KU:  54%|█████▎    | 363/676 [00:01<00:00, 349.75 Segments/s]
# Aligning zhpQhgha_KU:  59%|█████▉    | 400/676 [00:01<00:00, 353.99 Segments/s]
# Aligning zhpQhgha_KU:  65%|██████▍   | 437/676 [00:01<00:00, 357.51 Segments/s]
# Aligning zhpQhgha_KU:  70%|██████▉   | 473/676 [00:01<00:00, 354.01 Segments/s]
# Aligning zhpQhgha_KU:  75%|███████▌  | 509/676 [00:01<00:00, 342.18 Segments/s]
# Aligning zhpQhgha_KU:  80%|████████  | 544/676 [00:01<00:00, 314.93 Segments/s]
# Aligning zhpQhgha_KU:  85%|████████▌ | 576/676 [00:01<00:00, 313.11 Segments/s]
# Aligning zhpQhgha_KU:  90%|████████▉ | 608/676 [00:01<00:00, 309.64 Segments/s]
# Aligning zhpQhgha_KU:  95%|█████████▍| 641/676 [00:01<00:00, 315.05 Segments/s]
# Aligning zhpQhgha_KU: 100%|█████████▉| 673/676 [00:02<00:00, 310.78 Segments/s]
# [2024-12-03 11:04:21.660] | Success | Alignment to <CMU_MOSI_TimestampedWords> complete.
# [2024-12-03 11:04:21.660] | Status  | Replacing dataset content with aligned computational sequences
# [2024-12-03 11:04:21.665] | Success | Initialized empty <CMU_MOSI_TimestampedWords> computational sequence.
# [2024-12-03 11:04:21.665] | Status  | Checking the format of the data in <CMU_MOSI_TimestampedWords> computational sequence ...
# [2024-12-03 11:04:21.798] | Success | <CMU_MOSI_TimestampedWords> computational sequence data in correct format.
# [2024-12-03 11:04:21.799] | Status  | Checking the format of the metadata in <CMU_MOSI_TimestampedWords> computational sequence ...
# [2024-12-03 11:04:21.799] | Warning | <CMU_MOSI_TimestampedWords> computational sequence does not have all the required metadata ... continuing
# [2024-12-03 11:04:21.799] | Success | Initialized empty <CMU_MOSI_Visual_Facet_41> computational sequence.
# [2024-12-03 11:04:21.799] | Status  | Checking the format of the data in <CMU_MOSI_Visual_Facet_41> computational sequence ...
# [2024-12-03 11:04:21.973] | Success | <CMU_MOSI_Visual_Facet_41> computational sequence data in correct format.
# [2024-12-03 11:04:21.973] | Status  | Checking the format of the metadata in <CMU_MOSI_Visual_Facet_41> computational sequence ...
# [2024-12-03 11:04:21.973] | Warning | <CMU_MOSI_Visual_Facet_41> computational sequence does not have all the required metadata ... continuing
# [2024-12-03 11:04:21.973] | Success | Initialized empty <CMU_MOSI_COVAREP> computational sequence.
# [2024-12-03 11:04:21.973] | Status  | Checking the format of the data in <CMU_MOSI_COVAREP> computational sequence ...
# [2024-12-03 11:04:22.096] | Success | <CMU_MOSI_COVAREP> computational sequence data in correct format.
# [2024-12-03 11:04:22.096] | Status  | Checking the format of the metadata in <CMU_MOSI_COVAREP> computational sequence ...
# [2024-12-03 11:04:22.097] | Warning | <CMU_MOSI_COVAREP> computational sequence does not have all the required metadata ... continuing

# %% [markdown]
# ## Append annotations to the dataset and get the data points
#
# Now that we have a preprocessed dataset, all we need to do is to apply annotations to the data. Annotations are also computational sequences, since they are also just some values distributed on different time spans (e.g 1-3s is 'angry', 12-26s is 'neutral'). Hence, we just add the label computational sequence to the dataset and then align to the labels. Since we (may) want to preserve the whole sequences, this time we don't specify any collapse functions when aligning.
#
# Note that after alignment, the keys in the dataset changes from `video_id` to `video_id[segment_no]`, because alignment will segment each datapoint based on the segmentation of the pivot modality (in this case, it is segmented based on labels, which is what we need, and yes, one code block ago they are segmented to word level, which I didn't show you).
#
# ***Important: DO NOT add the labels together at the beginning, the labels will be segmented during the first alignment to words. This also holds for any situation where you want to do multiple levels of alignment.***

# %%
label_field = 'CMU_MOSI_Opinion_Labels'

# we add and align to lables to obtain labeled segments
# this time we don't apply collapse functions so that the temporal sequences are preserved
label_recipe = {label_field: os.path.join(DATA_PATH, "http__immortal.multicomp.cs.cmu.edu", "CMU-MOSI", "labels", label_field) + '.csd'}
dataset.add_computational_sequences(label_recipe, destination=None)
dataset.align(label_field)
# Out:
# [2024-12-03 11:04:22.210] | Success | Computational sequence read from file C:\Users\Viki\Documents\Thesis\tryout3\data\http__immortal.multicomp.cs.cmu.edu\CMU-MOSI\labels\CMU_MOSI_Opinion_Labels.csd ...
# [2024-12-03 11:04:22.240] | Status  | Checking the integrity of the <Opinion Segment Labels> computational sequence ...
# [2024-12-03 11:04:22.240] | Status  | Checking the format of the data in <Opinion Segment Labels> computational sequence ...
# [2024-12-03 11:04:22.323] | Success | <Opinion Segment Labels> computational sequence data in correct format.
# [2024-12-03 11:04:22.324] | Status  | Checking the format of the metadata in <Opinion Segment Labels> computational sequence ...
# [2024-12-03 11:04:22.324] | Warning | <Opinion Segment Labels> computational sequence does not have all the required metadata ... continuing
# [2024-12-03 11:04:22.324] | Status  | Unify was called ...
# [2024-12-03 11:04:22.462] | Success | Unify completed ...
# [2024-12-03 11:04:22.465] | Status  | Pre-alignment based on <CMU_MOSI_Opinion_Labels> computational sequence started ...
# [2024-12-03 11:04:22.687] | Status  | Pre-alignment done for <CMU_MOSI_TimestampedWords> ...
# [2024-12-03 11:04:22.913] | Status  | Pre-alignment done for <CMU_MOSI_Visual_Facet_41> ...
# [2024-12-03 11:04:23.166] | Status  | Pre-alignment done for <CMU_MOSI_COVAREP> ...
# [2024-12-03 11:04:23.170] | Status  | Alignment starting ...
# Overall Progress:   0%|          | 0/93 [00:00<?, ? Computational Sequence Entries/s]
#   0%|          | 0/13 [00:00<?, ? Segments/s]
# Aligning 03bSnISJMiM:   0%|          | 0/13 [00:00<?, ? Segments/s]
#
#   0%|          | 0/25 [00:00<?, ? Segments/s]
# Aligning 0h-zjBukYpk:   0%|          | 0/25 [00:00<?, ? Segments/s]
#
#   0%|          | 0/14 [00:00<?, ? Segments/s]
# Aligning 1DmNV9C1hbY:   0%|          | 0/14 [00:00<?, ? Segments/s]
# Overall Progress:   3%|▎         | 3/93 [00:00<00:04, 21.31 Computational Sequence Entries/s]
#   0%|          | 0/30 [00:00<?, ? Segments/s]
# Aligning 1iG0909rllw:   0%|          | 0/30 [00:00<?, ? Segments/s]
#
#   0%|          | 0/63 [00:00<?, ? Segments/s]
# Aligning 2WGyTLYerpo:   0%|          | 0/63 [00:00<?, ? Segments/s]
# Aligning 2WGyTLYerpo:  97%|█████████▋| 61/63 [00:00<00:00, 608.46 Segments/s]
#
#   0%|          | 0/30 [00:00<?, ? Segments/s]
# Aligning 2iD-tVS8NPw:   0%|          | 0/30 [00:00<?, ? Segments/s]
# Overall Progress:   6%|▋         | 6/93 [00:00<00:05, 15.29 Computational Sequence Entries/s]
#   0%|          | 0/24 [00:00<?, ? Segments/s]
# Aligning 5W7Z1C_fDaE:   0%|          | 0/24 [00:00<?, ? Segments/s]
#
#   0%|          | 0/12 [00:00<?, ? Segments/s]
# Aligning 6Egk_28TtTM:   0%|          | 0/12 [00:00<?, ? Segments/s]
#
#   0%|          | 0/14 [00:00<?, ? Segments/s]
# Aligning 6_0THN4chvY:   0%|          | 0/14 [00:00<?, ? Segments/s]
# Overall Progress:  10%|▉         | 9/93 [00:00<00:04, 18.87 Computational Sequence Entries/s]
#   0%|          | 0/19 [00:00<?, ? Segments/s]
# Aligning 73jzhE8R1TQ:   0%|          | 0/19 [00:00<?, ? Segments/s]
#
#   0%|          | 0/39 [00:00<?, ? Segments/s]
# Aligning 7JsX8y1ysxY:   0%|          | 0/39 [00:00<?, ? Segments/s]
#
#   0%|          | 0/23 [00:00<?, ? Segments/s]
# Aligning 8OtFthrtaJM:   0%|          | 0/23 [00:00<?, ? Segments/s]
# Overall Progress:  13%|█▎        | 12/93 [00:00<00:04, 18.02 Computational Sequence Entries/s]
#   0%|          | 0/30 [00:00<?, ? Segments/s]
# Aligning 8d-gEyoeBzc:   0%|          | 0/30 [00:00<?, ? Segments/s]
#
#   0%|          | 0/26 [00:00<?, ? Segments/s]
# Aligning 8qrpnFRGt2A:   0%|          | 0/26 [00:00<?, ? Segments/s]
# Overall Progress:  15%|█▌        | 14/93 [00:00<00:04, 18.08 Computational Sequence Entries/s]
#   0%|          | 0/25 [00:00<?, ? Segments/s]
# Aligning 9J25DZhivz8:   0%|          | 0/25 [00:00<?, ? Segments/s]
#
#   0%|          | 0/25 [00:00<?, ? Segments/s]
# Aligning 9T9Hf74oK10:   0%|          | 0/25 [00:00<?, ? Segments/s]
# Overall Progress:  17%|█▋        | 16/93 [00:00<00:04, 18.41 Computational Sequence Entries/s]
#   0%|          | 0/12 [00:00<?, ? Segments/s]
# Aligning 9c67fiY0wGQ:   0%|          | 0/12 [00:00<?, ? Segments/s]
#
#   0%|          | 0/33 [00:00<?, ? Segments/s]
# Aligning 9qR7uwkblbs:   0%|          | 0/33 [00:00<?, ? Segments/s]
#
#   0%|          | 0/31 [00:00<?, ? Segments/s]
# Aligning Af8D0E4ZXaw:   0%|          | 0/31 [00:00<?, ? Segments/s]
# Overall Progress:  20%|██        | 19/93 [00:01<00:03, 18.57 Computational Sequence Entries/s]
#   0%|          | 0/31 [00:00<?, ? Segments/s]
# Aligning BI97DNYfe5I:   0%|          | 0/31 [00:00<?, ? Segments/s]
#
#   0%|          | 0/31 [00:00<?, ? Segments/s]
# Aligning BXuRRbG0Ugk:   0%|          | 0/31 [00:00<?, ? Segments/s]
# Overall Progress:  23%|██▎       | 21/93 [00:01<00:03, 18.14 Computational Sequence Entries/s]
#   0%|          | 0/22 [00:00<?, ? Segments/s]
# Aligning Bfr499ggo-0:   0%|          | 0/22 [00:00<?, ? Segments/s]
#
#   0%|          | 0/30 [00:00<?, ? Segments/s]
# Aligning BioHAh1qJAQ:   0%|          | 0/30 [00:00<?, ? Segments/s]
#
#   0%|          | 0/26 [00:00<?, ? Segments/s]
# Aligning BvYR0L6f2Ig:   0%|          | 0/26 [00:00<?, ? Segments/s]
# Overall Progress:  26%|██▌       | 24/93 [00:01<00:03, 18.71 Computational Sequence Entries/s]
#   0%|          | 0/44 [00:00<?, ? Segments/s]
# Aligning Ci-AH39fi3Y:   0%|          | 0/44 [00:00<?, ? Segments/s]
#
#   0%|          | 0/31 [00:00<?, ? Segments/s]
# Aligning Clx4VXItLTE:   0%|          | 0/31 [00:00<?, ? Segments/s]
# Overall Progress:  28%|██▊       | 26/93 [00:01<00:03, 17.54 Computational Sequence Entries/s]
#   0%|          | 0/18 [00:00<?, ? Segments/s]
# Aligning Dg_0XKD0Mf4:   0%|          | 0/18 [00:00<?, ? Segments/s]
#
#   0%|          | 0/21 [00:00<?, ? Segments/s]
# Aligning G-xst2euQUc:   0%|          | 0/21 [00:00<?, ? Segments/s]
#
#   0%|          | 0/29 [00:00<?, ? Segments/s]
# Aligning G6GlGvlkxAQ:   0%|          | 0/29 [00:00<?, ? Segments/s]
# Overall Progress:  31%|███       | 29/93 [00:01<00:03, 18.64 Computational Sequence Entries/s]
#   0%|          | 0/18 [00:00<?, ? Segments/s]
# Aligning GWuJjcEuzt8:   0%|          | 0/18 [00:00<?, ? Segments/s]
#
#   0%|          | 0/34 [00:00<?, ? Segments/s]
# Aligning HEsqda8_d0Q:   0%|          | 0/34 [00:00<?, ? Segments/s]
# Overall Progress:  33%|███▎      | 31/93 [00:01<00:03, 17.12 Computational Sequence Entries/s]
#   0%|          | 0/39 [00:00<?, ? Segments/s]
# Aligning I5y0__X72p0:   0%|          | 0/39 [00:00<?, ? Segments/s]
#
#   0%|          | 0/16 [00:00<?, ? Segments/s]
# Aligning Iu2PFX3z_1s:   0%|          | 0/16 [00:00<?, ? Segments/s]
# Overall Progress:  35%|███▌      | 33/93 [00:01<00:03, 17.44 Computational Sequence Entries/s]
#   0%|          | 0/22 [00:00<?, ? Segments/s]
# Aligning IumbAb8q2dM:   0%|          | 0/22 [00:00<?, ? Segments/s]
#
#   0%|          | 0/20 [00:00<?, ? Segments/s]
# Aligning Jkswaaud0hk:   0%|          | 0/20 [00:00<?, ? Segments/s]
#
#   0%|          | 0/29 [00:00<?, ? Segments/s]
# Aligning LSi-o-IrDMs:   0%|          | 0/29 [00:00<?, ? Segments/s]
# Overall Progress:  39%|███▊      | 36/93 [00:01<00:03, 18.89 Computational Sequence Entries/s]
#   0%|          | 0/18 [00:00<?, ? Segments/s]
# Aligning MLal-t_vJPM:   0%|          | 0/18 [00:00<?, ? Segments/s]
#
#   0%|          | 0/13 [00:00<?, ? Segments/s]
# Aligning Njd1F0vZSm4:   0%|          | 0/13 [00:00<?, ? Segments/s]
#
#   0%|          | 0/32 [00:00<?, ? Segments/s]
# Aligning Nzq88NnDkEk:   0%|          | 0/32 [00:00<?, ? Segments/s]
# Overall Progress:  42%|████▏     | 39/93 [00:02<00:02, 20.00 Computational Sequence Entries/s]
#   0%|          | 0/16 [00:00<?, ? Segments/s]
# Aligning OQvJTdtJ2H4:   0%|          | 0/16 [00:00<?, ? Segments/s]
#
#   0%|          | 0/24 [00:00<?, ? Segments/s]
# Aligning OtBXNcAL_lE:   0%|          | 0/24 [00:00<?, ? Segments/s]
#
#   0%|          | 0/25 [00:00<?, ? Segments/s]
# Aligning Oz06ZWiO20M:   0%|          | 0/25 [00:00<?, ? Segments/s]
# Overall Progress:  45%|████▌     | 42/93 [00:02<00:02, 20.32 Computational Sequence Entries/s]
#   0%|          | 0/13 [00:00<?, ? Segments/s]
# Aligning POKffnXeBds:   0%|          | 0/13 [00:00<?, ? Segments/s]
#
#   0%|          | 0/12 [00:00<?, ? Segments/s]
# Aligning PZ-lDQFboO8:   0%|          | 0/12 [00:00<?, ? Segments/s]
#
#   0%|          | 0/18 [00:00<?, ? Segments/s]
# Aligning QN9ZIUWUXsY:   0%|          | 0/18 [00:00<?, ? Segments/s]
# Overall Progress:  48%|████▊     | 45/93 [00:02<00:02, 22.41 Computational Sequence Entries/s]
#   0%|          | 0/14 [00:00<?, ? Segments/s]
# Aligning Qr1Ca94K55A:   0%|          | 0/14 [00:00<?, ? Segments/s]
#
#   0%|          | 0/22 [00:00<?, ? Segments/s]
# Aligning Sqr0AcuoNnk:   0%|          | 0/22 [00:00<?, ? Segments/s]
#
#   0%|          | 0/15 [00:00<?, ? Segments/s]
# Aligning TvyZBvOMOTc:   0%|          | 0/15 [00:00<?, ? Segments/s]
# Overall Progress:  52%|█████▏    | 48/93 [00:02<00:01, 22.63 Computational Sequence Entries/s]
#   0%|          | 0/17 [00:00<?, ? Segments/s]
# Aligning VCslbP0mgZI:   0%|          | 0/17 [00:00<?, ? Segments/s]
#
#   0%|          | 0/55 [00:00<?, ? Segments/s]
# Aligning VbQk4H8hgr0:   0%|          | 0/55 [00:00<?, ? Segments/s]
#
#   0%|          | 0/9 [00:00<?, ? Segments/s]
# Aligning Vj1wYRQjB-o:   0%|          | 0/9 [00:00<?, ? Segments/s]
# Overall Progress:  55%|█████▍    | 51/93 [00:02<00:01, 22.03 Computational Sequence Entries/s]
#   0%|          | 0/32 [00:00<?, ? Segments/s]
# Aligning W8NXH0Djyww:   0%|          | 0/32 [00:00<?, ? Segments/s]
#
#   0%|          | 0/22 [00:00<?, ? Segments/s]
# Aligning WKA5OygbEKI:   0%|          | 0/22 [00:00<?, ? Segments/s]
#
#   0%|          | 0/11 [00:00<?, ? Segments/s]
# Aligning X3j2zQgwYgE:   0%|          | 0/11 [00:00<?, ? Segments/s]
# Overall Progress:  58%|█████▊    | 54/93 [00:02<00:01, 21.57 Computational Sequence Entries/s]
#   0%|          | 0/9 [00:00<?, ? Segments/s]
# Aligning ZAIRrfG22O0:   0%|          | 0/9 [00:00<?, ? Segments/s]
#
#   0%|          | 0/34 [00:00<?, ? Segments/s]
# Aligning ZUXBRvtny7o:   0%|          | 0/34 [00:00<?, ? Segments/s]
#
#   0%|          | 0/28 [00:00<?, ? Segments/s]
# Aligning _dI--eQ6qVU:   0%|          | 0/28 [00:00<?, ? Segments/s]
# Overall Progress:  61%|██████▏   | 57/93 [00:02<00:01, 21.48 Computational Sequence Entries/s]
#   0%|          | 0/30 [00:00<?, ? Segments/s]
# Aligning aiEXnCPZubE:   0%|          | 0/30 [00:00<?, ? Segments/s]
#
#   0%|          | 0/21 [00:00<?, ? Segments/s]
# Aligning atnd_PF-Lbs:   0%|          | 0/21 [00:00<?, ? Segments/s]
#
#   0%|          | 0/34 [00:00<?, ? Segments/s]
# Aligning bOL9jKpeJRs:   0%|          | 0/34 [00:00<?, ? Segments/s]
# Overall Progress:  65%|██████▍   | 60/93 [00:03<00:01, 20.96 Computational Sequence Entries/s]
#   0%|          | 0/25 [00:00<?, ? Segments/s]
# Aligning bvLlb-M3UXU:   0%|          | 0/25 [00:00<?, ? Segments/s]
#
#   0%|          | 0/15 [00:00<?, ? Segments/s]
# Aligning c5xsKMxpXnc:   0%|          | 0/15 [00:00<?, ? Segments/s]
#
#   0%|          | 0/33 [00:00<?, ? Segments/s]
# Aligning c7UH_rxdZv4:   0%|          | 0/33 [00:00<?, ? Segments/s]
# Overall Progress:  68%|██████▊   | 63/93 [00:03<00:01, 21.39 Computational Sequence Entries/s]
#   0%|          | 0/16 [00:00<?, ? Segments/s]
# Aligning cM3Yna7AavY:   0%|          | 0/16 [00:00<?, ? Segments/s]
#
#   0%|          | 0/24 [00:00<?, ? Segments/s]
# Aligning cW1FSBF59ik:   0%|          | 0/24 [00:00<?, ? Segments/s]
#
#   0%|          | 0/29 [00:00<?, ? Segments/s]
# Aligning cXypl4FnoZo:   0%|          | 0/29 [00:00<?, ? Segments/s]
# Overall Progress:  71%|███████   | 66/93 [00:03<00:01, 21.56 Computational Sequence Entries/s]
#   0%|          | 0/19 [00:00<?, ? Segments/s]
# Aligning d3_k5Xpfmik:   0%|          | 0/19 [00:00<?, ? Segments/s]
#
#   0%|          | 0/43 [00:00<?, ? Segments/s]
# Aligning d6hH302o4v8:   0%|          | 0/43 [00:00<?, ? Segments/s]
#
#   0%|          | 0/15 [00:00<?, ? Segments/s]
# Aligning dq3Nf_lMPnE:   0%|          | 0/15 [00:00<?, ? Segments/s]
# Overall Progress:  74%|███████▍  | 69/93 [00:03<00:01, 21.75 Computational Sequence Entries/s]
#   0%|          | 0/19 [00:00<?, ? Segments/s]
# Aligning etzxEpPuc6I:   0%|          | 0/19 [00:00<?, ? Segments/s]
#
#   0%|          | 0/30 [00:00<?, ? Segments/s]
# Aligning f9O3YtZ2VfI:   0%|          | 0/30 [00:00<?, ? Segments/s]
#
#   0%|          | 0/15 [00:00<?, ? Segments/s]
# Aligning f_pcplsH_V0:   0%|          | 0/15 [00:00<?, ? Segments/s]
# Overall Progress:  77%|███████▋  | 72/93 [00:03<00:00, 22.66 Computational Sequence Entries/s]
#   0%|          | 0/14 [00:00<?, ? Segments/s]
# Aligning fvVhgmXxadc:   0%|          | 0/14 [00:00<?, ? Segments/s]
#
#   0%|          | 0/18 [00:00<?, ? Segments/s]
# Aligning iiK8YX8oH1E:   0%|          | 0/18 [00:00<?, ? Segments/s]
#
#   0%|          | 0/27 [00:00<?, ? Segments/s]
# Aligning jUzDDGyPkXU:   0%|          | 0/27 [00:00<?, ? Segments/s]
# Overall Progress:  81%|████████  | 75/93 [00:03<00:00, 23.51 Computational Sequence Entries/s]
#   0%|          | 0/31 [00:00<?, ? Segments/s]
# Aligning k5Y_838nuGo:   0%|          | 0/31 [00:00<?, ? Segments/s]
#
#   0%|          | 0/30 [00:00<?, ? Segments/s]
# Aligning lXPQBPVc5Cw:   0%|          | 0/30 [00:00<?, ? Segments/s]
#
#   0%|          | 0/10 [00:00<?, ? Segments/s]
# Aligning nbWiPyCm4g0:   0%|          | 0/10 [00:00<?, ? Segments/s]
# Overall Progress:  84%|████████▍ | 78/93 [00:03<00:00, 23.25 Computational Sequence Entries/s]
#   0%|          | 0/24 [00:00<?, ? Segments/s]
# Aligning nzpVDcQ0ywM:   0%|          | 0/24 [00:00<?, ? Segments/s]
#
#   0%|          | 0/14 [00:00<?, ? Segments/s]
# Aligning ob23OKe5a9Q:   0%|          | 0/14 [00:00<?, ? Segments/s]
#
#   0%|          | 0/16 [00:00<?, ? Segments/s]
# Aligning pLTX3ipuDJI:   0%|          | 0/16 [00:00<?, ? Segments/s]
# Overall Progress:  87%|████████▋ | 81/93 [00:03<00:00, 24.06 Computational Sequence Entries/s]
#   0%|          | 0/21 [00:00<?, ? Segments/s]
# Aligning phBUpBr1hSo:   0%|          | 0/21 [00:00<?, ? Segments/s]
#
#   0%|          | 0/22 [00:00<?, ? Segments/s]
# Aligning rnaNMUZpvvg:   0%|          | 0/22 [00:00<?, ? Segments/s]
#
#   0%|          | 0/18 [00:00<?, ? Segments/s]
# Aligning tIrG4oNLFzE:   0%|          | 0/18 [00:00<?, ? Segments/s]
# Overall Progress:  90%|█████████ | 84/93 [00:04<00:00, 24.07 Computational Sequence Entries/s]
#   0%|          | 0/16 [00:00<?, ? Segments/s]
# Aligning tStelxIAHjw:   0%|          | 0/16 [00:00<?, ? Segments/s]
#
#   0%|          | 0/20 [00:00<?, ? Segments/s]
# Aligning tmZoasNr4rU:   0%|          | 0/20 [00:00<?, ? Segments/s]
#
#   0%|          | 0/16 [00:00<?, ? Segments/s]
# Aligning v0zCBqDeKcE:   0%|          | 0/16 [00:00<?, ? Segments/s]
# Overall Progress:  94%|█████████▎| 87/93 [00:04<00:00, 24.95 Computational Sequence Entries/s]
#   0%|          | 0/12 [00:00<?, ? Segments/s]
# Aligning vvZ4IcEtiZc:   0%|          | 0/12 [00:00<?, ? Segments/s]
#
#   0%|          | 0/22 [00:00<?, ? Segments/s]
# Aligning vyB00TXsimI:   0%|          | 0/22 [00:00<?, ? Segments/s]
#
#   0%|          | 0/30 [00:00<?, ? Segments/s]
# Aligning wMbj6ajWbic:   0%|          | 0/30 [00:00<?, ? Segments/s]
# Overall Progress:  97%|█████████▋| 90/93 [00:04<00:00, 24.04 Computational Sequence Entries/s]
#   0%|          | 0/24 [00:00<?, ? Segments/s]
# Aligning yDtzw_Y-7RU:   0%|          | 0/24 [00:00<?, ? Segments/s]
#
#   0%|          | 0/23 [00:00<?, ? Segments/s]
# Aligning yvsjCA6Y5Fc:   0%|          | 0/23 [00:00<?, ? Segments/s]
#
#   0%|          | 0/35 [00:00<?, ? Segments/s]
# Aligning zhpQhgha_KU:   0%|          | 0/35 [00:00<?, ? Segments/s]
# [2024-12-03 11:04:27.688] | Success | Alignment to <CMU_MOSI_Opinion_Labels> complete.
# [2024-12-03 11:04:27.688] | Status  | Replacing dataset content with aligned computational sequences
# [2024-12-03 11:04:27.852] | Success | Initialized empty <CMU_MOSI_TimestampedWords> computational sequence.
# [2024-12-03 11:04:27.852] | Status  | Checking the format of the data in <CMU_MOSI_TimestampedWords> computational sequence ...
# [2024-12-03 11:04:27.862] | Success | <CMU_MOSI_TimestampedWords> computational sequence data in correct format.
# [2024-12-03 11:04:27.862] | Status  | Checking the format of the metadata in <CMU_MOSI_TimestampedWords> computational sequence ...
# [2024-12-03 11:04:27.862] | Warning | <CMU_MOSI_TimestampedWords> computational sequence does not have all the required metadata ... continuing
# [2024-12-03 11:04:27.862] | Success | Initialized empty <CMU_MOSI_Visual_Facet_41> computational sequence.
# [2024-12-03 11:04:27.862] | Status  | Checking the format of the data in <CMU_MOSI_Visual_Facet_41> computational sequence ...
# [2024-12-03 11:04:27.871] | Success | <CMU_MOSI_Visual_Facet_41> computational sequence data in correct format.
# [2024-12-03 11:04:27.872] | Status  | Checking the format of the metadata in <CMU_MOSI_Visual_Facet_41> computational sequence ...
# [2024-12-03 11:04:27.872] | Warning | <CMU_MOSI_Visual_Facet_41> computational sequence does not have all the required metadata ... continuing
# [2024-12-03 11:04:27.872] | Success | Initialized empty <CMU_MOSI_COVAREP> computational sequence.
# [2024-12-03 11:04:27.872] | Status  | Checking the format of the data in <CMU_MOSI_COVAREP> computational sequence ...
# [2024-12-03 11:04:27.880] | Success | <CMU_MOSI_COVAREP> computational sequence data in correct format.
# [2024-12-03 11:04:27.881] | Status  | Checking the format of the metadata in <CMU_MOSI_COVAREP> computational sequence ...
# [2024-12-03 11:04:27.881] | Warning | <CMU_MOSI_COVAREP> computational sequence does not have all the required metadata ... continuing
# [2024-12-03 11:04:27.881] | Success | Initialized empty <CMU_MOSI_Opinion_Labels> computational sequence.
# [2024-12-03 11:04:27.881] | Status  | Checking the format of the data in <CMU_MOSI_Opinion_Labels> computational sequence ...
# [2024-12-03 11:04:27.892] | Success | <CMU_MOSI_Opinion_Labels> computational sequence data in correct format.
# [2024-12-03 11:04:27.892] | Status  | Checking the format of the metadata in <CMU_MOSI_Opinion_Labels> computational sequence ...
# [2024-12-03 11:04:27.892] | Warning | <CMU_MOSI_Opinion_Labels> computational sequence does not have all the required metadata ... continuing

# %%
# check out what the keys look like now
print(list(dataset[text_field_Words].keys())[55])
# Out:
# 1iG0909rllw[3]

# %%
num_segments = len(dataset[visual_field_Facet41].keys())  # Assuming all fields have the same segment keys
print(f"Number of segments: {num_segments}")
# Out:
# Number of segments: 2198

# %%
# Compute lengths of segments for each modality
segment_lengths_visual = [dataset[visual_field_Facet41][seg]['features'].shape[0] for seg in dataset[visual_field_Facet41].keys()]
segment_lengths_acoustic = [dataset[acoustic_field_COVAREP][seg]['features'].shape[0] for seg in dataset[acoustic_field_COVAREP].keys()]
segment_lengths_text = [dataset[text_field_Words][seg]['features'].shape[0] for seg in dataset[text_field_Words].keys()]

# Calculate maximum and minimum lengths
max_length_visual = max(segment_lengths_visual)
min_length_visual = min(segment_lengths_visual)

max_length_acoustic = max(segment_lengths_acoustic)
min_length_acoustic = min(segment_lengths_acoustic)

max_length_text = max(segment_lengths_text)
min_length_text = min(segment_lengths_text)

# Print the results
print(f"Visual modality: Max length = {max_length_visual}, Min length = {min_length_visual}")
print(f"Acoustic modality: Max length = {max_length_acoustic}, Min length = {min_length_acoustic}")
print(f"Text modality: Max length = {max_length_text}, Min length = {min_length_text}")
# Out:
# Visual modality: Max length = 125, Min length = 1
# Acoustic modality: Max length = 125, Min length = 1
# Text modality: Max length = 125, Min length = 1

# %%
for seg in dataset[visual_field_Facet41].keys():  # Assuming all modalities have the same segment keys
    visual_length = dataset[visual_field_Facet41][seg]['features'].shape[0]
    acoustic_length = dataset[acoustic_field_COVAREP][seg]['features'].shape[0]
    text_length = dataset[text_field_Words][seg]['features'].shape[0]
    
    print(f"Segment {seg}: Visual length = {visual_length}, Acoustic length = {acoustic_length}, Text length = {text_length}")
# Out:
# Segment 03bSnISJMiM[0]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment 03bSnISJMiM[1]: Visual length = 27, Acoustic length = 27, Text length = 27
# Segment 03bSnISJMiM[2]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 03bSnISJMiM[3]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 03bSnISJMiM[4]: Visual length = 4, Acoustic length = 4, Text length = 4
# Segment 03bSnISJMiM[5]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 03bSnISJMiM[6]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment 03bSnISJMiM[7]: Visual length = 20, Acoustic length = 20, Text length = 20
# Segment 03bSnISJMiM[8]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 03bSnISJMiM[9]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 03bSnISJMiM[10]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 03bSnISJMiM[11]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 03bSnISJMiM[12]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 0h-zjBukYpk[0]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment 0h-zjBukYpk[1]: Visual length = 33, Acoustic length = 33, Text length = 33
# Segment 0h-zjBukYpk[2]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 0h-zjBukYpk[3]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 0h-zjBukYpk[4]: Visual length = 22, Acoustic length = 22, Text length = 22
# Segment 0h-zjBukYpk[5]: Visual length = 21, Acoustic length = 21, Text length = 21
# Segment 0h-zjBukYpk[6]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment 0h-zjBukYpk[7]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 0h-zjBukYpk[8]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 0h-zjBukYpk[9]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 0h-zjBukYpk[10]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 0h-zjBukYpk[11]: Visual length = 3, Acoustic length = 3, Text length = 3
# Segment 0h-zjBukYpk[12]: Visual length = 3, Acoustic length = 3, Text length = 3
# Segment 0h-zjBukYpk[13]: Visual length = 28, Acoustic length = 28, Text length = 28
# Segment 0h-zjBukYpk[14]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 0h-zjBukYpk[15]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment 0h-zjBukYpk[16]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment 0h-zjBukYpk[17]: Visual length = 19, Acoustic length = 19, Text length = 19
# Segment 0h-zjBukYpk[18]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 0h-zjBukYpk[19]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment 0h-zjBukYpk[20]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 0h-zjBukYpk[21]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment 0h-zjBukYpk[22]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 0h-zjBukYpk[23]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 0h-zjBukYpk[24]: Visual length = 47, Acoustic length = 47, Text length = 47
# Segment 1DmNV9C1hbY[0]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment 1DmNV9C1hbY[1]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment 1DmNV9C1hbY[2]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment 1DmNV9C1hbY[3]: Visual length = 21, Acoustic length = 21, Text length = 21
# Segment 1DmNV9C1hbY[4]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 1DmNV9C1hbY[5]: Visual length = 18, Acoustic length = 18, Text length = 18
# Segment 1DmNV9C1hbY[6]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment 1DmNV9C1hbY[7]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 1DmNV9C1hbY[8]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 1DmNV9C1hbY[9]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 1DmNV9C1hbY[10]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment 1DmNV9C1hbY[11]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment 1DmNV9C1hbY[12]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 1DmNV9C1hbY[13]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 1iG0909rllw[0]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 1iG0909rllw[1]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 1iG0909rllw[2]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment 1iG0909rllw[3]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment 1iG0909rllw[4]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 1iG0909rllw[5]: Visual length = 3, Acoustic length = 3, Text length = 3
# Segment 1iG0909rllw[6]: Visual length = 29, Acoustic length = 29, Text length = 29
# Segment 1iG0909rllw[7]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 1iG0909rllw[8]: Visual length = 21, Acoustic length = 21, Text length = 21
# Segment 1iG0909rllw[9]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment 1iG0909rllw[10]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment 1iG0909rllw[11]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment 1iG0909rllw[12]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 1iG0909rllw[13]: Visual length = 24, Acoustic length = 24, Text length = 24
# Segment 1iG0909rllw[14]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 1iG0909rllw[15]: Visual length = 21, Acoustic length = 21, Text length = 21
# Segment 1iG0909rllw[16]: Visual length = 19, Acoustic length = 19, Text length = 19
# Segment 1iG0909rllw[17]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment 1iG0909rllw[18]: Visual length = 18, Acoustic length = 18, Text length = 18
# Segment 1iG0909rllw[19]: Visual length = 27, Acoustic length = 27, Text length = 27
# Segment 1iG0909rllw[20]: Visual length = 46, Acoustic length = 46, Text length = 46
# Segment 1iG0909rllw[21]: Visual length = 35, Acoustic length = 35, Text length = 35
# Segment 1iG0909rllw[22]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment 1iG0909rllw[23]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 1iG0909rllw[24]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 1iG0909rllw[25]: Visual length = 31, Acoustic length = 31, Text length = 31
# Segment 1iG0909rllw[26]: Visual length = 19, Acoustic length = 19, Text length = 19
# Segment 1iG0909rllw[27]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment 1iG0909rllw[28]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment 1iG0909rllw[29]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 2WGyTLYerpo[0]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 2WGyTLYerpo[1]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 2WGyTLYerpo[2]: Visual length = 22, Acoustic length = 22, Text length = 22
# Segment 2WGyTLYerpo[3]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment 2WGyTLYerpo[4]: Visual length = 16, Acoustic length = 16, Text length = 16
# Segment 2WGyTLYerpo[5]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 2WGyTLYerpo[6]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 2WGyTLYerpo[7]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 2WGyTLYerpo[8]: Visual length = 22, Acoustic length = 22, Text length = 22
# Segment 2WGyTLYerpo[9]: Visual length = 4, Acoustic length = 4, Text length = 4
# Segment 2WGyTLYerpo[10]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 2WGyTLYerpo[11]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 2WGyTLYerpo[12]: Visual length = 16, Acoustic length = 16, Text length = 16
# Segment 2WGyTLYerpo[13]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 2WGyTLYerpo[14]: Visual length = 4, Acoustic length = 4, Text length = 4
# Segment 2WGyTLYerpo[15]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment 2WGyTLYerpo[16]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 2WGyTLYerpo[17]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 2WGyTLYerpo[18]: Visual length = 25, Acoustic length = 25, Text length = 25
# Segment 2WGyTLYerpo[19]: Visual length = 3, Acoustic length = 3, Text length = 3
# Segment 2WGyTLYerpo[20]: Visual length = 3, Acoustic length = 3, Text length = 3
# Segment 2WGyTLYerpo[21]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 2WGyTLYerpo[22]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 2WGyTLYerpo[23]: Visual length = 41, Acoustic length = 41, Text length = 41
# Segment 2WGyTLYerpo[24]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 2WGyTLYerpo[25]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 2WGyTLYerpo[26]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 2WGyTLYerpo[27]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 2WGyTLYerpo[28]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 2WGyTLYerpo[29]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 2WGyTLYerpo[30]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment 2WGyTLYerpo[31]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 2WGyTLYerpo[32]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 2WGyTLYerpo[33]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 2WGyTLYerpo[34]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment 2WGyTLYerpo[35]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 2WGyTLYerpo[36]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 2WGyTLYerpo[37]: Visual length = 20, Acoustic length = 20, Text length = 20
# Segment 2WGyTLYerpo[38]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment 2WGyTLYerpo[39]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 2WGyTLYerpo[40]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 2WGyTLYerpo[41]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 2WGyTLYerpo[42]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 2WGyTLYerpo[44]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 2WGyTLYerpo[45]: Visual length = 4, Acoustic length = 4, Text length = 4
# Segment 2WGyTLYerpo[46]: Visual length = 3, Acoustic length = 3, Text length = 3
# Segment 2WGyTLYerpo[47]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 2WGyTLYerpo[48]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment 2WGyTLYerpo[49]: Visual length = 4, Acoustic length = 4, Text length = 4
# Segment 2WGyTLYerpo[50]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment 2WGyTLYerpo[51]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 2WGyTLYerpo[52]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 2WGyTLYerpo[53]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 2WGyTLYerpo[54]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment 2WGyTLYerpo[55]: Visual length = 21, Acoustic length = 21, Text length = 21
# Segment 2WGyTLYerpo[56]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment 2WGyTLYerpo[57]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment 2WGyTLYerpo[58]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 2WGyTLYerpo[59]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment 2WGyTLYerpo[60]: Visual length = 4, Acoustic length = 4, Text length = 4
# Segment 2WGyTLYerpo[61]: Visual length = 4, Acoustic length = 4, Text length = 4
# Segment 2WGyTLYerpo[62]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 2iD-tVS8NPw[0]: Visual length = 26, Acoustic length = 26, Text length = 26
# Segment 2iD-tVS8NPw[1]: Visual length = 18, Acoustic length = 18, Text length = 18
# Segment 2iD-tVS8NPw[2]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 2iD-tVS8NPw[3]: Visual length = 18, Acoustic length = 18, Text length = 18
# Segment 2iD-tVS8NPw[4]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment 2iD-tVS8NPw[5]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment 2iD-tVS8NPw[6]: Visual length = 37, Acoustic length = 37, Text length = 37
# Segment 2iD-tVS8NPw[7]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 2iD-tVS8NPw[8]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 2iD-tVS8NPw[9]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment 2iD-tVS8NPw[10]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 2iD-tVS8NPw[11]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 2iD-tVS8NPw[12]: Visual length = 27, Acoustic length = 27, Text length = 27
# Segment 2iD-tVS8NPw[13]: Visual length = 31, Acoustic length = 31, Text length = 31
# Segment 2iD-tVS8NPw[14]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 2iD-tVS8NPw[15]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 2iD-tVS8NPw[16]: Visual length = 21, Acoustic length = 21, Text length = 21
# Segment 2iD-tVS8NPw[17]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 2iD-tVS8NPw[18]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 2iD-tVS8NPw[19]: Visual length = 47, Acoustic length = 47, Text length = 47
# Segment 2iD-tVS8NPw[20]: Visual length = 39, Acoustic length = 39, Text length = 39
# Segment 2iD-tVS8NPw[21]: Visual length = 23, Acoustic length = 23, Text length = 23
# Segment 2iD-tVS8NPw[22]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 2iD-tVS8NPw[23]: Visual length = 28, Acoustic length = 28, Text length = 28
# Segment 2iD-tVS8NPw[24]: Visual length = 20, Acoustic length = 20, Text length = 20
# Segment 2iD-tVS8NPw[25]: Visual length = 45, Acoustic length = 45, Text length = 45
# Segment 2iD-tVS8NPw[26]: Visual length = 40, Acoustic length = 40, Text length = 40
# Segment 2iD-tVS8NPw[27]: Visual length = 16, Acoustic length = 16, Text length = 16
# Segment 2iD-tVS8NPw[28]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 2iD-tVS8NPw[29]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment 5W7Z1C_fDaE[0]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment 5W7Z1C_fDaE[1]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment 5W7Z1C_fDaE[2]: Visual length = 4, Acoustic length = 4, Text length = 4
# Segment 5W7Z1C_fDaE[3]: Visual length = 2, Acoustic length = 2, Text length = 2
# Segment 5W7Z1C_fDaE[4]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 5W7Z1C_fDaE[5]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 5W7Z1C_fDaE[6]: Visual length = 23, Acoustic length = 23, Text length = 23
# Segment 5W7Z1C_fDaE[7]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 5W7Z1C_fDaE[8]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 5W7Z1C_fDaE[9]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 5W7Z1C_fDaE[10]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 5W7Z1C_fDaE[11]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment 5W7Z1C_fDaE[12]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 5W7Z1C_fDaE[13]: Visual length = 20, Acoustic length = 20, Text length = 20
# Segment 5W7Z1C_fDaE[14]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment 5W7Z1C_fDaE[15]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 5W7Z1C_fDaE[16]: Visual length = 20, Acoustic length = 20, Text length = 20
# Segment 5W7Z1C_fDaE[17]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment 5W7Z1C_fDaE[18]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 5W7Z1C_fDaE[19]: Visual length = 4, Acoustic length = 4, Text length = 4
# Segment 5W7Z1C_fDaE[20]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment 5W7Z1C_fDaE[21]: Visual length = 26, Acoustic length = 26, Text length = 26
# Segment 5W7Z1C_fDaE[22]: Visual length = 21, Acoustic length = 21, Text length = 21
# Segment 5W7Z1C_fDaE[23]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 6Egk_28TtTM[0]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment 6Egk_28TtTM[1]: Visual length = 22, Acoustic length = 22, Text length = 22
# Segment 6Egk_28TtTM[2]: Visual length = 21, Acoustic length = 21, Text length = 21
# Segment 6Egk_28TtTM[3]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 6Egk_28TtTM[4]: Visual length = 19, Acoustic length = 19, Text length = 19
# Segment 6Egk_28TtTM[5]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment 6Egk_28TtTM[6]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment 6Egk_28TtTM[7]: Visual length = 27, Acoustic length = 27, Text length = 27
# Segment 6Egk_28TtTM[8]: Visual length = 25, Acoustic length = 25, Text length = 25
# Segment 6Egk_28TtTM[9]: Visual length = 20, Acoustic length = 20, Text length = 20
# Segment 6Egk_28TtTM[10]: Visual length = 33, Acoustic length = 33, Text length = 33
# Segment 6Egk_28TtTM[11]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 6_0THN4chvY[0]: Visual length = 26, Acoustic length = 26, Text length = 26
# Segment 6_0THN4chvY[1]: Visual length = 37, Acoustic length = 37, Text length = 37
# Segment 6_0THN4chvY[2]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment 6_0THN4chvY[3]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 6_0THN4chvY[4]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 6_0THN4chvY[5]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 6_0THN4chvY[6]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 6_0THN4chvY[7]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment 6_0THN4chvY[8]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment 6_0THN4chvY[9]: Visual length = 22, Acoustic length = 22, Text length = 22
# Segment 6_0THN4chvY[10]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 6_0THN4chvY[11]: Visual length = 23, Acoustic length = 23, Text length = 23
# Segment 6_0THN4chvY[12]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 6_0THN4chvY[13]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 73jzhE8R1TQ[0]: Visual length = 25, Acoustic length = 25, Text length = 25
# Segment 73jzhE8R1TQ[1]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment 73jzhE8R1TQ[2]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment 73jzhE8R1TQ[3]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 73jzhE8R1TQ[4]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 73jzhE8R1TQ[5]: Visual length = 16, Acoustic length = 16, Text length = 16
# Segment 73jzhE8R1TQ[6]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 73jzhE8R1TQ[7]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment 73jzhE8R1TQ[8]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 73jzhE8R1TQ[9]: Visual length = 23, Acoustic length = 23, Text length = 23
# Segment 73jzhE8R1TQ[10]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment 73jzhE8R1TQ[11]: Visual length = 24, Acoustic length = 24, Text length = 24
# Segment 73jzhE8R1TQ[12]: Visual length = 36, Acoustic length = 36, Text length = 36
# Segment 73jzhE8R1TQ[13]: Visual length = 26, Acoustic length = 26, Text length = 26
# Segment 73jzhE8R1TQ[14]: Visual length = 28, Acoustic length = 28, Text length = 28
# Segment 73jzhE8R1TQ[15]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment 73jzhE8R1TQ[16]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 73jzhE8R1TQ[17]: Visual length = 30, Acoustic length = 30, Text length = 30
# Segment 73jzhE8R1TQ[18]: Visual length = 16, Acoustic length = 16, Text length = 16
# Segment 7JsX8y1ysxY[0]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 7JsX8y1ysxY[1]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 7JsX8y1ysxY[2]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 7JsX8y1ysxY[3]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 7JsX8y1ysxY[4]: Visual length = 46, Acoustic length = 46, Text length = 46
# Segment 7JsX8y1ysxY[5]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 7JsX8y1ysxY[6]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 7JsX8y1ysxY[7]: Visual length = 53, Acoustic length = 53, Text length = 53
# Segment 7JsX8y1ysxY[8]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 7JsX8y1ysxY[9]: Visual length = 3, Acoustic length = 3, Text length = 3
# Segment 7JsX8y1ysxY[10]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 7JsX8y1ysxY[11]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment 7JsX8y1ysxY[12]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment 7JsX8y1ysxY[13]: Visual length = 24, Acoustic length = 24, Text length = 24
# Segment 7JsX8y1ysxY[14]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment 7JsX8y1ysxY[15]: Visual length = 4, Acoustic length = 4, Text length = 4
# Segment 7JsX8y1ysxY[16]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 7JsX8y1ysxY[17]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 7JsX8y1ysxY[18]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment 7JsX8y1ysxY[19]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment 7JsX8y1ysxY[20]: Visual length = 18, Acoustic length = 18, Text length = 18
# Segment 7JsX8y1ysxY[21]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 7JsX8y1ysxY[22]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 7JsX8y1ysxY[23]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 7JsX8y1ysxY[24]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 7JsX8y1ysxY[25]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment 7JsX8y1ysxY[26]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 7JsX8y1ysxY[27]: Visual length = 3, Acoustic length = 3, Text length = 3
# Segment 7JsX8y1ysxY[28]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 7JsX8y1ysxY[29]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 7JsX8y1ysxY[30]: Visual length = 4, Acoustic length = 4, Text length = 4
# Segment 7JsX8y1ysxY[31]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment 7JsX8y1ysxY[32]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 7JsX8y1ysxY[33]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 7JsX8y1ysxY[34]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 7JsX8y1ysxY[35]: Visual length = 27, Acoustic length = 27, Text length = 27
# Segment 7JsX8y1ysxY[36]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 7JsX8y1ysxY[37]: Visual length = 25, Acoustic length = 25, Text length = 25
# Segment 7JsX8y1ysxY[38]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 8OtFthrtaJM[0]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 8OtFthrtaJM[1]: Visual length = 16, Acoustic length = 16, Text length = 16
# Segment 8OtFthrtaJM[2]: Visual length = 22, Acoustic length = 22, Text length = 22
# Segment 8OtFthrtaJM[3]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 8OtFthrtaJM[4]: Visual length = 16, Acoustic length = 16, Text length = 16
# Segment 8OtFthrtaJM[5]: Visual length = 24, Acoustic length = 24, Text length = 24
# Segment 8OtFthrtaJM[6]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 8OtFthrtaJM[7]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 8OtFthrtaJM[8]: Visual length = 22, Acoustic length = 22, Text length = 22
# Segment 8OtFthrtaJM[9]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 8OtFthrtaJM[10]: Visual length = 23, Acoustic length = 23, Text length = 23
# Segment 8OtFthrtaJM[11]: Visual length = 30, Acoustic length = 30, Text length = 30
# Segment 8OtFthrtaJM[12]: Visual length = 51, Acoustic length = 51, Text length = 51
# Segment 8OtFthrtaJM[13]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 8OtFthrtaJM[14]: Visual length = 18, Acoustic length = 18, Text length = 18
# Segment 8OtFthrtaJM[15]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 8OtFthrtaJM[16]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 8OtFthrtaJM[17]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 8OtFthrtaJM[18]: Visual length = 18, Acoustic length = 18, Text length = 18
# Segment 8OtFthrtaJM[19]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 8OtFthrtaJM[20]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 8OtFthrtaJM[21]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment 8OtFthrtaJM[22]: Visual length = 27, Acoustic length = 27, Text length = 27
# Segment 8d-gEyoeBzc[0]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 8d-gEyoeBzc[1]: Visual length = 32, Acoustic length = 32, Text length = 32
# Segment 8d-gEyoeBzc[2]: Visual length = 41, Acoustic length = 41, Text length = 41
# Segment 8d-gEyoeBzc[3]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment 8d-gEyoeBzc[4]: Visual length = 22, Acoustic length = 22, Text length = 22
# Segment 8d-gEyoeBzc[5]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment 8d-gEyoeBzc[6]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment 8d-gEyoeBzc[7]: Visual length = 21, Acoustic length = 21, Text length = 21
# Segment 8d-gEyoeBzc[8]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment 8d-gEyoeBzc[9]: Visual length = 23, Acoustic length = 23, Text length = 23
# Segment 8d-gEyoeBzc[10]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 8d-gEyoeBzc[11]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment 8d-gEyoeBzc[12]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 8d-gEyoeBzc[13]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 8d-gEyoeBzc[14]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 8d-gEyoeBzc[15]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 8d-gEyoeBzc[16]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 8d-gEyoeBzc[17]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment 8d-gEyoeBzc[18]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment 8d-gEyoeBzc[19]: Visual length = 21, Acoustic length = 21, Text length = 21
# Segment 8d-gEyoeBzc[20]: Visual length = 50, Acoustic length = 50, Text length = 50
# Segment 8d-gEyoeBzc[21]: Visual length = 27, Acoustic length = 27, Text length = 27
# Segment 8d-gEyoeBzc[22]: Visual length = 26, Acoustic length = 26, Text length = 26
# Segment 8d-gEyoeBzc[23]: Visual length = 36, Acoustic length = 36, Text length = 36
# Segment 8d-gEyoeBzc[24]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 8d-gEyoeBzc[25]: Visual length = 42, Acoustic length = 42, Text length = 42
# Segment 8d-gEyoeBzc[26]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment 8d-gEyoeBzc[27]: Visual length = 19, Acoustic length = 19, Text length = 19
# Segment 8d-gEyoeBzc[28]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment 8d-gEyoeBzc[29]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 8qrpnFRGt2A[0]: Visual length = 47, Acoustic length = 47, Text length = 47
# Segment 8qrpnFRGt2A[1]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 8qrpnFRGt2A[2]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment 8qrpnFRGt2A[3]: Visual length = 19, Acoustic length = 19, Text length = 19
# Segment 8qrpnFRGt2A[4]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 8qrpnFRGt2A[5]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment 8qrpnFRGt2A[6]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 8qrpnFRGt2A[7]: Visual length = 20, Acoustic length = 20, Text length = 20
# Segment 8qrpnFRGt2A[8]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 8qrpnFRGt2A[9]: Visual length = 29, Acoustic length = 29, Text length = 29
# Segment 8qrpnFRGt2A[10]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment 8qrpnFRGt2A[11]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment 8qrpnFRGt2A[12]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 8qrpnFRGt2A[13]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 8qrpnFRGt2A[14]: Visual length = 49, Acoustic length = 49, Text length = 49
# Segment 8qrpnFRGt2A[15]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment 8qrpnFRGt2A[16]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 8qrpnFRGt2A[17]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment 8qrpnFRGt2A[18]: Visual length = 35, Acoustic length = 35, Text length = 35
# Segment 8qrpnFRGt2A[19]: Visual length = 22, Acoustic length = 22, Text length = 22
# Segment 8qrpnFRGt2A[20]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment 8qrpnFRGt2A[21]: Visual length = 20, Acoustic length = 20, Text length = 20
# Segment 8qrpnFRGt2A[22]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 8qrpnFRGt2A[23]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment 8qrpnFRGt2A[24]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment 8qrpnFRGt2A[25]: Visual length = 32, Acoustic length = 32, Text length = 32
# Segment 9J25DZhivz8[0]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 9J25DZhivz8[1]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment 9J25DZhivz8[2]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 9J25DZhivz8[3]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 9J25DZhivz8[4]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 9J25DZhivz8[5]: Visual length = 22, Acoustic length = 22, Text length = 22
# Segment 9J25DZhivz8[6]: Visual length = 35, Acoustic length = 35, Text length = 35
# Segment 9J25DZhivz8[7]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 9J25DZhivz8[8]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 9J25DZhivz8[9]: Visual length = 22, Acoustic length = 22, Text length = 22
# Segment 9J25DZhivz8[10]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment 9J25DZhivz8[11]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 9J25DZhivz8[12]: Visual length = 19, Acoustic length = 19, Text length = 19
# Segment 9J25DZhivz8[13]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 9J25DZhivz8[14]: Visual length = 4, Acoustic length = 4, Text length = 4
# Segment 9J25DZhivz8[15]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment 9J25DZhivz8[16]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment 9J25DZhivz8[17]: Visual length = 43, Acoustic length = 43, Text length = 43
# Segment 9J25DZhivz8[18]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment 9J25DZhivz8[19]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment 9J25DZhivz8[20]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 9J25DZhivz8[21]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment 9J25DZhivz8[22]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 9J25DZhivz8[23]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 9J25DZhivz8[24]: Visual length = 19, Acoustic length = 19, Text length = 19
# Segment 9T9Hf74oK10[0]: Visual length = 4, Acoustic length = 4, Text length = 4
# Segment 9T9Hf74oK10[1]: Visual length = 27, Acoustic length = 27, Text length = 27
# Segment 9T9Hf74oK10[2]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment 9T9Hf74oK10[3]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment 9T9Hf74oK10[4]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment 9T9Hf74oK10[5]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 9T9Hf74oK10[6]: Visual length = 29, Acoustic length = 29, Text length = 29
# Segment 9T9Hf74oK10[7]: Visual length = 35, Acoustic length = 35, Text length = 35
# Segment 9T9Hf74oK10[8]: Visual length = 23, Acoustic length = 23, Text length = 23
# Segment 9T9Hf74oK10[9]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 9T9Hf74oK10[10]: Visual length = 30, Acoustic length = 30, Text length = 30
# Segment 9T9Hf74oK10[11]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 9T9Hf74oK10[12]: Visual length = 16, Acoustic length = 16, Text length = 16
# Segment 9T9Hf74oK10[13]: Visual length = 18, Acoustic length = 18, Text length = 18
# Segment 9T9Hf74oK10[14]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment 9T9Hf74oK10[15]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment 9T9Hf74oK10[16]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 9T9Hf74oK10[17]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 9T9Hf74oK10[18]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 9T9Hf74oK10[19]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 9T9Hf74oK10[20]: Visual length = 16, Acoustic length = 16, Text length = 16
# Segment 9T9Hf74oK10[21]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment 9T9Hf74oK10[22]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 9T9Hf74oK10[23]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment 9T9Hf74oK10[24]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment 9c67fiY0wGQ[0]: Visual length = 16, Acoustic length = 16, Text length = 16
# Segment 9c67fiY0wGQ[1]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment 9c67fiY0wGQ[2]: Visual length = 25, Acoustic length = 25, Text length = 25
# Segment 9c67fiY0wGQ[3]: Visual length = 16, Acoustic length = 16, Text length = 16
# Segment 9c67fiY0wGQ[4]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment 9c67fiY0wGQ[5]: Visual length = 21, Acoustic length = 21, Text length = 21
# Segment 9c67fiY0wGQ[6]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 9c67fiY0wGQ[7]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 9c67fiY0wGQ[8]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 9c67fiY0wGQ[9]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 9c67fiY0wGQ[10]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 9c67fiY0wGQ[11]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment 9qR7uwkblbs[0]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment 9qR7uwkblbs[1]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 9qR7uwkblbs[2]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 9qR7uwkblbs[3]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 9qR7uwkblbs[4]: Visual length = 29, Acoustic length = 29, Text length = 29
# Segment 9qR7uwkblbs[5]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 9qR7uwkblbs[6]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment 9qR7uwkblbs[7]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 9qR7uwkblbs[8]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 9qR7uwkblbs[9]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment 9qR7uwkblbs[10]: Visual length = 32, Acoustic length = 32, Text length = 32
# Segment 9qR7uwkblbs[11]: Visual length = 24, Acoustic length = 24, Text length = 24
# Segment 9qR7uwkblbs[12]: Visual length = 20, Acoustic length = 20, Text length = 20
# Segment 9qR7uwkblbs[13]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment 9qR7uwkblbs[14]: Visual length = 39, Acoustic length = 39, Text length = 39
# Segment 9qR7uwkblbs[15]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment 9qR7uwkblbs[16]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 9qR7uwkblbs[17]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment 9qR7uwkblbs[18]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 9qR7uwkblbs[19]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 9qR7uwkblbs[20]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment 9qR7uwkblbs[21]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment 9qR7uwkblbs[22]: Visual length = 33, Acoustic length = 33, Text length = 33
# Segment 9qR7uwkblbs[23]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment 9qR7uwkblbs[24]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment 9qR7uwkblbs[25]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment 9qR7uwkblbs[26]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment 9qR7uwkblbs[27]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment 9qR7uwkblbs[28]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment 9qR7uwkblbs[29]: Visual length = 28, Acoustic length = 28, Text length = 28
# Segment 9qR7uwkblbs[30]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment 9qR7uwkblbs[31]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment 9qR7uwkblbs[32]: Visual length = 1, Acoustic length = 1, Text length = 1
# Segment Af8D0E4ZXaw[0]: Visual length = 25, Acoustic length = 25, Text length = 25
# Segment Af8D0E4ZXaw[1]: Visual length = 25, Acoustic length = 25, Text length = 25
# Segment Af8D0E4ZXaw[2]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment Af8D0E4ZXaw[3]: Visual length = 25, Acoustic length = 25, Text length = 25
# Segment Af8D0E4ZXaw[4]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment Af8D0E4ZXaw[5]: Visual length = 4, Acoustic length = 4, Text length = 4
# Segment Af8D0E4ZXaw[6]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment Af8D0E4ZXaw[7]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment Af8D0E4ZXaw[8]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment Af8D0E4ZXaw[9]: Visual length = 27, Acoustic length = 27, Text length = 27
# Segment Af8D0E4ZXaw[10]: Visual length = 20, Acoustic length = 20, Text length = 20
# Segment Af8D0E4ZXaw[11]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment Af8D0E4ZXaw[12]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment Af8D0E4ZXaw[13]: Visual length = 4, Acoustic length = 4, Text length = 4
# Segment Af8D0E4ZXaw[14]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment Af8D0E4ZXaw[15]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment Af8D0E4ZXaw[16]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment Af8D0E4ZXaw[17]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment Af8D0E4ZXaw[18]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment Af8D0E4ZXaw[19]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment Af8D0E4ZXaw[20]: Visual length = 46, Acoustic length = 46, Text length = 46
# Segment Af8D0E4ZXaw[21]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment Af8D0E4ZXaw[22]: Visual length = 20, Acoustic length = 20, Text length = 20
# Segment Af8D0E4ZXaw[23]: Visual length = 24, Acoustic length = 24, Text length = 24
# Segment Af8D0E4ZXaw[24]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment Af8D0E4ZXaw[25]: Visual length = 27, Acoustic length = 27, Text length = 27
# Segment Af8D0E4ZXaw[26]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment Af8D0E4ZXaw[27]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment Af8D0E4ZXaw[28]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment Af8D0E4ZXaw[29]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment Af8D0E4ZXaw[30]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment BI97DNYfe5I[0]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment BI97DNYfe5I[1]: Visual length = 23, Acoustic length = 23, Text length = 23
# Segment BI97DNYfe5I[2]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment BI97DNYfe5I[3]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment BI97DNYfe5I[4]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment BI97DNYfe5I[5]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment BI97DNYfe5I[6]: Visual length = 27, Acoustic length = 27, Text length = 27
# Segment BI97DNYfe5I[7]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment BI97DNYfe5I[8]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment BI97DNYfe5I[9]: Visual length = 24, Acoustic length = 24, Text length = 24
# Segment BI97DNYfe5I[10]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment BI97DNYfe5I[11]: Visual length = 18, Acoustic length = 18, Text length = 18
# Segment BI97DNYfe5I[12]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment BI97DNYfe5I[13]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment BI97DNYfe5I[14]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment BI97DNYfe5I[15]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment BI97DNYfe5I[16]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment BI97DNYfe5I[17]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment BI97DNYfe5I[18]: Visual length = 19, Acoustic length = 19, Text length = 19
# Segment BI97DNYfe5I[19]: Visual length = 1, Acoustic length = 1, Text length = 1
# Segment BI97DNYfe5I[20]: Visual length = 2, Acoustic length = 2, Text length = 2
# Segment BI97DNYfe5I[21]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment BI97DNYfe5I[22]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment BI97DNYfe5I[23]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment BI97DNYfe5I[24]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment BI97DNYfe5I[25]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment BI97DNYfe5I[26]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment BI97DNYfe5I[27]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment BI97DNYfe5I[28]: Visual length = 4, Acoustic length = 4, Text length = 4
# Segment BI97DNYfe5I[29]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment BI97DNYfe5I[30]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment BXuRRbG0Ugk[0]: Visual length = 42, Acoustic length = 42, Text length = 42
# Segment BXuRRbG0Ugk[1]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment BXuRRbG0Ugk[2]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment BXuRRbG0Ugk[3]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment BXuRRbG0Ugk[4]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment BXuRRbG0Ugk[5]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment BXuRRbG0Ugk[6]: Visual length = 20, Acoustic length = 20, Text length = 20
# Segment BXuRRbG0Ugk[7]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment BXuRRbG0Ugk[8]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment BXuRRbG0Ugk[9]: Visual length = 32, Acoustic length = 32, Text length = 32
# Segment BXuRRbG0Ugk[10]: Visual length = 16, Acoustic length = 16, Text length = 16
# Segment BXuRRbG0Ugk[11]: Visual length = 30, Acoustic length = 30, Text length = 30
# Segment BXuRRbG0Ugk[12]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment BXuRRbG0Ugk[13]: Visual length = 23, Acoustic length = 23, Text length = 23
# Segment BXuRRbG0Ugk[14]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment BXuRRbG0Ugk[15]: Visual length = 24, Acoustic length = 24, Text length = 24
# Segment BXuRRbG0Ugk[16]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment BXuRRbG0Ugk[17]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment BXuRRbG0Ugk[18]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment BXuRRbG0Ugk[19]: Visual length = 16, Acoustic length = 16, Text length = 16
# Segment BXuRRbG0Ugk[20]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment BXuRRbG0Ugk[21]: Visual length = 20, Acoustic length = 20, Text length = 20
# Segment BXuRRbG0Ugk[22]: Visual length = 24, Acoustic length = 24, Text length = 24
# Segment BXuRRbG0Ugk[23]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment BXuRRbG0Ugk[24]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment BXuRRbG0Ugk[25]: Visual length = 20, Acoustic length = 20, Text length = 20
# Segment BXuRRbG0Ugk[26]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment BXuRRbG0Ugk[27]: Visual length = 19, Acoustic length = 19, Text length = 19
# Segment BXuRRbG0Ugk[28]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment BXuRRbG0Ugk[29]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment BXuRRbG0Ugk[30]: Visual length = 20, Acoustic length = 20, Text length = 20
# Segment Bfr499ggo-0[0]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment Bfr499ggo-0[1]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment Bfr499ggo-0[2]: Visual length = 25, Acoustic length = 25, Text length = 25
# Segment Bfr499ggo-0[3]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment Bfr499ggo-0[4]: Visual length = 21, Acoustic length = 21, Text length = 21
# Segment Bfr499ggo-0[5]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment Bfr499ggo-0[6]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment Bfr499ggo-0[7]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment Bfr499ggo-0[8]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment Bfr499ggo-0[9]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment Bfr499ggo-0[10]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment Bfr499ggo-0[11]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment Bfr499ggo-0[12]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment Bfr499ggo-0[13]: Visual length = 18, Acoustic length = 18, Text length = 18
# Segment Bfr499ggo-0[14]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment Bfr499ggo-0[15]: Visual length = 19, Acoustic length = 19, Text length = 19
# Segment Bfr499ggo-0[16]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment Bfr499ggo-0[17]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment Bfr499ggo-0[18]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment Bfr499ggo-0[19]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment Bfr499ggo-0[20]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment Bfr499ggo-0[21]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment BioHAh1qJAQ[0]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment BioHAh1qJAQ[1]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment BioHAh1qJAQ[2]: Visual length = 26, Acoustic length = 26, Text length = 26
# Segment BioHAh1qJAQ[3]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment BioHAh1qJAQ[4]: Visual length = 19, Acoustic length = 19, Text length = 19
# Segment BioHAh1qJAQ[5]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment BioHAh1qJAQ[6]: Visual length = 21, Acoustic length = 21, Text length = 21
# Segment BioHAh1qJAQ[7]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment BioHAh1qJAQ[8]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment BioHAh1qJAQ[9]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment BioHAh1qJAQ[10]: Visual length = 14, Acoustic length = 14, Text length = 14
# ...
# Segment tStelxIAHjw[5]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment tStelxIAHjw[6]: Visual length = 4, Acoustic length = 4, Text length = 4
# Segment tStelxIAHjw[7]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment tStelxIAHjw[8]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment tStelxIAHjw[9]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment tStelxIAHjw[10]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment tStelxIAHjw[11]: Visual length = 4, Acoustic length = 4, Text length = 4
# Segment tStelxIAHjw[12]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment tStelxIAHjw[13]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment tStelxIAHjw[14]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment tStelxIAHjw[15]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment tmZoasNr4rU[0]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment tmZoasNr4rU[1]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment tmZoasNr4rU[2]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment tmZoasNr4rU[3]: Visual length = 23, Acoustic length = 23, Text length = 23
# Segment tmZoasNr4rU[4]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment tmZoasNr4rU[5]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment tmZoasNr4rU[6]: Visual length = 36, Acoustic length = 36, Text length = 36
# Segment tmZoasNr4rU[7]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment tmZoasNr4rU[8]: Visual length = 28, Acoustic length = 28, Text length = 28
# Segment tmZoasNr4rU[9]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment tmZoasNr4rU[10]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment tmZoasNr4rU[11]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment tmZoasNr4rU[12]: Visual length = 16, Acoustic length = 16, Text length = 16
# Segment tmZoasNr4rU[13]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment tmZoasNr4rU[14]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment tmZoasNr4rU[15]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment tmZoasNr4rU[16]: Visual length = 38, Acoustic length = 38, Text length = 38
# Segment tmZoasNr4rU[17]: Visual length = 3, Acoustic length = 3, Text length = 3
# Segment tmZoasNr4rU[18]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment tmZoasNr4rU[19]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment v0zCBqDeKcE[0]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment v0zCBqDeKcE[1]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment v0zCBqDeKcE[2]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment v0zCBqDeKcE[3]: Visual length = 16, Acoustic length = 16, Text length = 16
# Segment v0zCBqDeKcE[4]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment v0zCBqDeKcE[5]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment v0zCBqDeKcE[6]: Visual length = 20, Acoustic length = 20, Text length = 20
# Segment v0zCBqDeKcE[7]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment v0zCBqDeKcE[8]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment v0zCBqDeKcE[9]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment v0zCBqDeKcE[10]: Visual length = 35, Acoustic length = 35, Text length = 35
# Segment v0zCBqDeKcE[11]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment v0zCBqDeKcE[12]: Visual length = 19, Acoustic length = 19, Text length = 19
# Segment v0zCBqDeKcE[13]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment v0zCBqDeKcE[14]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment v0zCBqDeKcE[15]: Visual length = 4, Acoustic length = 4, Text length = 4
# Segment vvZ4IcEtiZc[0]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment vvZ4IcEtiZc[1]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment vvZ4IcEtiZc[2]: Visual length = 27, Acoustic length = 27, Text length = 27
# Segment vvZ4IcEtiZc[3]: Visual length = 26, Acoustic length = 26, Text length = 26
# Segment vvZ4IcEtiZc[4]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment vvZ4IcEtiZc[5]: Visual length = 21, Acoustic length = 21, Text length = 21
# Segment vvZ4IcEtiZc[6]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment vvZ4IcEtiZc[7]: Visual length = 16, Acoustic length = 16, Text length = 16
# Segment vvZ4IcEtiZc[8]: Visual length = 33, Acoustic length = 33, Text length = 33
# Segment vvZ4IcEtiZc[9]: Visual length = 18, Acoustic length = 18, Text length = 18
# Segment vvZ4IcEtiZc[10]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment vvZ4IcEtiZc[11]: Visual length = 35, Acoustic length = 35, Text length = 35
# Segment vyB00TXsimI[0]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment vyB00TXsimI[1]: Visual length = 28, Acoustic length = 28, Text length = 28
# Segment vyB00TXsimI[2]: Visual length = 26, Acoustic length = 26, Text length = 26
# Segment vyB00TXsimI[3]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment vyB00TXsimI[4]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment vyB00TXsimI[5]: Visual length = 26, Acoustic length = 26, Text length = 26
# Segment vyB00TXsimI[6]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment vyB00TXsimI[7]: Visual length = 22, Acoustic length = 22, Text length = 22
# Segment vyB00TXsimI[8]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment vyB00TXsimI[9]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment vyB00TXsimI[10]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment vyB00TXsimI[11]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment vyB00TXsimI[12]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment vyB00TXsimI[13]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment vyB00TXsimI[14]: Visual length = 19, Acoustic length = 19, Text length = 19
# Segment vyB00TXsimI[15]: Visual length = 31, Acoustic length = 31, Text length = 31
# Segment vyB00TXsimI[16]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment vyB00TXsimI[17]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment vyB00TXsimI[18]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment vyB00TXsimI[19]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment vyB00TXsimI[20]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment vyB00TXsimI[21]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment wMbj6ajWbic[0]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment wMbj6ajWbic[1]: Visual length = 24, Acoustic length = 24, Text length = 24
# Segment wMbj6ajWbic[2]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment wMbj6ajWbic[3]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment wMbj6ajWbic[4]: Visual length = 16, Acoustic length = 16, Text length = 16
# Segment wMbj6ajWbic[5]: Visual length = 27, Acoustic length = 27, Text length = 27
# Segment wMbj6ajWbic[6]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment wMbj6ajWbic[7]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment wMbj6ajWbic[8]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment wMbj6ajWbic[9]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment wMbj6ajWbic[10]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment wMbj6ajWbic[11]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment wMbj6ajWbic[12]: Visual length = 21, Acoustic length = 21, Text length = 21
# Segment wMbj6ajWbic[13]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment wMbj6ajWbic[14]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment wMbj6ajWbic[15]: Visual length = 24, Acoustic length = 24, Text length = 24
# Segment wMbj6ajWbic[16]: Visual length = 23, Acoustic length = 23, Text length = 23
# Segment wMbj6ajWbic[17]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment wMbj6ajWbic[18]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment wMbj6ajWbic[19]: Visual length = 16, Acoustic length = 16, Text length = 16
# Segment wMbj6ajWbic[20]: Visual length = 21, Acoustic length = 21, Text length = 21
# Segment wMbj6ajWbic[21]: Visual length = 18, Acoustic length = 18, Text length = 18
# Segment wMbj6ajWbic[22]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment wMbj6ajWbic[23]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment wMbj6ajWbic[24]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment wMbj6ajWbic[25]: Visual length = 10, Acoustic length = 10, Text length = 10
# Segment wMbj6ajWbic[26]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment wMbj6ajWbic[27]: Visual length = 20, Acoustic length = 20, Text length = 20
# Segment wMbj6ajWbic[28]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment wMbj6ajWbic[29]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment yDtzw_Y-7RU[0]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment yDtzw_Y-7RU[1]: Visual length = 26, Acoustic length = 26, Text length = 26
# Segment yDtzw_Y-7RU[2]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment yDtzw_Y-7RU[3]: Visual length = 21, Acoustic length = 21, Text length = 21
# Segment yDtzw_Y-7RU[4]: Visual length = 19, Acoustic length = 19, Text length = 19
# Segment yDtzw_Y-7RU[5]: Visual length = 48, Acoustic length = 48, Text length = 48
# Segment yDtzw_Y-7RU[6]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment yDtzw_Y-7RU[7]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment yDtzw_Y-7RU[8]: Visual length = 33, Acoustic length = 33, Text length = 33
# Segment yDtzw_Y-7RU[9]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment yDtzw_Y-7RU[10]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment yDtzw_Y-7RU[11]: Visual length = 16, Acoustic length = 16, Text length = 16
# Segment yDtzw_Y-7RU[12]: Visual length = 22, Acoustic length = 22, Text length = 22
# Segment yDtzw_Y-7RU[13]: Visual length = 23, Acoustic length = 23, Text length = 23
# Segment yDtzw_Y-7RU[14]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment yDtzw_Y-7RU[15]: Visual length = 17, Acoustic length = 17, Text length = 17
# Segment yDtzw_Y-7RU[16]: Visual length = 25, Acoustic length = 25, Text length = 25
# Segment yDtzw_Y-7RU[17]: Visual length = 23, Acoustic length = 23, Text length = 23
# Segment yDtzw_Y-7RU[18]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment yDtzw_Y-7RU[19]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment yDtzw_Y-7RU[20]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment yDtzw_Y-7RU[21]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment yDtzw_Y-7RU[22]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment yDtzw_Y-7RU[23]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment yvsjCA6Y5Fc[0]: Visual length = 26, Acoustic length = 26, Text length = 26
# Segment yvsjCA6Y5Fc[1]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment yvsjCA6Y5Fc[2]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment yvsjCA6Y5Fc[3]: Visual length = 20, Acoustic length = 20, Text length = 20
# Segment yvsjCA6Y5Fc[4]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment yvsjCA6Y5Fc[5]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment yvsjCA6Y5Fc[6]: Visual length = 8, Acoustic length = 8, Text length = 8
# Segment yvsjCA6Y5Fc[7]: Visual length = 23, Acoustic length = 23, Text length = 23
# Segment yvsjCA6Y5Fc[8]: Visual length = 18, Acoustic length = 18, Text length = 18
# Segment yvsjCA6Y5Fc[9]: Visual length = 23, Acoustic length = 23, Text length = 23
# Segment yvsjCA6Y5Fc[10]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment yvsjCA6Y5Fc[11]: Visual length = 40, Acoustic length = 40, Text length = 40
# Segment yvsjCA6Y5Fc[12]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment yvsjCA6Y5Fc[13]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment yvsjCA6Y5Fc[14]: Visual length = 14, Acoustic length = 14, Text length = 14
# Segment yvsjCA6Y5Fc[15]: Visual length = 50, Acoustic length = 50, Text length = 50
# Segment yvsjCA6Y5Fc[16]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment yvsjCA6Y5Fc[17]: Visual length = 29, Acoustic length = 29, Text length = 29
# Segment yvsjCA6Y5Fc[18]: Visual length = 36, Acoustic length = 36, Text length = 36
# Segment yvsjCA6Y5Fc[19]: Visual length = 4, Acoustic length = 4, Text length = 4
# Segment yvsjCA6Y5Fc[20]: Visual length = 23, Acoustic length = 23, Text length = 23
# Segment yvsjCA6Y5Fc[21]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment yvsjCA6Y5Fc[22]: Visual length = 63, Acoustic length = 63, Text length = 63
# Segment zhpQhgha_KU[0]: Visual length = 18, Acoustic length = 18, Text length = 18
# Segment zhpQhgha_KU[1]: Visual length = 16, Acoustic length = 16, Text length = 16
# Segment zhpQhgha_KU[2]: Visual length = 26, Acoustic length = 26, Text length = 26
# Segment zhpQhgha_KU[3]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment zhpQhgha_KU[4]: Visual length = 21, Acoustic length = 21, Text length = 21
# Segment zhpQhgha_KU[5]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment zhpQhgha_KU[6]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment zhpQhgha_KU[7]: Visual length = 19, Acoustic length = 19, Text length = 19
# Segment zhpQhgha_KU[8]: Visual length = 16, Acoustic length = 16, Text length = 16
# Segment zhpQhgha_KU[9]: Visual length = 38, Acoustic length = 38, Text length = 38
# Segment zhpQhgha_KU[10]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment zhpQhgha_KU[11]: Visual length = 20, Acoustic length = 20, Text length = 20
# Segment zhpQhgha_KU[12]: Visual length = 5, Acoustic length = 5, Text length = 5
# Segment zhpQhgha_KU[13]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment zhpQhgha_KU[14]: Visual length = 40, Acoustic length = 40, Text length = 40
# Segment zhpQhgha_KU[15]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment zhpQhgha_KU[16]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment zhpQhgha_KU[17]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment zhpQhgha_KU[18]: Visual length = 19, Acoustic length = 19, Text length = 19
# Segment zhpQhgha_KU[19]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment zhpQhgha_KU[20]: Visual length = 15, Acoustic length = 15, Text length = 15
# Segment zhpQhgha_KU[21]: Visual length = 9, Acoustic length = 9, Text length = 9
# Segment zhpQhgha_KU[22]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment zhpQhgha_KU[23]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment zhpQhgha_KU[24]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment zhpQhgha_KU[25]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment zhpQhgha_KU[26]: Visual length = 6, Acoustic length = 6, Text length = 6
# Segment zhpQhgha_KU[27]: Visual length = 11, Acoustic length = 11, Text length = 11
# Segment zhpQhgha_KU[28]: Visual length = 13, Acoustic length = 13, Text length = 13
# Segment zhpQhgha_KU[29]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment zhpQhgha_KU[30]: Visual length = 25, Acoustic length = 25, Text length = 25
# Segment zhpQhgha_KU[31]: Visual length = 21, Acoustic length = 21, Text length = 21
# Segment zhpQhgha_KU[32]: Visual length = 12, Acoustic length = 12, Text length = 12
# Segment zhpQhgha_KU[33]: Visual length = 7, Acoustic length = 7, Text length = 7
# Segment zhpQhgha_KU[34]: Visual length = 26, Acoustic length = 26, Text length = 26

# %%
# Extract unique video IDs
video_ids = set(seg.split("[")[0] for seg in dataset[visual_field_Facet41].keys())

# Count the number of unique video IDs
num_unique_ids = len(video_ids)

# Count segments for each video ID
video_segment_counts = {video_id: sum(seg.startswith(video_id) for seg in dataset[visual_field_Facet41].keys()) for video_id in video_ids}

# Print the total number of unique video IDs
print(f"Total number of unique video IDs: {num_unique_ids}\n")

# Print the segment counts for each video ID
for video_id, count in video_segment_counts.items():
    print(f"Video {video_id}: {count} segments")
# Out:
# Total number of unique video IDs: 93
#
# Video zhpQhgha_KU: 35 segments
# Video 8qrpnFRGt2A: 26 segments
# Video 1DmNV9C1hbY: 14 segments
# Video tStelxIAHjw: 16 segments
# Video 9qR7uwkblbs: 33 segments
# Video Sqr0AcuoNnk: 22 segments
# Video vyB00TXsimI: 22 segments
# Video 6Egk_28TtTM: 12 segments
# Video BXuRRbG0Ugk: 31 segments
# Video 9T9Hf74oK10: 25 segments
# Video BioHAh1qJAQ: 30 segments
# Video G6GlGvlkxAQ: 29 segments
# Video OQvJTdtJ2H4: 16 segments
# Video WKA5OygbEKI: 22 segments
# Video 0h-zjBukYpk: 25 segments
# Video bvLlb-M3UXU: 25 segments
# Video Vj1wYRQjB-o: 9 segments
# Video _dI--eQ6qVU: 28 segments
# Video cM3Yna7AavY: 16 segments
# Video rnaNMUZpvvg: 22 segments
# Video BvYR0L6f2Ig: 26 segments
# Video GWuJjcEuzt8: 18 segments
# Video c7UH_rxdZv4: 33 segments
# Video jUzDDGyPkXU: 27 segments
# Video cXypl4FnoZo: 29 segments
# Video 2WGyTLYerpo: 62 segments
# Video tmZoasNr4rU: 20 segments
# Video I5y0__X72p0: 39 segments
# Video wMbj6ajWbic: 30 segments
# Video ob23OKe5a9Q: 14 segments
# Video 5W7Z1C_fDaE: 24 segments
# Video etzxEpPuc6I: 19 segments
# Video Bfr499ggo-0: 22 segments
# Video nzpVDcQ0ywM: 24 segments
# Video PZ-lDQFboO8: 12 segments
# Video 9c67fiY0wGQ: 12 segments
# Video vvZ4IcEtiZc: 12 segments
# Video tIrG4oNLFzE: 18 segments
# Video dq3Nf_lMPnE: 15 segments
# Video yDtzw_Y-7RU: 24 segments
# Video ZAIRrfG22O0: 9 segments
# Video Iu2PFX3z_1s: 16 segments
# Video W8NXH0Djyww: 32 segments
# Video 2iD-tVS8NPw: 30 segments
# Video 8d-gEyoeBzc: 30 segments
# Video v0zCBqDeKcE: 16 segments
# Video lXPQBPVc5Cw: 30 segments
# Video VCslbP0mgZI: 17 segments
# Video f_pcplsH_V0: 15 segments
# Video c5xsKMxpXnc: 15 segments
# Video 73jzhE8R1TQ: 19 segments
# Video OtBXNcAL_lE: 24 segments
# Video cW1FSBF59ik: 24 segments
# Video fvVhgmXxadc: 14 segments
# Video iiK8YX8oH1E: 18 segments
# Video Af8D0E4ZXaw: 31 segments
# Video HEsqda8_d0Q: 34 segments
# Video k5Y_838nuGo: 31 segments
# Video 1iG0909rllw: 30 segments
# Video X3j2zQgwYgE: 11 segments
# Video aiEXnCPZubE: 30 segments
# Video ZUXBRvtny7o: 34 segments
# Video Jkswaaud0hk: 20 segments
# Video Nzq88NnDkEk: 32 segments
# Video nbWiPyCm4g0: 10 segments
# Video 6_0THN4chvY: 14 segments
# Video Clx4VXItLTE: 31 segments
# Video Njd1F0vZSm4: 13 segments
# Video 8OtFthrtaJM: 23 segments
# Video pLTX3ipuDJI: 16 segments
# Video bOL9jKpeJRs: 34 segments
# Video VbQk4H8hgr0: 55 segments
# Video QN9ZIUWUXsY: 18 segments
# Video Qr1Ca94K55A: 14 segments
# Video Ci-AH39fi3Y: 44 segments
# Video LSi-o-IrDMs: 29 segments
# Video BI97DNYfe5I: 31 segments
# Video IumbAb8q2dM: 22 segments
# Video Oz06ZWiO20M: 25 segments
# Video atnd_PF-Lbs: 21 segments
# Video d3_k5Xpfmik: 19 segments
# Video f9O3YtZ2VfI: 30 segments
# Video yvsjCA6Y5Fc: 23 segments
# Video 7JsX8y1ysxY: 39 segments
# Video TvyZBvOMOTc: 15 segments
# Video 03bSnISJMiM: 13 segments
# Video 9J25DZhivz8: 25 segments
# Video Dg_0XKD0Mf4: 18 segments
# Video d6hH302o4v8: 43 segments
# Video G-xst2euQUc: 21 segments
# Video phBUpBr1hSo: 21 segments
# Video POKffnXeBds: 13 segments
# Video MLal-t_vJPM: 18 segments

# %% [markdown]
# ## Splitting the dataset
#
# Now it comes to our final step: splitting the dataset into train/dev/test splits. This code block is a bit long in itself, so be patience and step through carefully with the explanatory comments.
#
# The SDK provides the splits in terms of video IDs (which video belong to which split), however, after alignment our dataset keys already changed from `video_id` to `video_id[segment_no]`. Hence, we need to extract the video ID when looping through the data to determine which split each data point belongs to.
#
# In the following data processing, I also include instance-wise Z-normalization (subtract by mean and divide by standard dev) and converted words to unique IDs.
#
# This example is based on PyTorch so I am using PyTorch related utils, but the same procedure should be easy to adapt to other frameworks.

# %%
# obtain the train/dev/test splits - these splits are based on video IDs
train_split = DATASET.standard_folds.standard_train_fold
dev_split = DATASET.standard_folds.standard_valid_fold
test_split = DATASET.standard_folds.standard_test_fold

# inspect the splits: they only contain video IDs
print(f"lengths: train {len(train_split)}, dev {len(dev_split)}, test {len(test_split)}\n")
print(train_split)
print(dev_split)
print(test_split)
# Out:
# lengths: train 52, dev 10, test 31
#
# ['2iD-tVS8NPw', '8d-gEyoeBzc', 'Qr1Ca94K55A', 'Ci-AH39fi3Y', '8qrpnFRGt2A', 'Bfr499ggo-0', 'QN9ZIUWUXsY', '9T9Hf74oK10', '7JsX8y1ysxY', '1iG0909rllw', 'Oz06ZWiO20M', 'BioHAh1qJAQ', '9c67fiY0wGQ', 'Iu2PFX3z_1s', 'Nzq88NnDkEk', 'Clx4VXItLTE', '9J25DZhivz8', 'Af8D0E4ZXaw', 'TvyZBvOMOTc', 'W8NXH0Djyww', '8OtFthrtaJM', '0h-zjBukYpk', 'Vj1wYRQjB-o', 'GWuJjcEuzt8', 'BI97DNYfe5I', 'PZ-lDQFboO8', '1DmNV9C1hbY', 'OQvJTdtJ2H4', 'I5y0__X72p0', '9qR7uwkblbs', 'G6GlGvlkxAQ', '6_0THN4chvY', 'Njd1F0vZSm4', 'BvYR0L6f2Ig', '03bSnISJMiM', 'Dg_0XKD0Mf4', '5W7Z1C_fDaE', 'VbQk4H8hgr0', 'G-xst2euQUc', 'MLal-t_vJPM', 'BXuRRbG0Ugk', 'LSi-o-IrDMs', 'Jkswaaud0hk', '2WGyTLYerpo', '6Egk_28TtTM', 'Sqr0AcuoNnk', 'POKffnXeBds', '73jzhE8R1TQ', 'OtBXNcAL_lE', 'HEsqda8_d0Q', 'VCslbP0mgZI', 'IumbAb8q2dM']
# ['WKA5OygbEKI', 'c5xsKMxpXnc', 'atnd_PF-Lbs', 'bvLlb-M3UXU', 'bOL9jKpeJRs', '_dI--eQ6qVU', 'ZAIRrfG22O0', 'X3j2zQgwYgE', 'aiEXnCPZubE', 'ZUXBRvtny7o']
# ['tmZoasNr4rU', 'zhpQhgha_KU', 'lXPQBPVc5Cw', 'iiK8YX8oH1E', 'tStelxIAHjw', 'nzpVDcQ0ywM', 'etzxEpPuc6I', 'cW1FSBF59ik', 'd6hH302o4v8', 'k5Y_838nuGo', 'pLTX3ipuDJI', 'jUzDDGyPkXU', 'f_pcplsH_V0', 'yvsjCA6Y5Fc', 'nbWiPyCm4g0', 'rnaNMUZpvvg', 'wMbj6ajWbic', 'cM3Yna7AavY', 'yDtzw_Y-7RU', 'vyB00TXsimI', 'dq3Nf_lMPnE', 'phBUpBr1hSo', 'd3_k5Xpfmik', 'v0zCBqDeKcE', 'tIrG4oNLFzE', 'fvVhgmXxadc', 'ob23OKe5a9Q', 'cXypl4FnoZo', 'vvZ4IcEtiZc', 'f9O3YtZ2VfI', 'c7UH_rxdZv4']

# %%
# we can see they are in the format of 'video_id[segment_no]', but the splits was specified with video_id only
# we need to use regex or something to match the video IDs...
import torch
import torch.nn as nn

from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm_notebook
from collections import defaultdict

# %%
import os
import matplotlib.pyplot as plt

def plot_hist(visual, acoustic, title="Segment"):
    # Create the folder if it doesn't exist
    folder_name = "Value distributions"
    os.makedirs(folder_name, exist_ok=True)
    
    # Plot the histograms
    plt.hist(visual.flatten(), bins=100, alpha=0.5, label='Visual')
    plt.hist(acoustic.flatten(), bins=100, alpha=0.5, label='Acoustic')
    plt.xlabel("Value")
    plt.ylabel("Frequency")
    plt.legend()
    plt.title(f"Value Distribution for {title}")
    plt.show()
    plt.close()  # Close the plot to free memory

    # 
    # # Save the figure to the specified folder with the given title
    # file_name = f"value_distribution_{title}.png"
    # file_path = os.path.join(folder_name, file_name)
    # plt.savefig(file_path)

# %%
# a sentinel epsilon for safe division, without it we will replace illegal values with a constant
EPS = 1e-8 # a small value to not end up in a situation in which we divide with 0

# construct a word2id mapping that automatically takes increment when new words are encountered
word2id = defaultdict(lambda: len(word2id))
UNK = word2id['<unk>']
PAD = word2id['<pad>']

# place holders for the final train/dev/test dataset
train = []
dev = []
test = []

# define a regular expression to extract the video ID out of the keys
pattern = re.compile('(.*)\[.*\]')
num_drop = 0 # a counter to count how many data points went into some processing issues


for segment in dataset[label_field].keys():
    
    # get the video ID and the features out of the aligned dataset
    vid = re.search(pattern, segment).group(1)
    label = dataset[label_field][segment]['features']
    _words = dataset[text_field_Words][segment]['features']
    _visual = dataset[visual_field_Facet41][segment]['features']
    _acoustic = dataset[acoustic_field_COVAREP][segment]['features']

    # if the sequences are not same length after alignment, there must be some problem with some modalities
    # we should drop it or inspect the data again
    # print(f"Just to chec: Encountered datapoint {vid} with text shape {_words.shape}, visual shape {_visual.shape}, acoustic shape {_acoustic.shape}")    
    if not _words.shape[0] == _visual.shape[0] == _acoustic.shape[0]:
        print(f"REAL DEALLLLLL  Encountered datapoint {vid} with text shape {_words.shape}, visual shape {_visual.shape}, acoustic shape {_acoustic.shape}")
        num_drop += 1
        continue
    
    # remove nan values
    label = np.nan_to_num(label)
    _visual = np.nan_to_num(_visual)
    _acoustic = np.nan_to_num(_acoustic)

    
    # plot_hist(_visual, _acoustic, segment)

    # print("remove speech pause moment")
    # remove speech pause tokens - this is in general helpful
    # we should remove speech pauses and corresponding visual/acoustic features together
    # otherwise modalities would no longer be aligned
    words = []
    visual = []
    acoustic = []
    # print(f"Processing segment {segment}: word[0] = {_words}")

    #SHALL I REMOVE THE UM WORDS????? pause fillers (umm, uhh, etc.),
    for i, word in enumerate(_words):
        # print(f"Processing segment {segment}: word[0] = {word[0]}")

        if word[0] != b'sp':
            words.append(word2id[word[0].decode('utf-8')]) # SDK stores strings as bytes, decode into strings here
            visual.append(_visual[i, :])
            acoustic.append(_acoustic[i, :])
        # print(f"Processing segment {segment}: word[0] = {word[0]}")

    words = np.asarray(words)
    visual = np.asarray(visual)
    acoustic = np.asarray(acoustic)
    
    # print(f"words: {words}, acoustic: {acoustic} ")

    # print(f"Visual range: min={np.min(visual)}, max={np.max(visual)}")
    # print(f"Acoustic range: min={np.min(acoustic)}, max={np.max(acoustic)}")
    

    # z-normalization per instance and remove nan/infs
    std_dev = np.std(visual, axis=0, keepdims=True)
    visual = np.nan_to_num((visual - visual.mean(0, keepdims=True)) / (EPS + std_dev))
    # Skip normalization for columns with zero std_dev
    visual[:, std_dev.flatten() == 0] = EPS
    
    # print(f"visual: {visual}")
    # visual = np.nan_to_num((visual - visual.mean(0, keepdims=True)) / (EPS + np.std(visual, axis=0, keepdims=True)))


    
    # z-normalization for acoustic
    
    acoustic_mean = np.nanmean(acoustic, axis=0, keepdims=True)
    std_dev_acoustic = np.nanstd(acoustic, axis=0, keepdims=True)
        
    
    std_dev_acoustic = np.nan_to_num(std_dev_acoustic)
    std_dev_acoustic[std_dev_acoustic == 0] = EPS
    # print(f"STD: {std_dev_acoustic}")
    
    acoustic = np.nan_to_num((acoustic - acoustic_mean) / (EPS + std_dev_acoustic))
    

    # Should i do normalization from 0 - 1 or -1 to 1?????

    
    # if np.any(std_dev_acoustic == 0):
    #     print("Error: std_dev_acoustic still contains zeros after safeguard.")
    if np.any(np.isnan(std_dev_acoustic)):
        print("Error: std_dev_acoustic contains NaNs.")
        
    if np.any(np.isnan(acoustic)):
        print("Error: NaN values in normalized acoustic data.")
    if np.any(np.isinf(acoustic)):
        print("Error: Infinite values in normalized acoustic data.")
        

    # plot_hist(visual, acoustic, segment)
    
    #why are the values not consistent???

    if vid in train_split:
        train.append(((words, visual, acoustic), label, segment))
    elif vid in dev_split:
        dev.append(((words, visual, acoustic), label, segment))
    elif vid in test_split:
        test.append(((words, visual, acoustic), label, segment))
    else:
        print(f"Found video that doesn't belong to any splits: {vid}")



print(f"Total number of {num_drop} datapoints have been dropped.")
# Out:
# Total number of 0 datapoints have been dropped.
# C:\Users\Viki\Documents\Thesis\tryout3\.venv\lib\site-packages\numpy\_core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\Viki\Documents\Thesis\tryout3\.venv\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1887: RuntimeWarning: overflow encountered in multiply
#   sqr = np.multiply(arr, arr, out=arr, where=where)

# %%
import random
sample = random.choice(train)

words = sample[0][0]  # Text data
visual = sample[0][1]  # Visual features
acoustic = sample[0][2]  # Acoustic features

print("Words:", words)
print("Visual shape:", visual.shape)
print("Acoustic shape:", acoustic.shape)
# Out:
# Words: [ 135   25  185  137    7  167  565  140  689  147  119  120    7 1533
#    38  119  120  492  565  211  147 1305]
# Visual shape: (22, 47)
# Acoustic shape: (22, 74)

# %%
# turn off the word2id - define a named function here to allow for pickling
def return_unk():
    return UNK
word2id.default_factory = return_unk

# %% [markdown]
# ## Inspect the dataset
#
# Now that we have loaded the data, we can check the sizes of each split, data point shapes, vocabulary size, etc.

# %% [markdown]
# ## Collate function in PyTorch
#
# Collate functions are functions used by PyTorch dataloader to gather batched data from dataset. It loads multiple data points from an iterable dataset object and put them in a certain format. Here we just use the lists we've constructed as the dataset and assume PyTorch dataloader will operate on that.

# %%
def multi_collate(batch):
    '''
    Collate functions assume batch = [Dataset[i] for i in index_set]
    '''
    # for later use we sort the batch in descending order of length
    batch = sorted(batch, key=lambda x: x[0][0].shape[0], reverse=True)
    
    # get the data out of the batch - use pad sequence util functions from PyTorch to pad things
    labels = torch.cat([torch.from_numpy(sample[1]) for sample in batch], dim=0)
    sentences = pad_sequence([torch.LongTensor(sample[0][0]) for sample in batch], padding_value=PAD)
    visual = pad_sequence([torch.FloatTensor(sample[0][1]) for sample in batch])
    acoustic = pad_sequence([torch.FloatTensor(sample[0][2]) for sample in batch])
    
    # lengths are useful later in using RNNs
    lengths = torch.LongTensor([sample[0][0].shape[0] for sample in batch])
    return sentences, visual, acoustic, labels, lengths

# construct dataloaders, dev and test could use around ~X3 times batch size since no_grad is used during eval
batch_sz = 56
train_loader = DataLoader(train, shuffle=True, batch_size=batch_sz, collate_fn=multi_collate)
dev_loader = DataLoader(dev, shuffle=False, batch_size=batch_sz*3, collate_fn=multi_collate)
test_loader = DataLoader(test, shuffle=False, batch_size=batch_sz*3, collate_fn=multi_collate)

# let's create a temporary dataloader just to see how the batch looks like
temp_loader = iter(DataLoader(test, shuffle=True, batch_size=8, collate_fn=multi_collate))
batch = next(temp_loader)

print(batch[0].shape) # word vectors, padded to maxlen
print(batch[1].shape) # visual features
print(batch[2].shape) # acoustic features
print(batch[3]) # labels
print(batch[4]) # lengths
# Out:
# torch.Size([20, 8])
# torch.Size([20, 8, 47])
# torch.Size([20, 8, 74])
# tensor([[ 2.0000],
#         [-2.4000],
#         [ 1.0000],
#         [ 1.2000],
#         [ 1.7500],
#         [-2.2000],
#         [ 2.2000],
#         [-1.0000]])
# tensor([20, 15, 12,  9,  9,  9,  7,  7])

# %%
# Let's actually inspect the transcripts to ensure it's correct
id2word = {v:k for k, v in word2id.items()}
examine_target = train
idx = np.random.randint(0, len(examine_target))
print(' '.join(list(map(lambda x: id2word[x], examine_target[idx][0][0].tolist()))))


# print(' '.join(examine_target[idx][0]))
print(examine_target[idx][1]) #label
print(examine_target[idx][2]) #segment
# Out:
# but i just wanted to put this up soon
# [[0.4]]
# HEsqda8_d0Q[32]

# %%
# Reverse mapping from word IDs to words
id2word = {v: k for k, v in word2id.items()}


# Specify how many examples to examine
num_examples = len(train)  # Ensure we don't exceed the dataset size


max_length = 0
min_length = float('inf')

for idx in range(num_examples):
    # Convert word IDs to words
    words = ' '.join(map(lambda x: id2word[x], train[idx][0][0].tolist()))
    label = train[idx][1]  # Label
    segment = train[idx][2]  # Segment

    length = len(words.split())  # Word count, not character count

    # Track the max and min lengths
    max_length = max(max_length, length)
    min_length = min(min_length, length)

    # Display the information
    print(f"Example {idx+1}:")
    print(f"Text: {words}")
    print(f"Length: {length}")
    print(f"Label: {label}")
    print(f"Segment: {segment}")
    print("-" * 40)  # Separator for readability
    if length==1:
        example = idx+1

# After the loop, print the max and min lengths
print(f"Maximum length: {max_length}")
print(f"Minimum length: {min_length}")
print(f"Example with length 1: {example}")
# Out:
# Example 1:
# Text: anyhow it was really good
# Length: 5
# Label: [[2.4]]
# Segment: 03bSnISJMiM[0]
# ----------------------------------------
# Example 2:
# Text: they didnt really do a whole bunch of background info on why she has to fight and be prepared
# Length: 19
# Label: [[-0.8]]
# Segment: 03bSnISJMiM[1]
# ----------------------------------------
# Example 3:
# Text: i mean they did a little bit of it
# Length: 9
# Label: [[-1.]]
# Segment: 03bSnISJMiM[2]
# ----------------------------------------
# Example 4:
# Text: but not a whole bunch
# Length: 5
# Label: [[-1.75]]
# Segment: 03bSnISJMiM[3]
# ----------------------------------------
# Example 5:
# Text: and they i guess
# Length: 4
# Label: [[0.]]
# Segment: 03bSnISJMiM[4]
# ----------------------------------------
# Example 6:
# Text: they live up with more
# Length: 5
# Label: [[0.]]
# Segment: 03bSnISJMiM[5]
# ----------------------------------------
# Example 7:
# Text: and but besides that it was all over pretty good
# Length: 10
# Label: [[0.8]]
# Segment: 03bSnISJMiM[6]
# ----------------------------------------
# Example 8:
# Text: and there is like someone while someone there was a lot of action
# Length: 13
# Label: [[0.]]
# Segment: 03bSnISJMiM[7]
# ----------------------------------------
# Example 9:
# Text: oh my god a lot of action
# Length: 7
# Label: [[0.2]]
# Segment: 03bSnISJMiM[8]
# ----------------------------------------
# Example 10:
# Text: there is sad part
# Length: 4
# Label: [[-1.2]]
# Segment: 03bSnISJMiM[9]
# ----------------------------------------
# Example 11:
# Text: a lot of sad parts
# Length: 5
# Label: [[-0.5]]
# Segment: 03bSnISJMiM[10]
# ----------------------------------------
# Example 12:
# Text: but it was really really awesome
# Length: 6
# Label: [[2.2]]
# Segment: 03bSnISJMiM[11]
# ----------------------------------------
# Example 13:
# Text: and its a really funny
# Length: 5
# Label: [[1.8]]
# Segment: 03bSnISJMiM[12]
# ----------------------------------------
# Example 14:
# Text: now the title of the movie basically says it all
# Length: 10
# Label: [[-0.4]]
# Segment: 0h-zjBukYpk[0]
# ----------------------------------------
# Example 15:
# Text: now im not even gonna sugar coat this this movie frustrated me to such an extreme extent that i was loudly exclaiming why at the end of the film
# Length: 29
# Label: [[-2.8]]
# Segment: 0h-zjBukYpk[1]
# ----------------------------------------
# Example 16:
# Text: my reason im a comic book fan
# Length: 7
# Label: [[-0.2]]
# Segment: 0h-zjBukYpk[2]
# ----------------------------------------
# Example 17:
# Text: that like to see comic book characters treated responsibly
# Length: 9
# Label: [[-1.4]]
# Segment: 0h-zjBukYpk[3]
# ----------------------------------------
# Example 18:
# Text: that huh before we go on with that i must say that this had a surprisingly decent cast
# Length: 18
# Label: [[0.8]]
# Segment: 0h-zjBukYpk[4]
# ----------------------------------------
# Example 19:
# Text: strange since one of my biggest grapes with the series was and always is the now
# Length: 16
# Label: [[-1.4]]
# Segment: 0h-zjBukYpk[5]
# ----------------------------------------
# Example 20:
# Text: now hugh jackman was always the best choice to play wolverine i will admit that
# Length: 15
# Label: [[1.8]]
# Segment: 0h-zjBukYpk[6]
# ----------------------------------------
# Example 21:
# Text: and in my opinion he carried the movie fine
# Length: 9
# Label: [[0.8]]
# Segment: 0h-zjBukYpk[7]
# ----------------------------------------
# Example 22:
# Text: you know nothing great
# Length: 4
# Label: [[-1.]]
# Segment: 0h-zjBukYpk[8]
# ----------------------------------------
# Example 23:
# Text: but you know he did it
# Length: 6
# Label: [[-0.6]]
# Segment: 0h-zjBukYpk[9]
# ----------------------------------------
# Example 24:
# Text: hes a star of the movie
# Length: 6
# Label: [[0.4]]
# Segment: 0h-zjBukYpk[10]
# ----------------------------------------
# Example 25:
# Text: nothing special
# Length: 2
# Label: [[-0.8]]
# Segment: 0h-zjBukYpk[11]
# ----------------------------------------
# Example 26:
# Text: he carried it
# Length: 3
# Label: [[1.25]]
# Segment: 0h-zjBukYpk[12]
# ----------------------------------------
# Example 27:
# Text: which is a smart move since you know you have to be real comic book fan to get what hes name is supposed to be
# Length: 25
# Label: [[1.4]]
# Segment: 0h-zjBukYpk[13]
# ----------------------------------------
# Example 28:
# Text: but its pretty but
# Length: 4
# Label: [[0.]]
# Segment: 0h-zjBukYpk[14]
# ----------------------------------------
# Example 29:
# Text: um i actually think that schreiber is a good actor
# Length: 10
# Label: [[0.6]]
# Segment: 0h-zjBukYpk[15]
# ----------------------------------------
# Example 30:
# Text: and he almost looks exactly the same as this character in defiance
# Length: 12
# Label: [[0.2]]
# Segment: 0h-zjBukYpk[16]
# ----------------------------------------
# Example 31:
# Text: i mean it was like he was too lazy to take off the costume or something
# Length: 16
# Label: [[-2.]]
# Segment: 0h-zjBukYpk[17]
# ----------------------------------------
# Example 32:
# Text: now other performances are borderline
# Length: 5
# Label: [[-0.4]]
# Segment: 0h-zjBukYpk[18]
# ----------------------------------------
# Example 33:
# Text: ok but the two big character appearances in this movie are easily and gambit
# Length: 14
# Label: [[0.6]]
# Segment: 0h-zjBukYpk[19]
# ----------------------------------------
# Example 34:
# Text: actually i liked him a lot
# Length: 6
# Label: [[2.]]
# Segment: 0h-zjBukYpk[20]
# ----------------------------------------
# Example 35:
# Text: and i thought he made a good actor for the dead poor character
# Length: 13
# Label: [[1.8]]
# Segment: 0h-zjBukYpk[21]
# ----------------------------------------
# Example 36:
# Text: now hes seen at the beginning that really sold me
# Length: 10
# Label: [[2.6]]
# Segment: 0h-zjBukYpk[22]
# ----------------------------------------
# Example 37:
# Text: i mean that was impressive
# Length: 5
# Label: [[2.6]]
# Segment: 0h-zjBukYpk[23]
# ----------------------------------------
# Example 38:
# Text: i liked that scene where he had a swords in there and theres bunch of people that are gonna shoot him boom boom boom boom take him down take him down bam bam bam bam bam take that with my magical swords
# Length: 42
# Label: [[2.2]]
# Segment: 0h-zjBukYpk[24]
# ----------------------------------------
# Example 39:
# Text: but for this one i just didnt feel like it
# Length: 10
# Label: [[-2.]]
# Segment: 1DmNV9C1hbY[0]
# ----------------------------------------
# Example 40:
# Text: um i loved the very first alvin and the movie
# Length: 10
# Label: [[1.6]]
# Segment: 1DmNV9C1hbY[1]
# ----------------------------------------
# Example 41:
# Text: because it had a real nostalgic feel to it
# Length: 9
# Label: [[1.]]
# Segment: 1DmNV9C1hbY[2]
# ----------------------------------------
# Example 42:
# Text: it reminded me of getting up on a saturday morning and eating fruit loops and um watching cartoons
# Length: 18
# Label: [[2.]]
# Segment: 1DmNV9C1hbY[3]
# ----------------------------------------
# Example 43:
# Text: but you know for this one i just didnt care
# Length: 10
# Label: [[-1.8]]
# Segment: 1DmNV9C1hbY[4]
# ----------------------------------------
# Example 44:
# Text: um i saw no reason why they needed to bring back the villain from the first one
# Length: 17
# Label: [[-1.6]]
# Segment: 1DmNV9C1hbY[5]
# ----------------------------------------
# Example 45:
# Text: and um while the trailer made the film look real nice and cute
# Length: 13
# Label: [[-1.6]]
# Segment: 1DmNV9C1hbY[6]
# ----------------------------------------
# Example 46:
# Text: it was just flat
# Length: 4
# Label: [[-1.8]]
# Segment: 1DmNV9C1hbY[7]
# ----------------------------------------
# Example 47:
# Text: um im sure kids are gonna love it
# Length: 8
# Label: [[2.2]]
# Segment: 1DmNV9C1hbY[8]
# ----------------------------------------
# Example 48:
# Text: kids are gonna love the film
# Length: 6
# Label: [[2.6]]
# Segment: 1DmNV9C1hbY[9]
# ----------------------------------------
# Example 49:
# Text: but for me i was just a little bored
# Length: 9
# Label: [[-1.8]]
# Segment: 1DmNV9C1hbY[10]
# ----------------------------------------
# Example 50:
# Text: sure there were cute money parts in the of the film
# Length: 11
# Label: [[0.4]]
# Segment: 1DmNV9C1hbY[11]
# ----------------------------------------
# Example 51:
# Text: but otherwise i dont know
# Length: 5
# Label: [[-1.25]]
# Segment: 1DmNV9C1hbY[12]
# ----------------------------------------
# Example 52:
# Text: i didnt even care for it
# Length: 6
# Label: [[-2.]]
# Segment: 1DmNV9C1hbY[13]
# ----------------------------------------
# Example 53:
# Text: and i thought they were average
# Length: 6
# Label: [[-0.4]]
# Segment: 1iG0909rllw[0]
# ----------------------------------------
# Example 54:
# Text: lets face it they are really not master pieces
# Length: 9
# Label: [[-1.75]]
# Segment: 1iG0909rllw[1]
# ----------------------------------------
# Example 55:
# Text: i thought twilight directed by catherine hardwicke was actually really rather enjoyable
# Length: 12
# Label: [[2.]]
# Segment: 1iG0909rllw[2]
# ----------------------------------------
# Example 56:
# Text: um i mean obviously it had its flaws
# Length: 8
# Label: [[-1.2]]
# Segment: 1iG0909rllw[3]
# ----------------------------------------
# Example 57:
# Text: but i thought it was good quite good
# Length: 8
# Label: [[2.2]]
# Segment: 1iG0909rllw[4]
# ----------------------------------------
# Example 58:
# Text: it was enjoyable
# Length: 3
# Label: [[1.6]]
# Segment: 1iG0909rllw[5]
# ----------------------------------------
# Example 59:
# Text: i thinking on hearing that chris weitz was gonna start the new moon because of the destruction that was phillip pullman the golden thought
# Length: 24
# Label: [[-0.6]]
# Segment: 1iG0909rllw[6]
# ----------------------------------------
# Example 60:
# Text: that film was awful
# Length: 4
# Label: [[-2.4]]
# Segment: 1iG0909rllw[7]
# ----------------------------------------
# Example 61:
# Text: and i i really know what to expect from new moon um in terms of his direction
# Length: 17
# Label: [[-0.2]]
# Segment: 1iG0909rllw[8]
# ----------------------------------------
# Example 62:
# Text: overall new moon was it was ok just average
# Length: 9
# Label: [[0.6]]
# Segment: 1iG0909rllw[9]
# ----------------------------------------
# Example 63:
# Text: the thing is its a very good translation of the book
# Length: 11
# Label: [[2.2]]
# Segment: 1iG0909rllw[10]
# ----------------------------------------
# Example 64:
# Text: its very very loyal to the book
# Length: 7
# Label: [[1.6]]
# Segment: 1iG0909rllw[11]
# ----------------------------------------
# Example 65:
# Text: and i really appreciate that loyalty
# Length: 6
# Label: [[1.4]]
# Segment: 1iG0909rllw[12]
# ----------------------------------------
# Example 66:
# Text: um however it is this loyalty to the original source that gives it its flaws
# Length: 15
# Label: [[-0.2]]
# Segment: 1iG0909rllw[13]
# ----------------------------------------
# Example 67:
# Text: book is not necessarily the most thrilling book ever
# Length: 9
# Label: [[-1.4]]
# Segment: 1iG0909rllw[14]
# ----------------------------------------
# Example 68:
# Text: i mean the entire is bella swan kristen stewards character around completely depressed
# Length: 13
# Label: [[-1.4]]
# Segment: 1iG0909rllw[15]
# ----------------------------------------
# Example 69:
# Text: it really the best the most thrilling read ever ill say that
# Length: 12
# Label: [[-1.4]]
# Segment: 1iG0909rllw[16]
# ----------------------------------------
# Example 70:
# Text: so moon even with the bigger better budgets huh it was still too long
# Length: 14
# Label: [[-1.8]]
# Segment: 1iG0909rllw[17]
# ----------------------------------------
# Example 71:
# Text: the too moments withdrawn out to the max as far as can go
# Length: 13
# Label: [[-1.]]
# Segment: 1iG0909rllw[18]
# ----------------------------------------
# Example 72:
# Text: and the script it left all the key plots and emotion from the characters to be exposed through dialogue
# Length: 19
# Label: [[0.4]]
# Segment: 1iG0909rllw[19]
# ----------------------------------------
# Example 73:
# Text: i think it was empire magazines review of new moon that said that kristen relied heavily on the tactic of tactic of blinking a lot which she really does do a lot
# Length: 32
# Label: [[-0.4]]
# Segment: 1iG0909rllw[20]
# ----------------------------------------
# Example 74:
# Text: but at the same goes for rob pattinson as edward and taylor lautner as jacob they do a lot of frowning im a manly man and i frown
# Length: 28
# Label: [[-0.2]]
# Segment: 1iG0909rllw[21]
# ----------------------------------------
# Example 75:
# Text: for the moment in this the whole cinema was and
# Length: 10
# Label: [[1.8]]
# Segment: 1iG0909rllw[22]
# ----------------------------------------
# Example 76:
# Text: and you knew you be laughing
# Length: 6
# Label: [[-1.]]
# Segment: 1iG0909rllw[23]
# ----------------------------------------
# Example 77:
# Text: my favorite scene would be the um
# Length: 7
# Label: [[2.]]
# Segment: 1iG0909rllw[24]
# ----------------------------------------
# Example 78:
# Text: um then my wins on screen i mean they were really worn in a lots which is a shame because i thought really rather good
# Length: 25
# Label: [[-0.6]]
# Segment: 1iG0909rllw[25]
# ----------------------------------------
# Example 79:
# Text: and um michael sheen as aro as well he was rather enjoyable to watch
# Length: 14
# Label: [[1.8]]
# Segment: 1iG0909rllw[26]
# ----------------------------------------
# Example 80:
# Text: and i think the that was my exciting bit of the entire film
# Length: 13
# Label: [[1.2]]
# Segment: 1iG0909rllw[27]
# ----------------------------------------
# Example 81:
# Text: the rest of the film was just watching kristen just mob around
# Length: 12
# Label: [[-1.4]]
# Segment: 1iG0909rllw[28]
# ----------------------------------------
# Example 82:
# Text: and that was really boring
# Length: 5
# Label: [[-1.6]]
# Segment: 1iG0909rllw[29]
# ----------------------------------------
# Example 83:
# Text: much say that i really enjoyed cowboys and aliens
# Length: 9
# Label: [[2.]]
# Segment: 2WGyTLYerpo[0]
# ----------------------------------------
# Example 84:
# Text: there was a lot of fun
# Length: 6
# Label: [[0.4]]
# Segment: 2WGyTLYerpo[1]
# ----------------------------------------
# Example 85:
# Text: you guys dont know what youre gonna go and see when you go walk into the movie called cowboys and aliens
# Length: 21
# Label: [[0.]]
# Segment: 2WGyTLYerpo[2]
# ----------------------------------------
# Example 86:
# Text: if youre expecting some artsy serious oscar contender than youre wrong
# Length: 11
# Label: [[-0.4]]
# Segment: 2WGyTLYerpo[3]
# ----------------------------------------
# Example 87:
# Text: the only oscar that i can even thing of is maybe like best cinematography
# Length: 14
# Label: [[0.]]
# Segment: 2WGyTLYerpo[4]
# ----------------------------------------
# Example 88:
# Text: because the cinematography in this movie is great
# Length: 8
# Label: [[2.4]]
# Segment: 2WGyTLYerpo[5]
# ----------------------------------------
# Example 89:
# Text: and maybe best visual effects
# Length: 5
# Label: [[1.6]]
# Segment: 2WGyTLYerpo[6]
# ----------------------------------------
# Example 90:
# Text: coz the visual effects are pretty cool
# Length: 7
# Label: [[1.8]]
# Segment: 2WGyTLYerpo[7]
# ----------------------------------------
# Example 91:
# Text: but again you you cant expect a huge like surreal mind bender from the movie called cowboys and aliens yo
# Length: 20
# Label: [[-0.4]]
# Segment: 2WGyTLYerpo[8]
# ----------------------------------------
# Example 92:
# Text: and its satisfactory
# Length: 3
# Label: [[0.8]]
# Segment: 2WGyTLYerpo[9]
# ----------------------------------------
# Example 93:
# Text: the action is really intense which surprised me
# Length: 8
# Label: [[2.2]]
# Segment: 2WGyTLYerpo[10]
# ----------------------------------------
# Example 94:
# Text: i didnt expect the action to be so intense
# Length: 9
# Label: [[1.2]]
# Segment: 2WGyTLYerpo[11]
# ----------------------------------------
# Example 95:
# Text: theres some really intense action scenes especially the scene when the aliens first invade
# Length: 14
# Label: [[2.]]
# Segment: 2WGyTLYerpo[12]
# ----------------------------------------
# Example 96:
# Text: that scene is like crazy
# Length: 5
# Label: [[0.2]]
# Segment: 2WGyTLYerpo[13]
# ----------------------------------------
# Example 97:
# Text: it gave me chills
# Length: 4
# Label: [[0.5]]
# Segment: 2WGyTLYerpo[14]
# ----------------------------------------
# Example 98:
# Text: i its a lot of fun
# Length: 6
# Label: [[2.]]
# Segment: 2WGyTLYerpo[15]
# ----------------------------------------
# Example 99:
# Text: the action is really cool
# Length: 5
# Label: [[2.6]]
# Segment: 2WGyTLYerpo[16]
# ----------------------------------------
# Example 100:
# Text: the aliens are really cool
# Length: 5
# Label: [[2.2]]
# Segment: 2WGyTLYerpo[17]
# ----------------------------------------
# Example 101:
# Text: one thing i like with the aliens is that a they are not just weak links that hide behind the technology
# Length: 21
# Label: [[1.4]]
# Segment: 2WGyTLYerpo[18]
# ----------------------------------------
# Example 102:
# Text: they are huge
# Length: 3
# Label: [[1.]]
# Segment: 2WGyTLYerpo[19]
# ----------------------------------------
# Example 103:
# Text: theyre really strong
# Length: 3
# Label: [[0.8]]
# Segment: 2WGyTLYerpo[20]
# ----------------------------------------
# Example 104:
# Text: and theyre kind of scary looking
# Length: 6
# Label: [[-0.8]]
# Segment: 2WGyTLYerpo[21]
# ----------------------------------------
# Example 105:
# Text: i didnt expect that
# Length: 4
# Label: [[0.]]
# Segment: 2WGyTLYerpo[22]
# ----------------------------------------
# Example 106:
# Text: and also i like how its kind of upfront to show them to us instead of hiding them like showing a little like an arm on scene or something no they just straight up show it to us
# Length: 38
# Label: [[1.6]]
# Segment: 2WGyTLYerpo[23]
# ----------------------------------------
# Example 107:
# Text: and i really enjoyed that
# Length: 5
# Label: [[1.8]]
# Segment: 2WGyTLYerpo[24]
# ----------------------------------------
# Example 108:
# Text: i it was really cool when they did that
# Length: 9
# Label: [[1.8]]
# Segment: 2WGyTLYerpo[25]
# ----------------------------------------
# Example 109:
# Text: coz the aliens were really cool looking
# Length: 7
# Label: [[1.8]]
# Segment: 2WGyTLYerpo[26]
# ----------------------------------------
# Example 110:
# Text: daniel craig does a very good job here
# Length: 8
# Label: [[2.4]]
# Segment: 2WGyTLYerpo[27]
# ----------------------------------------
# Example 111:
# Text: he kind of channels the man with no name clint eastwood
# Length: 11
# Label: [[0.6]]
# Segment: 2WGyTLYerpo[28]
# ----------------------------------------
# Example 112:
# Text: and a lot of people have been saying that
# Length: 9
# Label: [[-0.2]]
# Segment: 2WGyTLYerpo[29]
# ----------------------------------------
# Example 113:
# Text: i think he does a great job at what he does
# Length: 11
# Label: [[2.]]
# Segment: 2WGyTLYerpo[30]
# ----------------------------------------
# Example 114:
# Text: hes a really bad ass
# Length: 5
# Label: [[2.2]]
# Segment: 2WGyTLYerpo[31]
# ----------------------------------------
# Example 115:
# Text: is really really hard core
# Length: 5
# Label: [[1.2]]
# Segment: 2WGyTLYerpo[32]
# ----------------------------------------
# Example 116:
# Text: he doesnt take crap from anybody
# Length: 6
# Label: [[0.6]]
# Segment: 2WGyTLYerpo[33]
# ----------------------------------------
# Example 117:
# Text: and he does a really good job
# Length: 7
# Label: [[2.2]]
# Segment: 2WGyTLYerpo[34]
# ----------------------------------------
# Example 118:
# Text: also his innocent accent is pretty convincing
# Length: 7
# Label: [[1.2]]
# Segment: 2WGyTLYerpo[35]
# ----------------------------------------
# Example 119:
# Text: harrison ford is also good
# Length: 5
# Label: [[1.4]]
# Segment: 2WGyTLYerpo[36]
# ----------------------------------------
# Example 120:
# Text: hes he gives an entertaining performance as the kind of like the leader the of the town
# Length: 17
# Label: [[1.]]
# Segment: 2WGyTLYerpo[37]
# ----------------------------------------
# Example 121:
# Text: at first hes just kind of like grumpy old guy
# Length: 10
# Label: [[-0.6]]
# Segment: 2WGyTLYerpo[38]
# ----------------------------------------
# Example 122:
# Text: but he becomes more likeable
# Length: 5
# Label: [[0.6]]
# Segment: 2WGyTLYerpo[39]
# ----------------------------------------
# Example 123:
# Text: his guts developed more as more likeable character
# Length: 8
# Label: [[0.6]]
# Segment: 2WGyTLYerpo[40]
# ----------------------------------------
# Example 124:
# Text: so you can care about him
# Length: 6
# Label: [[0.]]
# Segment: 2WGyTLYerpo[41]
# ----------------------------------------
# Example 125:
# Text: and olivia wild pretty good
# Length: 5
# Label: [[2.]]
# Segment: 2WGyTLYerpo[42]
# ----------------------------------------
# Example 126:
# Text: and not a bad actor
# Length: 5
# Label: [[0.2]]
# Segment: 2WGyTLYerpo[44]
# ----------------------------------------
# Example 127:
# Text: actually pretty good
# Length: 3
# Label: [[1.4]]
# Segment: 2WGyTLYerpo[45]
# ----------------------------------------
# Example 128:
# Text: everything nowadays
# Length: 2
# Label: [[0.]]
# Segment: 2WGyTLYerpo[46]
# ----------------------------------------
# Example 129:
# Text: there are some flaws here
# Length: 5
# Label: [[-1.]]
# Segment: 2WGyTLYerpo[47]
# ----------------------------------------
# Example 130:
# Text: and there but theyre not huge glaring flaws
# Length: 8
# Label: [[-0.6]]
# Segment: 2WGyTLYerpo[48]
# ----------------------------------------
# Example 131:
# Text: but they are flaws
# Length: 4
# Label: [[-1.8]]
# Segment: 2WGyTLYerpo[49]
# ----------------------------------------
# Example 132:
# Text: such as sometimes the aliens in the western setting do look a little goofy
# Length: 14
# Label: [[-0.6]]
# Segment: 2WGyTLYerpo[50]
# ----------------------------------------
# Example 133:
# Text: but i was kind of expecting that
# Length: 7
# Label: [[0.]]
# Segment: 2WGyTLYerpo[51]
# ----------------------------------------
# Example 134:
# Text: i a huge fan of it
# Length: 6
# Label: [[-1.]]
# Segment: 2WGyTLYerpo[52]
# ----------------------------------------
# Example 135:
# Text: i just thought it was kind of stupid
# Length: 8
# Label: [[-2.]]
# Segment: 2WGyTLYerpo[53]
# ----------------------------------------
# Example 136:
# Text: and sometimes it kind of veers into cliche action movie territory
# Length: 11
# Label: [[-1.]]
# Segment: 2WGyTLYerpo[54]
# ----------------------------------------
# Example 137:
# Text: like a movie called cowboys and aliens a lot of people would think would be kind of like crazy
# Length: 19
# Label: [[-0.4]]
# Segment: 2WGyTLYerpo[55]
# ----------------------------------------
# Example 138:
# Text: but sometimes it just veers entirely cliche action movie territory again
# Length: 11
# Label: [[-1.6]]
# Segment: 2WGyTLYerpo[56]
# ----------------------------------------
# Example 139:
# Text: not a huge flaw but its there and its overall
# Length: 10
# Label: [[-1.4]]
# Segment: 2WGyTLYerpo[57]
# ----------------------------------------
# Example 140:
# Text: overall i really enjoyed cowboys and aliens
# Length: 7
# Label: [[2.]]
# Segment: 2WGyTLYerpo[58]
# ----------------------------------------
# Example 141:
# Text: and im gonna give it an eight out of ten
# Length: 10
# Label: [[2.2]]
# Segment: 2WGyTLYerpo[59]
# ----------------------------------------
# Example 142:
# Text: it was really fun
# Length: 4
# Label: [[1.4]]
# Segment: 2WGyTLYerpo[60]
# ----------------------------------------
# Example 143:
# Text: a very good time
# Length: 4
# Label: [[2.2]]
# Segment: 2WGyTLYerpo[61]
# ----------------------------------------
# Example 144:
# Text: and i recommend you check it out in theaters
# Length: 9
# Label: [[2.2]]
# Segment: 2WGyTLYerpo[62]
# ----------------------------------------
# Example 145:
# Text: before i went in to see the green lantern ive been hearing all these like critics basically just trashing this movie left and right
# Length: 24
# Label: [[-0.5]]
# Segment: 2iD-tVS8NPw[0]
# ----------------------------------------
# Example 146:
# Text: but i at the same time i do wanna just say that i enjoyed this movie
# Length: 16
# Label: [[2.2]]
# Segment: 2iD-tVS8NPw[1]
# ----------------------------------------
# Example 147:
# Text: i enjoyed it for what it was you know
# Length: 9
# Label: [[1.4]]
# Segment: 2iD-tVS8NPw[2]
# ----------------------------------------
# Example 148:
# Text: its a huge sort of spectacle movie that is great for this summer time you know
# Length: 16
# Label: [[2.2]]
# Segment: 2iD-tVS8NPw[3]
# ----------------------------------------
# Example 149:
# Text: this is a movie that youre gonna go out and see
# Length: 11
# Label: [[2.]]
# Segment: 2iD-tVS8NPw[4]
# ----------------------------------------
# Example 150:
# Text: and you wanna see it in because
# Length: 7
# Label: [[2.]]
# Segment: 2iD-tVS8NPw[5]
# ----------------------------------------
# Example 151:
# Text: because i i would actually say this probably is one of the first movies this year that ive seen this year that you wanna see in especially for just the opening portion
# Length: 32
# Label: [[2.4]]
# Segment: 2iD-tVS8NPw[6]
# ----------------------------------------
# Example 152:
# Text: it looks really good
# Length: 4
# Label: [[1.8]]
# Segment: 2iD-tVS8NPw[7]
# ----------------------------------------
# Example 153:
# Text: and the rest of it does look good as well
# Length: 10
# Label: [[1.4]]
# Segment: 2iD-tVS8NPw[8]
# ----------------------------------------
# Example 154:
# Text: and i just had fun watching this movie
# Length: 8
# Label: [[2.2]]
# Segment: 2iD-tVS8NPw[9]
# ----------------------------------------
# Example 155:
# Text: its not like a dark movie or anything
# Length: 8
# Label: [[0.2]]
# Segment: 2iD-tVS8NPw[10]
# ----------------------------------------
# Example 156:
# Text: its very much a light hearted
# Length: 6
# Label: [[1.2]]
# Segment: 2iD-tVS8NPw[11]
# ----------------------------------------
# Example 157:
# Text: so its perfect for kids as well as just like teenagers as well who just wanna see a lot of explosions and some crazy stuff
# Length: 25
# Label: [[2.2]]
# Segment: 2iD-tVS8NPw[12]
# ----------------------------------------
# Example 158:
# Text: and you know going into it or these watching the trailers before head i was really kind of hesitant about seeing the green lantern in the first place
# Length: 28
# Label: [[-1.]]
# Segment: 2iD-tVS8NPw[13]
# ----------------------------------------
# Example 159:
# Text: because it looks like a cartoon
# Length: 6
# Label: [[-1.5]]
# Segment: 2iD-tVS8NPw[14]
# ----------------------------------------
# Example 160:
# Text: im not really a huge fan of having like all these characters
# Length: 12
# Label: [[-1.6]]
# Segment: 2iD-tVS8NPw[15]
# ----------------------------------------
# Example 161:
# Text: because i think why not just make this you know movie this live action movie and talk cartoon
# Length: 18
# Label: [[-0.6]]
# Segment: 2iD-tVS8NPw[16]
# ----------------------------------------
# Example 162:
# Text: thats really the that youre gonna go
# Length: 7
# Label: [[0.33333334]]
# Segment: 2iD-tVS8NPw[17]
# ----------------------------------------
# Example 163:
# Text: and it seemed like they were gonna go that but
# Length: 10
# Label: [[0.]]
# Segment: 2iD-tVS8NPw[18]
# ----------------------------------------
# Example 164:
# Text: but i think there was also some sort of like um tone within the actual um powers of the green lantern and himself and that you can basically think up of anything and you can project that into the real life
# Length: 41
# Label: [[0.8]]
# Segment: 2iD-tVS8NPw[19]
# ----------------------------------------
# Example 165:
# Text: and i think having this sort of superpower almost this power to just imagine anything kind of just um helped me get passed that you know these are all characters and set
# Length: 32
# Label: [[1.]]
# Segment: 2iD-tVS8NPw[20]
# ----------------------------------------
# Example 166:
# Text: this is a playground and their imaginary playground and anything can happen anything that what also made the film exciting
# Length: 20
# Label: [[2.2]]
# Segment: 2iD-tVS8NPw[21]
# ----------------------------------------
# Example 167:
# Text: because you dont entirely know whats coming next
# Length: 8
# Label: [[0.2]]
# Segment: 2iD-tVS8NPw[22]
# ----------------------------------------
# Example 168:
# Text: but then you kind of like walk out of the movie and youre like well i i get what happened i understand what happened
# Length: 24
# Label: [[-1.]]
# Segment: 2iD-tVS8NPw[23]
# ----------------------------------------
# Example 169:
# Text: but what what would you do for green lantern movie that would be even like worth while now
# Length: 18
# Label: [[-0.8]]
# Segment: 2iD-tVS8NPw[24]
# ----------------------------------------
# Example 170:
# Text: because i mean if hes able to do all of this sort of stuff like how youre supposed to really put up a force that can push him to the next level or or destroy him at the same time
# Length: 40
# Label: [[0.]]
# Segment: 2iD-tVS8NPw[25]
# ----------------------------------------
# Example 171:
# Text: and it does kind of a lea helps alleviate what that whole was is about fighting the ultimate enemy within this first movie and that the threat is still there potentially speaking
# Length: 32
# Label: [[1.4]]
# Segment: 2iD-tVS8NPw[26]
# ----------------------------------------
# Example 172:
# Text: so its kind of interesting to see um where theyre gonna be going with that
# Length: 15
# Label: [[1.6]]
# Segment: 2iD-tVS8NPw[27]
# ----------------------------------------
# Example 173:
# Text: im looking forward to it ive got to say
# Length: 9
# Label: [[2.]]
# Segment: 2iD-tVS8NPw[28]
# ----------------------------------------
# Example 174:
# Text: its not like the green lantern is the next batman begins or or the dark
# Length: 15
# Label: [[-0.4]]
# Segment: 2iD-tVS8NPw[29]
# ----------------------------------------
# Example 175:
# Text: probably one of the probably one of the sundance um
# Length: 10
# Label: [[2.]]
# Segment: 5W7Z1C_fDaE[0]
# ----------------------------------------
# Example 176:
# Text: um as really the best way to describe this film is its big
# Length: 13
# Label: [[1.4]]
# Segment: 5W7Z1C_fDaE[1]
# ----------------------------------------
# Example 177:
# Text: its bold
# Length: 2
# Label: [[0.8]]
# Segment: 5W7Z1C_fDaE[2]
# ----------------------------------------
# Example 178:
# Text: its strong
# Length: 2
# Label: [[0.4]]
# Segment: 5W7Z1C_fDaE[3]
# ----------------------------------------
# Example 179:
# Text: it makes big statements
# Length: 4
# Label: [[2.]]
# Segment: 5W7Z1C_fDaE[4]
# ----------------------------------------
# Example 180:
# Text: it doesnt hold back
# Length: 4
# Label: [[0.5]]
# Segment: 5W7Z1C_fDaE[5]
# ----------------------------------------
# Example 181:
# Text: everything from the way its being released to the performances and to the story itself is absolutely the top impressive
# Length: 20
# Label: [[2.2]]
# Segment: 5W7Z1C_fDaE[6]
# ----------------------------------------
# Example 182:
# Text: and really well done
# Length: 4
# Label: [[2.6]]
# Segment: 5W7Z1C_fDaE[7]
# ----------------------------------------
# Example 183:
# Text: its a huge break through for kevin smith
# Length: 8
# Label: [[2.4]]
# Segment: 5W7Z1C_fDaE[8]
# ----------------------------------------
# Example 184:
# Text: its completely different from anything weve ever seen him do before
# Length: 11
# Label: [[0.4]]
# Segment: 5W7Z1C_fDaE[9]
# ----------------------------------------
# Example 185:
# Text: john goodman absolutely amazing
# Length: 4
# Label: [[2.6]]
# Segment: 5W7Z1C_fDaE[10]
# ----------------------------------------
# Example 186:
# Text: melissa leo will have you out to your inner core with her tiny little smile
# Length: 15
# Label: [[0.8]]
# Segment: 5W7Z1C_fDaE[11]
# ----------------------------------------
# Example 187:
# Text: its so well done
# Length: 4
# Label: [[2.6]]
# Segment: 5W7Z1C_fDaE[12]
# ----------------------------------------
# Example 188:
# Text: for all of those people who are hating on it i dont know what they are complaining about it
# Length: 19
# Label: [[1.8]]
# Segment: 5W7Z1C_fDaE[13]
# ----------------------------------------
# Example 189:
# Text: its a horror film ia a true sense
# Length: 8
# Label: [[0.25]]
# Segment: 5W7Z1C_fDaE[14]
# ----------------------------------------
# Example 190:
# Text: and it is absolutely horrifying
# Length: 5
# Label: [[-2.]]
# Segment: 5W7Z1C_fDaE[15]
# ----------------------------------------
# Example 191:
# Text: um it is it is one of those films thats not gonna be easy for you to find
# Length: 18
# Label: [[0.2]]
# Segment: 5W7Z1C_fDaE[16]
# ----------------------------------------
# Example 192:
# Text: its being released in a very interesting way
# Length: 8
# Label: [[1.2]]
# Segment: 5W7Z1C_fDaE[17]
# ----------------------------------------
# Example 193:
# Text: whenever it comes to your town do not miss it
# Length: 10
# Label: [[2.8]]
# Segment: 5W7Z1C_fDaE[18]
# ----------------------------------------
# Example 194:
# Text: its well made
# Length: 3
# Label: [[2.8]]
# Segment: 5W7Z1C_fDaE[19]
# ----------------------------------------
# Example 195:
# Text: its dare i say fun to watch in a really messed up kind of way
# Length: 15
# Label: [[2.]]
# Segment: 5W7Z1C_fDaE[20]
# ----------------------------------------
# Example 196:
# Text: its dare i say fun to watch in a really messed up kind of way and even now its a horror film
# Length: 22
# Label: [[1.6]]
# Segment: 5W7Z1C_fDaE[21]
# ----------------------------------------
# Example 197:
# Text: its got some fun kevin smith moments in it for you to laugh with um
# Length: 15
# Label: [[1.8]]
# Segment: 5W7Z1C_fDaE[22]
# ----------------------------------------
# Example 198:
# Text: absolutely not to be
# Length: 4
# Label: [[2.4]]
# Segment: 5W7Z1C_fDaE[23]
# ----------------------------------------
# Example 199:
# Text: i just got finished watching an excellent movie called mars needs moms
# Length: 12
# Label: [[3.]]
# Segment: 6Egk_28TtTM[0]
# ----------------------------------------
# Example 200:
# Text: and my favorite characters in the movie would have to be milo milos mother and gribble
# Length: 16
# Label: [[2.]]
# Segment: 6Egk_28TtTM[1]
# ----------------------------------------
# Example 201:
# Text: i liked gribble because he helped milo get milos mother away from the which
# Length: 14
# Label: [[1.8]]
# Segment: 6Egk_28TtTM[2]
# ----------------------------------------
# Example 202:
# Text: which i thought was awesome
# Length: 5
# Label: [[2.8]]
# Segment: 6Egk_28TtTM[3]
# ----------------------------------------
# Example 203:
# Text: and my favorite part in the movie was when milo has to save gribble
# Length: 14
# Label: [[2.2]]
# Segment: 6Egk_28TtTM[4]
# ----------------------------------------
# Example 204:
# Text: and i would recommend this movie for ages and up
# Length: 10
# Label: [[2.]]
# Segment: 6Egk_28TtTM[5]
# ----------------------------------------
# Example 205:
# Text: because it is a good movie
# Length: 6
# Label: [[2.2]]
# Segment: 6Egk_28TtTM[6]
# ----------------------------------------
# Example 206:
# Text: and it depends what age you are and how you to how you feel like see the movie
# Length: 18
# Label: [[0.8]]
# Segment: 6Egk_28TtTM[7]
# ----------------------------------------
# Example 207:
# Text: like for example my brother is five years old and he didnt think this movie was scary at all
# Length: 19
# Label: [[-0.4]]
# Segment: 6Egk_28TtTM[8]
# ----------------------------------------
# Example 208:
# Text: i am eight years old and i thought it was really s kind of scary
# Length: 15
# Label: [[0.6]]
# Segment: 6Egk_28TtTM[9]
# ----------------------------------------
# Example 209:
# Text: and i think i why i would be scared is because i would feel scared and kind of sad if i lost my own mother
# Length: 25
# Label: [[-1.2]]
# Segment: 6Egk_28TtTM[10]
# ----------------------------------------
# Example 210:
# Text: but it all turns out great in the end
# Length: 9
# Label: [[2.4]]
# Segment: 6Egk_28TtTM[11]
# ----------------------------------------
# Example 211:
# Text: and so i was kind of curious to see maybe if that was what disney was going for and it was what were going for
# Length: 25
# Label: [[1.6]]
# Segment: 6_0THN4chvY[0]
# ----------------------------------------
# Example 212:
# Text: but i bet if you put them next to the new film that the style would be similar enough that you wouldnt be able to really tell what the difference is
# Length: 31
# Label: [[0.6]]
# Segment: 6_0THN4chvY[1]
# ----------------------------------------
# Example 213:
# Text: um its its great if you remember that was old films
# Length: 11
# Label: [[2.]]
# Segment: 6_0THN4chvY[2]
# ----------------------------------------
# Example 214:
# Text: would be great for kids too
# Length: 6
# Label: [[2.]]
# Segment: 6_0THN4chvY[3]
# ----------------------------------------
# Example 215:
# Text: the story is pretty simple
# Length: 5
# Label: [[0.]]
# Segment: 6_0THN4chvY[4]
# ----------------------------------------
# Example 216:
# Text: weve got great jokes
# Length: 4
# Label: [[1.6]]
# Segment: 6_0THN4chvY[5]
# ----------------------------------------
# Example 217:
# Text: um funny jokes that the kids would get
# Length: 8
# Label: [[0.8]]
# Segment: 6_0THN4chvY[6]
# ----------------------------------------
# Example 218:
# Text: um i love the scene where and pooh think that owl is getting sick
# Length: 14
# Label: [[2.]]
# Segment: 6_0THN4chvY[7]
# ----------------------------------------
# Example 219:
# Text: because he says issue and they think he is saying at you
# Length: 12
# Label: [[-0.6]]
# Segment: 6_0THN4chvY[8]
# ----------------------------------------
# Example 220:
# Text: um that was probably part of the trailer that got me to go and see the movie
# Length: 17
# Label: [[0.4]]
# Segment: 6_0THN4chvY[9]
# ----------------------------------------
# Example 221:
# Text: wanted to see how they could frame that
# Length: 8
# Label: [[0.25]]
# Segment: 6_0THN4chvY[10]
# ----------------------------------------
# Example 222:
# Text: so um if you seen winnie the pooh and you like family films go see it
# Length: 16
# Label: [[1.8]]
# Segment: 6_0THN4chvY[11]
# ----------------------------------------
# Example 223:
# Text: its a great one
# Length: 4
# Label: [[2.2]]
# Segment: 6_0THN4chvY[12]
# ----------------------------------------
# Example 224:
# Text: i recommend it
# Length: 3
# Label: [[2.2]]
# Segment: 6_0THN4chvY[13]
# ----------------------------------------
# Example 225:
# Text: um so there are things that i liked about the movie better than i liked about the book and vice verse
# Length: 21
# Label: [[1.]]
# Segment: 73jzhE8R1TQ[0]
# ----------------------------------------
# Example 226:
# Text: it like it like oh the book was so much harder than movie
# Length: 13
# Label: [[-0.8]]
# Segment: 73jzhE8R1TQ[1]
# ----------------------------------------
# Example 227:
# Text: maybe because number four was not my all time favorite book
# Length: 11
# Label: [[-0.8]]
# Segment: 73jzhE8R1TQ[2]
# ----------------------------------------
# Example 228:
# Text: it was a good book
# Length: 5
# Label: [[1.6]]
# Segment: 73jzhE8R1TQ[3]
# ----------------------------------------
# Example 229:
# Text: but but um i crazy about it
# Length: 7
# Label: [[-0.8]]
# Segment: 73jzhE8R1TQ[4]
# ----------------------------------------
# Example 230:
# Text: so yeah and the movie was pretty good in my opinion
# Length: 11
# Label: [[1.8]]
# Segment: 73jzhE8R1TQ[5]
# ----------------------------------------
# Example 231:
# Text: so i liked the movie
# Length: 5
# Label: [[1.4]]
# Segment: 73jzhE8R1TQ[6]
# ----------------------------------------
# Example 232:
# Text: because it did a good job of explaining the back story in the book
# Length: 14
# Label: [[1.8]]
# Segment: 73jzhE8R1TQ[7]
# ----------------------------------------
# Example 233:
# Text: good job of explaining thing with lorain the the
# Length: 9
# Label: [[0.5]]
# Segment: 73jzhE8R1TQ[8]
# ----------------------------------------
# Example 234:
# Text: the numbers they and they kind of stuck to the book of it so i like that
# Length: 17
# Label: [[1.4]]
# Segment: 73jzhE8R1TQ[9]
# ----------------------------------------
# Example 235:
# Text: and but were too hollywood for me
# Length: 7
# Label: [[-1.2]]
# Segment: 73jzhE8R1TQ[10]
# ----------------------------------------
# Example 236:
# Text: like th this thing really a big deal but um i i like the fact that john had an because
# Length: 20
# Label: [[-1.2]]
# Segment: 73jzhE8R1TQ[11]
# ----------------------------------------
# Example 237:
# Text: because think about it if you if your top priority is survival than why would you be worried about having the latest technology you know what i mean
# Length: 28
# Label: [[-0.6]]
# Segment: 73jzhE8R1TQ[12]
# ----------------------------------------
# Example 238:
# Text: so since were not really sure what their financial situation is they could be like scraping by or they could be totally rich
# Length: 23
# Label: [[0.]]
# Segment: 73jzhE8R1TQ[13]
# ----------------------------------------
# Example 239:
# Text: but my like he have an he care about the latest trends so thats really what the lieutenant i
# Length: 19
# Label: [[-1.6]]
# Segment: 73jzhE8R1TQ[14]
# ----------------------------------------
# Example 240:
# Text: i thought it was all too commercial in that aspect
# Length: 10
# Label: [[-0.2]]
# Segment: 73jzhE8R1TQ[15]
# ----------------------------------------
# Example 241:
# Text: um like i said it big deal
# Length: 7
# Label: [[-0.4]]
# Segment: 73jzhE8R1TQ[16]
# ----------------------------------------
# Example 242:
# Text: and you probably dont think so but you know just one of those little things that that hurt you for some reason you know what i mean
# Length: 27
# Label: [[-1.6]]
# Segment: 73jzhE8R1TQ[17]
# ----------------------------------------
# Example 243:
# Text: um another thing that did bother me were the um
# Length: 10
# Label: [[-1.2]]
# Segment: 73jzhE8R1TQ[18]
# ----------------------------------------
# Example 244:
# Text: um graphics were incredible
# Length: 4
# Label: [[1.8]]
# Segment: 7JsX8y1ysxY[0]
# ----------------------------------------
# Example 245:
# Text: um some really good acting
# Length: 5
# Label: [[2.2]]
# Segment: 7JsX8y1ysxY[1]
# ----------------------------------------
# Example 246:
# Text: some really acting
# Length: 3
# Label: [[-2.6]]
# Segment: 7JsX8y1ysxY[2]
# ----------------------------------------
# Example 247:
# Text: so this was pretty funny
# Length: 5
# Label: [[1.4]]
# Segment: 7JsX8y1ysxY[3]
# ----------------------------------------
# Example 248:
# Text: coz people were like eating popcorn and you see the first show and people you hear like this this ripple effect of whispering oh my god is that a is that am i looking at this right what
# Length: 38
# Label: [[1.]]
# Segment: 7JsX8y1ysxY[4]
# ----------------------------------------
# Example 249:
# Text: i thought that was really funny
# Length: 6
# Label: [[1.6]]
# Segment: 7JsX8y1ysxY[5]
# ----------------------------------------
# Example 250:
# Text: um there been less blue nudity
# Length: 6
# Label: [[-1.6]]
# Segment: 7JsX8y1ysxY[6]
# ----------------------------------------
# Example 251:
# Text: because what was weird was the fact that in part of the movie hes wearing like a blue um overall thing medal thing so i was like why not wear the whole whole time you know why why you got to go command on us
# Length: 45
# Label: [[-1.2]]
# Segment: 7JsX8y1ysxY[7]
# ----------------------------------------
# Example 252:
# Text: it was funny though
# Length: 4
# Label: [[1.8]]
# Segment: 7JsX8y1ysxY[8]
# ----------------------------------------
# Example 253:
# Text: hes funny
# Length: 2
# Label: [[2.]]
# Segment: 7JsX8y1ysxY[9]
# ----------------------------------------
# Example 254:
# Text: its kind of weird
# Length: 4
# Label: [[-1.]]
# Segment: 7JsX8y1ysxY[10]
# ----------------------------------------
# Example 255:
# Text: i dont know classic superhero kind of getting on kind of thing
# Length: 12
# Label: [[0.6]]
# Segment: 7JsX8y1ysxY[11]
# ----------------------------------------
# Example 256:
# Text: all right so enough of the nudity
# Length: 7
# Label: [[-1.6]]
# Segment: 7JsX8y1ysxY[12]
# ----------------------------------------
# Example 257:
# Text: um but what sucked what was bad was malin akerman the girl who plays the silk spectre um
# Length: 18
# Label: [[-2.2]]
# Segment: 7JsX8y1ysxY[13]
# ----------------------------------------
# Example 258:
# Text: um junior lady girl i know i i mean she looked fan fantastic
# Length: 13
# Label: [[-0.4]]
# Segment: 7JsX8y1ysxY[14]
# ----------------------------------------
# Example 259:
# Text: she looked phenomenal
# Length: 3
# Label: [[2.2]]
# Segment: 7JsX8y1ysxY[15]
# ----------------------------------------
# Example 260:
# Text: she looked like a superhero
# Length: 5
# Label: [[0.8]]
# Segment: 7JsX8y1ysxY[16]
# ----------------------------------------
# Example 261:
# Text: but she acted like power ranger
# Length: 6
# Label: [[-0.4]]
# Segment: 7JsX8y1ysxY[17]
# ----------------------------------------
# Example 262:
# Text: and theres a vast difference between those two things
# Length: 9
# Label: [[-0.2]]
# Segment: 7JsX8y1ysxY[18]
# ----------------------------------------
# Example 263:
# Text: ill tell you who made the movie
# Length: 7
# Label: [[0.8]]
# Segment: 7JsX8y1ysxY[19]
# ----------------------------------------
# Example 264:
# Text: who was just kick ass of time was the guy that played our rorschach
# Length: 14
# Label: [[1.8]]
# Segment: 7JsX8y1ysxY[20]
# ----------------------------------------
# Example 265:
# Text: but anyways he was awesome
# Length: 5
# Label: [[2.6]]
# Segment: 7JsX8y1ysxY[21]
# ----------------------------------------
# Example 266:
# Text: i thought that was very cool
# Length: 6
# Label: [[2.4]]
# Segment: 7JsX8y1ysxY[22]
# ----------------------------------------
# Example 267:
# Text: um he was awesome
# Length: 4
# Label: [[2.4]]
# Segment: 7JsX8y1ysxY[23]
# ----------------------------------------
# Example 268:
# Text: like he was incredible
# Length: 4
# Label: [[2.6]]
# Segment: 7JsX8y1ysxY[24]
# ----------------------------------------
# Example 269:
# Text: the other guy that did a really good job was um jeffrey dean morgan
# Length: 14
# Label: [[1.8]]
# Segment: 7JsX8y1ysxY[25]
# ----------------------------------------
# Example 270:
# Text: he did a very good job
# Length: 6
# Label: [[2.]]
# Segment: 7JsX8y1ysxY[26]
# ----------------------------------------
# Example 271:
# Text: very dark
# Length: 2
# Label: [[-1.25]]
# Segment: 7JsX8y1ysxY[27]
# ----------------------------------------
# Example 272:
# Text: um i really liked guy
# Length: 5
# Label: [[-1.5]]
# Segment: 7JsX8y1ysxY[28]
# ----------------------------------------
# Example 273:
# Text: but um he did a really good job at acting
# Length: 10
# Label: [[2.2]]
# Segment: 7JsX8y1ysxY[29]
# ----------------------------------------
# Example 274:
# Text: i was very impressed
# Length: 4
# Label: [[2.2]]
# Segment: 7JsX8y1ysxY[30]
# ----------------------------------------
# Example 275:
# Text: so overall its its like a blend of youve got alternative history
# Length: 12
# Label: [[0.6]]
# Segment: 7JsX8y1ysxY[31]
# ----------------------------------------
# Example 276:
# Text: and its very very interesting
# Length: 5
# Label: [[1.4]]
# Segment: 7JsX8y1ysxY[32]
# ----------------------------------------
# Example 277:
# Text: um but its extremely dark
# Length: 5
# Label: [[-0.6]]
# Segment: 7JsX8y1ysxY[33]
# ----------------------------------------
# Example 278:
# Text: i warn you its a very very dark
# Length: 8
# Label: [[-1.]]
# Segment: 7JsX8y1ysxY[34]
# ----------------------------------------
# Example 279:
# Text: and um theres not in my opinion there very much of a balance between sort of like the good evil kind of thing
# Length: 23
# Label: [[-1.6]]
# Segment: 7JsX8y1ysxY[35]
# ----------------------------------------
# Example 280:
# Text: and it seemed like everything was sort of overwhelmingly bad
# Length: 10
# Label: [[-1.6]]
# Segment: 7JsX8y1ysxY[36]
# ----------------------------------------
# Example 281:
# Text: um so at the end theres not really a whole lot of redeeming value that i think you come up with
# Length: 21
# Label: [[-1.8]]
# Segment: 7JsX8y1ysxY[37]
# ----------------------------------------
# Example 282:
# Text: but um you know overall it was good
# Length: 8
# Label: [[1.8]]
# Segment: 7JsX8y1ysxY[38]
# ----------------------------------------
# Example 283:
# Text: which is where all great relationships should start
# Length: 8
# Label: [[0.4]]
# Segment: 8OtFthrtaJM[0]
# ----------------------------------------
# Example 284:
# Text: and just its very its very chaotic at the end of this movie
# Length: 13
# Label: [[-1.]]
# Segment: 8OtFthrtaJM[1]
# ----------------------------------------
# Example 285:
# Text: i literally said out loud what que what is this movie that i am seeing what is this
# Length: 18
# Label: [[-2.4]]
# Segment: 8OtFthrtaJM[2]
# ----------------------------------------
# Example 286:
# Text: i do not understand this movie
# Length: 6
# Label: [[-2.]]
# Segment: 8OtFthrtaJM[3]
# ----------------------------------------
# Example 287:
# Text: but theres a reason for that theres a reason for why i was confused
# Length: 14
# Label: [[-0.2]]
# Segment: 8OtFthrtaJM[4]
# ----------------------------------------
# Example 288:
# Text: first off the commercial makes the terrible terrible mistake of saying that it is more thought provoking than inception
# Length: 19
# Label: [[-2.6]]
# Segment: 8OtFthrtaJM[5]
# ----------------------------------------
# Example 289:
# Text: thanks a lot commercial
# Length: 4
# Label: [[-1.4]]
# Segment: 8OtFthrtaJM[6]
# ----------------------------------------
# Example 290:
# Text: the entire time i was constantly comparing it to inception
# Length: 10
# Label: [[-0.2]]
# Segment: 8OtFthrtaJM[7]
# ----------------------------------------
# Example 291:
# ...
# Length: 24
# Label: [[-1.6]]
# Segment: VCslbP0mgZI[13]
# ----------------------------------------
# Example 1185:
# Text: so if i give zach snyder the benefit of the doubt this is a movie that looks great has some bad acting
# Length: 22
# Label: [[0.4]]
# Segment: VCslbP0mgZI[14]
# ----------------------------------------
# Example 1186:
# Text: and has way too much violence against women
# Length: 8
# Label: [[-1.8]]
# Segment: VCslbP0mgZI[15]
# ----------------------------------------
# Example 1187:
# Text: if i dont give zach snyder the benefit of the
# Length: 10
# Label: [[-0.6]]
# Segment: VCslbP0mgZI[16]
# ----------------------------------------
# Example 1188:
# Text: and this is the one that i can say was disappointed
# Length: 11
# Label: [[-2.2]]
# Segment: VbQk4H8hgr0[0]
# ----------------------------------------
# Example 1189:
# Text: i love the first and the second and
# Length: 8
# Label: [[2.]]
# Segment: VbQk4H8hgr0[1]
# ----------------------------------------
# Example 1190:
# Text: and i was really hoping that this one be just as good
# Length: 12
# Label: [[-0.8]]
# Segment: VbQk4H8hgr0[2]
# ----------------------------------------
# Example 1191:
# Text: and it just that it anything new to offer
# Length: 9
# Label: [[-2.2]]
# Segment: VbQk4H8hgr0[3]
# ----------------------------------------
# Example 1192:
# Text: i was really disappointed with that
# Length: 6
# Label: [[-2.2]]
# Segment: VbQk4H8hgr0[4]
# ----------------------------------------
# Example 1193:
# Text: i mean i went in there hoping to see something original and funny like the first two
# Length: 17
# Label: [[-1.8]]
# Segment: VbQk4H8hgr0[5]
# ----------------------------------------
# Example 1194:
# Text: and it offered nothing of the such
# Length: 7
# Label: [[-2.]]
# Segment: VbQk4H8hgr0[6]
# ----------------------------------------
# Example 1195:
# Text: it funny
# Length: 2
# Label: [[-0.4]]
# Segment: VbQk4H8hgr0[7]
# ----------------------------------------
# Example 1196:
# Text: there was a few jokes ok yeah make you giggle or something
# Length: 12
# Label: [[0.6]]
# Segment: VbQk4H8hgr0[8]
# ----------------------------------------
# Example 1197:
# Text: but thats nothing major
# Length: 4
# Label: [[-0.25]]
# Segment: VbQk4H8hgr0[9]
# ----------------------------------------
# Example 1198:
# Text: nothing really that funny
# Length: 4
# Label: [[-1.]]
# Segment: VbQk4H8hgr0[10]
# ----------------------------------------
# Example 1199:
# Text: or anything original
# Length: 3
# Label: [[-1.6]]
# Segment: VbQk4H8hgr0[11]
# ----------------------------------------
# Example 1200:
# Text: the characters are all the same
# Length: 6
# Label: [[-1.6]]
# Segment: VbQk4H8hgr0[12]
# ----------------------------------------
# Example 1201:
# Text: and not even as good as the first two movies
# Length: 10
# Label: [[-1.2]]
# Segment: VbQk4H8hgr0[13]
# ----------------------------------------
# Example 1202:
# Text: and i loved puss in boots
# Length: 6
# Label: [[2.]]
# Segment: VbQk4H8hgr0[14]
# ----------------------------------------
# Example 1203:
# Text: and he even that great this time around
# Length: 8
# Label: [[-2.]]
# Segment: VbQk4H8hgr0[15]
# ----------------------------------------
# Example 1204:
# Text: the donkey and puss in boots rivalry thats going on it just it as funny the third time around
# Length: 19
# Label: [[-1.8]]
# Segment: VbQk4H8hgr0[16]
# ----------------------------------------
# Example 1205:
# Text: and there was nothing new to offer
# Length: 7
# Label: [[-2.]]
# Segment: VbQk4H8hgr0[17]
# ----------------------------------------
# Example 1206:
# Text: plain and simply it was dull for me
# Length: 8
# Label: [[-2.]]
# Segment: VbQk4H8hgr0[18]
# ----------------------------------------
# Example 1207:
# Text: it been so much better i i i saw it being so much better in my head but it just it
# Length: 21
# Label: [[-2.]]
# Segment: VbQk4H8hgr0[19]
# ----------------------------------------
# Example 1208:
# Text: it disappointed me highly
# Length: 4
# Label: [[-2.2]]
# Segment: VbQk4H8hgr0[20]
# ----------------------------------------
# Example 1209:
# Text: and i was just sort of discouraged after seeing the movie
# Length: 11
# Label: [[-2.6]]
# Segment: VbQk4H8hgr0[21]
# ----------------------------------------
# Example 1210:
# Text: and im wish i had my money back
# Length: 8
# Label: [[-3.]]
# Segment: VbQk4H8hgr0[22]
# ----------------------------------------
# Example 1211:
# Text: um it was a waste of my time
# Length: 8
# Label: [[-2.8]]
# Segment: VbQk4H8hgr0[23]
# ----------------------------------------
# Example 1212:
# Text: and i dont suggest anyone go see it
# Length: 8
# Label: [[-2.2]]
# Segment: VbQk4H8hgr0[24]
# ----------------------------------------
# Example 1213:
# Text: if youre hoping to if you have to have if you have kids and youre forced to go which you probably will if you have kids you know put up with it as a parent
# Length: 35
# Label: [[-1.6]]
# Segment: VbQk4H8hgr0[25]
# ----------------------------------------
# Example 1214:
# Text: but on your own dont go see it
# Length: 8
# Label: [[-1.8]]
# Segment: VbQk4H8hgr0[26]
# ----------------------------------------
# Example 1215:
# Text: its not really that great
# Length: 5
# Label: [[-2.]]
# Segment: VbQk4H8hgr0[27]
# ----------------------------------------
# Example 1216:
# Text: everyone is split on this one just as they were on spiderman
# Length: 12
# Label: [[-0.4]]
# Segment: VbQk4H8hgr0[28]
# ----------------------------------------
# Example 1217:
# Text: and just they are with all the other sequels that are coming out an this one
# Length: 16
# Label: [[0.]]
# Segment: VbQk4H8hgr0[29]
# ----------------------------------------
# Example 1218:
# Text: i have to agree on the negative side it was not great
# Length: 12
# Label: [[-1.4]]
# Segment: VbQk4H8hgr0[30]
# ----------------------------------------
# Example 1219:
# Text: it even remotely good
# Length: 4
# Label: [[-2.8]]
# Segment: VbQk4H8hgr0[31]
# ----------------------------------------
# Example 1220:
# Text: i mean theres a few moments yeah that are original and funny
# Length: 12
# Label: [[0.4]]
# Segment: VbQk4H8hgr0[32]
# ----------------------------------------
# Example 1221:
# Text: and theres a ne an introduction of a new character justine character already in the film
# Length: 16
# Label: [[-0.2]]
# Segment: VbQk4H8hgr0[33]
# ----------------------------------------
# Example 1222:
# Text: but they didnt even give him that much to do the he had only few minor lines
# Length: 17
# Label: [[-1.8]]
# Segment: VbQk4H8hgr0[34]
# ----------------------------------------
# Example 1223:
# Text: and none of them were really that great i mean stands out in your mind
# Length: 15
# Label: [[-1.4]]
# Segment: VbQk4H8hgr0[35]
# ----------------------------------------
# Example 1224:
# Text: so the addition of this character was pretty pointless
# Length: 9
# Label: [[-1.8]]
# Segment: VbQk4H8hgr0[36]
# ----------------------------------------
# Example 1225:
# Text: i mean its to the story
# Length: 6
# Label: [[-0.2]]
# Segment: VbQk4H8hgr0[37]
# ----------------------------------------
# Example 1226:
# Text: but i still find it pointless in the end of the movie
# Length: 12
# Label: [[-2.]]
# Segment: VbQk4H8hgr0[38]
# ----------------------------------------
# Example 1227:
# Text: and the characters just the same as the first two that i fell in love with them
# Length: 17
# Label: [[-1.2]]
# Segment: VbQk4H8hgr0[39]
# ----------------------------------------
# Example 1228:
# Text: it just kind of made me wanna really walk out of the theater
# Length: 13
# Label: [[-2.6]]
# Segment: VbQk4H8hgr0[40]
# ----------------------------------------
# Example 1229:
# Text: so that just pissed me off more
# Length: 7
# Label: [[-2.4]]
# Segment: VbQk4H8hgr0[41]
# ----------------------------------------
# Example 1230:
# Text: but really i just walked up and left at that moment
# Length: 11
# Label: [[-2.4]]
# Segment: VbQk4H8hgr0[42]
# ----------------------------------------
# Example 1231:
# Text: it was boring
# Length: 3
# Label: [[-2.]]
# Segment: VbQk4H8hgr0[43]
# ----------------------------------------
# Example 1232:
# Text: and not at all original in my opinion
# Length: 8
# Label: [[-2.2]]
# Segment: VbQk4H8hgr0[44]
# ----------------------------------------
# Example 1233:
# Text: it been so much better
# Length: 5
# Label: [[-1.8]]
# Segment: VbQk4H8hgr0[45]
# ----------------------------------------
# Example 1234:
# Text: than the second sequel was really great
# Length: 7
# Label: [[2.2]]
# Segment: VbQk4H8hgr0[46]
# ----------------------------------------
# Example 1235:
# Text: and i loved it and this one just was a flat of disappointments
# Length: 13
# Label: [[-2.2]]
# Segment: VbQk4H8hgr0[47]
# ----------------------------------------
# Example 1236:
# Text: so im gonna rate this one two stars
# Length: 8
# Label: [[-1.8]]
# Segment: VbQk4H8hgr0[48]
# ----------------------------------------
# Example 1237:
# Text: it really be one
# Length: 4
# Label: [[-1.]]
# Segment: VbQk4H8hgr0[49]
# ----------------------------------------
# Example 1238:
# Text: but im gonna give it a two to be fair
# Length: 10
# Label: [[-1.2]]
# Segment: VbQk4H8hgr0[50]
# ----------------------------------------
# Example 1239:
# Text: because the movie did have some points when i was laughing
# Length: 11
# Label: [[0.4]]
# Segment: VbQk4H8hgr0[51]
# ----------------------------------------
# Example 1240:
# Text: but very few
# Length: 3
# Label: [[-0.8]]
# Segment: VbQk4H8hgr0[52]
# ----------------------------------------
# Example 1241:
# Text: and it worth it in my opinion to go see it
# Length: 11
# Label: [[-2.4]]
# Segment: VbQk4H8hgr0[53]
# ----------------------------------------
# Example 1242:
# Text: so i
# Length: 2
# Label: [[0.2]]
# Segment: VbQk4H8hgr0[54]
# ----------------------------------------
# Example 1243:
# Text: well he plays that well so hes a good villain
# Length: 10
# Label: [[1.4]]
# Segment: Vj1wYRQjB-o[0]
# ----------------------------------------
# Example 1244:
# Text: he also has some really cool guns so that its like a desert eagle but it has to barrels to it
# Length: 21
# Label: [[2.2]]
# Segment: Vj1wYRQjB-o[1]
# ----------------------------------------
# Example 1245:
# Text: its pretty pretty scary looking
# Length: 5
# Label: [[-0.8]]
# Segment: Vj1wYRQjB-o[2]
# ----------------------------------------
# Example 1246:
# Text: i wouldnt want that pointed at me
# Length: 7
# Label: [[-0.8]]
# Segment: Vj1wYRQjB-o[3]
# ----------------------------------------
# Example 1247:
# Text: and i who would i mean
# Length: 6
# Label: [[0.5]]
# Segment: Vj1wYRQjB-o[4]
# ----------------------------------------
# Example 1248:
# Text: um like i said i thought the movie was great
# Length: 10
# Label: [[2.2]]
# Segment: Vj1wYRQjB-o[5]
# ----------------------------------------
# Example 1249:
# Text: the action they do have is really well done
# Length: 9
# Label: [[1.8]]
# Segment: Vj1wYRQjB-o[6]
# ----------------------------------------
# Example 1250:
# Text: um they did a good job with car
# Length: 8
# Label: [[1.6]]
# Segment: Vj1wYRQjB-o[7]
# ----------------------------------------
# Example 1251:
# Text: they did a good job with the fight scenes
# Length: 9
# Label: [[2.]]
# Segment: Vj1wYRQjB-o[8]
# ----------------------------------------
# Example 1252:
# Text: now was just fantastic
# Length: 4
# Label: [[2.8]]
# Segment: W8NXH0Djyww[0]
# ----------------------------------------
# Example 1253:
# Text: surprised me
# Length: 2
# Label: [[-0.25]]
# Segment: W8NXH0Djyww[1]
# ----------------------------------------
# Example 1254:
# Text: uh it was so much better than i thought it was going to be
# Length: 14
# Label: [[2.4]]
# Segment: W8NXH0Djyww[2]
# ----------------------------------------
# Example 1255:
# Text: and this town was like from a good old western
# Length: 10
# Label: [[0.6]]
# Segment: W8NXH0Djyww[3]
# ----------------------------------------
# Example 1256:
# Text: it had all this stereotypical traits of a western town
# Length: 10
# Label: [[-0.8]]
# Segment: W8NXH0Djyww[4]
# ----------------------------------------
# Example 1257:
# Text: i but it was it was cool
# Length: 7
# Label: [[1.6]]
# Segment: W8NXH0Djyww[5]
# ----------------------------------------
# Example 1258:
# Text: it was a great movie
# Length: 5
# Label: [[2.]]
# Segment: W8NXH0Djyww[6]
# ----------------------------------------
# Example 1259:
# Text: and now what i loved about this movie was like the supporting characters in this movie
# Length: 16
# Label: [[2.2]]
# Segment: W8NXH0Djyww[7]
# ----------------------------------------
# Example 1260:
# Text: the all the animals were just so funny
# Length: 8
# Label: [[2.]]
# Segment: W8NXH0Djyww[8]
# ----------------------------------------
# Example 1261:
# Text: um they all played off each other
# Length: 7
# Label: [[0.8]]
# Segment: W8NXH0Djyww[9]
# ----------------------------------------
# Example 1262:
# Text: theyre like the dumb kinda cowboys that dont know what theyre doing always asking dumb questions staying saying stupid shit
# Length: 20
# Label: [[-2.2]]
# Segment: W8NXH0Djyww[10]
# ----------------------------------------
# Example 1263:
# Text: and it was just oh it was hysterical
# Length: 8
# Label: [[2.4]]
# Segment: W8NXH0Djyww[11]
# ----------------------------------------
# Example 1264:
# Text: and the stuff he said was just it was just so funny
# Length: 12
# Label: [[2.2]]
# Segment: W8NXH0Djyww[12]
# ----------------------------------------
# Example 1265:
# Text: and he did a wonderful job
# Length: 6
# Label: [[2.2]]
# Segment: W8NXH0Djyww[13]
# ----------------------------------------
# Example 1266:
# Text: all the cinematography in this movie was great
# Length: 8
# Label: [[2.4]]
# Segment: W8NXH0Djyww[14]
# ----------------------------------------
# Example 1267:
# Text: like all the sunsets and all the landscapes of the films they just looked so realistic in every almost every scene
# Length: 21
# Label: [[2.4]]
# Segment: W8NXH0Djyww[15]
# ----------------------------------------
# Example 1268:
# Text: um like this movie had great action sequences
# Length: 8
# Label: [[1.]]
# Segment: W8NXH0Djyww[16]
# ----------------------------------------
# Example 1269:
# Text: this aw this one really cool action sequences where like this ronny uh johnny posse they were getting chased by all these like possums
# Length: 24
# Label: [[2.2]]
# Segment: W8NXH0Djyww[17]
# ----------------------------------------
# Example 1270:
# Text: or nah i wouldnt say possums but prairie dogs
# Length: 9
# Label: [[-0.75]]
# Segment: W8NXH0Djyww[18]
# ----------------------------------------
# Example 1271:
# Text: im not even sure what they were
# Length: 7
# Label: [[-1.]]
# Segment: W8NXH0Djyww[19]
# ----------------------------------------
# Example 1272:
# Text: it was just so cool
# Length: 5
# Label: [[2.6]]
# Segment: W8NXH0Djyww[20]
# ----------------------------------------
# Example 1273:
# Text: like a covered wagon horse kinda cowboy chase sequence
# Length: 9
# Label: [[-0.2]]
# Segment: W8NXH0Djyww[21]
# ----------------------------------------
# Example 1274:
# Text: oh it was so cool
# Length: 5
# Label: [[2.2]]
# Segment: W8NXH0Djyww[22]
# ----------------------------------------
# Example 1275:
# Text: um but this movie it had everything humor romance action
# Length: 10
# Label: [[2.6]]
# Segment: W8NXH0Djyww[23]
# ----------------------------------------
# Example 1276:
# Text: of course um it was just it was fun it was a fun entertaining movie
# Length: 15
# Label: [[1.8]]
# Segment: W8NXH0Djyww[24]
# ----------------------------------------
# Example 1277:
# Text: uh it was good for the entire family
# Length: 8
# Label: [[2.]]
# Segment: W8NXH0Djyww[25]
# ----------------------------------------
# Example 1278:
# Text: um definitely recommend checking seeing this uh checking this movie out
# Length: 11
# Label: [[1.4]]
# Segment: W8NXH0Djyww[26]
# ----------------------------------------
# Example 1279:
# Text: uh i rated it four out of five stars
# Length: 9
# Label: [[1.8]]
# Segment: W8NXH0Djyww[27]
# ----------------------------------------
# Example 1280:
# Text: um the one thing i didnt like about this movie was they brought the main uh the bad character i should say in kinda late
# Length: 25
# Label: [[-1.5]]
# Segment: W8NXH0Djyww[28]
# ----------------------------------------
# Example 1281:
# Text: but that didnt really matter
# Length: 5
# Label: [[-0.4]]
# Segment: W8NXH0Djyww[29]
# ----------------------------------------
# Example 1282:
# Text: um everything else held up its own
# Length: 7
# Label: [[0.6]]
# Segment: W8NXH0Djyww[30]
# ----------------------------------------
# Example 1283:
# Text: um definitely check out this movie uh in a theatre near you
# Length: 12
# Label: [[2.]]
# Segment: W8NXH0Djyww[31]
# ----------------------------------------
# Maximum length: 102
# Minimum length: 1
# Example with length 1: 1171

# %%
# Reverse mapping from word IDs to words
id2word = {v: k for k, v in word2id.items()}

# Specify how many examples to examine
num_examples = len(dev)  # Ensure we don't exceed the dataset size

max_length = 0
min_length = float('inf')

for idx in range(num_examples):
    # Convert word IDs to words
    words = ' '.join(map(lambda x: id2word[x], dev[idx][0][0].tolist()))
    label = dev[idx][1]  # Label
    segment = dev[idx][2]  # Segment

    # Calculate the length of the words (number of words)
    length = len(words.split())  # Word count, not character count

    # Track the max and min lengths
    max_length = max(max_length, length)
    min_length = min(min_length, length)

    # Display the information
    print(f"Example {idx+1}:")
    print(f"Text: {words}")
    print(f"Length: {length}")
    print(f"Label: {label}")
    print(f"Segment: {segment}")
    print("-" * 40)  # Separator for readability

# After the loop, print the max and min lengths
print(f"Maximum length: {max_length}")
print(f"Minimum length: {min_length}")
# Out:
# Example 1:
# Text: uh i really enjoyed doing them for the philly d movie club so i thought oh why not
# Length: 18
# Label: [[1.8]]
# Segment: WKA5OygbEKI[0]
# ----------------------------------------
# Example 2:
# Text: uh is a really cute movie
# Length: 6
# Label: [[2.2]]
# Segment: WKA5OygbEKI[1]
# ----------------------------------------
# Example 3:
# Text: um i i liked a lot of the movie
# Length: 9
# Label: [[1.2]]
# Segment: WKA5OygbEKI[2]
# ----------------------------------------
# Example 4:
# Text: i will admit im a big johnny depp fan
# Length: 9
# Label: [[1.8]]
# Segment: WKA5OygbEKI[3]
# ----------------------------------------
# Example 5:
# Text: um i pretty much will go see any movie that kind of has an interesting plot if hes in it
# Length: 20
# Label: [[0.6]]
# Segment: WKA5OygbEKI[4]
# ----------------------------------------
# Example 6:
# Text: um its not his best
# Length: 5
# Label: [[-1.4]]
# Segment: WKA5OygbEKI[5]
# ----------------------------------------
# Example 7:
# Text: i mean corpse bride hes really good in corpse bride
# Length: 10
# Label: [[1.6]]
# Segment: WKA5OygbEKI[6]
# ----------------------------------------
# Example 8:
# Text: and kind of falls into that
# Length: 6
# Label: [[0.]]
# Segment: WKA5OygbEKI[7]
# ----------------------------------------
# Example 9:
# Text: well its a johnny depp movie so its entertaining
# Length: 9
# Label: [[1.4]]
# Segment: WKA5OygbEKI[8]
# ----------------------------------------
# Example 10:
# Text: but its not something that i would go buy
# Length: 9
# Label: [[-0.4]]
# Segment: WKA5OygbEKI[9]
# ----------------------------------------
# Example 11:
# Text: or something i would recommend
# Length: 5
# Label: [[-0.6]]
# Segment: WKA5OygbEKI[10]
# ----------------------------------------
# Example 12:
# Text: unless you have little kids to bring with you
# Length: 9
# Label: [[0.2]]
# Segment: WKA5OygbEKI[11]
# ----------------------------------------
# Example 13:
# Text: oh it has some really good references of past johnny depp films in it like while the getting bounced along the highway you run into henry s thompson
# Length: 28
# Label: [[2.]]
# Segment: WKA5OygbEKI[12]
# ----------------------------------------
# Example 14:
# Text: uh hes super entertaining as the chameleon
# Length: 7
# Label: [[2.2]]
# Segment: WKA5OygbEKI[13]
# ----------------------------------------
# Example 15:
# Text: i mean johnny a wonderful voice actor so um he hes i do hes an incredible voice actor
# Length: 18
# Label: [[1.8]]
# Segment: WKA5OygbEKI[14]
# ----------------------------------------
# Example 16:
# Text: like thats really the best part of the movie is listening to him uh pull off all these different voices
# Length: 20
# Label: [[1.8]]
# Segment: WKA5OygbEKI[15]
# ----------------------------------------
# Example 17:
# Text: and be this really quirky little chameleon
# Length: 7
# Label: [[0.4]]
# Segment: WKA5OygbEKI[16]
# ----------------------------------------
# Example 18:
# Text: um i i would yeah i would recommend it if you have little kids
# Length: 14
# Label: [[1.]]
# Segment: WKA5OygbEKI[17]
# ----------------------------------------
# Example 19:
# Text: but if you dont really have any small friends uh that sounded really perverted small children that you are related to um to take to the movies uh i wouldnt go see it by myself
# Length: 35
# Label: [[-1.4]]
# Segment: WKA5OygbEKI[18]
# ----------------------------------------
# Example 20:
# Text: i definitely will buy it
# Length: 5
# Label: [[0.]]
# Segment: WKA5OygbEKI[19]
# ----------------------------------------
# Example 21:
# Text: but uh it was worth the free movie passes that i used on it
# Length: 14
# Label: [[1.6]]
# Segment: WKA5OygbEKI[20]
# ----------------------------------------
# Example 22:
# Text: and thanks for listening to me ramble
# Length: 7
# Label: [[0.4]]
# Segment: WKA5OygbEKI[21]
# ----------------------------------------
# Example 23:
# Text: not great
# Length: 2
# Label: [[0.8]]
# Segment: X3j2zQgwYgE[0]
# ----------------------------------------
# Example 24:
# Text: sigh i really think what this was missing was that humor and that wit that than the other movies
# Length: 19
# Label: [[-1.6]]
# Segment: X3j2zQgwYgE[1]
# ----------------------------------------
# Example 25:
# Text: um its just not there
# Length: 5
# Label: [[-2.]]
# Segment: X3j2zQgwYgE[2]
# ----------------------------------------
# Example 26:
# Text: its okay
# Length: 2
# Label: [[0.2]]
# Segment: X3j2zQgwYgE[3]
# ----------------------------------------
# Example 27:
# Text: but its really not wonderful
# Length: 5
# Label: [[-2.2]]
# Segment: X3j2zQgwYgE[4]
# ----------------------------------------
# Example 28:
# Text: nothing to rush out and see
# Length: 6
# Label: [[-0.4]]
# Segment: X3j2zQgwYgE[5]
# ----------------------------------------
# Example 29:
# Text: there arent a lot of kids movies out right now so
# Length: 11
# Label: [[0.]]
# Segment: X3j2zQgwYgE[6]
# ----------------------------------------
# Example 30:
# Text: and i guess normally is for adults
# Length: 7
# Label: [[0.]]
# Segment: X3j2zQgwYgE[7]
# ----------------------------------------
# Example 31:
# Text: but lack you know very lackluster
# Length: 6
# Label: [[-2.2]]
# Segment: X3j2zQgwYgE[8]
# ----------------------------------------
# Example 32:
# Text: chuckle be forewarned low expectations
# Length: 5
# Label: [[-1.2]]
# Segment: X3j2zQgwYgE[9]
# ----------------------------------------
# Example 33:
# Text: okay and now its late
# Length: 5
# Label: [[0.4]]
# Segment: X3j2zQgwYgE[10]
# ----------------------------------------
# Example 34:
# Text: save your money wait til it comes out on rental
# Length: 10
# Label: [[-2.]]
# Segment: ZAIRrfG22O0[0]
# ----------------------------------------
# Example 35:
# Text: for me it was a waste of time
# Length: 8
# Label: [[-2.6]]
# Segment: ZAIRrfG22O0[1]
# ----------------------------------------
# Example 36:
# Text: there were a few funny lines
# Length: 6
# Label: [[0.6]]
# Segment: ZAIRrfG22O0[2]
# ----------------------------------------
# Example 37:
# Text: but after an hour i just said enough i had to walk out
# Length: 13
# Label: [[-2.4]]
# Segment: ZAIRrfG22O0[3]
# ----------------------------------------
# Example 38:
# Text: the movie theatre gave me credit to a future movie so that i appreciate it
# Length: 15
# Label: [[1.25]]
# Segment: ZAIRrfG22O0[4]
# ----------------------------------------
# Example 39:
# Text: uh if you like the kind of movie that ben stiller did a night at the museum then you probably would like something uh like this
# Length: 26
# Label: [[1.4]]
# Segment: ZAIRrfG22O0[5]
# ----------------------------------------
# Example 40:
# Text: uh if you didnt like that type of movie then i really dont think youre gonna like this at all
# Length: 20
# Label: [[-1.6]]
# Segment: ZAIRrfG22O0[6]
# ----------------------------------------
# Example 41:
# Text: and youre better off saving your money uh and maybe renting it when it comes out on uh video so
# Length: 20
# Label: [[-1.6]]
# Segment: ZAIRrfG22O0[7]
# ----------------------------------------
# Example 42:
# Text: but uh theres definitely far better movies that you can uh go see than um tongue clicking than so
# Length: 19
# Label: [[-1.6]]
# Segment: ZAIRrfG22O0[8]
# ----------------------------------------
# Example 43:
# Text: nine ninety screening plus i am number four you cant go wrong with that
# Length: 14
# Label: [[2.25]]
# Segment: ZUXBRvtny7o[0]
# ----------------------------------------
# Example 44:
# Text: i was not looking forward to see this movie
# Length: 9
# Label: [[-1.4]]
# Segment: ZUXBRvtny7o[1]
# ----------------------------------------
# Example 45:
# Text: but i went and i dig this movie
# Length: 8
# Label: [[1.]]
# Segment: ZUXBRvtny7o[2]
# ----------------------------------------
# Example 46:
# Text: i was happy to see it
# Length: 6
# Label: [[1.8]]
# Segment: ZUXBRvtny7o[3]
# ----------------------------------------
# Example 47:
# Text: plus i had a good time
# Length: 6
# Label: [[1.4]]
# Segment: ZUXBRvtny7o[4]
# ----------------------------------------
# Example 48:
# Text: im wanting to talk about the good things about this movie
# Length: 11
# Label: [[0.4]]
# Segment: ZUXBRvtny7o[5]
# ----------------------------------------
# Example 49:
# Text: the soundtrack is good its really good some really great songs
# Length: 11
# Label: [[2.4]]
# Segment: ZUXBRvtny7o[6]
# ----------------------------------------
# Example 50:
# Text: and the best thing about that is that all two songs um well not all of them but some of the songs are not well well connected with the scenes
# Length: 30
# Label: [[-1.4]]
# Segment: ZUXBRvtny7o[7]
# ----------------------------------------
# Example 51:
# Text: um anyways the music is good
# Length: 6
# Label: [[1.4]]
# Segment: ZUXBRvtny7o[8]
# ----------------------------------------
# Example 52:
# Text: its stuttering that is a good thing
# Length: 7
# Label: [[1.25]]
# Segment: ZUXBRvtny7o[9]
# ----------------------------------------
# Example 53:
# Text: i really dig the special effects of this movie
# Length: 9
# Label: [[2.6]]
# Segment: ZUXBRvtny7o[10]
# ----------------------------------------
# Example 54:
# Text: like in the middle of the movie it starts with really great action sequences
# Length: 14
# Label: [[1.8]]
# Segment: ZUXBRvtny7o[11]
# ----------------------------------------
# Example 55:
# Text: amazing special effects
# Length: 3
# Label: [[2.2]]
# Segment: ZUXBRvtny7o[12]
# ----------------------------------------
# Example 56:
# Text: and the ending was really really great too
# Length: 8
# Label: [[2.6]]
# Segment: ZUXBRvtny7o[13]
# ----------------------------------------
# Example 57:
# Text: its it was my favorite part of the movie
# Length: 9
# Label: [[0.8]]
# Segment: ZUXBRvtny7o[14]
# ----------------------------------------
# Example 58:
# Text: the main problem of this movie is that this movie is so cheesy
# Length: 13
# Label: [[-2.]]
# Segment: ZUXBRvtny7o[15]
# ----------------------------------------
# Example 59:
# Text: i mean the blood is like twilight with some with some action and with likable characters and that that is important guys
# Length: 22
# Label: [[1.6]]
# Segment: ZUXBRvtny7o[16]
# ----------------------------------------
# Example 60:
# Text: the characters of i am number four are likable
# Length: 9
# Label: [[2.]]
# Segment: ZUXBRvtny7o[17]
# ----------------------------------------
# Example 61:
# Text: not like the characters of of twilight
# Length: 7
# Label: [[0.]]
# Segment: ZUXBRvtny7o[18]
# ----------------------------------------
# Example 62:
# Text: um the ending is open for a sequel
# Length: 8
# Label: [[0.25]]
# Segment: ZUXBRvtny7o[19]
# ----------------------------------------
# Example 63:
# Text: and uh i am looking forward to see a sequel of this movie
# Length: 13
# Label: [[2.]]
# Segment: ZUXBRvtny7o[20]
# ----------------------------------------
# Example 64:
# Text: because i really dig this movie
# Length: 6
# Label: [[0.75]]
# Segment: ZUXBRvtny7o[21]
# ----------------------------------------
# Example 65:
# Text: i really dig this movie
# Length: 5
# Label: [[0.8]]
# Segment: ZUXBRvtny7o[22]
# ----------------------------------------
# Example 66:
# Text: the picture quality was really great
# Length: 6
# Label: [[2.]]
# Segment: ZUXBRvtny7o[23]
# ----------------------------------------
# Example 67:
# Text: i will even pick up this movie on um
# Length: 9
# Label: [[1.8]]
# Segment: ZUXBRvtny7o[24]
# ----------------------------------------
# Example 68:
# Text: i will even pick up this movie on um anyways um the movie for me is three starts out of five stars three solid stars
# Length: 25
# Label: [[2.2]]
# Segment: ZUXBRvtny7o[25]
# ----------------------------------------
# Example 69:
# Text: cause i had a good time
# Length: 6
# Label: [[1.3333334]]
# Segment: ZUXBRvtny7o[26]
# ----------------------------------------
# Example 70:
# Text: and uh this movie i was not looking forward to see this movie
# Length: 13
# Label: [[-1.2]]
# Segment: ZUXBRvtny7o[27]
# ----------------------------------------
# Example 71:
# Text: but it was really good
# Length: 5
# Label: [[2.2]]
# Segment: ZUXBRvtny7o[28]
# ----------------------------------------
# Example 72:
# Text: the acting is its normal its not bad its not bad at all
# Length: 13
# Label: [[0.4]]
# Segment: ZUXBRvtny7o[29]
# ----------------------------------------
# Example 73:
# Text: the likable characters make this movie a really good movie
# Length: 10
# Label: [[1.4]]
# Segment: ZUXBRvtny7o[30]
# ----------------------------------------
# Example 74:
# Text: im willing to go with friends alone with family to watch on a rainy day and if you can watch it at half price at a midnight show screening
# Length: 29
# Label: [[0.4]]
# Segment: ZUXBRvtny7o[31]
# ----------------------------------------
# Example 75:
# Text: cause its worth it
# Length: 4
# Label: [[0.8]]
# Segment: ZUXBRvtny7o[32]
# ----------------------------------------
# Example 76:
# Text: so yeah if you want to have fun this weekend go watch it watch this movie
# Length: 16
# Label: [[2.4]]
# Segment: ZUXBRvtny7o[33]
# ----------------------------------------
# Example 77:
# Text: but i can safely assure you that even if they didnt it would still be a hit
# Length: 17
# Label: [[2.4]]
# Segment: _dI--eQ6qVU[0]
# ----------------------------------------
# Example 78:
# Text: and i loved it
# Length: 4
# Label: [[3.]]
# Segment: _dI--eQ6qVU[1]
# ----------------------------------------
# Example 79:
# Text: i dont know if fans of the comic would be as inclined to say the same because i dont know how much it differs from the comic or radio program that people like so much
# Length: 35
# Label: [[-0.2]]
# Segment: _dI--eQ6qVU[2]
# ----------------------------------------
# Example 80:
# Text: but just going into this a as an observer and someone who has no idea it was a fantastic film it was so much fun
# Length: 25
# Label: [[3.]]
# Segment: _dI--eQ6qVU[3]
# ----------------------------------------
# Example 81:
# Text: and i would tell you right now it was hilarious
# Length: 10
# Label: [[3.]]
# Segment: _dI--eQ6qVU[4]
# ----------------------------------------
# Example 82:
# Text: it was really really funny
# Length: 5
# Label: [[2.8]]
# Segment: _dI--eQ6qVU[5]
# ----------------------------------------
# Example 83:
# Text: and most of you know hes a pretty funny guy
# Length: 10
# Label: [[1.8]]
# Segment: _dI--eQ6qVU[6]
# ----------------------------------------
# Example 84:
# Text: and he up this movie big time totally
# Length: 8
# Label: [[2.6]]
# Segment: _dI--eQ6qVU[7]
# ----------------------------------------
# Example 85:
# Text: so that doesnt surprise me
# Length: 5
# Label: [[0.6]]
# Segment: _dI--eQ6qVU[8]
# ----------------------------------------
# Example 86:
# Text: and the humor it was kind of necessary
# Length: 8
# Label: [[1.]]
# Segment: _dI--eQ6qVU[9]
# ----------------------------------------
# Example 87:
# Text: i feel like if they have inserted the humor into this movie it wouldve been just too serious and kind of boring in a sense
# Length: 25
# Label: [[0.4]]
# Segment: _dI--eQ6qVU[10]
# ----------------------------------------
# Example 88:
# Text: but the humor really just nailed it
# Length: 7
# Label: [[2.6]]
# Segment: _dI--eQ6qVU[11]
# ----------------------------------------
# Example 89:
# Text: and the action sequences in this movie are i
# Length: 9
# Label: [[2.6]]
# Segment: _dI--eQ6qVU[12]
# ----------------------------------------
# Example 90:
# Text: i love when people do this
# Length: 6
# Label: [[2.2]]
# Segment: _dI--eQ6qVU[13]
# ----------------------------------------
# Example 91:
# Text: when they just come up with these totally completely new stylized ways of developing action sequences
# Length: 16
# Label: [[1.6]]
# Segment: _dI--eQ6qVU[14]
# ----------------------------------------
# Example 92:
# Text: coz sure its fun to see a super hero go round and kick bad guy butt you know punch kick whatever bam
# Length: 22
# Label: [[0.8]]
# Segment: _dI--eQ6qVU[15]
# ----------------------------------------
# Example 93:
# Text: but when they figure out a new way to interpret this
# Length: 11
# Label: [[-0.25]]
# Segment: _dI--eQ6qVU[16]
# ----------------------------------------
# Example 94:
# Text: and add something like an extra spark in there
# Length: 9
# Label: [[0.8]]
# Segment: _dI--eQ6qVU[17]
# ----------------------------------------
# Example 95:
# Text: that makes it more visually truly appealing
# Length: 7
# Label: [[1.4]]
# Segment: _dI--eQ6qVU[18]
# ----------------------------------------
# Example 96:
# Text: and just different
# Length: 3
# Label: [[0.2]]
# Segment: _dI--eQ6qVU[19]
# ----------------------------------------
# Example 97:
# Text: it engages the audience more
# Length: 5
# Label: [[1.8]]
# Segment: _dI--eQ6qVU[20]
# ----------------------------------------
# Example 98:
# Text: and i just really enjoyed it
# Length: 6
# Label: [[2.]]
# Segment: _dI--eQ6qVU[21]
# ----------------------------------------
# Example 99:
# Text: the green hornet did something similar
# Length: 6
# Label: [[0.]]
# Segment: _dI--eQ6qVU[22]
# ----------------------------------------
# Example 100:
# Text: but they took a new spin on it
# Length: 8
# Label: [[1.4]]
# Segment: _dI--eQ6qVU[23]
# ----------------------------------------
# Example 101:
# Text: and i just loved it
# Length: 5
# Label: [[2.6]]
# Segment: _dI--eQ6qVU[24]
# ----------------------------------------
# Example 102:
# Text: and i feel like even though the fighting sequences were a little bit long in some places t
# Length: 18
# Label: [[-0.6]]
# Segment: _dI--eQ6qVU[25]
# ----------------------------------------
# Example 103:
# Text: so i meant if i was wearing glasses and was seeing this in i wouldve enjoyed it a lot more
# Length: 20
# Label: [[-0.4]]
# Segment: _dI--eQ6qVU[26]
# ----------------------------------------
# Example 104:
# Text: and i would want the sequences to be even longer rather than shorter
# Length: 13
# Label: [[0.2]]
# Segment: _dI--eQ6qVU[27]
# ----------------------------------------
# Example 105:
# Text: browning is mediocre role
# Length: 4
# Label: [[-2.2]]
# Segment: aiEXnCPZubE[0]
# ----------------------------------------
# Example 106:
# Text: theres never a feeling of star quality with her
# Length: 9
# Label: [[-1.2]]
# Segment: aiEXnCPZubE[1]
# ----------------------------------------
# Example 107:
# Text: she terrible
# Length: 2
# Label: [[-0.6]]
# Segment: aiEXnCPZubE[2]
# ----------------------------------------
# Example 108:
# Text: but quite frankly she is implausible
# Length: 6
# Label: [[-1.6]]
# Segment: aiEXnCPZubE[3]
# ----------------------------------------
# Example 109:
# Text: like the average horror film the uninvited
# Length: 7
# Label: [[0.]]
# Segment: aiEXnCPZubE[4]
# ----------------------------------------
# Example 110:
# Text: and visually stunning
# Length: 3
# Label: [[2.8]]
# Segment: aiEXnCPZubE[5]
# ----------------------------------------
# Example 111:
# Text: and i dont know why people are hating on the film because i really do love it
# Length: 17
# Label: [[2.2]]
# Segment: aiEXnCPZubE[6]
# ----------------------------------------
# Example 112:
# Text: overall browning is just fails to deliver
# Length: 7
# Label: [[-2.4]]
# Segment: aiEXnCPZubE[7]
# ----------------------------------------
# Example 113:
# Text: and is upstaged by many other performances in the film
# Length: 10
# Label: [[-0.2]]
# Segment: aiEXnCPZubE[8]
# ----------------------------------------
# Example 114:
# Text: the supporting cast is either hit or miss
# Length: 8
# Label: [[-0.2]]
# Segment: aiEXnCPZubE[9]
# ----------------------------------------
# Example 115:
# Text: the hits include oscar isaak as the main villain like i said blue jena malone is the soft spoken rocket and the stealing abby cornish is sweet pea a troubled and reluctant young woman in the pack
# Length: 37
# Label: [[0.8]]
# Segment: aiEXnCPZubE[10]
# ----------------------------------------
# Example 116:
# Text: the misses include you know vanessa hudgens
# Length: 7
# Label: [[-0.4]]
# Segment: aiEXnCPZubE[11]
# ----------------------------------------
# Example 117:
# Text: who doesnt have any presents or greatness at all
# Length: 9
# Label: [[-2.]]
# Segment: aiEXnCPZubE[12]
# ----------------------------------------
# Example 118:
# Text: and the other horrible i mean absolutely atrocious carla gugino as doctor vera gorski
# Length: 14
# Label: [[-3.]]
# Segment: aiEXnCPZubE[13]
# ----------------------------------------
# Example 119:
# Text: whos accent is so and
# Length: 5
# Label: [[-2.8]]
# Segment: aiEXnCPZubE[14]
# ----------------------------------------
# Example 120:
# Text: and whos is ridiculous
# Length: 4
# Label: [[-0.4]]
# Segment: aiEXnCPZubE[15]
# ----------------------------------------
# Example 121:
# Text: and her character is also undeveloped and weak
# Length: 8
# Label: [[-1.8]]
# Segment: aiEXnCPZubE[16]
# ----------------------------------------
# Example 122:
# Text: jon hamm and scott glenn could bring you know they could be interesting characters
# Length: 14
# Label: [[0.4]]
# Segment: aiEXnCPZubE[17]
# ----------------------------------------
# Example 123:
# Text: and they could have great back stories
# Length: 7
# Label: [[-0.2]]
# Segment: aiEXnCPZubE[18]
# ----------------------------------------
# Example 124:
# Text: but they you know they they bring nothing to this table
# Length: 11
# Label: [[-2.4]]
# Segment: aiEXnCPZubE[19]
# ----------------------------------------
# Example 125:
# Text: and which hurts the film drastically
# Length: 6
# Label: [[-2.2]]
# Segment: aiEXnCPZubE[20]
# ----------------------------------------
# Example 126:
# Text: because they are interesting characters
# Length: 5
# Label: [[2.]]
# Segment: aiEXnCPZubE[21]
# ----------------------------------------
# Example 127:
# Text: and could have interesting back stories
# Length: 6
# Label: [[0.8]]
# Segment: aiEXnCPZubE[22]
# ----------------------------------------
# Example 128:
# Text: the acting could be better and is very medio
# Length: 9
# Label: [[-1.2]]
# Segment: aiEXnCPZubE[23]
# ----------------------------------------
# Example 129:
# Text: there is some sort of greatness to sucker punch though
# Length: 10
# Label: [[1.6]]
# Segment: aiEXnCPZubE[24]
# ----------------------------------------
# Example 130:
# Text: first the visual effects here are stellar
# Length: 7
# Label: [[2.6]]
# Segment: aiEXnCPZubE[25]
# ----------------------------------------
# Example 131:
# Text: they are unique
# Length: 3
# Label: [[2.8]]
# Segment: aiEXnCPZubE[26]
# ----------------------------------------
# Example 132:
# Text: incredible and
# Length: 2
# Label: [[1.]]
# Segment: aiEXnCPZubE[27]
# ----------------------------------------
# Example 133:
# Text: and just overall superb
# Length: 4
# Label: [[2.6]]
# Segment: aiEXnCPZubE[28]
# ----------------------------------------
# Example 134:
# Text: and the action in the movie is so well used
# Length: 10
# Label: [[2.8]]
# Segment: aiEXnCPZubE[29]
# ----------------------------------------
# Example 135:
# Text: its bad
# Length: 2
# Label: [[-3.]]
# Segment: atnd_PF-Lbs[0]
# ----------------------------------------
# Example 136:
# Text: oh god this is bad
# Length: 5
# Label: [[-3.]]
# Segment: atnd_PF-Lbs[1]
# ----------------------------------------
# Example 137:
# Text: im not even gonna go to the lows to make a whole night video about this movie
# Length: 17
# Label: [[-1.2]]
# Segment: atnd_PF-Lbs[2]
# ----------------------------------------
# Example 138:
# Text: so no now know this i am not a fan of the final destination series
# Length: 15
# Label: [[-2.4]]
# Segment: atnd_PF-Lbs[3]
# ----------------------------------------
# Example 139:
# Text: i hate it
# Length: 3
# Label: [[-2.8]]
# Segment: atnd_PF-Lbs[4]
# ----------------------------------------
# Example 140:
# Text: i might have to watch the first two again or maybe just the first one to stabilize my thoughts on the series
# Length: 22
# Label: [[0.]]
# Segment: atnd_PF-Lbs[5]
# ----------------------------------------
# Example 141:
# Text: but as far as im concerned this series is garbage
# Length: 10
# Label: [[-2.6]]
# Segment: atnd_PF-Lbs[6]
# ----------------------------------------
# Example 142:
# Text: you can sense my excitement when i heard this was being released
# Length: 12
# Label: [[-0.5]]
# Segment: atnd_PF-Lbs[7]
# ----------------------------------------
# Example 143:
# Text: now i wont even talk about acting coz its just so bad
# Length: 12
# Label: [[-2.8]]
# Segment: atnd_PF-Lbs[8]
# ----------------------------------------
# Example 144:
# Text: its a joke really
# Length: 4
# Label: [[-2.4]]
# Segment: atnd_PF-Lbs[9]
# ----------------------------------------
# Example 145:
# Text: now let just get into two things that will possibly attract you to this film the violence and the viewers
# Length: 20
# Label: [[0.4]]
# Segment: atnd_PF-Lbs[10]
# ----------------------------------------
# Example 146:
# Text: viewers please resist from these two
# Length: 6
# Label: [[-1.5]]
# Segment: atnd_PF-Lbs[11]
# ----------------------------------------
# Example 147:
# Text: the violence here is pretty bad
# Length: 6
# Label: [[-2.]]
# Segment: atnd_PF-Lbs[12]
# ----------------------------------------
# Example 148:
# Text: about two creative scenes in here um one being in intestinal journey through the rectum in a swimming pool drain and a tire decapitation that
# Length: 25
# Label: [[-0.4]]
# Segment: atnd_PF-Lbs[13]
# ----------------------------------------
# Example 149:
# Text: the tire decapitation might not sound all that unique
# Length: 9
# Label: [[0.]]
# Segment: atnd_PF-Lbs[14]
# ----------------------------------------
# Example 150:
# Text: but the way its pulled off its like wow that was sick
# Length: 12
# Label: [[2.2]]
# Segment: atnd_PF-Lbs[15]
# ----------------------------------------
# Example 151:
# Text: i mean not the sick like oh my god that was awesome
# Length: 12
# Label: [[1.]]
# Segment: atnd_PF-Lbs[16]
# ----------------------------------------
# Example 152:
# Text: no sick in the oh my god that was crazy that kind of sick
# Length: 14
# Label: [[-0.8]]
# Segment: atnd_PF-Lbs[17]
# ----------------------------------------
# Example 153:
# Text: theres many different ways of saying sick nowadays
# Length: 8
# Label: [[-0.25]]
# Segment: atnd_PF-Lbs[18]
# ----------------------------------------
# Example 154:
# Text: but um yeah wow say that in two two scenes death even nearly unique is a bit harsh
# Length: 18
# Label: [[-0.2]]
# Segment: atnd_PF-Lbs[19]
# ----------------------------------------
# Example 155:
# Text: the race stadium scene and the mall scenes in the beginning and the end where massive amounts of people die in the craziest ways are pretty good for late night buddy viewing you see you know what i mean by late night buddy if
# Length: 44
# Label: [[2.2]]
# Segment: atnd_PF-Lbs[20]
# ----------------------------------------
# Example 156:
# Text: and i was unbelievably shocked how much i loved it
# Length: 10
# Label: [[3.]]
# Segment: bOL9jKpeJRs[0]
# ----------------------------------------
# Example 157:
# Text: it was full of action
# Length: 5
# Label: [[1.6]]
# Segment: bOL9jKpeJRs[1]
# ----------------------------------------
# Example 158:
# Text: great dialogue
# Length: 2
# Label: [[2.]]
# Segment: bOL9jKpeJRs[2]
# ----------------------------------------
# Example 159:
# Text: the characters were so great and well developed
# Length: 8
# Label: [[2.4]]
# Segment: bOL9jKpeJRs[3]
# ----------------------------------------
# Example 160:
# Text: its really just a heart warming story
# Length: 7
# Label: [[1.4]]
# Segment: bOL9jKpeJRs[4]
# ----------------------------------------
# Example 161:
# Text: its a great movie to see over and over again your whole family can see it
# Length: 16
# Label: [[2.4]]
# Segment: bOL9jKpeJRs[5]
# ----------------------------------------
# Example 162:
# Text: its not that violent
# Length: 4
# Label: [[-0.2]]
# Segment: bOL9jKpeJRs[6]
# ----------------------------------------
# Example 163:
# Text: it is a bit violent and not enough so you can bring your year old
# Length: 15
# Label: [[0.]]
# Segment: bOL9jKpeJRs[7]
# ----------------------------------------
# Example 164:
# Text: i really felt for the dad in the because
# Length: 9
# Label: [[1.]]
# Segment: bOL9jKpeJRs[8]
# ----------------------------------------
# Example 165:
# Text: because he was protecting over his family and after they went missing even though theyre a bend of outsiders and have all those powers
# Length: 24
# Label: [[1.2]]
# Segment: bOL9jKpeJRs[9]
# ----------------------------------------
# Example 166:
# Text: the dad was just really protective
# Length: 6
# Label: [[1.8]]
# Segment: bOL9jKpeJRs[10]
# ----------------------------------------
# Example 167:
# Text: and he made sure that hes whole family was safe
# Length: 10
# Label: [[1.4]]
# Segment: bOL9jKpeJRs[11]
# ----------------------------------------
# Example 168:
# Text: very heart warming
# Length: 3
# Label: [[2.2]]
# Segment: bOL9jKpeJRs[12]
# ----------------------------------------
# Example 169:
# Text: very touching
# Length: 2
# Label: [[2.]]
# Segment: bOL9jKpeJRs[13]
# ----------------------------------------
# Example 170:
# Text: brad bird is a great writer and director
# Length: 8
# Label: [[2.6]]
# Segment: bOL9jKpeJRs[14]
# ----------------------------------------
# Example 171:
# Text: um i think that my favorite part of the entire movie was when you find out at the end that the little baby had powers
# Length: 25
# Label: [[2.2]]
# Segment: bOL9jKpeJRs[15]
# ----------------------------------------
# Example 172:
# Text: it was so cute
# Length: 4
# Label: [[2.4]]
# Segment: bOL9jKpeJRs[16]
# ----------------------------------------
# Example 173:
# Text: just the great great movie
# Length: 5
# Label: [[3.]]
# Segment: bOL9jKpeJRs[17]
# ----------------------------------------
# Example 174:
# Text: i really recommend you all see the my
# Length: 8
# Label: [[2.4]]
# Segment: bOL9jKpeJRs[18]
# ----------------------------------------
# Example 175:
# Text: my boyfriend got really excited when i told him we were gonna go see the and
# Length: 16
# Label: [[2.]]
# Segment: bOL9jKpeJRs[19]
# ----------------------------------------
# Example 176:
# Text: and than um when i went to blockbuster and i picked it up and i brought it back home he got really disappointed
# Length: 23
# Label: [[-1.]]
# Segment: bOL9jKpeJRs[20]
# ----------------------------------------
# Example 177:
# Text: i think its because it was such a moving film
# Length: 10
# Label: [[2.]]
# Segment: bOL9jKpeJRs[21]
# ----------------------------------------
# Example 178:
# Text: and i dont think he knows how to handle his emotions in that department
# Length: 14
# Label: [[-1.]]
# Segment: bOL9jKpeJRs[22]
# ----------------------------------------
# Example 179:
# Text: so it was just a little awkward
# Length: 7
# Label: [[-1.]]
# Segment: bOL9jKpeJRs[23]
# ----------------------------------------
# Example 180:
# Text: so it was just a little awkward
# Length: 7
# Label: [[-0.6]]
# Segment: bOL9jKpeJRs[24]
# ----------------------------------------
# Example 181:
# Text: but um weve overcome that
# Length: 5
# Label: [[1.]]
# Segment: bOL9jKpeJRs[25]
# ----------------------------------------
# Example 182:
# Text: you know a lot of people have been talking about the even though it came out such a long time theres
# Length: 21
# Label: [[0.]]
# Segment: bOL9jKpeJRs[26]
# ----------------------------------------
# Example 183:
# Text: theres been a lot of buzz about it lately and you know a lot of controversy over it
# Length: 18
# Label: [[-0.4]]
# Segment: bOL9jKpeJRs[27]
# ----------------------------------------
# Example 184:
# Text: been saying its really intense
# Length: 5
# Label: [[0.4]]
# Segment: bOL9jKpeJRs[28]
# ----------------------------------------
# Example 185:
# Text: i can see that
# Length: 4
# Label: [[0.5]]
# Segment: bOL9jKpeJRs[29]
# ----------------------------------------
# Example 186:
# Text: there are parts that are very intense
# Length: 7
# Label: [[0.]]
# Segment: bOL9jKpeJRs[30]
# ----------------------------------------
# Example 187:
# Text: but for the most part it is a family friendly warm and fuzzy so
# Length: 14
# Label: [[1.]]
# Segment: bOL9jKpeJRs[31]
# ----------------------------------------
# Example 188:
# Text: so go see the i
# Length: 5
# Label: [[2.]]
# Segment: bOL9jKpeJRs[32]
# ----------------------------------------
# Example 189:
# Text: i know you guys are gonna love it
# Length: 8
# Label: [[2.8]]
# Segment: bOL9jKpeJRs[33]
# ----------------------------------------
# Example 190:
# Text: and its really what you wouldve its
# Length: 7
# Label: [[-0.2]]
# Segment: bvLlb-M3UXU[0]
# ----------------------------------------
# Example 191:
# Text: its not a compelling narrative by any means
# Length: 8
# Label: [[-2.2]]
# Segment: bvLlb-M3UXU[1]
# ----------------------------------------
# Example 192:
# Text: theres little to no character development all movie
# Length: 8
# Label: [[-2.4]]
# Segment: bvLlb-M3UXU[2]
# ----------------------------------------
# Example 193:
# Text: and yet this movie is incredibly enjoyable for action fans
# Length: 10
# Label: [[2.2]]
# Segment: bvLlb-M3UXU[3]
# ----------------------------------------
# Example 194:
# Text: and really theres no humongous tale to these guys
# Length: 9
# Label: [[-1.2]]
# Segment: bvLlb-M3UXU[4]
# ----------------------------------------
# Example 195:
# Text: not a complicated story
# Length: 4
# Label: [[-0.4]]
# Segment: bvLlb-M3UXU[5]
# ----------------------------------------
# Example 196:
# Text: but you know what you dont need a formula for an action movie
# Length: 13
# Label: [[-1.]]
# Segment: bvLlb-M3UXU[6]
# ----------------------------------------
# Example 197:
# Text: theres a bad guy guy go take him down thats really all you need
# Length: 14
# Label: [[0.]]
# Segment: bvLlb-M3UXU[7]
# ----------------------------------------
# Example 198:
# Text: this movie essentially was made for three reasons in my opinion
# Length: 11
# Label: [[-0.25]]
# Segment: bvLlb-M3UXU[8]
# ----------------------------------------
# Example 199:
# Text: the first reason is the obvious just to make an exciting enjoyable action film
# Length: 14
# Label: [[1.6]]
# Segment: bvLlb-M3UXU[9]
# ----------------------------------------
# Example 200:
# Text: and thats you know all thats all you really needed to do
# Length: 12
# Label: [[-0.2]]
# Segment: bvLlb-M3UXU[10]
# ----------------------------------------
# Example 201:
# Text: and comes through on that
# Length: 5
# Label: [[1.2]]
# Segment: bvLlb-M3UXU[11]
# ----------------------------------------
# Example 202:
# Text: the second reason this movie was made and in my opinion the real reason it was made again its silvestre telling himself i still got it
# Length: 26
# Label: [[-1.2]]
# Segment: bvLlb-M3UXU[12]
# ----------------------------------------
# Example 203:
# Text: um ive got to give him credit
# Length: 7
# Label: [[1.]]
# Segment: bvLlb-M3UXU[13]
# ----------------------------------------
# Example 204:
# Text: hes in terrific shape for a man twice my age who looks significantly better than me
# Length: 16
# Label: [[2.2]]
# Segment: bvLlb-M3UXU[14]
# ----------------------------------------
# Example 205:
# Text: thats kind of made me feel depressed
# Length: 7
# Label: [[-1.6]]
# Segment: bvLlb-M3UXU[15]
# ----------------------------------------
# Example 206:
# Text: but hey whatever and is showing yeah maybe hes not what he was twenty twenty five years ago but he still has every right to be billed as an action star
# Length: 31
# Label: [[1.2]]
# Segment: bvLlb-M3UXU[16]
# ----------------------------------------
# Example 207:
# Text: theres actually yeah yeah scenes triple stand off with silvestre arnold bruce willis and yeah actually in a way kind of fell hollow
# Length: 23
# Label: [[-1.]]
# Segment: bvLlb-M3UXU[17]
# ----------------------------------------
# Example 208:
# Text: because you know its basically it was knowing these guys arent in the shape they were twenty twenty five years ago
# Length: 21
# Label: [[1.2]]
# Segment: bvLlb-M3UXU[18]
# ----------------------------------------
# Example 209:
# Text: and i dont know if this scene took place twenty years ago when those guys were absolutely prime it wouldve been just um absolutely breath taking monumental moment in cinematic history
# Length: 31
# Label: [[-0.6]]
# Segment: bvLlb-M3UXU[19]
# ----------------------------------------
# Example 210:
# Text: but seeing it today now when it was really nothing more than just a one ship
# Length: 16
# Label: [[-1.2]]
# Segment: bvLlb-M3UXU[20]
# ----------------------------------------
# Example 211:
# Text: it lost a lot of feeling
# Length: 6
# Label: [[-1.8]]
# Segment: bvLlb-M3UXU[21]
# ----------------------------------------
# Example 212:
# Text: it the final you know finally happened u uniting that we all come to expect
# Length: 15
# Label: [[0.8]]
# Segment: bvLlb-M3UXU[22]
# ----------------------------------------
# Example 213:
# Text: it just it felt kind of cut and dry
# Length: 9
# Label: [[-1.4]]
# Segment: bvLlb-M3UXU[23]
# ----------------------------------------
# Example 214:
# Text: which would start the planning that i wish it has happened earlier in their careers
# Length: 15
# Label: [[-1.4]]
# Segment: bvLlb-M3UXU[24]
# ----------------------------------------
# Example 215:
# Text: and i thought this movie was gonna be really good because matt damon was in it
# Length: 16
# Label: [[-0.75]]
# Segment: c5xsKMxpXnc[0]
# ----------------------------------------
# Example 216:
# Text: and i was really disappointed
# Length: 5
# Label: [[-2.6]]
# Segment: c5xsKMxpXnc[1]
# ----------------------------------------
# Example 217:
# Text: like they talk for like five minutes and instantly kiss which is dumb
# Length: 13
# Label: [[-1.8]]
# Segment: c5xsKMxpXnc[2]
# ----------------------------------------
# Example 218:
# Text: what i liked about this movie was the concept was cool
# Length: 11
# Label: [[2.]]
# Segment: c5xsKMxpXnc[3]
# ----------------------------------------
# Example 219:
# Text: but they did not execute it very well
# Length: 8
# Label: [[-2.2]]
# Segment: c5xsKMxpXnc[4]
# ----------------------------------------
# Example 220:
# Text: and they left a lot of plot holes
# Length: 8
# Label: [[-2.]]
# Segment: c5xsKMxpXnc[5]
# ----------------------------------------
# Example 221:
# Text: this movie is terrible for these reasons
# Length: 7
# Label: [[-3.]]
# Segment: c5xsKMxpXnc[6]
# ----------------------------------------
# Example 222:
# Text: number one because the love is forced
# Length: 7
# Label: [[-1.2]]
# Segment: c5xsKMxpXnc[7]
# ----------------------------------------
# Example 223:
# Text: you dont feel that these two people love each other
# Length: 10
# Label: [[-1.4]]
# Segment: c5xsKMxpXnc[8]
# ----------------------------------------
# Example 224:
# Text: and it is very rushed
# Length: 5
# Label: [[-1.2]]
# Segment: c5xsKMxpXnc[9]
# ----------------------------------------
# Example 225:
# Text: i mean you dont see why these two people love each other
# Length: 12
# Label: [[-0.8]]
# Segment: c5xsKMxpXnc[10]
# ----------------------------------------
# Example 226:
# Text: theres no character development really with these two
# Length: 8
# Label: [[-2.]]
# Segment: c5xsKMxpXnc[11]
# ----------------------------------------
# Example 227:
# Text: like they have their own separate character development but none where these two should be together
# Length: 16
# Label: [[-1.2]]
# Segment: c5xsKMxpXnc[12]
# ----------------------------------------
# Example 228:
# Text: theres no reason why they should be together
# Length: 8
# Label: [[-2.]]
# Segment: c5xsKMxpXnc[13]
# ----------------------------------------
# Example 229:
# Text: you dont see why they should like each other cause they dont show it in the movie
# Length: 17
# Label: [[-1.4]]
# Segment: c5xsKMxpXnc[14]
# ----------------------------------------
# Maximum length: 44
# Minimum length: 2

# %%
# Reverse mapping from word IDs to words
id2word = {v: k for k, v in word2id.items()}

# Specify how many examples to examine
num_examples = len(test)  # Ensure we don't exceed the dataset size

max_length = 0
min_length = float('inf')


for idx in range(num_examples):
    # Convert word IDs to words
    words = ' '.join(map(lambda x: id2word[x], test[idx][0][0].tolist()))
    label = test[idx][1]  # Label
    segment = test[idx][2]  # Segment

    length = len(words.split())  # Word count, not character count

    # Track the max and min lengths
    max_length = max(max_length, length)
    min_length = min(min_length, length)

    # Display the information
    print(f"Example {idx+1}:")
    print(f"Text: {words}")
    print(f"Length: {length}")
    print(f"Label: {label}")
    print(f"Segment: {segment}")
    print("-" * 40)  # Separator for readability
    if length == 1:
        example = idx+1

# After the loop, print the max and min lengths
print(f"Maximum length: {max_length}")
print(f"Minimum length: {min_length}")
print(f"example with length 1: {example}")
# Out:
# Example 1:
# Text: oh my gosh bad movie
# Length: 5
# Label: [[-2.8]]
# Segment: c7UH_rxdZv4[0]
# ----------------------------------------
# Example 2:
# Text: really bad movie
# Length: 3
# Label: [[-2.6]]
# Segment: c7UH_rxdZv4[1]
# ----------------------------------------
# Example 3:
# Text: i wish i because
# Length: 4
# Label: [[-0.8]]
# Segment: c7UH_rxdZv4[2]
# ----------------------------------------
# Example 4:
# Text: because i truly love an action flick action comedy flick even better right
# Length: 13
# Label: [[1.6]]
# Segment: c7UH_rxdZv4[3]
# ----------------------------------------
# Example 5:
# Text: but basically seth rogan brought none of the charm that he normally does to his roles
# Length: 16
# Label: [[-2.2]]
# Segment: c7UH_rxdZv4[4]
# ----------------------------------------
# Example 6:
# Text: in fact i have to say that this was one of those obnoxious main characters ive seen a long time
# Length: 20
# Label: [[-2.6]]
# Segment: c7UH_rxdZv4[5]
# ----------------------------------------
# Example 7:
# Text: a horrible protagonist
# Length: 3
# Label: [[-3.]]
# Segment: c7UH_rxdZv4[6]
# ----------------------------------------
# Example 8:
# Text: he um had all the charm of a boy the whole film
# Length: 12
# Label: [[-2.8]]
# Segment: c7UH_rxdZv4[7]
# ----------------------------------------
# Example 9:
# Text: and unlike other films for they kind of a boy but they bring something to the table you know
# Length: 19
# Label: [[-0.4]]
# Segment: c7UH_rxdZv4[8]
# ----------------------------------------
# Example 10:
# Text: theres something that just kind of makes tham so slightly endearing even though theyre kind of the jack ass you know
# Length: 21
# Label: [[0.8]]
# Segment: c7UH_rxdZv4[9]
# ----------------------------------------
# Example 11:
# Text: youre like oh theyre still kind of cool
# Length: 8
# Label: [[1.]]
# Segment: c7UH_rxdZv4[10]
# ----------------------------------------
# Example 12:
# Text: no no hes not funny at all
# Length: 7
# Label: [[-2.8]]
# Segment: c7UH_rxdZv4[11]
# ----------------------------------------
# Example 13:
# Text: um hes just a jack ass
# Length: 6
# Label: [[-2.6]]
# Segment: c7UH_rxdZv4[12]
# ----------------------------------------
# Example 14:
# Text: um kato kicks ass handsome guy
# Length: 6
# Label: [[1.2]]
# Segment: c7UH_rxdZv4[13]
# ----------------------------------------
# Example 15:
# Text: boring
# Length: 1
# Label: [[-2.4]]
# Segment: c7UH_rxdZv4[14]
# ----------------------------------------
# Example 16:
# Text: hes boring
# Length: 2
# Label: [[-2.]]
# Segment: c7UH_rxdZv4[15]
# ----------------------------------------
# Example 17:
# Text: just like look away what he can do he can do lots of stuff
# Length: 14
# Label: [[-1.4]]
# Segment: c7UH_rxdZv4[16]
# ----------------------------------------
# Example 18:
# Text: what wa what hes what w why you have no skills cant
# Length: 12
# Label: [[-2.25]]
# Segment: c7UH_rxdZv4[17]
# ----------------------------------------
# Example 19:
# Text: even tell funny jokes
# Length: 4
# Label: [[-1.8]]
# Segment: c7UH_rxdZv4[18]
# ----------------------------------------
# Example 20:
# Text: and than cameron diaz whos supposed to be plucky i guess but just of useless
# Length: 15
# Label: [[-1.8]]
# Segment: c7UH_rxdZv4[19]
# ----------------------------------------
# Example 21:
# Text: hi im pretty i have a giant smile im supposed to know walk of screen
# Length: 15
# Label: [[-0.8]]
# Segment: c7UH_rxdZv4[20]
# ----------------------------------------
# Example 22:
# Text: um yeah the characters didnt care weather they lived or died
# Length: 11
# Label: [[-2.4]]
# Segment: c7UH_rxdZv4[21]
# ----------------------------------------
# Example 23:
# Text: kato was the only one that was any good whatsoever
# Length: 10
# Label: [[-0.6]]
# Segment: c7UH_rxdZv4[22]
# ----------------------------------------
# Example 24:
# Text: and he was still boring
# Length: 5
# Label: [[-1.8]]
# Segment: c7UH_rxdZv4[23]
# ----------------------------------------
# Example 25:
# Text: um yeah the special effects were ok
# Length: 7
# Label: [[0.]]
# Segment: c7UH_rxdZv4[24]
# ----------------------------------------
# Example 26:
# Text: nothing thats worth going to theaters to see
# Length: 8
# Label: [[-2.6]]
# Segment: c7UH_rxdZv4[25]
# ----------------------------------------
# Example 27:
# Text: and yeah i think the only character who actually showed their motivation anything they did was the villain
# Length: 18
# Label: [[-1.8]]
# Segment: c7UH_rxdZv4[26]
# ----------------------------------------
# Example 28:
# Text: he was the only character that was slightly interesting
# Length: 9
# Label: [[-0.8]]
# Segment: c7UH_rxdZv4[27]
# ----------------------------------------
# Example 29:
# Text: who seemed to have genuine affection for other human beings
# Length: 10
# Label: [[0.6]]
# Segment: c7UH_rxdZv4[28]
# ----------------------------------------
# Example 30:
# Text: and it was kind of interesting
# Length: 6
# Label: [[1.2]]
# Segment: c7UH_rxdZv4[29]
# ----------------------------------------
# Example 31:
# Text: i mean the only character that shows genuine care for other people be the villain
# Length: 15
# Label: [[-1.4]]
# Segment: c7UH_rxdZv4[30]
# ----------------------------------------
# Example 32:
# Text: yeah skip it
# Length: 3
# Label: [[-2.2]]
# Segment: c7UH_rxdZv4[31]
# ----------------------------------------
# Example 33:
# Text: dont see it
# Length: 3
# Label: [[-1.8]]
# Segment: c7UH_rxdZv4[32]
# ----------------------------------------
# Example 34:
# Text: i just got back from the movie theaters to go see a movie ive been waiting probably about a year and a half to two years for
# Length: 27
# Label: [[2.2]]
# Segment: cM3Yna7AavY[0]
# ----------------------------------------
# Example 35:
# Text: if you are as big a fan of disney as i am
# Length: 12
# Label: [[2.5]]
# Segment: cM3Yna7AavY[1]
# ----------------------------------------
# Example 36:
# Text: you know of course i was for the princess and the frog
# Length: 12
# Label: [[1.]]
# Segment: cM3Yna7AavY[2]
# ----------------------------------------
# Example 37:
# Text: i had some high o maybe not high expectations per se but i was expecting this to be a good movie
# Length: 21
# Label: [[0.6]]
# Segment: cM3Yna7AavY[3]
# ----------------------------------------
# Example 38:
# Text: and oh oh my gosh i was blown away
# Length: 9
# Label: [[2.8]]
# Segment: cM3Yna7AavY[4]
# ----------------------------------------
# Example 39:
# Text: anyway oh you can see im still speechless this movie was just beautiful
# Length: 13
# Label: [[2.8]]
# Segment: cM3Yna7AavY[5]
# ----------------------------------------
# Example 40:
# Text: it was incredible see all the different color smooth hand drawn animation you know
# Length: 14
# Label: [[3.]]
# Segment: cM3Yna7AavY[6]
# ----------------------------------------
# Example 41:
# Text: they arent doing so well brother bear
# Length: 7
# Label: [[-0.6]]
# Segment: cM3Yna7AavY[7]
# ----------------------------------------
# Example 42:
# Text: so um i guess people just want to see um computer animated films from now on
# Length: 16
# Label: [[-0.2]]
# Segment: cM3Yna7AavY[8]
# ----------------------------------------
# Example 43:
# Text: i personally i liked atlantis
# Length: 5
# Label: [[1.6]]
# Segment: cM3Yna7AavY[9]
# ----------------------------------------
# Example 44:
# Text: i liked and stich
# Length: 4
# Label: [[2.]]
# Segment: cM3Yna7AavY[10]
# ----------------------------------------
# Example 45:
# Text: i didnt really i mean planet was ok
# Length: 8
# Label: [[-1.]]
# Segment: cM3Yna7AavY[11]
# ----------------------------------------
# Example 46:
# Text: i didnt really like brother bear
# Length: 6
# Label: [[-1.6]]
# Segment: cM3Yna7AavY[12]
# ----------------------------------------
# Example 47:
# Text: and i hated home on the range
# Length: 7
# Label: [[-2.6]]
# Segment: cM3Yna7AavY[13]
# ----------------------------------------
# Example 48:
# Text: it was oh i couldnt even watch it
# Length: 8
# Label: [[-2.4]]
# Segment: cM3Yna7AavY[14]
# ----------------------------------------
# Example 49:
# Text: oh god why did i watch that movie
# Length: 8
# Label: [[-2.8]]
# Segment: cM3Yna7AavY[15]
# ----------------------------------------
# Example 50:
# Text: probably widely considered to be one of the failed one of the most failed movies of the franchise
# Length: 18
# Label: [[-2.6]]
# Segment: cW1FSBF59ik[0]
# ----------------------------------------
# Example 51:
# Text: first of all id like to say little james or jimmy hes so cute hes so anyways
# Length: 17
# Label: [[3.]]
# Segment: cW1FSBF59ik[1]
# ----------------------------------------
# Example 52:
# Text: im pretty sure the first time it you would be kinda freaked out the whole time you know
# Length: 18
# Label: [[-1.]]
# Segment: cW1FSBF59ik[2]
# ----------------------------------------
# Example 53:
# Text: sigh i love when they show all the the war scenes all the the time they spent in the military and shit
# Length: 22
# Label: [[1.6]]
# Segment: cW1FSBF59ik[3]
# ----------------------------------------
# Example 54:
# Text: thats freaking epic
# Length: 3
# Label: [[2.]]
# Segment: cW1FSBF59ik[4]
# ----------------------------------------
# Example 55:
# Text: and i like how it shows
# Length: 6
# Label: [[1.2]]
# Segment: cW1FSBF59ik[5]
# ----------------------------------------
# Example 56:
# Text: its pretty sic
# Length: 3
# Label: [[0.5]]
# Segment: cW1FSBF59ik[6]
# ----------------------------------------
# Example 57:
# Text: i love the name wade
# Length: 5
# Label: [[1.8]]
# Segment: cW1FSBF59ik[7]
# ----------------------------------------
# Example 58:
# Text: but i do not take ryan reynolds seriously for shit in this movie
# Length: 13
# Label: [[-2.4]]
# Segment: cW1FSBF59ik[8]
# ----------------------------------------
# Example 59:
# Text: i love him as an actor based on his looks as a actual talented actor no
# Length: 16
# Label: [[-1.]]
# Segment: cW1FSBF59ik[9]
# ----------------------------------------
# Example 60:
# Text: laughing he certainly doesnt fit the bill either for any marvel movie um zero
# Length: 14
# Label: [[-1.]]
# Segment: cW1FSBF59ik[10]
# ----------------------------------------
# Example 61:
# Text: after he busts all his caps in the air and rans and all the dead bodies fall around him fucking sick
# Length: 21
# Label: [[2.2]]
# Segment: cW1FSBF59ik[11]
# ----------------------------------------
# Example 62:
# Text: same with um wades uh sword scene where hes like sound effects its freaking epic
# Length: 15
# Label: [[2.]]
# Segment: cW1FSBF59ik[12]
# ----------------------------------------
# Example 63:
# Text: um lip smacking sigh marvel once again decided to toss another random bitch in this movie bitch
# Length: 17
# Label: [[-1.2]]
# Segment: cW1FSBF59ik[13]
# ----------------------------------------
# Example 64:
# Text: the random bitch that nobody knows where the fuck she came from why marvel why do you insist on torturing me
# Length: 21
# Label: [[-2.6]]
# Segment: cW1FSBF59ik[14]
# ----------------------------------------
# Example 65:
# Text: lip smacking anyway lip smacking i love sabre tooth in this movie
# Length: 12
# Label: [[3.]]
# Segment: cW1FSBF59ik[15]
# ----------------------------------------
# Example 66:
# Text: he was fucking epic
# Length: 4
# Label: [[2.4]]
# Segment: cW1FSBF59ik[16]
# ----------------------------------------
# Example 67:
# Text: lieb schriever or however the fuck you say his name is a fucking tremendously awesome actor
# Length: 16
# Label: [[2.6]]
# Segment: cW1FSBF59ik[17]
# ----------------------------------------
# Example 68:
# Text: ive never seen him in anything else
# Length: 7
# Label: [[0.2]]
# Segment: cW1FSBF59ik[18]
# ----------------------------------------
# Example 69:
# Text: but in this oh my god i love you
# Length: 9
# Label: [[2.5]]
# Segment: cW1FSBF59ik[19]
# ----------------------------------------
# Example 70:
# Text: and you probably did the best portrayal of sabre tooth ever
# Length: 11
# Label: [[1.6]]
# Segment: cW1FSBF59ik[20]
# ----------------------------------------
# Example 71:
# Text: although i do agree that the look could have been changed to fit the actual sabre like with the right hair
# Length: 21
# Label: [[-1.]]
# Segment: cW1FSBF59ik[21]
# ----------------------------------------
# Example 72:
# Text: um we i love the scene where sabre tooth throws wolverine into the truck that feel good um
# Length: 18
# Label: [[1.4]]
# Segment: cW1FSBF59ik[22]
# ----------------------------------------
# Example 73:
# Text: um fred dukes is the blob
# Length: 6
# Label: [[0.]]
# Segment: cW1FSBF59ik[23]
# ----------------------------------------
# Example 74:
# Text: seeing red riding hood for a really long time
# Length: 9
# Label: [[1.]]
# Segment: cXypl4FnoZo[0]
# ----------------------------------------
# Example 75:
# Text: and um ill just say overall if i think it was good
# Length: 12
# Label: [[1.]]
# Segment: cXypl4FnoZo[1]
# ----------------------------------------
# Example 76:
# Text: but um i liked it
# Length: 5
# Label: [[1.8]]
# Segment: cXypl4FnoZo[2]
# ----------------------------------------
# Example 77:
# Text: i thought it could be really bad um but it didnt look like it would be but it been
# Length: 19
# Label: [[-0.8]]
# Segment: cXypl4FnoZo[3]
# ----------------------------------------
# Example 78:
# Text: um i like did i thought catherine hardwicke did a good job
# Length: 12
# Label: [[1.8]]
# Segment: cXypl4FnoZo[4]
# ----------------------------------------
# Example 79:
# Text: and um i liked you know catherine hardwicke is like you know kind of ridiculous
# Length: 15
# Label: [[-0.6]]
# Segment: cXypl4FnoZo[5]
# ----------------------------------------
# Example 80:
# Text: and she was kind of during twilight
# Length: 7
# Label: [[-1.]]
# Segment: cXypl4FnoZo[6]
# ----------------------------------------
# Example 81:
# Text: but um i i like seeing um female directors because there arent that many compare to you know guy directors
# Length: 20
# Label: [[1.4]]
# Segment: cXypl4FnoZo[7]
# ----------------------------------------
# Example 82:
# Text: so the more like women directors that i see you know i i i like seeing that
# Length: 17
# Label: [[1.2]]
# Segment: cXypl4FnoZo[8]
# ----------------------------------------
# Example 83:
# Text: so um i thought she did great with this movie
# Length: 10
# Label: [[2.]]
# Segment: cXypl4FnoZo[9]
# ----------------------------------------
# Example 84:
# Text: um anyway i would say just you go and see it if you were thinking about seeing it but you sure if it would be worth seeing
# Length: 27
# Label: [[1.4]]
# Segment: cXypl4FnoZo[10]
# ----------------------------------------
# Example 85:
# Text: um i say go see it coz i i enjoyed it now
# Length: 12
# Label: [[2.]]
# Segment: cXypl4FnoZo[11]
# ----------------------------------------
# Example 86:
# Text: um i i dont like well i dont know if i wanna say i dont like this but i wish that it wouldve been different who the wolf actually turned out to be
# Length: 33
# Label: [[-1.]]
# Segment: cXypl4FnoZo[12]
# ----------------------------------------
# Example 87:
# Text: um i just i wouldve like me and louis were saying we were thinking the whole time like who be who be
# Length: 22
# Label: [[-0.6]]
# Segment: cXypl4FnoZo[13]
# ----------------------------------------
# Example 88:
# Text: um we had like we have guessed everybody um this like this random dude who what does he do
# Length: 19
# Label: [[0.]]
# Segment: cXypl4FnoZo[14]
# ----------------------------------------
# Example 89:
# Text: i dont know how to like tell you who he is coz youre gonna be like that doesnt narrow it down at all
# Length: 23
# Label: [[-0.6]]
# Segment: cXypl4FnoZo[15]
# ----------------------------------------
# Example 90:
# Text: its just like this this character whos kind of random
# Length: 10
# Label: [[-0.6]]
# Segment: cXypl4FnoZo[16]
# ----------------------------------------
# Example 91:
# Text: and he i dont i think he maybe he got mad when hah i dont know
# Length: 16
# Label: [[-0.25]]
# Segment: cXypl4FnoZo[17]
# ----------------------------------------
# Example 92:
# Text: um but yeah whatever um he we thought it would be him because they showing him a lot but they showed him enough to they kind of be like oh it was him in the end
# Length: 36
# Label: [[0.8]]
# Segment: cXypl4FnoZo[18]
# ----------------------------------------
# Example 93:
# Text: um a i wish we wished that it wouldve been um the guy
# Length: 13
# Label: [[-1.]]
# Segment: cXypl4FnoZo[19]
# ----------------------------------------
# Example 94:
# Text: um we wished it wouldve been peter because it wouldve made sense throat cleaning that um peter
# Length: 17
# Label: [[-0.6]]
# Segment: cXypl4FnoZo[20]
# ----------------------------------------
# Example 95:
# Text: like we wanted to be that she knew um amanda character knew it was peter but was pretending that she didnt so that she got a reason to run away with him and they could be together
# Length: 37
# Label: [[0.2]]
# Segment: cXypl4FnoZo[21]
# ----------------------------------------
# Example 96:
# Text: and it would make sense
# Length: 5
# Label: [[0.4]]
# Segment: cXypl4FnoZo[22]
# ----------------------------------------
# Example 97:
# Text: and and we kind of wanted it to be like but not that but that wouldve been good right like coz that it would give tham a reason coz they wanted to get married but they because she was gonna marry the other guy
# Length: 44
# Label: [[0.2]]
# Segment: cXypl4FnoZo[23]
# ----------------------------------------
# Example 98:
# Text: and another thing the other guy she was supposed to marry was a hundred times better looking than peter
# Length: 19
# Label: [[-1.2]]
# Segment: cXypl4FnoZo[24]
# ----------------------------------------
# Example 99:
# Text: was nicer than peter
# Length: 4
# Label: [[0.6]]
# Segment: cXypl4FnoZo[25]
# ----------------------------------------
# Example 100:
# Text: i was saying if not gonna marry him i will
# Length: 10
# Label: [[0.8]]
# Segment: cXypl4FnoZo[26]
# ----------------------------------------
# Example 101:
# Text: because i thought he was um peter was annoying
# Length: 9
# Label: [[-2.2]]
# Segment: cXypl4FnoZo[27]
# ----------------------------------------
# Example 102:
# Text: i didnt like peter
# Length: 4
# Label: [[-1.4]]
# Segment: cXypl4FnoZo[28]
# ----------------------------------------
# Example 103:
# Text: who have named themselves after the places um to which they have traveled in which i think is a really nice as
# Length: 22
# Label: [[2.]]
# Segment: d3_k5Xpfmik[0]
# ----------------------------------------
# Example 104:
# Text: a basically um like
# Length: 4
# Label: [[0.]]
# Segment: d3_k5Xpfmik[1]
# ----------------------------------------
# Example 105:
# Text: the um cross of personality is really um charismatic and dynamic
# Length: 11
# Label: [[2.]]
# Segment: d3_k5Xpfmik[2]
# ----------------------------------------
# Example 106:
# Text: um it just goes to show that you really cant trust anyone in this situation
# Length: 15
# Label: [[-1.]]
# Segment: d3_k5Xpfmik[3]
# ----------------------------------------
# Example 107:
# Text: is a really horror comedy
# Length: 5
# Label: [[2.2]]
# Segment: d3_k5Xpfmik[4]
# ----------------------------------------
# Example 108:
# Text: as it contains um rea really well done and faithful to the zombie horror sub and
# Length: 16
# Label: [[1.6]]
# Segment: d3_k5Xpfmik[5]
# ----------------------------------------
# Example 109:
# Text: and um while also maintains its kind of detached um satire of the genre
# Length: 14
# Label: [[0.4]]
# Segment: d3_k5Xpfmik[6]
# ----------------------------------------
# Example 110:
# Text: but its really well done
# Length: 5
# Label: [[2.2]]
# Segment: d3_k5Xpfmik[7]
# ----------------------------------------
# Example 111:
# Text: because um you really wanna see it for yourself
# Length: 9
# Label: [[1.4]]
# Segment: d3_k5Xpfmik[8]
# ----------------------------------------
# Example 112:
# Text: um its basically a um slow motion show case of different events
# Length: 12
# Label: [[0.4]]
# Segment: d3_k5Xpfmik[9]
# ----------------------------------------
# Example 113:
# Text: this credit sequence i think is the best credit sequence um since watchman
# Length: 13
# Label: [[2.4]]
# Segment: d3_k5Xpfmik[10]
# ----------------------------------------
# Example 114:
# Text: and i honestly think if we have seen watchman this would be the best credit sequence of the year
# Length: 19
# Label: [[2.]]
# Segment: d3_k5Xpfmik[11]
# ----------------------------------------
# Example 115:
# Text: yeah it really is good i mean
# Length: 7
# Label: [[2.2]]
# Segment: d3_k5Xpfmik[12]
# ----------------------------------------
# Example 116:
# Text: it uses um and this just doesnt apply to the um um credit se sequence on it own but to the movie as a whole it really knows how to use s slow motion without making it a gimmick
# Length: 39
# Label: [[2.]]
# Segment: d3_k5Xpfmik[13]
# ----------------------------------------
# Example 117:
# Text: the sequences of the beginning of the film which features columbus some of his rules um to surviving a zombie are really well done
# Length: 24
# Label: [[2.6]]
# Segment: d3_k5Xpfmik[14]
# ----------------------------------------
# Example 118:
# Text: the sequence is really well done
# Length: 6
# Label: [[2.]]
# Segment: d3_k5Xpfmik[15]
# ----------------------------------------
# Example 119:
# Text: but its a very kind of um stylistic edge on it
# Length: 11
# Label: [[1.6]]
# Segment: d3_k5Xpfmik[16]
# ----------------------------------------
# Example 120:
# Text: it its almost like um imagining tarantino directed a zombie movie
# Length: 11
# Label: [[0.8]]
# Segment: d3_k5Xpfmik[17]
# ----------------------------------------
# Example 121:
# Text: and the style of the film like the um the free streams of slow motion the um the jump cooks and all that stuff feels very kind of um tarantino ask
# Length: 31
# Label: [[0.2]]
# Segment: d3_k5Xpfmik[18]
# ----------------------------------------
# Example 122:
# Text: this movie was horrible
# Length: 4
# Label: [[-2.8]]
# Segment: d6hH302o4v8[0]
# ----------------------------------------
# Example 123:
# Text: nicholas cage should not do these kind of movies
# Length: 9
# Label: [[-1.8]]
# Segment: d6hH302o4v8[1]
# ----------------------------------------
# Example 124:
# Text: hes always in these kinds of movies all this sorcerer witch voodoo kind of movies
# Length: 15
# Label: [[0.2]]
# Segment: d6hH302o4v8[2]
# ----------------------------------------
# Example 125:
# Text: and its getting really tiring
# Length: 5
# Label: [[-1.6]]
# Segment: d6hH302o4v8[3]
# ----------------------------------------
# Example 126:
# Text: hes horrible at it
# Length: 4
# Label: [[-1.3333334]]
# Segment: d6hH302o4v8[4]
# ----------------------------------------
# Example 127:
# Text: no one takes him seriously
# Length: 5
# Label: [[-2.]]
# Segment: d6hH302o4v8[5]
# ----------------------------------------
# Example 128:
# Text: w w w when hes onscreen i want to punch him in the face
# Length: 14
# Label: [[-2.8]]
# Segment: d6hH302o4v8[6]
# ----------------------------------------
# Example 129:
# Text: hes very boring
# Length: 3
# Label: [[-2.2]]
# Segment: d6hH302o4v8[7]
# ----------------------------------------
# Example 130:
# Text: he wa he was very annoying
# Length: 6
# Label: [[-2.4]]
# Segment: d6hH302o4v8[8]
# ----------------------------------------
# Example 131:
# Text: he didnt know what he was talking about
# Length: 8
# Label: [[-1.2]]
# Segment: d6hH302o4v8[9]
# ----------------------------------------
# Example 132:
# Text: and i was sitting in the theatre sleeping
# Length: 8
# Label: [[-1.]]
# Segment: d6hH302o4v8[10]
# ----------------------------------------
# Example 133:
# Text: he was very good in but
# Length: 6
# Label: [[1.4]]
# Segment: d6hH302o4v8[11]
# ----------------------------------------
# Example 134:
# Text: but in this movie he good at all
# Length: 8
# Label: [[-2.]]
# Segment: d6hH302o4v8[12]
# ----------------------------------------
# Example 135:
# Text: i i i didnt really care for his character at all
# Length: 11
# Label: [[-1.8]]
# Segment: d6hH302o4v8[13]
# ----------------------------------------
# Example 136:
# Text: hes very boring as well
# Length: 5
# Label: [[-1.75]]
# Segment: d6hH302o4v8[14]
# ----------------------------------------
# Example 137:
# Text: whole movies very boring
# Length: 4
# Label: [[-2.]]
# Segment: d6hH302o4v8[15]
# ----------------------------------------
# Example 138:
# Text: it made no sense
# Length: 4
# Label: [[-2.]]
# Segment: d6hH302o4v8[16]
# ----------------------------------------
# Example 139:
# Text: i didnt really care about it at all
# Length: 8
# Label: [[-2.]]
# Segment: d6hH302o4v8[17]
# ----------------------------------------
# Example 140:
# Text: i had no idea why i even saw this movie
# Length: 10
# Label: [[-2.8]]
# Segment: d6hH302o4v8[18]
# ----------------------------------------
# Example 141:
# Text: uh the trailer looked like it could be a little g good
# Length: 12
# Label: [[1.]]
# Segment: d6hH302o4v8[19]
# ----------------------------------------
# Example 142:
# Text: but when i saw it was just totally boring
# Length: 9
# Label: [[-2.4]]
# Segment: d6hH302o4v8[20]
# ----------------------------------------
# Example 143:
# Text: but it really made well
# Length: 5
# Label: [[-1.]]
# Segment: d6hH302o4v8[21]
# ----------------------------------------
# Example 144:
# Text: and this is the worst by far
# Length: 7
# Label: [[-2.6]]
# Segment: d6hH302o4v8[22]
# ----------------------------------------
# Example 145:
# Text: it was very very very boring
# Length: 6
# Label: [[-2.8]]
# Segment: d6hH302o4v8[23]
# ----------------------------------------
# Example 146:
# Text: made no sense
# Length: 3
# Label: [[-1.6]]
# Segment: d6hH302o4v8[24]
# ----------------------------------------
# Example 147:
# Text: action were very dumb
# Length: 4
# Label: [[-2.6]]
# Segment: d6hH302o4v8[25]
# ----------------------------------------
# Example 148:
# Text: i hated it
# Length: 3
# Label: [[-2.6]]
# Segment: d6hH302o4v8[26]
# ----------------------------------------
# Example 149:
# Text: but the last half hour of the movie it felt like they had added like a orgasm
# Length: 17
# Label: [[-1.]]
# Segment: d6hH302o4v8[27]
# ----------------------------------------
# Example 150:
# Text: you know they just tried uh with the that they put t t t they they threw so much at you
# Length: 21
# Label: [[-1.8]]
# Segment: d6hH302o4v8[28]
# ----------------------------------------
# Example 151:
# Text: and it was awful
# Length: 4
# Label: [[-2.8]]
# Segment: d6hH302o4v8[29]
# ----------------------------------------
# Example 152:
# Text: like it was like spewing last half hour of the movie
# Length: 11
# Label: [[-1.4]]
# Segment: d6hH302o4v8[30]
# ----------------------------------------
# Example 153:
# Text: like every single scene was it
# Length: 6
# Label: [[-0.6]]
# Segment: d6hH302o4v8[31]
# ----------------------------------------
# Example 154:
# Text: it was terrible
# Length: 3
# Label: [[-3.]]
# Segment: d6hH302o4v8[32]
# ----------------------------------------
# Example 155:
# Text: i hated it
# Length: 3
# Label: [[-3.]]
# Segment: d6hH302o4v8[33]
# ----------------------------------------
# Example 156:
# Text: i was sitting there in the theatre laughing how bad the movie was at some points
# Length: 16
# Label: [[-1.6]]
# Segment: d6hH302o4v8[34]
# ----------------------------------------
# Example 157:
# Text: uh huh how about the acting and the action was was just so dull
# Length: 14
# Label: [[-2.2]]
# Segment: d6hH302o4v8[35]
# ----------------------------------------
# Example 158:
# Text: and boring
# Length: 2
# Label: [[-2.2]]
# Segment: d6hH302o4v8[36]
# ----------------------------------------
# Example 159:
# Text: do not see this movie
# Length: 5
# Label: [[-3.]]
# Segment: d6hH302o4v8[37]
# ----------------------------------------
# Example 160:
# Text: season of the witch was horrible acting
# Length: 7
# Label: [[-3.]]
# Segment: d6hH302o4v8[38]
# ----------------------------------------
# Example 161:
# Text: dull
# Length: 1
# Label: [[-1.]]
# Segment: d6hH302o4v8[39]
# ----------------------------------------
# Example 162:
# Text: just dont see this movie
# Length: 5
# Label: [[-2.4]]
# Segment: d6hH302o4v8[40]
# ----------------------------------------
# Example 163:
# Text: i dont know why i even saw it
# Length: 8
# Label: [[-1.4]]
# Segment: d6hH302o4v8[41]
# ----------------------------------------
# Example 164:
# Text: so season of the witch is rated out of so
# Length: 10
# Label: [[-2.5]]
# Segment: d6hH302o4v8[42]
# ----------------------------------------
# Example 165:
# Text: changes and growth of the characters its a path of discovery
# Length: 11
# Label: [[0.]]
# Segment: dq3Nf_lMPnE[0]
# ----------------------------------------
# Example 166:
# Text: the last minute title that they threw on at the theaters
# Length: 11
# Label: [[-1.4]]
# Segment: dq3Nf_lMPnE[1]
# ----------------------------------------
# Example 167:
# Text: dreamworks is confusing me
# Length: 4
# Label: [[-1.2]]
# Segment: dq3Nf_lMPnE[2]
# ----------------------------------------
# Example 168:
# Text: they solved this dilemma by removing the past within its a wonderful life twist of new betty everything
# Length: 18
# Label: [[-0.4]]
# Segment: dq3Nf_lMPnE[3]
# ----------------------------------------
# Example 169:
# Text: everything that happened in and are wiped away
# Length: 8
# Label: [[1.2]]
# Segment: dq3Nf_lMPnE[4]
# ----------------------------------------
# Example 170:
# Text: not a bad idea for a sequel
# Length: 7
# Label: [[0.8]]
# Segment: dq3Nf_lMPnE[5]
# ----------------------------------------
# Example 171:
# Text: but also not very original
# Length: 5
# Label: [[-2.]]
# Segment: dq3Nf_lMPnE[6]
# ----------------------------------------
# Example 172:
# Text: misses out on the magic that made the first film a real joy to view
# Length: 15
# Label: [[0.6]]
# Segment: dq3Nf_lMPnE[7]
# ----------------------------------------
# Example 173:
# Text: gone are the wickedly satirical stand ups of the world of fairy tales
# Length: 13
# Label: [[-0.8]]
# Segment: dq3Nf_lMPnE[8]
# ----------------------------------------
# Example 174:
# Text: and also the cute wings to pop culture
# Length: 8
# Label: [[1.]]
# Segment: dq3Nf_lMPnE[9]
# ----------------------------------------
# Example 175:
# Text: and their place is a run of the mill animated action adventure plot with a few chuckles in
# Length: 18
# Label: [[-0.6]]
# Segment: dq3Nf_lMPnE[10]
# ----------------------------------------
# Example 176:
# Text: it seems like the writers and creators took the easy way out
# Length: 12
# Label: [[-1.6]]
# Segment: dq3Nf_lMPnE[11]
# ----------------------------------------
# Example 177:
# Text: if award for the great characters of in his supporting cast they are still voiced by the original stars mike myers eddie murphy cameron diaz and antonio banderas the film would be a real bust
# Length: 35
# Label: [[-1.2]]
# Segment: dq3Nf_lMPnE[12]
# ----------------------------------------
# Example 178:
# Text: unless your kids are dying to see it id wait for the i
# Length: 13
# Label: [[-1.8]]
# Segment: dq3Nf_lMPnE[13]
# ----------------------------------------
# Example 179:
# Text: i give forever after directed by mike mitchell a grade of b minus
# Length: 13
# Label: [[1.]]
# Segment: dq3Nf_lMPnE[14]
# ----------------------------------------
# Example 180:
# Text: um so channing tatum and marlon are transporting it they get ambushed by um i think its cobra its kinda hard to explain it
# Length: 24
# Label: [[0.4]]
# Segment: etzxEpPuc6I[0]
# ----------------------------------------
# Example 181:
# Text: like the dude that made the technologies i i cant ruin the movie
# Length: 13
# Label: [[1.2]]
# Segment: etzxEpPuc6I[1]
# ----------------------------------------
# Example 182:
# Text: um from there it just goes into the
# Length: 8
# Label: [[-1.6]]
# Segment: etzxEpPuc6I[2]
# ----------------------------------------
# Example 183:
# Text: the thing about this movie is like i i i wanna compare it to transformers and i actually did
# Length: 19
# Label: [[0.8]]
# Segment: etzxEpPuc6I[3]
# ----------------------------------------
# Example 184:
# Text: i was like you know theyre both hasbro toys theyre both moves that are com made for children
# Length: 18
# Label: [[0.]]
# Segment: etzxEpPuc6I[4]
# ----------------------------------------
# Example 185:
# Text: but they have a lot of adult situations in it
# Length: 10
# Label: [[0.4]]
# Segment: etzxEpPuc6I[5]
# ----------------------------------------
# Example 186:
# Text: but the thing about joe compared to transformers is didnt know what it wanted to do
# Length: 16
# Label: [[-1.2]]
# Segment: etzxEpPuc6I[6]
# ----------------------------------------
# Example 187:
# Text: like in some parts you had people getting killed and the next part you had jokes and stupid humor and all that other crap
# Length: 24
# Label: [[-1.]]
# Segment: etzxEpPuc6I[7]
# ----------------------------------------
# Example 188:
# Text: as for joe was it was just like laughing its the the plot the the acting is terrible
# Length: 18
# Label: [[-2.8]]
# Segment: etzxEpPuc6I[8]
# ----------------------------------------
# Example 189:
# Text: the plot is ridiculous but no one took it seriously
# Length: 10
# Label: [[-1.4]]
# Segment: etzxEpPuc6I[9]
# ----------------------------------------
# Example 190:
# Text: like like even the actors were just like you know its a movie about a fucking toy
# Length: 17
# Label: [[-1.6]]
# Segment: etzxEpPuc6I[10]
# ----------------------------------------
# Example 191:
# Text: laughing so theyre just sitting there
# Length: 6
# Label: [[0.6666667]]
# Segment: etzxEpPuc6I[11]
# ----------------------------------------
# Example 192:
# Text: like this one part where the girls like my daddy taught me to win win and then looking in the camera and im like wow like um this pretty bad
# Length: 30
# Label: [[-2.2]]
# Segment: etzxEpPuc6I[12]
# ----------------------------------------
# Example 193:
# Text: but the they they knew it was just a movie about a a a a doll so they didnt take it seriously
# Length: 22
# Label: [[-1.2]]
# Segment: etzxEpPuc6I[13]
# ----------------------------------------
# Example 194:
# Text: like knowing is half the battle
# Length: 6
# Label: [[0.2]]
# Segment: etzxEpPuc6I[14]
# ----------------------------------------
# Example 195:
# Text: but the movie was well it was ridiculously terrible
# Length: 9
# Label: [[-2.4]]
# Segment: etzxEpPuc6I[15]
# ----------------------------------------
# Example 196:
# Text: like it was like the acting was terrible the action made up for it
# Length: 14
# Label: [[-0.4]]
# Segment: etzxEpPuc6I[16]
# ----------------------------------------
# Example 197:
# Text: there was parts this ive seen some creative depths in this movie ive never seen before
# Length: 16
# Label: [[1.4]]
# Segment: etzxEpPuc6I[17]
# ----------------------------------------
# Example 198:
# Text: ive seen people get shot in the eye you know and that would be it but people getting shot in the eye and then the they heads explode and then some dude get his torso cut open and and some dudes hanging out of the car his head got blown off and freaking people are flying and jumping
# Length: 58
# Label: [[-0.5]]
# Segment: etzxEpPuc6I[18]
# ----------------------------------------
# Example 199:
# Text: what whatever the name is too long
# Length: 7
# Label: [[-1.2]]
# Segment: f9O3YtZ2VfI[0]
# ----------------------------------------
# Example 200:
# Text: its a very interesting idea
# Length: 5
# Label: [[1.25]]
# Segment: f9O3YtZ2VfI[1]
# ----------------------------------------
# Example 201:
# Text: and its they looked like it had a good core
# Length: 10
# Label: [[0.6]]
# Segment: f9O3YtZ2VfI[2]
# ----------------------------------------
# Example 202:
# Text: but it just too many problems with it
# Length: 8
# Label: [[-2.4]]
# Segment: f9O3YtZ2VfI[3]
# ----------------------------------------
# Example 203:
# Text: the first problem is that its all told in flashback from a point just before katrina hits new orleans
# Length: 19
# Label: [[-1.8]]
# Segment: f9O3YtZ2VfI[4]
# ----------------------------------------
# Example 204:
# Text: i didnt need any of that crap
# Length: 7
# Label: [[-2.6]]
# Segment: f9O3YtZ2VfI[5]
# ----------------------------------------
# Example 205:
# Text: i dont need it all told in flashback
# Length: 8
# Label: [[-1.2]]
# Segment: f9O3YtZ2VfI[6]
# ----------------------------------------
# Example 206:
# Text: i dont need the added element of katrina
# Length: 8
# Label: [[-1.8]]
# Segment: f9O3YtZ2VfI[7]
# ----------------------------------------
# Example 207:
# Text: it it just its too much crap in here
# Length: 9
# Label: [[-2.2]]
# Segment: f9O3YtZ2VfI[8]
# ----------------------------------------
# Example 208:
# Text: the the movies is too long
# Length: 6
# Label: [[-2.]]
# Segment: f9O3YtZ2VfI[9]
# ----------------------------------------
# Example 209:
# Text: they just need to cut that out
# Length: 7
# Label: [[-0.8]]
# Segment: f9O3YtZ2VfI[10]
# ----------------------------------------
# Example 210:
# Text: another thing is we dont need his entire life
# Length: 9
# Label: [[-1.8]]
# Segment: f9O3YtZ2VfI[11]
# ----------------------------------------
# Example 211:
# Text: th we do not need the entire span birth to death
# Length: 11
# Label: [[-1.6]]
# Segment: f9O3YtZ2VfI[12]
# ----------------------------------------
# Example 212:
# Text: just give me a nice interesting choke
# Length: 7
# Label: [[1.2]]
# Segment: f9O3YtZ2VfI[13]
# ----------------------------------------
# Example 213:
# Text: and scale it down on like two hours
# Length: 8
# Label: [[-1.2]]
# Segment: f9O3YtZ2VfI[14]
# ----------------------------------------
# Example 214:
# Text: this also falls in to the is very popular these days if you do a whole all of um
# Length: 19
# Label: [[-1.]]
# Segment: f9O3YtZ2VfI[15]
# ----------------------------------------
# Example 215:
# Text: um and if youre gonna do mostly just make an animated movie
# Length: 12
# Label: [[-2.]]
# Segment: f9O3YtZ2VfI[16]
# ----------------------------------------
# Example 216:
# Text: this looks like it just has a polyurethane coating on it
# Length: 11
# Label: [[-1.]]
# Segment: f9O3YtZ2VfI[17]
# ----------------------------------------
# Example 217:
# Text: makes him look too too good
# Length: 6
# Label: [[-0.6]]
# Segment: f9O3YtZ2VfI[18]
# ----------------------------------------
# Example 218:
# Text: but dont get me wrong its not all bad
# Length: 9
# Label: [[-0.4]]
# Segment: f9O3YtZ2VfI[19]
# ----------------------------------------
# Example 219:
# Text: its got my two favorite in it tilda swinton and cate blanchett
# Length: 12
# Label: [[2.]]
# Segment: f9O3YtZ2VfI[20]
# ----------------------------------------
# Example 220:
# Text: like i said before is a very interesting idea
# Length: 9
# Label: [[1.4]]
# Segment: f9O3YtZ2VfI[21]
# ----------------------------------------
# Example 221:
# Text: and they did a lot of good things with it
# Length: 10
# Label: [[1.6]]
# Segment: f9O3YtZ2VfI[22]
# ----------------------------------------
# Example 222:
# Text: but its its like someone made you a kick ass sandwich but they put mayonnaise on it and you dont like mayonnaise and its not like tomato or lettuce where you can pick it off no its got it mayonnaise in its all over everything and now youre stuck with this kick ass sandwich that would be kick ass if it didnt have mayonnaise on it but it has mayonnaise on it or you go make another sandwich go make another sandwich
# Length: 82
# Label: [[-2.6]]
# Segment: f9O3YtZ2VfI[23]
# ----------------------------------------
# Example 223:
# Text: this movie is just not quite good enough
# Length: 8
# Label: [[-1.4]]
# Segment: f9O3YtZ2VfI[24]
# ----------------------------------------
# Example 224:
# Text: i really liked david finch
# Length: 5
# Label: [[1.4]]
# Segment: f9O3YtZ2VfI[25]
# ----------------------------------------
# Example 225:
# Text: i liked all the um i like the cast
# Length: 9
# Label: [[1.6]]
# Segment: f9O3YtZ2VfI[26]
# ----------------------------------------
# Example 226:
# Text: but and its a good story
# Length: 6
# Label: [[1.2]]
# Segment: f9O3YtZ2VfI[27]
# ----------------------------------------
# Example 227:
# Text: but clap huh its a pass
# Length: 6
# Label: [[-2.]]
# Segment: f9O3YtZ2VfI[28]
# ----------------------------------------
# Example 228:
# Text: my neighbor probably thinks im crazy yelling about movies to a camera
# Length: 12
# Label: [[-1.]]
# Segment: f9O3YtZ2VfI[29]
# ----------------------------------------
# Example 229:
# Text: so you better appreciate this review
# Length: 6
# Label: [[0.25]]
# Segment: f_pcplsH_V0[0]
# ----------------------------------------
# Example 230:
# Text: but to any of you who are i expect a thumbs up
# Length: 12
# Label: [[1.4]]
# Segment: f_pcplsH_V0[1]
# ----------------------------------------
# Example 231:
# Text: theyre back to you having two killers thankfully
# Length: 8
# Label: [[0.8]]
# Segment: f_pcplsH_V0[2]
# ----------------------------------------
# Example 232:
# Text: because it does make a lot more sense having the killer be able to be everywhere if theres two of them
# Length: 21
# Label: [[0.5]]
# Segment: f_pcplsH_V0[3]
# ----------------------------------------
# Example 233:
# Text: my overall opinion of the results of this process are its better than scream and
# Length: 15
# Label: [[1.2]]
# Segment: f_pcplsH_V0[4]
# ----------------------------------------
# Example 234:
# Text: and actually is better than scream a
# Length: 7
# Label: [[1.6]]
# Segment: f_pcplsH_V0[5]
# ----------------------------------------
# Example 235:
# Text: a lot of people dont like scream i
# Length: 8
# Label: [[0.]]
# Segment: f_pcplsH_V0[6]
# ----------------------------------------
# Example 236:
# Text: i think its highly underrated
# Length: 5
# Label: [[0.8]]
# Segment: f_pcplsH_V0[7]
# ----------------------------------------
# Example 237:
# Text: i hated scream but
# Length: 4
# Label: [[-2.4]]
# Segment: f_pcplsH_V0[8]
# ----------------------------------------
# Example 238:
# Text: but i think this one did beat scream now
# Length: 9
# Label: [[1.2]]
# Segment: f_pcplsH_V0[9]
# ----------------------------------------
# Example 239:
# Text: now i didnt really like the first hour that much though
# Length: 11
# Label: [[-0.4]]
# Segment: f_pcplsH_V0[10]
# ----------------------------------------
# Example 240:
# Text: im sure you all remember the stab movies that were based on the scream movies or the experiences of sidney in universe so that people could comment on the killers the movies or following up the movies well in the first hour those become way way way too much of a plot point basically
# Length: 54
# Label: [[-0.8]]
# Segment: f_pcplsH_V0[11]
# ----------------------------------------
# Example 241:
# Text: i think i want to see it
# Length: 7
# Label: [[1.6]]
# Segment: f_pcplsH_V0[12]
# ----------------------------------------
# Example 242:
# Text: but it actually basically makes the characters not just of the genre within which they are in but of their own franchise to a ridiculous extent
# Length: 26
# Label: [[-1.]]
# Segment: f_pcplsH_V0[13]
# ----------------------------------------
# Example 243:
# Text: im just kinda like no this is going to far
# Length: 10
# Label: [[-1.]]
# Segment: f_pcplsH_V0[14]
# ----------------------------------------
# Example 244:
# Text: it only had the potential to be a film that was both and action packed
# Length: 15
# Label: [[-0.4]]
# Segment: fvVhgmXxadc[0]
# ----------------------------------------
# Example 245:
# Text: but unfortunately its just an ugly wild violent and sadistic exercise
# Length: 11
# Label: [[-2.8]]
# Segment: fvVhgmXxadc[1]
# ----------------------------------------
# Example 246:
# Text: that i got very little joy out of
# Length: 8
# Label: [[-2.2]]
# Segment: fvVhgmXxadc[2]
# ----------------------------------------
# Example 247:
# Text: in fact i got mostly pain out of it
# Length: 9
# Label: [[-2.8]]
# Segment: fvVhgmXxadc[3]
# ----------------------------------------
# Example 248:
# Text: thats pretty heavily inferred in the opening sequence
# Length: 8
# Label: [[0.]]
# Segment: fvVhgmXxadc[4]
# ----------------------------------------
# Example 249:
# Text: when she gets there is forced to not only be trapped in the vocation that she obviously doesnt wanna be in
# Length: 21
# Label: [[-0.2]]
# Segment: fvVhgmXxadc[5]
# ----------------------------------------
# Example 250:
# Text: now it also takes so really creepy the fact that emily browning in this movie looks like underage
# Length: 18
# Label: [[-1.]]
# Segment: fvVhgmXxadc[6]
# ----------------------------------------
# Example 251:
# Text: but i dont know
# Length: 4
# Label: [[-0.5]]
# Segment: fvVhgmXxadc[7]
# ----------------------------------------
# Example 252:
# Text: that kind of looks like video game in a certain fact
# Length: 11
# Label: [[-0.4]]
# Segment: fvVhgmXxadc[8]
# ----------------------------------------
# Example 253:
# Text: the first time she goes in it looks like a japanese temple
# Length: 12
# Label: [[0.]]
# Segment: fvVhgmXxadc[9]
# ----------------------------------------
# Example 254:
# Text: and later time she goes like a world war battlefield um castle this kind of pulled out of lord of the rings
# Length: 22
# Label: [[-0.2]]
# Segment: fvVhgmXxadc[10]
# ----------------------------------------
# Example 255:
# Text: whats in her mind within her mind in a way its kind of like inception in that kind
# Length: 18
# Label: [[0.]]
# Segment: fvVhgmXxadc[11]
# ----------------------------------------
# Example 256:
# Text: of playing with the idea whats real whats not what the matrix films did
# Length: 14
# Label: [[0.2]]
# Segment: fvVhgmXxadc[12]
# ----------------------------------------
# Example 257:
# Text: although actually the best comparison this is this film would actually be something like pans labyrinth
# Length: 16
# Label: [[0.]]
# Segment: fvVhgmXxadc[13]
# ----------------------------------------
# Example 258:
# Text: its one of those romantic comedies that we all dread
# Length: 10
# Label: [[-2.6]]
# Segment: iiK8YX8oH1E[0]
# ----------------------------------------
# Example 259:
# Text: now the real star of something borrowed is goodwin
# Length: 9
# Label: [[1.2]]
# Segment: iiK8YX8oH1E[1]
# ----------------------------------------
# Example 260:
# Text: kind of yells and screams through the whole movie
# Length: 9
# Label: [[-1.25]]
# Segment: iiK8YX8oH1E[2]
# ----------------------------------------
# Example 261:
# Text: and if you can tolerate her the rest of the movie any batter
# Length: 13
# Label: [[-2.]]
# Segment: iiK8YX8oH1E[3]
# ----------------------------------------
# Example 262:
# Text: um it kind of follows the path of my best friends wedding julia roberts movie except it takes thirty minutes longer to deviate from the scripts of my best friends wedding
# Length: 31
# Label: [[-0.4]]
# Segment: iiK8YX8oH1E[4]
# ----------------------------------------
# Example 263:
# Text: there are some funny moments
# Length: 5
# Label: [[0.2]]
# Segment: iiK8YX8oH1E[5]
# ----------------------------------------
# Example 264:
# Text: but mostly its just kate hudson being very annoying
# Length: 9
# Label: [[-1.6]]
# Segment: iiK8YX8oH1E[6]
# ----------------------------------------
# Example 265:
# Text: and i think its predictable up an to a point
# Length: 10
# Label: [[-1.]]
# Segment: iiK8YX8oH1E[7]
# ----------------------------------------
# Example 266:
# Text: i think with with these kind of movies we kind of predict
# Length: 12
# Label: [[0.4]]
# Segment: iiK8YX8oH1E[8]
# ----------------------------------------
# Example 267:
# Text: and we second guess ourselves
# Length: 5
# Label: [[0.]]
# Segment: iiK8YX8oH1E[9]
# ----------------------------------------
# Example 268:
# Text: so i will give it points for not being exactly like my best friends wedding even at the trailer sets it up that way
# Length: 24
# Label: [[1.]]
# Segment: iiK8YX8oH1E[10]
# ----------------------------------------
# Example 269:
# Text: goodwin is fun to watch
# Length: 5
# Label: [[1.8]]
# Segment: iiK8YX8oH1E[11]
# ----------------------------------------
# Example 270:
# Text: but i dont think leading material
# Length: 6
# Label: [[-2.]]
# Segment: iiK8YX8oH1E[12]
# ----------------------------------------
# Example 271:
# Text: and like i said kate hudson couldnt be more annoying here
# Length: 11
# Label: [[-1.2]]
# Segment: iiK8YX8oH1E[13]
# ----------------------------------------
# Example 272:
# Text: if there is any in this movie its john krasinski
# Length: 10
# Label: [[0.6]]
# Segment: iiK8YX8oH1E[14]
# ----------------------------------------
# Example 273:
# Text: who i dont usually like
# Length: 5
# Label: [[0.]]
# Segment: iiK8YX8oH1E[15]
# ----------------------------------------
# Example 274:
# Text: but he has some of the funniest scenes in this movie
# Length: 11
# Label: [[1.6]]
# Segment: iiK8YX8oH1E[16]
# ----------------------------------------
# Example 275:
# Text: he seems to be the only realistic character here
# Length: 9
# Label: [[-1.]]
# Segment: iiK8YX8oH1E[17]
# ----------------------------------------
# Example 276:
# Text: the action is fucking awesome
# Length: 5
# Label: [[2.8]]
# Segment: jUzDDGyPkXU[0]
# ----------------------------------------
# Example 277:
# Text: the action is really really well directed
# Length: 7
# Label: [[2.6]]
# Segment: jUzDDGyPkXU[1]
# ----------------------------------------
# Example 278:
# Text: its very of district
# Length: 4
# Label: [[0.]]
# Segment: jUzDDGyPkXU[2]
# ----------------------------------------
# Example 279:
# Text: like someone watched the third act of district a bunch of times like lets make this into an entire movie be awesome and thats pretty much what they did here
# Length: 30
# Label: [[-1.6]]
# Segment: jUzDDGyPkXU[3]
# ----------------------------------------
# Example 280:
# Text: but it didnt turn out quite nearly as awesome as that movie did
# Length: 13
# Label: [[-1.2]]
# Segment: jUzDDGyPkXU[4]
# ----------------------------------------
# Example 281:
# Text: in fact this movie even on the same level as district nor is it um for uh black hawk down which people are comparing it to
# Length: 26
# Label: [[-1.6]]
# Segment: jUzDDGyPkXU[5]
# ----------------------------------------
# Example 282:
# Text: i didnt really see a comparison to black hawk down until like the very very end
# Length: 16
# ...
# ----------------------------------------
# Example 600:
# Text: dennis quaid i think had a lot of fun
# Length: 9
# Label: [[1.8]]
# Segment: wMbj6ajWbic[25]
# ----------------------------------------
# Example 601:
# Text: um same with christopher eccleston
# Length: 5
# Label: [[0.]]
# Segment: wMbj6ajWbic[26]
# ----------------------------------------
# Example 602:
# Text: so i i think it was cool to actually see ray park in action great action star
# Length: 17
# Label: [[2.4]]
# Segment: wMbj6ajWbic[27]
# ----------------------------------------
# Example 603:
# Text: he does a great job with his snake eyes which is always cool to see that
# Length: 16
# Label: [[1.8]]
# Segment: wMbj6ajWbic[28]
# ----------------------------------------
# Example 604:
# Text: joe movie is how international it was it was very
# Length: 10
# Label: [[0.8]]
# Segment: wMbj6ajWbic[29]
# ----------------------------------------
# Example 605:
# Text: but let me first say this i liked it more than i expected i would
# Length: 15
# Label: [[0.8]]
# Segment: yDtzw_Y-7RU[0]
# ----------------------------------------
# Example 606:
# Text: this film is slavishly devoted to the original book or nov novella uh by uh charles dickens
# Length: 17
# Label: [[0.8]]
# Segment: yDtzw_Y-7RU[1]
# ----------------------------------------
# Example 607:
# Text: number one it means its much scarier than you could imagine
# Length: 11
# Label: [[0.75]]
# Segment: yDtzw_Y-7RU[2]
# ----------------------------------------
# Example 608:
# Text: my year old was terrified through part of this because the original version is terrifying
# Length: 15
# Label: [[-1.]]
# Segment: yDtzw_Y-7RU[3]
# ----------------------------------------
# Example 609:
# Text: let me say this if your christianity is extremely legalistic this is the film for you
# Length: 16
# Label: [[0.5]]
# Segment: yDtzw_Y-7RU[4]
# ----------------------------------------
# Example 610:
# Text: cause this is a film that basically says you know what you should do you should take care of poor people because jesus told us to take care of poor people and if you dont take care of poor people youre gonna burn in hell
# Length: 45
# Label: [[-1.2]]
# Segment: yDtzw_Y-7RU[5]
# ----------------------------------------
# Example 611:
# Text: so laughing if thats your form of christianity its a christian film
# Length: 12
# Label: [[-0.2]]
# Segment: yDtzw_Y-7RU[6]
# ----------------------------------------
# Example 612:
# Text: um its not my form
# Length: 5
# Label: [[-1.5]]
# Segment: yDtzw_Y-7RU[7]
# ----------------------------------------
# Example 613:
# Text: um another thing about this film is in its devotion is that sometimes my children could not understand what was being said because they were speaking english
# Length: 27
# Label: [[-1.]]
# Segment: yDtzw_Y-7RU[8]
# ----------------------------------------
# Example 614:
# Text: sometimes i missed what was being said
# Length: 7
# Label: [[-0.6]]
# Segment: yDtzw_Y-7RU[9]
# ----------------------------------------
# Example 615:
# Text: therefore a lot of social commentary goes sound effect over your head
# Length: 12
# Label: [[-1.4]]
# Segment: yDtzw_Y-7RU[10]
# ----------------------------------------
# Example 616:
# Text: or just really doesnt make any difference to us today at all
# Length: 12
# Label: [[-0.6666667]]
# Segment: yDtzw_Y-7RU[11]
# ----------------------------------------
# Example 617:
# Text: um all this stuff about debtors prison for instance doesnt really um jive here in century america
# Length: 17
# Label: [[-1.8]]
# Segment: yDtzw_Y-7RU[12]
# ----------------------------------------
# Example 618:
# Text: and this film is this amazing like i say slavish devotion to charles dickens with an amusement park ride
# Length: 19
# Label: [[2.2]]
# Segment: yDtzw_Y-7RU[13]
# ----------------------------------------
# Example 619:
# Text: because this thing is is meant to be seen in which
# Length: 11
# Label: [[0.6]]
# Segment: yDtzw_Y-7RU[14]
# ----------------------------------------
# Example 620:
# Text: and throughout the film youre going sound effects laughing either from the terrifying characters
# Length: 14
# Label: [[0.6]]
# Segment: yDtzw_Y-7RU[15]
# ----------------------------------------
# Example 621:
# Text: or most likely from going very quickly through london with you know demon horses chasing you so uh theres that
# Length: 20
# Label: [[0.2]]
# Segment: yDtzw_Y-7RU[16]
# ----------------------------------------
# Example 622:
# Text: also about the animation the people just like in polar express a film i really did not like
# Length: 18
# Label: [[-2.]]
# Segment: yDtzw_Y-7RU[17]
# ----------------------------------------
# Example 623:
# Text: um the people seemed sort of dead
# Length: 7
# Label: [[-1.6]]
# Segment: yDtzw_Y-7RU[18]
# ----------------------------------------
# Example 624:
# Text: except their eyes are kind of like this welcome to the polar express
# Length: 13
# Label: [[-0.6]]
# Segment: yDtzw_Y-7RU[19]
# ----------------------------------------
# Example 625:
# Text: and thats a lot to be said for a one minute review
# Length: 12
# Label: [[0.2]]
# Segment: yDtzw_Y-7RU[20]
# ----------------------------------------
# Example 626:
# Text: i actually like the film
# Length: 5
# Label: [[2.]]
# Segment: yDtzw_Y-7RU[21]
# ----------------------------------------
# Example 627:
# Text: um i enjoyed myself in it you might as well
# Length: 10
# Label: [[2.2]]
# Segment: yDtzw_Y-7RU[22]
# ----------------------------------------
# Example 628:
# Text: i would not take a young
# Length: 6
# Label: [[-0.8]]
# Segment: yDtzw_Y-7RU[23]
# ----------------------------------------
# Example 629:
# Text: robin hood starring russel crow um first thing i got to say i was dreading going in to see this movie
# Length: 21
# Label: [[-2.]]
# Segment: yvsjCA6Y5Fc[0]
# ----------------------------------------
# Example 630:
# Text: the trailers really doing it much for me
# Length: 8
# Label: [[-1.2]]
# Segment: yvsjCA6Y5Fc[1]
# ----------------------------------------
# Example 631:
# Text: so i really was not looking forward to seeing this movie
# Length: 11
# Label: [[-2.]]
# Segment: yvsjCA6Y5Fc[2]
# ----------------------------------------
# Example 632:
# Text: um but i guess say maybe my expectations were lowered by these other reviews that i read
# Length: 17
# Label: [[-0.2]]
# Segment: yvsjCA6Y5Fc[3]
# ----------------------------------------
# Example 633:
# Text: but i didnt mind it
# Length: 5
# Label: [[0.4]]
# Segment: yvsjCA6Y5Fc[4]
# ----------------------------------------
# Example 634:
# Text: but i didnt find it all that bad
# Length: 8
# Label: [[0.]]
# Segment: yvsjCA6Y5Fc[5]
# ----------------------------------------
# Example 635:
# Text: i didnt find it all that good
# Length: 7
# Label: [[-1.8]]
# Segment: yvsjCA6Y5Fc[6]
# ----------------------------------------
# Example 636:
# Text: like i said maybe my expectations were lowered because of all of those reviews but i really didnt hate it
# Length: 20
# Label: [[0.4]]
# Segment: yvsjCA6Y5Fc[7]
# ----------------------------------------
# Example 637:
# Text: like what people could hate about this movie there are some negatives to say the least
# Length: 16
# Label: [[-1.4]]
# Segment: yvsjCA6Y5Fc[8]
# ----------------------------------------
# Example 638:
# Text: um really first and foremost it just lacked the charm of these past robin hood movies that we know
# Length: 19
# Label: [[-2.]]
# Segment: yvsjCA6Y5Fc[9]
# ----------------------------------------
# Example 639:
# Text: theres men in tights which you know hilarious spoof of the story
# Length: 12
# Label: [[2.]]
# Segment: yvsjCA6Y5Fc[10]
# ----------------------------------------
# Example 640:
# Text: theres a kevin costner prince of fee version which was supposed to be the dark and edgy version of his time i mean but that was what thirteen years ago fourteen years ago probably more than that
# Length: 37
# Label: [[-0.6]]
# Segment: yvsjCA6Y5Fc[11]
# ----------------------------------------
# Example 641:
# Text: and it just lacked the charm of those past movies
# Length: 10
# Label: [[-2.]]
# Segment: yvsjCA6Y5Fc[12]
# ----------------------------------------
# Example 642:
# Text: it did seem to focus too much on epic epic epic
# Length: 11
# Label: [[-1.]]
# Segment: yvsjCA6Y5Fc[13]
# ----------------------------------------
# Example 643:
# Text: and it really just lacked what made the other movies more enjoyable
# Length: 12
# Label: [[-2.]]
# Segment: yvsjCA6Y5Fc[14]
# ----------------------------------------
# Example 644:
# Text: and suffers from what i call kingdom of heaven where it builds too much for these huge catastrophic war sequences theyre supposed to blow you away but the problem is you dont give a damn because it just lacks that charm of the past movies
# Length: 45
# Label: [[-1.8]]
# Segment: yvsjCA6Y5Fc[15]
# ----------------------------------------
# Example 645:
# Text: um not in all instances but the ones that matter the most yeah
# Length: 13
# Label: [[-0.6]]
# Segment: yvsjCA6Y5Fc[16]
# ----------------------------------------
# Example 646:
# Text: um russel crow and cate blanchette just did not sell it for me i had a very hard time just buying it
# Length: 22
# Label: [[-2.2]]
# Segment: yvsjCA6Y5Fc[17]
# ----------------------------------------
# Example 647:
# Text: like were supposed to believe that these two are in their mid you know mid thirties at the oldest and laughter theyre looking pretty rough in this movie
# Length: 28
# Label: [[-1.6]]
# Segment: yvsjCA6Y5Fc[18]
# ----------------------------------------
# Example 648:
# Text: i can appreciate that
# Length: 4
# Label: [[0.8]]
# Segment: yvsjCA6Y5Fc[19]
# ----------------------------------------
# Example 649:
# Text: hes not gonna be looking like a chipper bright young man but early thirties really you want me to buy that
# Length: 21
# Label: [[-1.8]]
# Segment: yvsjCA6Y5Fc[20]
# ----------------------------------------
# Example 650:
# Text: i cant do it
# Length: 4
# Label: [[-1.6]]
# Segment: yvsjCA6Y5Fc[21]
# ----------------------------------------
# Example 651:
# Text: especially when hes hanging around with a married men who all but one of them are probably early twenties laughter and one of them is maybe mid twenties and meanwhile theyre hanging in with papa russel it just looks like you know its bunch of a guys hanging there so one brought dad along coz he offered to
# Length: 58
# Label: [[-1.2]]
# Segment: yvsjCA6Y5Fc[22]
# ----------------------------------------
# Example 652:
# Text: im gonna start off with saying that i really very impressed with the movie
# Length: 14
# Label: [[-1.6]]
# Segment: zhpQhgha_KU[0]
# ----------------------------------------
# Example 653:
# Text: and i liked the first movie i thought the first movie was really good
# Length: 14
# Label: [[1.6]]
# Segment: zhpQhgha_KU[1]
# ----------------------------------------
# Example 654:
# Text: but this movie kind of came off like really sad travel video i dont know
# Length: 15
# Label: [[-1.6]]
# Segment: zhpQhgha_KU[2]
# ----------------------------------------
# Example 655:
# Text: i mean that sounds really harsh
# Length: 6
# Label: [[-1.6]]
# Segment: zhpQhgha_KU[3]
# ----------------------------------------
# Example 656:
# Text: but i just i just i dont know i didnt really like the movie all that much
# Length: 17
# Label: [[-2.2]]
# Segment: zhpQhgha_KU[4]
# ----------------------------------------
# Example 657:
# Text: i mean i had some some good moments
# Length: 8
# Label: [[1.]]
# Segment: zhpQhgha_KU[5]
# ----------------------------------------
# Example 658:
# Text: and a few funny parts
# Length: 5
# Label: [[1.]]
# Segment: zhpQhgha_KU[6]
# ----------------------------------------
# Example 659:
# Text: but all in all i just thought it was really over overly sad
# Length: 13
# Label: [[-1.]]
# Segment: zhpQhgha_KU[7]
# ----------------------------------------
# Example 660:
# Text: i dont know i just thought i just thought it was really really sad
# Length: 14
# Label: [[-1.]]
# Segment: zhpQhgha_KU[8]
# ----------------------------------------
# Example 661:
# Text: um i mean if you really like the show and you really liked the first movie and you still wanna go and see this im not gonna discourage you from seeing it
# Length: 32
# Label: [[0.6]]
# Segment: zhpQhgha_KU[9]
# ----------------------------------------
# Example 662:
# Text: i just personally i just didnt really enjoy it
# Length: 9
# Label: [[-2.4]]
# Segment: zhpQhgha_KU[10]
# ----------------------------------------
# Example 663:
# Text: um it also really didnt need a lot of the things that it had in it
# Length: 16
# Label: [[-1.4]]
# Segment: zhpQhgha_KU[11]
# ----------------------------------------
# Example 664:
# Text: like it been shorter
# Length: 4
# Label: [[-1.]]
# Segment: zhpQhgha_KU[12]
# ----------------------------------------
# Example 665:
# Text: but a lot of the footage was kind of unnecessary
# Length: 10
# Label: [[-1.5]]
# Segment: zhpQhgha_KU[13]
# ----------------------------------------
# Example 666:
# Text: and i mean i dont know i just i feel like i dont mean if i have wasted those two hours i just feel like i done something better with them
# Length: 31
# Label: [[-2.]]
# Segment: zhpQhgha_KU[14]
# ----------------------------------------
# Example 667:
# Text: i think that charlotte and miranda have some really nice moments in the movie
# Length: 14
# Label: [[1.8]]
# Segment: zhpQhgha_KU[15]
# ----------------------------------------
# Example 668:
# Text: i really think that i really like the character
# Length: 9
# Label: [[1.75]]
# Segment: zhpQhgha_KU[16]
# ----------------------------------------
# Example 669:
# Text: actually the most upbeat character in the whole movie
# Length: 9
# Label: [[0.6]]
# Segment: zhpQhgha_KU[17]
# ----------------------------------------
# Example 670:
# Text: i think that um and that everybody i do feel really bad for charlotte
# Length: 14
# Label: [[-0.8]]
# Segment: zhpQhgha_KU[18]
# ----------------------------------------
# Example 671:
# Text: she does have a lot of issues
# Length: 7
# Label: [[-1.4]]
# Segment: zhpQhgha_KU[19]
# ----------------------------------------
# Example 672:
# Text: and you really can kind of whether youve got to have kids
# Length: 12
# Label: [[0.6]]
# Segment: zhpQhgha_KU[20]
# ----------------------------------------
# Example 673:
# Text: i mean even if you dont have kids
# Length: 8
# Label: [[0.6]]
# Segment: zhpQhgha_KU[21]
# ----------------------------------------
# Example 674:
# Text: because its just just about getting getting time for yourself
# Length: 10
# Label: [[-0.5]]
# Segment: zhpQhgha_KU[22]
# ----------------------------------------
# Example 675:
# Text: and not being really stressed out
# Length: 6
# Label: [[0.]]
# Segment: zhpQhgha_KU[23]
# ----------------------------------------
# Example 676:
# Text: and i think that thats thats a very issue
# Length: 9
# Label: [[1.]]
# Segment: zhpQhgha_KU[24]
# ----------------------------------------
# Example 677:
# Text: i think that they all have like a lot of issues
# Length: 11
# Label: [[0.]]
# Segment: zhpQhgha_KU[25]
# ----------------------------------------
# Example 678:
# Text: and that some are very yeah
# Length: 6
# Label: [[0.8]]
# Segment: zhpQhgha_KU[26]
# ----------------------------------------
# Example 679:
# Text: yeah i mean it it has some fun moments
# Length: 9
# Label: [[1.4]]
# Segment: zhpQhgha_KU[27]
# ----------------------------------------
# Example 680:
# Text: but all in all really that big of a fan
# Length: 10
# Label: [[-1.2]]
# Segment: zhpQhgha_KU[28]
# ----------------------------------------
# Example 681:
# Text: because there really all that much to it for me
# Length: 10
# Label: [[-2.]]
# Segment: zhpQhgha_KU[29]
# ----------------------------------------
# Example 682:
# Text: um like i said if you like it feel free to go see it i just personally that into it
# Length: 20
# Label: [[-1.]]
# Segment: zhpQhgha_KU[30]
# ----------------------------------------
# Example 683:
# Text: um yeah i mean if you wanna see a video um its gonna be who enjoyed a film
# Length: 18
# Label: [[0.8]]
# Segment: zhpQhgha_KU[31]
# ----------------------------------------
# Example 684:
# Text: if you do wanna see somebody whos possibly critiquing it
# Length: 10
# Label: [[-0.4]]
# Segment: zhpQhgha_KU[32]
# ----------------------------------------
# Example 685:
# Text: and she really enjoyed the film
# Length: 6
# Label: [[1.2]]
# Segment: zhpQhgha_KU[33]
# ----------------------------------------
# Example 686:
# Text: um so if you like to hear a um like more positive review check out her review it is very good
# Length: 21
# Label: [[0.6]]
# Segment: zhpQhgha_KU[34]
# ----------------------------------------
# Maximum length: 112
# Minimum length: 1
# example with length 1: 161

# %% [markdown]
# ## Define a multimodal model
#
# Here we show a simple example of late-fusion LSTM. Late-fusion refers to combining the features from different modalities at the final prediction stage, without introducing any interactions between them before that.

# %%
# let's define a simple model that can deal with multimodal variable length sequence
class LFLSTM(nn.Module):
    def __init__(self, input_sizes, hidden_sizes, fc1_size, output_size, dropout_rate):
        super(LFLSTM, self).__init__()
        self.input_size = input_sizes
        self.hidden_size = hidden_sizes
        self.fc1_size = fc1_size
        self.output_size = output_size
        self.dropout_rate = dropout_rate
        
        # defining modules - two layer bidirectional LSTM with layer norm in between
        self.embed = nn.Embedding(len(word2id), input_sizes[0])
        self.trnn1 = nn.LSTM(input_sizes[0], hidden_sizes[0], bidirectional=True)
        self.trnn2 = nn.LSTM(2*hidden_sizes[0], hidden_sizes[0], bidirectional=True)
        
        self.vrnn1 = nn.LSTM(input_sizes[1], hidden_sizes[1], bidirectional=True)
        self.vrnn2 = nn.LSTM(2*hidden_sizes[1], hidden_sizes[1], bidirectional=True)
        
        self.arnn1 = nn.LSTM(input_sizes[2], hidden_sizes[2], bidirectional=True)
        self.arnn2 = nn.LSTM(2*hidden_sizes[2], hidden_sizes[2], bidirectional=True)

        self.fc1 = nn.Linear(sum(hidden_sizes)*4, fc1_size)
        self.fc2 = nn.Linear(fc1_size, output_size)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout_rate)
        self.tlayer_norm = nn.LayerNorm((hidden_sizes[0]*2,))
        self.vlayer_norm = nn.LayerNorm((hidden_sizes[1]*2,))
        self.alayer_norm = nn.LayerNorm((hidden_sizes[2]*2,))
        self.bn = nn.BatchNorm1d(sum(hidden_sizes)*4)

        
    def extract_features(self, sequence, lengths, rnn1, rnn2, layer_norm):
        packed_sequence = pack_padded_sequence(sequence, lengths)
        packed_h1, (final_h1, _) = rnn1(packed_sequence)
        padded_h1, _ = pad_packed_sequence(packed_h1)
        normed_h1 = layer_norm(padded_h1)
        packed_normed_h1 = pack_padded_sequence(normed_h1, lengths)
        _, (final_h2, _) = rnn2(packed_normed_h1)
        return final_h1, final_h2

        
    def fusion(self, sentences, visual, acoustic, lengths):
        batch_size = lengths.size(0)
        
        max_idx = sentences.max().item()
        if max_idx >= self.embed.num_embeddings:
            raise ValueError(f"Sentence contains an index {max_idx} that exceeds the embedding matrix size {self.embedding.num_embeddings - 1}. Please ensure input indices are within the vocab size.")

        sentences = self.embed(sentences)
        
        # extract features from text modality
        final_h1t, final_h2t = self.extract_features(sentences, lengths, self.trnn1, self.trnn2, self.tlayer_norm)
        
        # extract features from visual modality
        final_h1v, final_h2v = self.extract_features(visual, lengths, self.vrnn1, self.vrnn2, self.vlayer_norm)
        
        # extract features from acoustic modality
        final_h1a, final_h2a = self.extract_features(acoustic, lengths, self.arnn1, self.arnn2, self.alayer_norm)

        
        # simple late fusion -- concatenation + normalization
        h = torch.cat((final_h1t, final_h2t, final_h1v, final_h2v, final_h1a, final_h2a),
                       dim=2).permute(1, 0, 2).contiguous().view(batch_size, -1)
        return self.bn(h)

    def forward(self, sentences, visual, acoustic, lengths):
        batch_size = lengths.size(0)
        h = self.fusion(sentences, visual, acoustic, lengths)
        h = self.fc1(h)
        h = self.dropout(h)
        h = self.relu(h)
        o = self.fc2(h)
        return o

# %% [markdown]
# ## Load pretrained embeddings
#
# We define a function for loading pretrained word embeddings stored in GloVe-style file. Contextualized embeddings obviously cannot be stored and loaded this way, though.

# %%
import tqdm
from tqdm import tqdm_notebook

# %%
# define a function that loads data from GloVe-like embedding files
# we will add tutorials for loading contextualized embeddings later
# 2196017 is the vocab size of GloVe here.

def load_emb(w2i, path_to_embedding, embedding_size=300, embedding_vocab=2196017, init_emb=None):
    if init_emb is None:
        emb_mat = np.random.randn(len(w2i), embedding_size)
    else:
        emb_mat = init_emb
    f = open(path_to_embedding, 'r', encoding='utf-8', errors='replace')
    found = 0
    for line in tqdm_notebook(f, total=embedding_vocab):
        try:
            content = line.strip().split()
            vector = np.asarray(list(map(lambda x: float(x), content[-300:])))
            word = ' '.join(content[:-300])
            if word in w2i:
                idx = w2i[word]
                emb_mat[idx, :] = vector
                found += 1
        except ValueError as e:
            print(f"Skipping invalid line: {line}")
        
    print(f"Found {found} words in the embedding file.")
    return torch.tensor(emb_mat).float()

# %% [markdown]
# ## Training a model
#
# Next we train a model. We use Adam with gradient clipping and weight decay for training, and our loss here is Mean Absolute Error (MOSI is a regression dataset). We exclude the embeddings from trainable computation graph to prevent overfitting. We also apply a early-stopping scheme with learning rate annealing based on validation loss.

# %%
from torch.optim import Adam, SGD
from sklearn.metrics import accuracy_score

# %%
import os
path = 'C:\\Users\\Viki\\Documents\\Thesis\\tryout3\\data'
if os.access(path, os.R_OK):
    print("Directory is readable")
else:
    print("No read permission")
if os.access(path, os.W_OK):
    print("Directory is writable")
else:
    print("No write permission")
# Out:
# Directory is readable
# Directory is writable

# %%
torch.manual_seed(123)
torch.cuda.manual_seed_all(123)

CUDA = torch.cuda.is_available()
MAX_EPOCH = 1000

text_size = 300
visual_size = 47
acoustic_size = 74

# define some model settings and hyper-parameters
input_sizes = [text_size, visual_size, acoustic_size]
hidden_sizes = [int(text_size * 1.5), int(visual_size * 1.5), int(acoustic_size * 1.5)]
fc1_size = sum(hidden_sizes) // 2
dropout = 0.25
output_size = 1
curr_patience = patience = 8
num_trials = 3
grad_clip_value = 1.0
weight_decay = 0.1

if os.path.exists(CACHE_PATH):
    pretrained_emb, word2id = torch.load(CACHE_PATH)
elif WORD_EMB_PATH is not None:
    pretrained_emb = load_emb(word2id, WORD_EMB_PATH)
    torch.save((pretrained_emb, word2id), CACHE_PATH)
else:
    pretrained_emb = None

model = LFLSTM(input_sizes, hidden_sizes, fc1_size, output_size, dropout)
if pretrained_emb is not None:
    model.embed.weight.data = pretrained_emb
model.embed.requires_grad = False
optimizer = Adam([param for param in model.parameters() if param.requires_grad], weight_decay=weight_decay)

if CUDA:
    model.cuda()
criterion = nn.L1Loss(reduction='sum')
criterion_test = nn.L1Loss(reduction='sum')
best_valid_loss = float('inf')
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.1)
lr_scheduler.step() # for some reason it seems the StepLR needs to be stepped once first
train_losses = []
valid_losses = []
for e in range(MAX_EPOCH):
    model.train()
    train_iter = tqdm_notebook(train_loader)
    train_loss = 0.0
    for batch in train_iter:
        model.zero_grad()
        t, v, a, y, l = batch
        batch_size = t.size(0)
        if CUDA:
            t = t.cuda()
            v = v.cuda()
            a = a.cuda()
            y = y.cuda()
            l = l.cuda()
        y_tilde = model(t, v, a, l)
        loss = criterion(y_tilde, y)
        loss.backward()
        torch.nn.utils.clip_grad_value_([param for param in model.parameters() if param.requires_grad], grad_clip_value)
        optimizer.step()
        train_iter.set_description(f"Epoch {e}/{MAX_EPOCH}, current batch loss: {round(loss.item()/batch_size, 4)}")
        train_loss += loss.item()
    train_loss = train_loss / len(train)
    train_losses.append(train_loss)
    print(f"Training loss: {round(train_loss, 4)}")

    model.eval()
    with torch.no_grad():
        valid_loss = 0.0
        for batch in dev_loader:
            model.zero_grad()
            t, v, a, y, l = batch
            if CUDA:
                t = t.cuda()
                v = v.cuda()
                a = a.cuda()
                y = y.cuda()
                l = l.cuda()
            y_tilde = model(t, v, a, l)
            loss = criterion(y_tilde, y)
            valid_loss += loss.item()
    
    valid_loss = valid_loss/len(dev)
    valid_losses.append(valid_loss)
    print(f"Validation loss: {round(valid_loss, 4)}")
    print(f"Current patience: {curr_patience}, current trial: {num_trials}.")
    if valid_loss <= best_valid_loss:
        best_valid_loss = valid_loss
        print("Found new best model on dev set!")
        torch.save(model.state_dict(), 'model.std')
        torch.save(optimizer.state_dict(), 'optim.std')
        curr_patience = patience
    else:
        curr_patience -= 1
        if curr_patience <= -1:
            print("Running out of patience, loading previous best model.")
            num_trials -= 1
            curr_patience = patience
            model.load_state_dict(torch.load('model.std'))
            optimizer.load_state_dict(torch.load('optim.std'))
            lr_scheduler.step()
            print(f"Current learning rate: {optimizer.state_dict()['param_groups'][0]['lr']}")
    
    if num_trials <= 0:
        print("Running out of patience, early stopping.")
        break

model.load_state_dict(torch.load('model.std'))
y_true = []
y_pred = []
model.eval()
with torch.no_grad():
    test_loss = 0.0
    for batch in test_loader:
        model.zero_grad()
        t, v, a, y, l = batch
        if CUDA:
            t = t.cuda()
            v = v.cuda()
            a = a.cuda()
            y = y.cuda()
            l = l.cuda()
        y_tilde = model(t, v, a, l)
        loss = criterion_test(y_tilde, y)
        y_true.append(y_tilde.detach().cpu().numpy())
        y_pred.append(y.detach().cpu().numpy())
        test_loss += loss.item()
print(f"Test set performance: {test_loss/len(test)}")
y_true = np.concatenate(y_true, axis=0)
y_pred = np.concatenate(y_pred, axis=0)
                  
y_true_bin = y_true >= 0
y_pred_bin = y_pred >= 0
bin_acc = accuracy_score(y_true_bin, y_pred_bin)
print(f"Test set accuracy is {bin_acc}")
# Out:
# C:\Users\Viki\AppData\Local\Temp\ipykernel_33664\2241769401.py:23: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   pretrained_emb, word2id = torch.load(CACHE_PATH)
# C:\Users\Viki\AppData\Local\Temp\ipykernel_33664\2241769401.py:47: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   train_iter = tqdm_notebook(train_loader)
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 1.3179
# Validation loss: 1.3969
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.9565
# Validation loss: 1.2881
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.7411
# Validation loss: 1.2608
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.5924
# Validation loss: 1.1824
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.4733
# Validation loss: 1.2676
# Current patience: 8, current trial: 3.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.4268
# Validation loss: 1.2268
# Current patience: 7, current trial: 3.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.4001
# Validation loss: 1.2312
# Current patience: 6, current trial: 3.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.373
# Validation loss: 1.2132
# Current patience: 5, current trial: 3.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.3412
# Validation loss: 1.2214
# Current patience: 4, current trial: 3.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.3416
# Validation loss: 1.1989
# Current patience: 3, current trial: 3.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.3221
# Validation loss: 1.2358
# Current patience: 2, current trial: 3.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.3246
# Validation loss: 1.1948
# Current patience: 1, current trial: 3.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.2999
# Validation loss: 1.2116
# Current patience: 0, current trial: 3.
# Running out of patience, loading previous best model.
# Current learning rate: 1e-05
# C:\Users\Viki\AppData\Local\Temp\ipykernel_33664\2241769401.py:102: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('model.std'))
# C:\Users\Viki\AppData\Local\Temp\ipykernel_33664\2241769401.py:103: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   optimizer.load_state_dict(torch.load('optim.std'))
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.4781
# Validation loss: 1.2005
# Current patience: 8, current trial: 2.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.4546
# Validation loss: 1.2138
# Current patience: 7, current trial: 2.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.4294
# Validation loss: 1.2088
# Current patience: 6, current trial: 2.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.4174
# Validation loss: 1.2119
# Current patience: 5, current trial: 2.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.3871
# Validation loss: 1.2122
# Current patience: 4, current trial: 2.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.365
# Validation loss: 1.2178
# Current patience: 3, current trial: 2.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.3683
# Validation loss: 1.2062
# Current patience: 2, current trial: 2.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.3542
# Validation loss: 1.2167
# Current patience: 1, current trial: 2.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.3356
# Validation loss: 1.2038
# Current patience: 0, current trial: 2.
# Running out of patience, loading previous best model.
# Current learning rate: 1e-05
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.4712
# Validation loss: 1.1985
# Current patience: 8, current trial: 1.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.4374
# Validation loss: 1.2085
# Current patience: 7, current trial: 1.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.4274
# Validation loss: 1.2102
# Current patience: 6, current trial: 1.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.4065
# Validation loss: 1.2185
# Current patience: 5, current trial: 1.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.3911
# Validation loss: 1.2264
# Current patience: 4, current trial: 1.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.3779
# Validation loss: 1.2122
# Current patience: 3, current trial: 1.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.3636
# Validation loss: 1.2198
# Current patience: 2, current trial: 1.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.3519
# Validation loss: 1.2098
# Current patience: 1, current trial: 1.
#   0%|          | 0/23 [00:00<?, ?it/s]
# Training loss: 0.3427
# Validation loss: 1.2119
# Current patience: 0, current trial: 1.
# Running out of patience, loading previous best model.
# Current learning rate: 1e-05
# Running out of patience, early stopping.
# C:\Users\Viki\AppData\Local\Temp\ipykernel_33664\2241769401.py:111: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('model.std'))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 126
#     124     y = y.cuda()
#     125     l = l.cuda()
# --> 126 y_tilde = model(t, v, a, l)
#     127 loss = criterion_test(y_tilde, y)
#     128 y_true.append(y_tilde.detach().cpu().numpy())
#
# File ~\Documents\Thesis\tryout3\.venv\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\Documents\Thesis\tryout3\.venv\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[56], line 68, in LFLSTM.forward(self, sentences, visual, acoustic, lengths)
#      66 def forward(self, sentences, visual, acoustic, lengths):
#      67     batch_size = lengths.size(0)
# ---> 68     h = self.fusion(sentences, visual, acoustic, lengths)
#      69     h = self.fc1(h)
#      70     h = self.dropout(h)
#
# Cell In[56], line 47, in LFLSTM.fusion(self, sentences, visual, acoustic, lengths)
#      45 max_idx = sentences.max().item()
#      46 if max_idx >= self.embed.num_embeddings:
# ---> 47     raise ValueError(f"Sentence contains an index {max_idx} that exceeds the embedding matrix size {self.embedding.num_embeddings - 1}. Please ensure input indices are within the vocab size.")
#      49 sentences = self.embed(sentences)
#      51 # extract features from text modality
#
# File ~\Documents\Thesis\tryout3\.venv\lib\site-packages\torch\nn\modules\module.py:1931, in Module.__getattr__(self, name)
#    1929     if name in modules:
#    1930         return modules[name]
# -> 1931 raise AttributeError(
#    1932     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1933 )
#
# AttributeError: 'LFLSTM' object has no attribute 'embedding'

# %%
# import torch
# import numpy as np
# from sklearn.metrics import accuracy_score
# import torch.nn as nn

# Assume necessary variables like model, test_loader, CUDA, dic_size, etc. are already defined.

# Define the loss function (assuming MSELoss as used previously)

# Load the model state (assuming it's already saved in 'model.std')
model.load_state_dict(torch.load('model.std'))

# Prepare for evaluation
y_true = []
y_pred = []

# Set model to evaluation mode
model.eval()

# No gradient calculation
with torch.no_grad():
    test_loss = 0.0

    # Iterate over the test set
    for batch_idx, batch in enumerate(test_loader):
        # Zero the gradients
        model.zero_grad()

        # Unpack batch
        t, v, a, y, l = batch

        # Check input data dimensions (optional debugging step)
        print(f"Batch {batch_idx+1}: t.shape={t.shape}, v.shape={v.shape}, a.shape={a.shape}, y.shape={y.shape}, l.shape={l.shape}")

        # Move to CUDA if available
        if CUDA:
            t = t.cuda()
            v = v.cuda()
            a = a.cuda()
            y = y.cuda()
            l = l.cuda()

        # Forward pass
        y_tilde = model(t, v, a, l)

        # Check if the forward pass output is as expected
        print(f"y_tilde shape: {y_tilde.shape}, y shape: {y.shape}")

        # Compute loss
        loss = criterion_test(y_tilde, y)
        
        # Print loss for this batch
        print(f"Batch {batch_idx+1} Loss: {loss.item()}")

        # Collect predictions and true values
        y_true.append(y_tilde.detach().cpu().numpy())
        y_pred.append(y.detach().cpu().numpy())

        # Accumulate loss
        test_loss += loss.item()

    # Compute average test loss
    avg_test_loss = test_loss / len(test_loader)
    print(f"Test set performance (Average Loss): {avg_test_loss}")

    # Concatenate all true values and predictions
    y_true = np.concatenate(y_true, axis=0)
    y_pred = np.concatenate(y_pred, axis=0)

    # Check the first few predictions and ground truth values
    print(f"First few predictions (y_tilde): {y_pred[:5]}")
    print(f"First few ground truth values (y): {y_true[:5]}")

    # Convert to binary for classification accuracy
    y_true_bin = y_true >= 0
    y_pred_bin = y_pred >= 0

    # Print first few binary values for sanity check
    print(f"First few binary predictions: {y_pred_bin[:5]}")
    print(f"First few binary ground truth values: {y_true_bin[:5]}")

    # Calculate binary accuracy
    bin_acc = accuracy_score(y_true_bin, y_pred_bin)
    print(f"Test set binary accuracy: {bin_acc}")

    # Optionally, print the total number of test examples processed
    print(f"Total test examples processed: {len(test_loader.dataset)}")
